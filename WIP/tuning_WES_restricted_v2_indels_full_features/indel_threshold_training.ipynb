# %%
import csv
import gzip
import json
import os
import sys
import random
import bisect
from typing import Dict, Any, List

import numpy as np
import pandas as pd
import optuna

# -----------------------
# Configuration / Hardcoded Paths
# -----------------------
SAMPLES_CSV = "training_complete_processed_metadata.csv"
OUT_DIR = "training_results_indels"
BLACKLIST_BED = "../../resources/master_blacklist.bed" 
ARTEFACT_GENES_BED = "../../resources/master_blacklist.bed"
EXOME_BED_PATH = "../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed" # NEW

N_TRIALS = 3000
SEED = 42
# -----------------------
# Constants
# -----------------------
GENOME_SIZE = 6.4e9
R_CORD = 2e-9
EPS = 1e-15
CORD_WEIGHT = 5.0

# Set seeds
random.seed(SEED)
np.random.seed(SEED)

# -----------------------
# Math Helpers
# -----------------------
def poisson_deviance(y_arr: np.ndarray, lam_arr: np.ndarray, weights: np.ndarray = None) -> float:
    y = np.asarray(y_arr, dtype=float)
    lam = np.asarray(lam_arr, dtype=float) + EPS
    
    with np.errstate(divide='ignore', invalid='ignore'):
        log_term = np.log(y / lam)
        term1 = np.where(y > 0, y * log_term, 0.0)
    
    dev = 2.0 * (term1 - (y - lam))
    if weights is not None:
        dev = dev * weights
        
    return float(np.sum(dev))

def expected_lambda(sample_type: str, age: float, bases: float) -> float:
    st = str(sample_type).lower()
    current_age = float(age) if pd.notna(age) else 0.0
    
    if "cord" in st:
        rate = R_CORD
    elif "pbmc" in st:
        rate = R_CORD + (0.7 * current_age) / GENOME_SIZE
    elif "t_cell" in st or "tcell" in st or "t-cell" in st:
        rate = (14.5 / GENOME_SIZE) + (1.0 * current_age) / GENOME_SIZE
    else:
        # Fallback to the original baseline if an unknown type appears
        rate = R_CORD + (2.0 * current_age) / GENOME_SIZE
        
    return rate * bases

# -----------------------
# BED File Lookup Logic
# -----------------------
class BedLookup:
    def __init__(self, bed_path: str, name: str):
        self.intervals = {} 
        self.name = name
        self._load_bed(bed_path)

    def _load_bed(self, bed_path: str):
        if not os.path.exists(bed_path):
            print(f"[WARN] BED file not found: {bed_path}. {self.name} filter will do nothing.", file=sys.stderr)
            return

        print(f"[INFO] Loading {self.name} from {bed_path}...")
        count = 0
        with open(bed_path, 'r') as f:
            for line in f:
                if line.startswith('#') or not line.strip():
                    continue
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                chrom, start, end = parts[0], int(parts[1]), int(parts[2])
                
                if chrom not in self.intervals:
                    self.intervals[chrom] = []
                self.intervals[chrom].append((start, end))
                count += 1
        
        for chrom in self.intervals:
            self.intervals[chrom].sort(key=lambda x: x[0])
        print(f"[INFO] Loaded {count} regions for {self.name}.")

    def is_overlapped(self, chrom: str, pos: int) -> bool:
        if chrom not in self.intervals:
            return False
        
        regions = self.intervals[chrom]
        query_idx = pos - 1 
        idx = bisect.bisect_right(regions, (query_idx, float('inf')))
        
        for i in range(max(0, idx - 1), -1, -1):
            start, end = regions[i]
            if end <= query_idx:
                break 
            if start <= query_idx < end:
                return True
        return False

# -----------------------
# VCF Parsing to DataFrame
# -----------------------
def parse_vcf_to_df(vcf_path: str, sample_id: str) -> pd.DataFrame:
    data = []
    if not os.path.exists(vcf_path):
        print(f"[WARN] File not found: {vcf_path}", file=sys.stderr)
        return pd.DataFrame()

    openf = gzip.open if vcf_path.endswith(".gz") else open
    try:
        with openf(vcf_path, "rt") as fh:
            for line in fh:
                if line.startswith("#"):
                    continue
                fields = line.strip().split("\t")
                chrom, pos = fields[0], int(fields[1])
                alt = fields[4] # NEW: Extract the ALT sequence
                info_str = fields[7]
                info_dict = {k: v for item in info_str.split(";") for k, v in [item.split("=", 1) if "=" in item else (item, "Yes")]}
                
                # NEW: Added ALT to the dictionary
                info_dict.update({"sample_id": sample_id, "CHROM": chrom, "POS": pos, "ALT": alt})
                data.append(info_dict)
    except Exception as e:
        print(f"[ERROR] Error reading {vcf_path}: {e}", file=sys.stderr)
        return pd.DataFrame()

    if not data:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    
    def to_num(col, dtype, default):
        return pd.to_numeric(df[col], errors='coerce').fillna(default).astype(dtype) if col in df.columns else pd.Series([default]*len(df), dtype=dtype)

    def to_str(col, default):
        return df[col].fillna(default) if col in df.columns else pd.Series([default]*len(df))

    df['CHROM'] = to_str('CHROM', 'chr1')
    df['ALT'] = to_str('ALT', '') # NEW: String column for ALT
    df['POS'] = to_num('POS', int, 0)
    df['INDEL_LENGTH'] = to_num('INDEL_LENGTH', int, 0)
    df['MEAN_INSET_QUAL'] = to_num('MEAN_INSET_QUAL', float, -1.0)
    df['MEAN_DEL_ANCHOR_QUAL'] = to_num('MEAN_DEL_ANCHOR_QUAL', float, -1.0)
    df['HOMOPOLYMER_LEN'] = to_num('HOMOPOLYMER_LEN', int, 0)
    df['N_SLIPPAGE_SSCS'] = to_num('N_SLIPPAGE_SSCS', int, 0)
    df['GC_CONTENT'] = to_num('GC_CONTENT', float, 0.5) 
    df['DIST_TO_OTHER_INDEL'] = to_num('DIST_TO_OTHER_INDEL', int, 10000)
    df['RP_MED_SSCS'] = to_num('RP_MED_SSCS', float, 75.0)
    df['SD_BASEQ'] = to_num('SD_BASEQ', float, 1000) #NEW 1
    df['AVG_ALT_READ_MEAN_BASEQ'] = to_num('AVG_ALT_READ_MEAN_BQ', float, 0) # NEW 2
    df['MEAN_REF_MAPQ'] = to_num('MEAN_REF_MAPQ', float, 0.0) # NEW 3
    df['AVG_REF_ASXS'] = to_num('AVG_REF_ASXS', float, 0.0) # NEW 4
    df['AVG_ALTREAD_VARIANTS'] = to_num('AVG_ALTREAD_VARIANTS', float, 1000) # NEW 5
    df['AVG_NONALTREAD_VARIANTS'] = to_num('AVG_NONALTREAD_VARIANTS', float, 1000) # NEW 6
    df['MEAN_INSERT'] = to_num('MEAN_INSERT', float, 1000) # NEW 7
    df['SD_INSERT'] = to_num('SD_INSERT', float, 1000) # NEW 8
    df['AVG_READ_POSITION'] = to_num('AVG_READ_POSITION', float, 75) # NEW 9
    df['AVG_READ_LENGTH'] = to_num('AVG_READ_LENGTH', float, 150) # NEW 10
    df['RP_SD_SSCS'] = to_num('RP_SD_SSCS', float, 0) # Not sure if to use this metric...
    df['STRAND_BIAS_SSCS'] = to_num('STRAND_BIAS_SSCS', float, 1) # Will use this and RP_SD above but conditional to a minimum N_ALT_SSCS, just as for the SNV caller
    df['AVG_ALT_N_COUNT'] = to_num('AVG_ALT_N_COUNT', float, 0.0)
    df['N_ALT_SSCS'] = to_num('N_ALT_SSCS', int, 0)
    df['N_TOTAL'] = to_num('N_TOTAL', int, 0)
    df['N_ALT'] = to_num('N_ALT', int, 0) 
    df['N_TOTAL_SSCS'] = to_num('N_TOTAL_SSCS', int, -1)
    df['DEPTH_PERCENTILE'] = to_num('DEPTH_PERCENTILE', int, 50)
    df['VARIANTS_20BP'] = to_num('VARIANTS_20BP', int, 0)
    df['VARIANTS_250BP'] = to_num('VARIANTS_250BP', int, 0)
    df['MEDIAN_DIST_TO_SOFTCLIP'] = to_num('MEDIAN_DIST_TO_SOFTCLIP', int, 1000)
    df['AVG_ASXS'] = to_num('AVG_ALT_ASXS', float, 0.0) 
    df['MEAN_MAPQ'] = to_num('MEAN_ALT_MAPQ', float, 0.0) 
    df['AVG_ALT_EXCESS_NM'] = to_num('AVG_ALT_EXCESS_NM', float, 0.0)
    df['AVG_ALT_SOFTCLIP'] = to_num('AVG_ALT_SOFTCLIP', float, 0.0)
    df['REF_ENTROPY_40BP'] = to_num('REF_ENTROPY_40BP', float, 2.0)
    df['IN_BLACKLIST'] = to_str('IN_BLACKLIST', "NO")
    df['IN_GNOMAD_COMMON'] = to_str('IN_GNOMAD_COMMON', "No")
    df['IN_CB_PON'] = to_str('IN_CB_PON', "No")

    with np.errstate(divide='ignore', invalid='ignore'):
        df['VAF_SSCS'] = (df['N_ALT_SSCS'] / df['N_TOTAL_SSCS']).fillna(0.0)

    return df

# -----------------------
# Aggregation & Filtering Logic
# -----------------------
def aggregate_samples(samples_meta: List[Dict]) -> List[Dict]:
    """Groups all cord blood samples to combat Poisson noise."""
    agg_meta, cord_ids = [], []
    cord_exp, cord_bases = 0.0, 0.0
    
    for s in samples_meta:
        lam = expected_lambda(s['sample_type'], s['age'], s['bases'])
        if "cord" in s['sample_type'].lower():
            cord_ids.append(s['sample_id'])
            cord_exp += lam
            cord_bases += s['bases']
        else:
            agg_meta.append({
                'sample_ids': [s['sample_id']],
                'sample_type': s['sample_type'],
                'age': s['age'],
                'bases': s['bases'],
                'expected_lambda': lam,
                'is_cord': False
            })
            
    if cord_ids:
        agg_meta.append({
            'sample_ids': cord_ids, 
            'sample_type': 'cord_aggregate',
            'age': 0.0, 
            'bases': cord_bases,
            'expected_lambda': cord_exp,
            'is_cord': True
        })
    return agg_meta

def get_static_mask(df: pd.DataFrame, pon_flags: Dict[str, bool], ignore_blacklists: bool = False, ignore_cb_pon: bool = False) -> pd.Series:
    """Filters evaluated ONCE before Optuna runs to save immense computation time."""
    mask = (df['N_TOTAL_SSCS'] > 0) & (df['N_ALT_SSCS'] > 1)
    
    # Filter out insertions that contain 'N' in the inserted sequence
    has_n_in_insertion = (df['INDEL_LENGTH'] > 0) & (df['ALT'].str.contains('N', case=False, na=False))
    mask &= (~has_n_in_insertion)
    
    if pon_flags.get("use_cord_pon", False):
        mask &= (df['IN_BLACKLIST'] != "YES")

    # NEW: Hard filter for IN_CB_PON
    if not ignore_cb_pon:
        mask &= (df['IN_CB_PON'] != "Yes")

    if not ignore_blacklists:
        mask &= (~df['IN_CLUSTER_BLACKLIST']) & (~df['IN_ARTEFACT_BLACKLIST'])
        
    return mask

# -----------------------
# Aggregation & Filtering Logic
# -----------------------
def get_dynamic_mask(df: pd.DataFrame, thresholds: Dict[str, Any]) -> pd.Series:
    """Filters evaluated during every Optuna trial."""
    mask = (df['N_TOTAL'] >= thresholds['n_total_min'])
    mask &= (df['DEPTH_PERCENTILE'] <= thresholds['depth_percentile_max'])
    mask &= (df['MEAN_MAPQ'] >= thresholds['mean_mapq_min'])
    mask &= (df['AVG_ASXS'] > thresholds['asxs_min'])

    is_ins = df['INDEL_LENGTH'] > 0
    is_del = df['INDEL_LENGTH'] < 0
    mask &= ((is_ins & (df['MEAN_INSET_QUAL'] >= thresholds['mean_inset_qual_min'])) | 
             (is_del & (df['MEAN_DEL_ANCHOR_QUAL'] >= thresholds['mean_del_anchor_qual_min'])))

    is_1bp = df['INDEL_LENGTH'].abs() == 1
    is_long = df['INDEL_LENGTH'].abs() > 1
    mask &= ((is_1bp & (df['HOMOPOLYMER_LEN'] <= thresholds['hp_max_1bp'])) | 
             (is_long & (df['HOMOPOLYMER_LEN'] <= thresholds['hp_max_long'])))
    
    mask &= (df['N_SLIPPAGE_SSCS'] <= thresholds['max_slippage_reads'])
    mask &= (df['VARIANTS_20BP'] <= thresholds['variants_20bp_max'])
    mask &= (df['VARIANTS_250BP'] <= thresholds['variants_250bp_max'])
    mask &= (df['REF_ENTROPY_40BP'] >= thresholds['ref_entropy_min'])
    mask &= (df['AVG_ALT_SOFTCLIP'] <= thresholds['avg_alt_softclip_max'])
    mask &= (df['MEDIAN_DIST_TO_SOFTCLIP'] >= thresholds['dist_to_softclip_min'])
    mask &= (df['AVG_ALT_EXCESS_NM'] <= thresholds['avg_alt_nm_max'])
    mask &= (df['GC_CONTENT'] >= thresholds['gc_min']) & (df['GC_CONTENT'] <= thresholds['gc_max'])
    mask &= (df['DIST_TO_OTHER_INDEL'] >= thresholds['min_dist_to_indel'])
    mask &= (df['RP_MED_SSCS'] >= thresholds['min_rp_med']) & (df['RP_MED_SSCS'] <= thresholds['max_rp_med'])
    mask &= (df['AVG_ALT_N_COUNT'] <= thresholds['max_n_count'])
    mask &= (df['VAF_SSCS'] <= thresholds['germline_vaf_max'])

    # --- NEW FEATURES ---
    mask &= (df['SD_BASEQ'] <= thresholds['sd_baseq_max'])
    mask &= (df['AVG_ALT_READ_MEAN_BASEQ'] >= thresholds['avg_alt_read_mean_baseq_min'])
    mask &= (df['MEAN_REF_MAPQ'] >= thresholds['mean_ref_mapq_min'])
    mask &= (df['AVG_REF_ASXS'] >= thresholds['avg_ref_asxs_min'])
    mask &= (df['AVG_ALTREAD_VARIANTS'] <= thresholds['avg_altread_variants_max'])
    mask &= (df['AVG_NONALTREAD_VARIANTS'] <= thresholds['avg_nonaltread_variants_max'])
    mask &= (df['MEAN_INSERT'] >= thresholds['mean_insert_min']) & (df['MEAN_INSERT'] <= thresholds['mean_insert_max'])
    mask &= (df['SD_INSERT'] <= thresholds['sd_insert_max'])
    mask &= (df['AVG_READ_POSITION'] >= thresholds['avg_read_position_min']) & (df['AVG_READ_POSITION'] <= thresholds['avg_read_position_max'])
    mask &= (df['AVG_READ_LENGTH'] >= thresholds['avg_read_length_min'])

    # Strand Bias (Conditional)
    enough_reads_sb = df['N_ALT_SSCS'] >= thresholds['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < thresholds['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > thresholds['strand_bias_max'])
    mask &= ~(enough_reads_sb & bad_bias)

    # RP SD (Conditional)
    enough_reads_rp = df['N_ALT_SSCS'] >= thresholds['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < thresholds['rp_sd_min']
    mask &= ~(enough_reads_rp & bad_rp_sd)
    
    return mask

# -----------------------
# Optimization Objective
# -----------------------
def make_objective(filtered_df: pd.DataFrame, agg_meta: List[Dict]):
    exp_arr = np.array([m['expected_lambda'] for m in agg_meta])
    weights_arr = np.array([CORD_WEIGHT if m['is_cord'] else 1.0 for m in agg_meta])

    def objective(trial):
        thresholds = {
            "n_total_min": trial.suggest_int("n_total_min", 10, 30),
            "depth_percentile_max": trial.suggest_int("depth_percentile_max", 95, 99),
            "mean_inset_qual_min": trial.suggest_int("mean_inset_qual_min", 20, 50),
            "mean_del_anchor_qual_min": trial.suggest_int("mean_del_anchor_qual_min", 20, 50),
            "hp_max_1bp": trial.suggest_int("hp_max_1bp", 3, 6),
            "hp_max_long": trial.suggest_int("hp_max_long", 8, 15),
            "max_slippage_reads": trial.suggest_int("max_slippage_reads", 0, 5),
            "asxs_min": trial.suggest_int("asxs_min", 10, 60),
            "mean_mapq_min": trial.suggest_int("mean_mapq_min", 20, 50),
            "avg_alt_nm_max": trial.suggest_float("avg_alt_nm_max", 0.0, 5.0),
            "avg_alt_softclip_max": trial.suggest_float("avg_alt_softclip_max", 0.0, 5.0),
            "dist_to_softclip_min": trial.suggest_int("dist_to_softclip_min", 0, 5),
            "variants_20bp_max": trial.suggest_int("variants_20bp_max", 0, 4),
            "variants_250bp_max": trial.suggest_int("variants_250bp_max", 0, 15),
            "ref_entropy_min": trial.suggest_float("ref_entropy_min", 0.0, 2.1),
            "gc_min": trial.suggest_float("gc_min", 0.01, 0.2),
            "gc_max": trial.suggest_float("gc_max", 0.8, 0.99),
            "min_dist_to_indel": trial.suggest_int("min_dist_to_indel", 0, 500),
            "min_rp_med": trial.suggest_float("min_rp_med", 0.01, 0.08),
            "max_rp_med": trial.suggest_float("max_rp_med", 0.92, 0.99),
            "max_n_count": trial.suggest_float("max_n_count", 0.0, 3.0),
            "germline_vaf_max": trial.suggest_float("germline_vaf_max", 0.2, 0.2),
            
            # --- NEW FEATURES ---
            
            "sd_baseq_max": trial.suggest_float("sd_baseq_max", 0.0, 50.0),
            "avg_alt_read_mean_baseq_min": trial.suggest_float("avg_alt_read_mean_baseq_min", 00.0, 60.0),
            "mean_ref_mapq_min": trial.suggest_float("mean_ref_mapq_min", 20.0, 60.0),
            "avg_ref_asxs_min": trial.suggest_float("avg_ref_asxs_min", 10.0, 60.0),
            "avg_altread_variants_max": trial.suggest_float("avg_altread_variants_max", 0.0, 5.0),
            "avg_nonaltread_variants_max": trial.suggest_float("avg_nonaltread_variants_max", 0.0, 10.0),
            "mean_insert_min": trial.suggest_float("mean_insert_min", 0.0, 150.0),
            "mean_insert_max": trial.suggest_float("mean_insert_max", 500.0, 1000.0),
            "sd_insert_max": trial.suggest_float("sd_insert_max", 00.0, 800.0),
            "avg_read_position_min": trial.suggest_float("avg_read_position_min", 0.0, 10.0),
            "avg_read_position_max": trial.suggest_float("avg_read_position_max", 130.0, 150.0), 
            "avg_read_length_min": trial.suggest_float("avg_read_length_min", 50.0, 150.0),
            
            # --- CONDITIONAL FEATURES ---
            "strand_bias_n_alt_min": trial.suggest_int("strand_bias_n_alt_min", 3, 10),
            "strand_bias_min": trial.suggest_float("strand_bias_min", 0.0, 0.3),
            "strand_bias_max": trial.suggest_float("strand_bias_max", 0.7, 1.0),
            "rp_sd_min_alt": trial.suggest_int("rp_sd_min_alt", 3, 10),
            "rp_sd_min": trial.suggest_float("rp_sd_min", 0.0, 15.0),
        }

        dyn_mask = get_dynamic_mask(filtered_df, thresholds)
        obs_counts = filtered_df[dyn_mask]['sample_id'].value_counts()
        
        obs_arr = [sum(obs_counts.get(sid, 0) for sid in m['sample_ids']) for m in agg_meta]
        return poisson_deviance(np.array(obs_arr), exp_arr, weights=weights_arr)
    
    return objective

# -----------------------
# Reporting
# -----------------------
def evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, outdir):
    os.makedirs(outdir, exist_ok=True)
    
    # NEW: Added ignore_cb_pon flags to isolate the counts
    static_mask_final = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False, ignore_cb_pon=False)
    static_mask_clean = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=True, ignore_cb_pon=False)
    static_mask_no_cb_pon = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False, ignore_cb_pon=True)
    
    dyn_mask = get_dynamic_mask(all_variants_df, best_thresholds)
    
    pass_mask_final = static_mask_final & dyn_mask
    pass_mask_clean = static_mask_clean & dyn_mask
    pass_mask_no_cb_pon = static_mask_no_cb_pon & dyn_mask # NEW
    
    count_saved_by_blacklist = (pass_mask_clean & (~pass_mask_final)).sum()
    count_saved_by_cb_pon = (pass_mask_no_cb_pon & (~pass_mask_final)).sum() # NEW
    
    obs_series = all_variants_df[pass_mask_final].groupby('sample_id').size()
    
    observed, expected, ids, ages, bases, types, weights = [], [], [], [], [], [], []

    for s in samples_meta:
        sid = s['sample_id']
        ids.append(sid)
        observed.append(obs_series.get(sid, 0))
        expected.append(expected_lambda(s['sample_type'], s['age'], s['bases']))
        ages.append(s['age'])
        bases.append(s['bases'])
        types.append(s['sample_type'])
        weights.append(CORD_WEIGHT if "cord" in s['sample_type'].lower() else 1.0)

    obs_arr, exp_arr, weights_arr = np.array(observed), np.array(expected), np.array(weights)

    with open(os.path.join(outdir, "best_thresholds.json"), "w") as fh:
        json.dump({"thresholds": best_thresholds, "pon_flags": pon_flags, "blacklists_enforced": True, "cord_penalty_weight": CORD_WEIGHT}, fh, indent=2)

    dev = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
    mean_ratio = float(np.mean(obs_arr / (exp_arr + EPS)))
    
    with open(os.path.join(outdir, "summary.json"), "w") as fh:
        json.dump({
            "n_samples": len(samples_meta),
            "obs_mean_over_expected": mean_ratio,
            "total_observed": int(np.sum(obs_arr)),
            "total_expected": float(np.sum(exp_arr)),
            "weighted_poisson_deviance": dev,
            "variants_blocked_by_blacklists": int(count_saved_by_blacklist),
            "variants_blocked_by_cb_pon": int(count_saved_by_cb_pon) # NEW
        }, fh, indent=2)

    pd.DataFrame({
        "sample_id": ids, "sample_type": types, "age": ages, "bases": bases,
        "observed": observed, "expected": expected, "weight_used": weights 
    }).to_csv(os.path.join(outdir, "observed_expected.csv"), index=False)
    
    final_pass_df = all_variants_df[pass_mask_final]
    n_ins = (final_pass_df['INDEL_LENGTH'] > 0).sum()
    n_del = (final_pass_df['INDEL_LENGTH'] < 0).sum()
    n_1bp = (final_pass_df['INDEL_LENGTH'].abs() == 1).sum()
    n_long = (final_pass_df['INDEL_LENGTH'].abs() > 1).sum()
    
    ins_del_ratio = n_ins / n_del if n_del > 0 else 0.0
    bp1_long_ratio = n_1bp / n_long if n_long > 0 else 0.0

    print("-" * 30)
    print("FINAL RESULTS")
    print("-" * 30)
    print(f"Total Samples:         {len(samples_meta)}")
    print(f"Total Observed Indels: {int(np.sum(obs_arr))}")
    print(f"Total Expected Indels: {float(np.sum(exp_arr)):.2f}")
    print(f"Weighted Deviance:     {dev:.4f}")
    print(f"Mean Obs/Exp Ratio:    {mean_ratio:.4f}")
    print(f"Blacklist Blocked:     {count_saved_by_blacklist}")
    print(f"CB PON Blocked:        {count_saved_by_cb_pon}") # NEW
    print("-" * 30)
    print("INDEL METRICS (Passing Variants)")
    print("-" * 30)
    print(f"Insertions: {n_ins} | Deletions: {n_del}")
    print(f"INS / DEL Ratio:       {ins_del_ratio:.3f}")
    print(f"1bp Indels: {n_1bp} | >1bp Indels: {n_long}")
    print(f"1bp / >1bp Ratio:      {bp1_long_ratio:.3f}")
    print("-" * 30)

    
# -----------------------
# Execution Block
# -----------------------
if __name__ == "__main__":
    print(f"[INFO] Reading metadata from {SAMPLES_CSV}...")
    samples_meta = []
    with open(SAMPLES_CSV, newline='') as csvfile:
        for r in csv.DictReader(csvfile):
            samples_meta.append({
                "sample_id": r["sample_id"],
                "vcf_path": r["vcf_path"],
                "sample_type": r["sample_type"].lower(),
                "age": float(r["age"]) if r.get("age") else None,
                "bases": float(r["total_callable_bases_in_wes"]),
            })
    print(f"[INFO] Loaded {len(samples_meta)} samples.")

    print("[INFO] Loading VCFs into DataFrame...")
    df_list = [parse_vcf_to_df(s["vcf_path"], s["sample_id"]) for s in samples_meta]
    all_variants_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    
    print(f"[INFO] Total variants loaded: {len(all_variants_df)}")

    if not all_variants_df.empty:
        chroms = all_variants_df['CHROM'].values
        poses = all_variants_df['POS'].values

        # ---------------------------------------------------------
        # NEW: Filter by WES BED immediately to save computation
        # ---------------------------------------------------------
        bed_lookup_exome = BedLookup(EXOME_BED_PATH, "Exome Targets")
        in_exome_mask = [bed_lookup_exome.is_overlapped(c, p) for c, p in zip(chroms, poses)]
        all_variants_df = all_variants_df[in_exome_mask].reset_index(drop=True)
        print(f"[INFO] Variants remaining after WES target restriction: {len(all_variants_df)}")

        # Proceed only if we still have variants left
        if not all_variants_df.empty:
            # Re-extract chroms and poses for the remaining on-target variants
            chroms = all_variants_df['CHROM'].values
            poses = all_variants_df['POS'].values

            bed_lookup_cluster = BedLookup(BLACKLIST_BED, "Cluster Blacklist")
            all_variants_df['IN_CLUSTER_BLACKLIST'] = [bed_lookup_cluster.is_overlapped(c, p) for c, p in zip(chroms, poses)]
            
            bed_lookup_genes = BedLookup(ARTEFACT_GENES_BED, "Artefact Gene Blacklist")
            all_variants_df['IN_ARTEFACT_BLACKLIST'] = [bed_lookup_genes.is_overlapped(c, p) for c, p in zip(chroms, poses)]
            
            hits_cluster = sum(all_variants_df['IN_CLUSTER_BLACKLIST'])
            print(f"[INFO] Found {hits_cluster} variants in Cluster blacklist.")

            # Aggregate cords for robust optimization
            agg_meta = aggregate_samples(samples_meta)
            
            # Pre-filter static masks to massively speed up Optuna
            pon_flags = {"use_cord_pon": True}
            static_mask = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False)
            static_filtered_df = all_variants_df[static_mask].copy()

            run_diagnostic_waterfall(static_filtered_df)
            # ---------------------------

            print(f"[INFO] Starting Optuna (Trials={N_TRIALS}). Evaluating {len(static_filtered_df)} valid candidates per trial...")

            print(f"[INFO] Starting Optuna (Trials={N_TRIALS}). Evaluating {len(static_filtered_df)} valid candidates per trial...")
            study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=SEED))
            
            objective = make_objective(static_filtered_df, agg_meta)
            study.optimize(objective, n_trials=N_TRIALS)

            print(f"[INFO] Best Weighted Deviance: {study.best_value:.4f}")

            print("[INFO] Generating report...")
            evaluate_and_report(study.best_params, pon_flags, all_variants_df, samples_meta, OUT_DIR)
        else:
            print("[WARN] No variants remained after Exome BED filtering.")
# Out:
# [INFO] Reading metadata from training_complete_processed_metadata.csv...
# [INFO] Loaded 18 samples.
# [INFO] Loading VCFs into DataFrame...
# [INFO] Total variants loaded: 19992
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Variants remaining after WES target restriction: 19312
# [INFO] Loading Cluster Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Cluster Blacklist.
# [INFO] Loading Artefact Gene Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Artefact Gene Blacklist.
# [I 2026-04-24 16:54:38,084] A new study created in memory with name: no-name-c4146dcb-cc09-46ec-8504-8d55abf39eab
# [I 2026-04-24 16:54:38,191] Trial 0 finished with value: 2470.522547308156 and parameters: {'n_total_min': 17, 'depth_percentile_max': 99, 'mean_inset_qual_min': 42, 'mean_del_anchor_qual_min': 38, 'hp_max_1bp': 3, 'hp_max_long': 9, 'max_slippage_reads': 0, 'asxs_min': 54, 'mean_mapq_min': 38, 'avg_alt_nm_max': 3.540362888980227, 'avg_alt_softclip_max': 0.10292247147901223, 'dist_to_softclip_min': 5, 'variants_20bp_max': 4, 'variants_250bp_max': 3, 'ref_entropy_min': 0.38183243113491133, 'gc_min': 0.044846856872152424, 'gc_max': 0.8578060261623122, 'min_dist_to_indel': 262, 'min_rp_med': 0.040236151304948106, 'max_rp_med': 0.9403860398138629, 'max_n_count': 1.8355586841671383, 'germline_vaf_max': 0.2, 'sd_baseq_max': 6.974693032602092, 'avg_alt_read_mean_baseq_min': 17.52867891211309, 'mean_ref_mapq_min': 34.65447373174767, 'avg_ref_asxs_min': 32.8034992108518, 'avg_altread_variants_max': 3.925879806965068, 'avg_nonaltread_variants_max': 1.9967378215835974, 'mean_insert_min': 77.13516576204174, 'mean_insert_max': 796.2072844310212, 'sd_insert_max': 37.16033017599818, 'avg_read_position_min': 6.075448519014383, 'avg_read_position_max': 133.41048247374584, 'avg_read_length_min': 56.50515929852795, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.2896896099223678, 'strand_bias_max': 0.9425192044349383, 'rp_sd_min_alt': 5, 'rp_sd_min': 1.465081710095758}. Best is trial 0 with value: 2470.522547308156.
# [I 2026-04-24 16:54:38,197] Trial 1 finished with value: 2378.3705288647984 and parameters: {'n_total_min': 24, 'depth_percentile_max': 97, 'mean_inset_qual_min': 23, 'mean_del_anchor_qual_min': 35, 'hp_max_1bp': 3, 'hp_max_long': 15, 'max_slippage_reads': 1, 'asxs_min': 43, 'mean_mapq_min': 29, 'avg_alt_nm_max': 2.600340105889054, 'avg_alt_softclip_max': 2.7335513967163982, 'dist_to_softclip_min': 1, 'variants_20bp_max': 4, 'variants_250bp_max': 12, 'ref_entropy_min': 1.9729477772847972, 'gc_min': 0.18001719658125329, 'gc_max': 0.9136009959741062, 'min_dist_to_indel': 461, 'min_rp_med': 0.016194475143634365, 'max_rp_med': 0.9337188003693402, 'max_n_count': 0.1356818667316142, 'germline_vaf_max': 0.2, 'sd_baseq_max': 16.266516538163216, 'avg_alt_read_mean_baseq_min': 23.320637381368922, 'mean_ref_mapq_min': 30.853961270955836, 'avg_ref_asxs_min': 51.436875457596464, 'avg_altread_variants_max': 1.7837666334679465, 'avg_nonaltread_variants_max': 2.8093450968738076, 'mean_insert_min': 81.40441247373727, 'mean_insert_max': 570.4621124873813, 'sd_insert_max': 641.7575846032317, 'avg_read_position_min': 0.7455064367977082, 'avg_read_position_max': 149.73773873201034, 'avg_read_length_min': 127.22447692966574, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.0016566351370807197, 'strand_bias_max': 0.9446384285364502, 'rp_sd_min_alt': 8, 'rp_sd_min': 10.93510752061481}. Best is trial 1 with value: 2378.3705288647984.
# [I 2026-04-24 16:54:38,202] Trial 2 finished with value: 2470.522547308156 and parameters: {'n_total_min': 26, 'depth_percentile_max': 95, 'mean_inset_qual_min': 31, 'mean_del_anchor_qual_min': 23, 'hp_max_1bp': 6, 'hp_max_long': 12, 'max_slippage_reads': 1, 'asxs_min': 13, 'mean_mapq_min': 29, 'avg_alt_nm_max': 1.6259166101337352, 'avg_alt_softclip_max': 3.64803089169032, 'dist_to_softclip_min': 3, 'variants_20bp_max': 4, 'variants_250bp_max': 7, 'ref_entropy_min': 0.2511479164704336, 'gc_min': 0.14551650957236906, 'gc_max': 0.9445491592372105, 'min_dist_to_indel': 281, 'min_rp_med': 0.06396770259681928, 'max_rp_med': 0.9545656917455073, 'max_n_count': 1.568198488145982, 'germline_vaf_max': 0.2, 'sd_baseq_max': 21.37705091792748, 'avg_alt_read_mean_baseq_min': 1.5251476046457113, 'mean_ref_mapq_min': 24.315657079732176, 'avg_ref_asxs_min': 11.571459284336713, 'avg_altread_variants_max': 3.182052056318902, 'avg_nonaltread_variants_max': 3.143559810763267, 'mean_insert_min': 76.28560367470541, 'mean_insert_max': 953.7832369630465, 'sd_insert_max': 199.43378331909994, 'avg_read_position_min': 4.103829230356297, 'avg_read_position_max': 145.11102277086098, 'avg_read_length_min': 72.87981654916224, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.0869254358741304, 'strand_bias_max': 0.7483663861762013, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.121805693466253}. Best is trial 1 with value: 2378.3705288647984.
# [I 2026-04-24 16:54:38,213] Trial 3 finished with value: 2470.522547308156 and parameters: {'n_total_min': 23, 'depth_percentile_max': 99, 'mean_inset_qual_min': 44, 'mean_del_anchor_qual_min': 25, 'hp_max_1bp': 6, 'hp_max_long': 12, 'max_slippage_reads': 4, 'asxs_min': 55, 'mean_mapq_min': 29, 'avg_alt_nm_max': 0.5502596226383838, 'avg_alt_softclip_max': 1.1396758127097084, 'dist_to_softclip_min': 2, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.014599474115500478, 'gc_min': 0.10704198748973749, 'gc_max': 0.879308090598268, 'min_dist_to_indel': 111, 'min_rp_med': 0.018390575713357796, 'max_rp_med': 0.943633061998254, 'max_n_count': 2.8287291117375575, 'germline_vaf_max': 0.2, 'sd_baseq_max': 16.160146601037763, 'avg_alt_read_mean_baseq_min': 31.127437304601965, 'mean_ref_mapq_min': 48.12075835580711, 'avg_ref_asxs_min': 28.1814801189647, 'avg_altread_variants_max': 4.858910413604804, 'avg_nonaltread_variants_max': 9.624472949421111, 'mean_insert_min': 37.767344373804626, 'mean_insert_max': 748.6242529461928, 'sd_insert_max': 240.70264785341573, 'avg_read_position_min': 2.848404943774676, 'avg_read_position_max': 130.73773894709066, 'avg_read_length_min': 110.95643339798968, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.015443625374996805, 'strand_bias_max': 0.7835939392709834, 'rp_sd_min_alt': 10, 'rp_sd_min': 3.5934283600045864}. Best is trial 1 with value: 2378.3705288647984.
# [INFO] Found 5279 variants in Cluster blacklist.
#
# ========================================
#    DYNAMIC FILTER WATERFALL DIAGNOSTIC
# ========================================
# FILTER STEP                    | REMAINING  | DROPPED HERE
# -------------------------------------------------------
# N_TOTAL                        | 1533       | 29
# DEPTH_PERCENTILE               | 1533       | 0
# MEAN_MAPQ                      | 1504       | 29
# AVG_ASXS                       | 1504       | 0
# INSET/ANCHOR_QUAL              | 1504       | 0
# HOMOPOLYMER                    | 1503       | 1
# SLIPPAGE                       | 1452       | 51
# VARIANTS_20BP                  | 1369       | 83
# VARIANTS_250BP                 | 1287       | 82
# REF_ENTROPY                    | 1287       | 0
# ALT_SOFTCLIP                   | 1259       | 28
# DIST_SOFTCLIP                  | 1259       | 0
# ALT_EXCESS_NM                  | 1208       | 51
# GC_CONTENT                     | 1204       | 4
# DIST_OTHER_INDEL               | 1204       | 0
# RP_MED                         | 1204       | 0
# ALT_N_COUNT                    | 1178       | 26
# GERMLINE_VAF                   | 915        | 263
# SD_BASEQ                       | 892        | 23
# AVG_ALT_READ_MEAN_BASEQ        | 891        | 1
# MEAN_REF_MAPQ                  | 891        | 0
# AVG_REF_ASXS                   | 891        | 0
# AVG_ALTREAD_VARIANTS           | 891        | 0
# AVG_NONALTREAD_VARIANTS        | 890        | 1
# MEAN_INSERT                    | 890        | 0
# SD_INSERT                      | 890        | 0
# AVG_READ_POSITION              | 890        | 0
# AVG_READ_LENGTH                | 888        | 2
# STRAND_BIAS                    | 888        | 0
# RP_SD                          | 888        | 0
# ========================================
#
# [INFO] Starting Optuna (Trials=3000). Evaluating 1562 valid candidates per trial...
# [INFO] Starting Optuna (Trials=3000). Evaluating 1562 valid candidates per trial...
# [I 2026-04-24 16:54:38,217] Trial 4 finished with value: 2470.522547308156 and parameters: {'n_total_min': 13, 'depth_percentile_max': 97, 'mean_inset_qual_min': 50, 'mean_del_anchor_qual_min': 27, 'hp_max_1bp': 5, 'hp_max_long': 14, 'max_slippage_reads': 1, 'asxs_min': 47, 'mean_mapq_min': 31, 'avg_alt_nm_max': 3.1615291529678973, 'avg_alt_softclip_max': 3.1676485538044736, 'dist_to_softclip_min': 3, 'variants_20bp_max': 0, 'variants_250bp_max': 13, 'ref_entropy_min': 0.6736381364406453, 'gc_min': 0.0454385169759723, 'gc_max': 0.8077472768954052, 'min_dist_to_indel': 296, 'min_rp_med': 0.057429505328959775, 'max_rp_med': 0.92116114802495, 'max_n_count': 1.5362791748978428, 'germline_vaf_max': 0.2, 'sd_baseq_max': 11.324788759896897, 'avg_alt_read_mean_baseq_min': 38.71036742456699, 'mean_ref_mapq_min': 26.97465716019966, 'avg_ref_asxs_min': 44.546886905123294, 'avg_altread_variants_max': 1.933676731502687, 'avg_nonaltread_variants_max': 9.367299887367345, 'mean_insert_min': 20.628141621898987, 'mean_insert_max': 670.5331755251293, 'sd_insert_max': 90.77881699247126, 'avg_read_position_min': 9.246936182785628, 'avg_read_position_max': 147.54678706761962, 'avg_read_length_min': 75.79416277151556, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.24516666006036475, 'strand_bias_max': 0.8665602434798387, 'rp_sd_min_alt': 7, 'rp_sd_min': 3.627784363506775}. Best is trial 1 with value: 2378.3705288647984.
# [I 2026-04-24 16:54:38,222] Trial 5 finished with value: 2470.522547308156 and parameters: {'n_total_min': 11, 'depth_percentile_max': 99, 'mean_inset_qual_min': 47, 'mean_del_anchor_qual_min': 39, 'hp_max_1bp': 4, 'hp_max_long': 10, 'max_slippage_reads': 4, 'asxs_min': 55, 'mean_mapq_min': 47, 'avg_alt_nm_max': 3.899377729288119, 'avg_alt_softclip_max': 3.2101582307714387, 'dist_to_softclip_min': 0, 'variants_20bp_max': 0, 'variants_250bp_max': 14, 'ref_entropy_min': 1.2735010252851389, 'gc_min': 0.011747439807159633, 'gc_max': 0.8192795931445461, 'min_dist_to_indel': 332, 'min_rp_med': 0.010354310869235309, 'max_rp_med': 0.9312565635992249, 'max_n_count': 1.6462013680997583, 'germline_vaf_max': 0.2, 'sd_baseq_max': 34.59475988463466, 'avg_alt_read_mean_baseq_min': 39.11767557015603, 'mean_ref_mapq_min': 28.970772378422392, 'avg_ref_asxs_min': 45.6089610673768, 'avg_altread_variants_max': 1.1862454374840004, 'avg_nonaltread_variants_max': 3.2539969815926773, 'mean_insert_min': 111.97371076770362, 'mean_insert_max': 824.8164495236073, 'sd_insert_max': 679.3787283953424, 'avg_read_position_min': 6.576128923003433, 'avg_read_position_max': 141.36617206670942, 'avg_read_length_min': 59.36747678280925, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.07956071030451763, 'strand_bias_max': 0.7731968930137251, 'rp_sd_min_alt': 10, 'rp_sd_min': 5.896465870001406}. Best is trial 1 with value: 2378.3705288647984.
# [I 2026-04-24 16:54:38,230] Trial 6 finished with value: 2470.522547308156 and parameters: {'n_total_min': 28, 'depth_percentile_max': 98, 'mean_inset_qual_min': 44, 'mean_del_anchor_qual_min': 35, 'hp_max_1bp': 5, 'hp_max_long': 11, 'max_slippage_reads': 1, 'asxs_min': 46, 'mean_mapq_min': 28, 'avg_alt_nm_max': 0.1215798321572692, 'avg_alt_softclip_max': 3.227361479535839, 'dist_to_softclip_min': 1, 'variants_20bp_max': 4, 'variants_250bp_max': 15, 'ref_entropy_min': 1.921215219462942, 'gc_min': 0.08033015304853444, 'gc_max': 0.8029367571404848, 'min_dist_to_indel': 465, 'min_rp_med': 0.03997289038221201, 'max_rp_med': 0.9876658373330569, 'max_n_count': 2.8908599312677588, 'germline_vaf_max': 0.2, 'sd_baseq_max': 42.650472773368, 'avg_alt_read_mean_baseq_min': 17.666933524175143, 'mean_ref_mapq_min': 35.40390914407701, 'avg_ref_asxs_min': 52.556833575842845, 'avg_altread_variants_max': 1.5846100257813882, 'avg_nonaltread_variants_max': 1.6949274668609249, 'mean_insert_min': 83.52018936875253, 'mean_insert_max': 968.0773870803905, 'sd_insert_max': 556.8238373399784, 'avg_read_position_min': 5.700611700893649, 'avg_read_position_max': 131.94352987541538, 'avg_read_length_min': 111.50072266991697, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.04202520457095721, 'strand_bias_max': 0.855498895709121, 'rp_sd_min_alt': 10, 'rp_sd_min': 11.111529266313067}. Best is trial 1 with value: 2378.3705288647984.
# [I 2026-04-24 16:54:38,235] Trial 7 finished with value: 2470.522547308156 and parameters: {'n_total_min': 24, 'depth_percentile_max': 98, 'mean_inset_qual_min': 31, 'mean_del_anchor_qual_min': 29, 'hp_max_1bp': 6, 'hp_max_long': 14, 'max_slippage_reads': 5, 'asxs_min': 56, 'mean_mapq_min': 35, 'avg_alt_nm_max': 2.507581473435998, 'avg_alt_softclip_max': 3.9914758948338758, 'dist_to_softclip_min': 3, 'variants_20bp_max': 3, 'variants_250bp_max': 12, 'ref_entropy_min': 1.8690112178168894, 'gc_min': 0.0742190798017918, 'gc_max': 0.8713607610015894, 'min_dist_to_indel': 47, 'min_rp_med': 0.050479609869732184, 'max_rp_med': 0.922515959165772, 'max_n_count': 1.3967940543973805, 'germline_vaf_max': 0.2, 'sd_baseq_max': 27.13223173537883, 'avg_alt_read_mean_baseq_min': 17.192475127697065, 'mean_ref_mapq_min': 43.63333042276043, 'avg_ref_asxs_min': 11.52501249695247, 'avg_altread_variants_max': 0.18674094374607209, 'avg_nonaltread_variants_max': 8.226005606596583, 'mean_insert_min': 54.02859621168943, 'mean_insert_max': 563.5302563259424, 'sd_insert_max': 417.7946080438435, 'avg_read_position_min': 7.699935530986108, 'avg_read_position_max': 134.31642054993685, 'avg_read_length_min': 112.28904758190002, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.01550451635058231, 'strand_bias_max': 0.8594063894704443, 'rp_sd_min_alt': 7, 'rp_sd_min': 9.561448522473098}. Best is trial 1 with value: 2378.3705288647984.
# [I 2026-04-24 16:54:38,243] Trial 8 finished with value: 1381.3593627775851 and parameters: {'n_total_min': 25, 'depth_percentile_max': 99, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 30, 'hp_max_1bp': 6, 'hp_max_long': 10, 'max_slippage_reads': 2, 'asxs_min': 14, 'mean_mapq_min': 20, 'avg_alt_nm_max': 4.813242073389626, 'avg_alt_softclip_max': 4.1799006025610295, 'dist_to_softclip_min': 4, 'variants_20bp_max': 2, 'variants_250bp_max': 2, 'ref_entropy_min': 0.3285177896092807, 'gc_min': 0.057546150651273116, 'gc_max': 0.9043530662941629, 'min_dist_to_indel': 358, 'min_rp_med': 0.05621381637024119, 'max_rp_med': 0.9395953727862161, 'max_n_count': 2.8645958419895825, 'germline_vaf_max': 0.2, 'sd_baseq_max': 36.89484583478843, 'avg_alt_read_mean_baseq_min': 33.26124315068404, 'mean_ref_mapq_min': 44.46882984937409, 'avg_ref_asxs_min': 30.980003121389494, 'avg_altread_variants_max': 1.2386549475057873, 'avg_nonaltread_variants_max': 3.559726786512616, 'mean_insert_min': 113.67691656965536, 'mean_insert_max': 507.19674431487795, 'sd_insert_max': 92.85811240553299, 'avg_read_position_min': 0.4600264202175275, 'avg_read_position_max': 130.81457604637941, 'avg_read_length_min': 135.5460584011007, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.14225214872619754, 'strand_bias_max': 0.7293502481953004, 'rp_sd_min_alt': 6, 'rp_sd_min': 7.102076561708485}. Best is trial 8 with value: 1381.3593627775851.
# [I 2026-04-24 16:54:38,252] Trial 9 finished with value: 2459.990406508853 and parameters: {'n_total_min': 13, 'depth_percentile_max': 97, 'mean_inset_qual_min': 32, 'mean_del_anchor_qual_min': 39, 'hp_max_1bp': 5, 'hp_max_long': 8, 'max_slippage_reads': 2, 'asxs_min': 41, 'mean_mapq_min': 35, 'avg_alt_nm_max': 4.282449205941611, 'avg_alt_softclip_max': 3.293468158094725, 'dist_to_softclip_min': 0, 'variants_20bp_max': 0, 'variants_250bp_max': 10, 'ref_entropy_min': 0.05567375213740581, 'gc_min': 0.12129736044195803, 'gc_max': 0.978643745870742, 'min_dist_to_indel': 288, 'min_rp_med': 0.037171894834456536, 'max_rp_med': 0.9650301752909647, 'max_n_count': 1.3747586714745499, 'germline_vaf_max': 0.2, 'sd_baseq_max': 27.280839465796745, 'avg_alt_read_mean_baseq_min': 56.48788852659151, 'mean_ref_mapq_min': 35.44410551203097, 'avg_ref_asxs_min': 58.05952819119571, 'avg_altread_variants_max': 4.526753209780319, 'avg_nonaltread_variants_max': 1.9579113478929644, 'mean_insert_min': 10.404195131274818, 'mean_insert_max': 550.3890006887133, 'sd_insert_max': 14.577460521239782, 'avg_read_position_min': 0.944429607559284, 'avg_read_position_max': 143.66013546832713, 'avg_read_length_min': 57.1188648460229, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.25346259329083637, 'strand_bias_max': 0.7069815807207477, 'rp_sd_min_alt': 9, 'rp_sd_min': 4.227821621600999}. Best is trial 8 with value: 1381.3593627775851.
# [I 2026-04-24 16:54:38,282] Trial 10 finished with value: 2470.522547308156 and parameters: {'n_total_min': 30, 'depth_percentile_max': 95, 'mean_inset_qual_min': 20, 'mean_del_anchor_qual_min': 48, 'hp_max_1bp': 4, 'hp_max_long': 8, 'max_slippage_reads': 3, 'asxs_min': 15, 'mean_mapq_min': 21, 'avg_alt_nm_max': 4.961813327301686, 'avg_alt_softclip_max': 4.959142635537945, 'dist_to_softclip_min': 5, 'variants_20bp_max': 2, 'variants_250bp_max': 0, 'ref_entropy_min': 0.992699413981692, 'gc_min': 0.015213864624731142, 'gc_max': 0.9153650120663129, 'min_dist_to_indel': 384, 'min_rp_med': 0.0727516806418861, 'max_rp_med': 0.9676925559459525, 'max_n_count': 2.3744079967498566, 'germline_vaf_max': 0.2, 'sd_baseq_max': 49.90957619749756, 'avg_alt_read_mean_baseq_min': 58.00004682414733, 'mean_ref_mapq_min': 54.872831595853036, 'avg_ref_asxs_min': 25.068576236591895, 'avg_altread_variants_max': 0.16792942467236127, 'avg_nonaltread_variants_max': 5.648745904837504, 'mean_insert_min': 149.4024797621153, 'mean_insert_max': 655.7706160051262, 'sd_insert_max': 362.2093234377504, 'avg_read_position_min': 2.485771806191799, 'avg_read_position_max': 136.8204336688016, 'avg_read_length_min': 136.90448268518855, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.1668326918948302, 'strand_bias_max': 0.998923161497077, 'rp_sd_min_alt': 3, 'rp_sd_min': 14.480069190981826}. Best is trial 8 with value: 1381.3593627775851.
# [I 2026-04-24 16:54:38,306] Trial 11 finished with value: 2470.522547308156 and parameters: {'n_total_min': 21, 'depth_percentile_max': 96, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 33, 'hp_max_1bp': 3, 'hp_max_long': 15, 'max_slippage_reads': 2, 'asxs_min': 29, 'mean_mapq_min': 21, 'avg_alt_nm_max': 1.6720799695039439, 'avg_alt_softclip_max': 1.9413533728363166, 'dist_to_softclip_min': 4, 'variants_20bp_max': 2, 'variants_250bp_max': 7, 'ref_entropy_min': 1.4081447994702612, 'gc_min': 0.1956806284630649, 'gc_max': 0.9258448433766405, 'min_dist_to_indel': 478, 'min_rp_med': 0.02780298570858551, 'max_rp_med': 0.9409019865912047, 'max_n_count': 0.021685218839673698, 'germline_vaf_max': 0.2, 'sd_baseq_max': 2.2813018245183354, 'avg_alt_read_mean_baseq_min': 26.334754658367817, 'mean_ref_mapq_min': 48.28777914265404, 'avg_ref_asxs_min': 41.00744538922787, 'avg_altread_variants_max': 2.3676988794509004, 'avg_nonaltread_variants_max': 5.2871955346272195, 'mean_insert_min': 112.90993923069671, 'mean_insert_max': 526.353674888555, 'sd_insert_max': 745.7497981280233, 'avg_read_position_min': 0.24276539383393153, 'avg_read_position_max': 148.89797484937355, 'avg_read_length_min': 149.9147222026846, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.17092457879092526, 'strand_bias_max': 0.9226618850937899, 'rp_sd_min_alt': 5, 'rp_sd_min': 7.991627248381503}. Best is trial 8 with value: 1381.3593627775851.
# [I 2026-04-24 16:54:38,335] Trial 12 finished with value: 2470.522547308156 and parameters: {'n_total_min': 19, 'depth_percentile_max': 98, 'mean_inset_qual_min': 37, 'mean_del_anchor_qual_min': 45, 'hp_max_1bp': 4, 'hp_max_long': 11, 'max_slippage_reads': 0, 'asxs_min': 30, 'mean_mapq_min': 23, 'avg_alt_nm_max': 4.8999476223945955, 'avg_alt_softclip_max': 4.87440999215581, 'dist_to_softclip_min': 1, 'variants_20bp_max': 1, 'variants_250bp_max': 4, 'ref_entropy_min': 0.7529135637327962, 'gc_min': 0.1987894158897421, 'gc_max': 0.9018432070679429, 'min_dist_to_indel': 403, 'min_rp_med': 0.07969726263467976, 'max_rp_med': 0.950401729280576, 'max_n_count': 0.09591297466855395, 'germline_vaf_max': 0.2, 'sd_baseq_max': 36.17399360544866, 'avg_alt_read_mean_baseq_min': 43.00314458405511, 'mean_ref_mapq_min': 20.026009772828072, 'avg_ref_asxs_min': 21.80619071478615, 'avg_altread_variants_max': 0.9956094961444014, 'avg_nonaltread_variants_max': 0.45917697532588164, 'mean_insert_min': 109.87237110058605, 'mean_insert_max': 629.0316456615276, 'sd_insert_max': 551.945468174554, 'avg_read_position_min': 1.6990038059034396, 'avg_read_position_max': 138.01466878481938, 'avg_read_length_min': 131.1114340953206, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.11803668301721065, 'strand_bias_max': 0.9292807911079445, 'rp_sd_min_alt': 8, 'rp_sd_min': 7.870115508779408}. Best is trial 8 with value: 1381.3593627775851.
# [I 2026-04-24 16:54:38,363] Trial 13 finished with value: 886.881306196035 and parameters: {'n_total_min': 26, 'depth_percentile_max': 96, 'mean_inset_qual_min': 26, 'mean_del_anchor_qual_min': 20, 'hp_max_1bp': 3, 'hp_max_long': 13, 'max_slippage_reads': 3, 'asxs_min': 21, 'mean_mapq_min': 42, 'avg_alt_nm_max': 2.410715913374974, 'avg_alt_softclip_max': 2.3058837788475612, 'dist_to_softclip_min': 2, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'ref_entropy_min': 1.537865207930086, 'gc_min': 0.16304757827391286, 'gc_max': 0.9574596679983549, 'min_dist_to_indel': 149, 'min_rp_med': 0.027806642802924653, 'max_rp_med': 0.931514163132709, 'max_n_count': 2.1204987861298927, 'germline_vaf_max': 0.2, 'sd_baseq_max': 18.788113889007253, 'avg_alt_read_mean_baseq_min': 4.873473992211597, 'mean_ref_mapq_min': 41.2856610513437, 'avg_ref_asxs_min': 38.47187050396487, 'avg_altread_variants_max': 2.9657395835189115, 'avg_nonaltread_variants_max': 4.209219801045197, 'mean_insert_min': 145.46281635860188, 'mean_insert_max': 510.49640833885, 'sd_insert_max': 568.6550767406918, 'avg_read_position_min': 0.025889513465016722, 'avg_read_position_max': 140.64425615781414, 'avg_read_length_min': 128.33036781153834, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.19955238882778395, 'strand_bias_max': 0.8106354147645216, 'rp_sd_min_alt': 5, 'rp_sd_min': 13.182125335523512}. Best is trial 13 with value: 886.881306196035.
# [I 2026-04-24 16:54:38,386] Trial 14 finished with value: 2470.522547308156 and parameters: {'n_total_min': 27, 'depth_percentile_max': 96, 'mean_inset_qual_min': 26, 'mean_del_anchor_qual_min': 20, 'hp_max_1bp': 4, 'hp_max_long': 13, 'max_slippage_reads': 3, 'asxs_min': 21, 'mean_mapq_min': 45, 'avg_alt_nm_max': 1.6169645431474842, 'avg_alt_softclip_max': 1.811208751999482, 'dist_to_softclip_min': 4, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'ref_entropy_min': 1.57244070634715, 'gc_min': 0.14310007232711322, 'gc_max': 0.988637329382697, 'min_dist_to_indel': 178, 'min_rp_med': 0.02958098424621912, 'max_rp_med': 0.9313477834854836, 'max_n_count': 2.248251834702396, 'germline_vaf_max': 0.2, 'sd_baseq_max': 33.72219355826088, 'avg_alt_read_mean_baseq_min': 5.7197559581730175, 'mean_ref_mapq_min': 41.81527610421723, 'avg_ref_asxs_min': 35.66595599387838, 'avg_altread_variants_max': 3.150482741219947, 'avg_nonaltread_variants_max': 7.030332266712058, 'mean_insert_min': 149.79313554329764, 'mean_insert_max': 502.75940747659075, 'sd_insert_max': 434.10995639608694, 'avg_read_position_min': 4.110899143205565, 'avg_read_position_max': 139.62839684380884, 'avg_read_length_min': 93.075958956552, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.20111202233540268, 'strand_bias_max': 0.8115851029937883, 'rp_sd_min_alt': 5, 'rp_sd_min': 14.772312784941935}. Best is trial 13 with value: 886.881306196035.
# [I 2026-04-24 16:54:38,411] Trial 15 finished with value: 2470.522547308156 and parameters: {'n_total_min': 30, 'depth_percentile_max': 96, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 31, 'hp_max_1bp': 5, 'hp_max_long': 10, 'max_slippage_reads': 3, 'asxs_min': 21, 'mean_mapq_min': 43, 'avg_alt_nm_max': 2.960022690328959, 'avg_alt_softclip_max': 2.2011996819082316, 'dist_to_softclip_min': 2, 'variants_20bp_max': 3, 'variants_250bp_max': 4, 'ref_entropy_min': 1.037879976392934, 'gc_min': 0.16123008279465248, 'gc_max': 0.9549262062237811, 'min_dist_to_indel': 180, 'min_rp_med': 0.051064301020932956, 'max_rp_med': 0.9641363362014128, 'max_n_count': 2.4304583139503455, 'germline_vaf_max': 0.2, 'sd_baseq_max': 43.86356814697258, 'avg_alt_read_mean_baseq_min': 10.035368269371187, 'mean_ref_mapq_min': 58.866595580902896, 'avg_ref_asxs_min': 19.93636108361037, 'avg_altread_variants_max': 3.129391251843876, 'avg_nonaltread_variants_max': 4.3531580773564595, 'mean_insert_min': 131.02898072665838, 'mean_insert_max': 614.7560717251938, 'sd_insert_max': 286.6664440041853, 'avg_read_position_min': 2.3420814968142953, 'avg_read_position_max': 135.90644753358086, 'avg_read_length_min': 149.05517555242804, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2099354586427856, 'strand_bias_max': 0.7035437541310391, 'rp_sd_min_alt': 3, 'rp_sd_min': 6.5546448071434185}. Best is trial 13 with value: 886.881306196035.
# [I 2026-04-24 16:54:38,433] Trial 16 finished with value: 2470.522547308156 and parameters: {'n_total_min': 21, 'depth_percentile_max': 96, 'mean_inset_qual_min': 27, 'mean_del_anchor_qual_min': 20, 'hp_max_1bp': 3, 'hp_max_long': 13, 'max_slippage_reads': 4, 'asxs_min': 10, 'mean_mapq_min': 50, 'avg_alt_nm_max': 2.046215098186509, 'avg_alt_softclip_max': 4.2513136434340115, 'dist_to_softclip_min': 4, 'variants_20bp_max': 1, 'variants_250bp_max': 1, 'ref_entropy_min': 1.591611702667628, 'gc_min': 0.08148186482488662, 'gc_max': 0.9535866204897052, 'min_dist_to_indel': 189, 'min_rp_med': 0.06502605087017845, 'max_rp_med': 0.9494480969053022, 'max_n_count': 0.8394490984569873, 'germline_vaf_max': 0.2, 'sd_baseq_max': 23.049910577572483, 'avg_alt_read_mean_baseq_min': 46.70583977574302, 'mean_ref_mapq_min': 47.8655523488435, 'avg_ref_asxs_min': 36.786170257606955, 'avg_altread_variants_max': 2.481216662839689, 'avg_nonaltread_variants_max': 4.162449474368668, 'mean_insert_min': 128.9368638148644, 'mean_insert_max': 711.4019843530436, 'sd_insert_max': 533.4543476825426, 'avg_read_position_min': 3.811884446394603, 'avg_read_position_max': 141.02138178058848, 'avg_read_length_min': 122.8462314985072, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.1327697123126238, 'strand_bias_max': 0.8199410651417384, 'rp_sd_min_alt': 6, 'rp_sd_min': 12.880651648203612}. Best is trial 13 with value: 886.881306196035.
# [I 2026-04-24 16:54:38,455] Trial 17 finished with value: 783.8620614083331 and parameters: {'n_total_min': 17, 'depth_percentile_max': 98, 'mean_inset_qual_min': 38, 'mean_del_anchor_qual_min': 24, 'hp_max_1bp': 6, 'hp_max_long': 10, 'max_slippage_reads': 2, 'asxs_min': 19, 'mean_mapq_min': 41, 'avg_alt_nm_max': 0.958122963594153, 'avg_alt_softclip_max': 1.2112164780579597, 'dist_to_softclip_min': 2, 'variants_20bp_max': 1, 'variants_250bp_max': 6, 'ref_entropy_min': 0.5422724310898875, 'gc_min': 0.056259741502691696, 'gc_max': 0.8516927595310532, 'min_dist_to_indel': 9, 'min_rp_med': 0.02908285429562633, 'max_rp_med': 0.928153655275725, 'max_n_count': 2.0621613524452806, 'germline_vaf_max': 0.2, 'sd_baseq_max': 32.35436443668281, 'avg_alt_read_mean_baseq_min': 31.379089663703947, 'mean_ref_mapq_min': 53.08786919527121, 'avg_ref_asxs_min': 30.28592783833295, 'avg_altread_variants_max': 0.838582013089427, 'avg_nonaltread_variants_max': 6.220629376470243, 'mean_insert_min': 96.04758619589762, 'mean_insert_max': 847.282009211284, 'sd_insert_max': 128.93170315021678, 'avg_read_position_min': 0.12716005658313773, 'avg_read_position_max': 143.65498189456721, 'avg_read_length_min': 95.9316684810164, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.19937180514289962, 'strand_bias_max': 0.7314691505326583, 'rp_sd_min_alt': 4, 'rp_sd_min': 9.585607881551327}. Best is trial 17 with value: 783.8620614083331.
# [I 2026-04-24 16:54:38,481] Trial 18 finished with value: 2470.522547308156 and parameters: {'n_total_min': 17, 'depth_percentile_max': 98, 'mean_inset_qual_min': 39, 'mean_del_anchor_qual_min': 24, 'hp_max_1bp': 4, 'hp_max_long': 9, 'max_slippage_reads': 5, 'asxs_min': 23, 'mean_mapq_min': 40, 'avg_alt_nm_max': 1.0616670035171045, 'avg_alt_softclip_max': 1.125637671612471, 'dist_to_softclip_min': 2, 'variants_20bp_max': 1, 'variants_250bp_max': 6, 'ref_entropy_min': 0.617165830906187, 'gc_min': 0.11671896024542795, 'gc_max': 0.8304778158175724, 'min_dist_to_indel': 11, 'min_rp_med': 0.028576947664450358, 'max_rp_med': 0.9265160359024599, 'max_n_count': 1.9474734364071211, 'germline_vaf_max': 0.2, 'sd_baseq_max': 30.045166822649655, 'avg_alt_read_mean_baseq_min': 11.471474442932593, 'mean_ref_mapq_min': 54.507608645208514, 'avg_ref_asxs_min': 40.90385110337667, 'avg_altread_variants_max': 3.8220489266077036, 'avg_nonaltread_variants_max': 6.406968055490214, 'mean_insert_min': 96.99221932024066, 'mean_insert_max': 892.0629604915364, 'sd_insert_max': 794.2392469916322, 'avg_read_position_min': 1.60469888276967, 'avg_read_position_max': 144.90635313063478, 'avg_read_length_min': 92.88106286102585, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2051052584840097, 'strand_bias_max': 0.7590942246313473, 'rp_sd_min_alt': 4, 'rp_sd_min': 9.69649400148656}. Best is trial 17 with value: 783.8620614083331.
# [I 2026-04-24 16:54:38,503] Trial 19 finished with value: 702.7662055663793 and parameters: {'n_total_min': 17, 'depth_percentile_max': 95, 'mean_inset_qual_min': 28, 'mean_del_anchor_qual_min': 23, 'hp_max_1bp': 5, 'hp_max_long': 13, 'max_slippage_reads': 3, 'asxs_min': 32, 'mean_mapq_min': 40, 'avg_alt_nm_max': 0.751114304689394, 'avg_alt_softclip_max': 1.2744775141446294, 'dist_to_softclip_min': 1, 'variants_20bp_max': 1, 'variants_250bp_max': 9, 'ref_entropy_min': 1.1990090989579438, 'gc_min': 0.09175560999411925, 'gc_max': 0.8449175907467917, 'min_dist_to_indel': 96, 'min_rp_med': 0.02255520261626471, 'max_rp_med': 0.9874847811967135, 'max_n_count': 1.1070791718719086, 'germline_vaf_max': 0.2, 'sd_baseq_max': 18.756931613157455, 'avg_alt_read_mean_baseq_min': 46.90130934926883, 'mean_ref_mapq_min': 52.429195367016284, 'avg_ref_asxs_min': 18.322615826777707, 'avg_altread_variants_max': 0.7172226779293837, 'avg_nonaltread_variants_max': 7.282418697747382, 'mean_insert_min': 56.19816476754849, 'mean_insert_max': 866.9474009807735, 'sd_insert_max': 167.44074630969422, 'avg_read_position_min': 0.12535072793112428, 'avg_read_position_max': 143.22603293878262, 'avg_read_length_min': 80.30927632084644, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.2505252450508905, 'strand_bias_max': 0.8055522327095681, 'rp_sd_min_alt': 4, 'rp_sd_min': 13.105105881777108}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,530] Trial 20 finished with value: 2470.522547308156 and parameters: {'n_total_min': 16, 'depth_percentile_max': 95, 'mean_inset_qual_min': 40, 'mean_del_anchor_qual_min': 27, 'hp_max_1bp': 6, 'hp_max_long': 11, 'max_slippage_reads': 2, 'asxs_min': 34, 'mean_mapq_min': 37, 'avg_alt_nm_max': 0.8233462657068903, 'avg_alt_softclip_max': 0.0213282429841839, 'dist_to_softclip_min': 1, 'variants_20bp_max': 1, 'variants_250bp_max': 5, 'ref_entropy_min': 0.8549725500994014, 'gc_min': 0.09492892011882387, 'gc_max': 0.8427486077308279, 'min_dist_to_indel': 80, 'min_rp_med': 0.020220218244272125, 'max_rp_med': 0.9893893020311024, 'max_n_count': 0.8716370118039279, 'germline_vaf_max': 0.2, 'sd_baseq_max': 11.31206271547067, 'avg_alt_read_mean_baseq_min': 47.602145441756875, 'mean_ref_mapq_min': 53.75066012399958, 'avg_ref_asxs_min': 16.373951732448685, 'avg_altread_variants_max': 0.6708347268485219, 'avg_nonaltread_variants_max': 7.825439206908685, 'mean_insert_min': 55.58190417564605, 'mean_insert_max': 883.437654154105, 'sd_insert_max': 149.66347611832686, 'avg_read_position_min': 9.760470169417282, 'avg_read_position_max': 143.26244197110196, 'avg_read_length_min': 80.51728931068158, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.2791440403038815, 'strand_bias_max': 0.7305633060521222, 'rp_sd_min_alt': 4, 'rp_sd_min': 9.888121993313847}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,558] Trial 21 finished with value: 922.5970504053271 and parameters: {'n_total_min': 19, 'depth_percentile_max': 95, 'mean_inset_qual_min': 27, 'mean_del_anchor_qual_min': 22, 'hp_max_1bp': 5, 'hp_max_long': 13, 'max_slippage_reads': 3, 'asxs_min': 26, 'mean_mapq_min': 41, 'avg_alt_nm_max': 0.045004066257051, 'avg_alt_softclip_max': 1.0951723895210606, 'dist_to_softclip_min': 2, 'variants_20bp_max': 2, 'variants_250bp_max': 9, 'ref_entropy_min': 1.3371230066961048, 'gc_min': 0.13378280657440333, 'gc_max': 0.8477208586414382, 'min_dist_to_indel': 143, 'min_rp_med': 0.03398894335403789, 'max_rp_med': 0.9827077968417879, 'max_n_count': 1.0407934186657246, 'germline_vaf_max': 0.2, 'sd_baseq_max': 18.625558502139235, 'avg_alt_read_mean_baseq_min': 49.28091872775069, 'mean_ref_mapq_min': 50.94906757336654, 'avg_ref_asxs_min': 27.07026218927505, 'avg_altread_variants_max': 0.6508515916581733, 'avg_nonaltread_variants_max': 6.5679107288498155, 'mean_insert_min': 55.79078170791158, 'mean_insert_max': 859.646027049236, 'sd_insert_max': 348.5450601825489, 'avg_read_position_min': 0.2333144294176827, 'avg_read_position_max': 146.29970755042297, 'avg_read_length_min': 100.16270656427203, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.24043270984905177, 'strand_bias_max': 0.8080246442041658, 'rp_sd_min_alt': 4, 'rp_sd_min': 13.004377453264789}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,584] Trial 22 finished with value: 2470.522547308156 and parameters: {'n_total_min': 15, 'depth_percentile_max': 96, 'mean_inset_qual_min': 33, 'mean_del_anchor_qual_min': 26, 'hp_max_1bp': 5, 'hp_max_long': 14, 'max_slippage_reads': 4, 'asxs_min': 35, 'mean_mapq_min': 44, 'avg_alt_nm_max': 1.0677534536291469, 'avg_alt_softclip_max': 0.5915368068543025, 'dist_to_softclip_min': 1, 'variants_20bp_max': 1, 'variants_250bp_max': 10, 'ref_entropy_min': 1.1775404013546924, 'gc_min': 0.05922715052852366, 'gc_max': 0.8817374601058287, 'min_dist_to_indel': 0, 'min_rp_med': 0.02334172764801284, 'max_rp_med': 0.9767838790040473, 'max_n_count': 2.087669188690298, 'germline_vaf_max': 0.2, 'sd_baseq_max': 22.549536183519066, 'avg_alt_read_mean_baseq_min': 35.57836198754177, 'mean_ref_mapq_min': 57.69359624092131, 'avg_ref_asxs_min': 19.326145891850352, 'avg_altread_variants_max': 2.1185254888258322, 'avg_nonaltread_variants_max': 7.9053540666255415, 'mean_insert_min': 35.70417659415041, 'mean_insert_max': 789.0329275641149, 'sd_insert_max': 147.6788283510179, 'avg_read_position_min': 1.5286719884231623, 'avg_read_position_max': 142.56282164274893, 'avg_read_length_min': 87.38883996853289, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.18324663120600332, 'strand_bias_max': 0.8910095946011478, 'rp_sd_min_alt': 4, 'rp_sd_min': 13.526298441899574}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,617] Trial 23 finished with value: 969.2636198433925 and parameters: {'n_total_min': 22, 'depth_percentile_max': 95, 'mean_inset_qual_min': 29, 'mean_del_anchor_qual_min': 20, 'hp_max_1bp': 6, 'hp_max_long': 12, 'max_slippage_reads': 3, 'asxs_min': 18, 'mean_mapq_min': 41, 'avg_alt_nm_max': 2.0493852931582266, 'avg_alt_softclip_max': 1.5986322535861934, 'dist_to_softclip_min': 0, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'ref_entropy_min': 1.6767901318844456, 'gc_min': 0.0326634177829271, 'gc_max': 0.8684242964950609, 'min_dist_to_indel': 69, 'min_rp_med': 0.012453583037514945, 'max_rp_med': 0.9772149485563053, 'max_n_count': 1.193331149641931, 'germline_vaf_max': 0.2, 'sd_baseq_max': 12.203936983269681, 'avg_alt_read_mean_baseq_min': 25.695940219663612, 'mean_ref_mapq_min': 40.72038541632848, 'avg_ref_asxs_min': 23.521392273457064, 'avg_altread_variants_max': 0.4376487616407383, 'avg_nonaltread_variants_max': 5.76205085665924, 'mean_insert_min': 92.83617455140573, 'mean_insert_max': 931.8991538716731, 'sd_insert_max': 284.6139786431746, 'avg_read_position_min': 0.06134602838591811, 'avg_read_position_max': 139.5154821556932, 'avg_read_length_min': 103.09884424264456, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.2249077562683746, 'strand_bias_max': 0.8276686955559401, 'rp_sd_min_alt': 3, 'rp_sd_min': 11.46826268655332}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,686] Trial 24 finished with value: 2470.522547308156 and parameters: {'n_total_min': 19, 'depth_percentile_max': 96, 'mean_inset_qual_min': 24, 'mean_del_anchor_qual_min': 23, 'hp_max_1bp': 5, 'hp_max_long': 13, 'max_slippage_reads': 2, 'asxs_min': 26, 'mean_mapq_min': 47, 'avg_alt_nm_max': 0.6841361687099652, 'avg_alt_softclip_max': 2.4414962785857632, 'dist_to_softclip_min': 2, 'variants_20bp_max': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.5351081910106118, 'gc_min': 0.09981197563601686, 'gc_max': 0.8319454808555871, 'min_dist_to_indel': 121, 'min_rp_med': 0.02318208519203002, 'max_rp_med': 0.9352559967769826, 'max_n_count': 0.4769454102304438, 'germline_vaf_max': 0.2, 'sd_baseq_max': 29.978057350490374, 'avg_alt_read_mean_baseq_min': 52.14830915892615, 'mean_ref_mapq_min': 50.39842960645787, 'avg_ref_asxs_min': 15.438603317868981, 'avg_altread_variants_max': 2.8260917447784504, 'avg_nonaltread_variants_max': 4.853082901961333, 'mean_insert_min': 63.593922162092746, 'mean_insert_max': 851.3453040345047, 'sd_insert_max': 480.97227184608784, 'avg_read_position_min': 3.124507173248915, 'avg_read_position_max': 141.96509392064615, 'avg_read_length_min': 81.55902804684968, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2690516057344716, 'strand_bias_max': 0.7785272707396681, 'rp_sd_min_alt': 5, 'rp_sd_min': 13.784212352996008}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,716] Trial 25 finished with value: 2470.522547308156 and parameters: {'n_total_min': 14, 'depth_percentile_max': 97, 'mean_inset_qual_min': 34, 'mean_del_anchor_qual_min': 28, 'hp_max_1bp': 4, 'hp_max_long': 12, 'max_slippage_reads': 3, 'asxs_min': 31, 'mean_mapq_min': 33, 'avg_alt_nm_max': 1.2840809276785798, 'avg_alt_softclip_max': 1.518812062526948, 'dist_to_softclip_min': 3, 'variants_20bp_max': 1, 'variants_250bp_max': 6, 'ref_entropy_min': 0.8962706867281413, 'gc_min': 0.16371253144838785, 'gc_max': 0.85660567306987, 'min_dist_to_indel': 39, 'min_rp_med': 0.03330378543160954, 'max_rp_med': 0.9609445929443663, 'max_n_count': 2.4769666403186976, 'germline_vaf_max': 0.2, 'sd_baseq_max': 18.578476232184727, 'avg_alt_read_mean_baseq_min': 42.73449104124806, 'mean_ref_mapq_min': 37.26610774716141, 'avg_ref_asxs_min': 30.3918601922071, 'avg_altread_variants_max': 1.441582352383539, 'avg_nonaltread_variants_max': 8.610896541285573, 'mean_insert_min': 39.464440064595735, 'mean_insert_max': 915.8438501184253, 'sd_insert_max': 617.3120539673936, 'avg_read_position_min': 1.3300596284566242, 'avg_read_position_max': 138.38419668915776, 'avg_read_length_min': 66.0137505789121, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.22576862075940413, 'strand_bias_max': 0.7907366314093278, 'rp_sd_min_alt': 6, 'rp_sd_min': 12.133382684545147}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,743] Trial 26 finished with value: 2470.522547308156 and parameters: {'n_total_min': 10, 'depth_percentile_max': 95, 'mean_inset_qual_min': 29, 'mean_del_anchor_qual_min': 22, 'hp_max_1bp': 6, 'hp_max_long': 14, 'max_slippage_reads': 4, 'asxs_min': 38, 'mean_mapq_min': 38, 'avg_alt_nm_max': 0.35081761744038165, 'avg_alt_softclip_max': 0.7306102445691391, 'dist_to_softclip_min': 1, 'variants_20bp_max': 0, 'variants_250bp_max': 8, 'ref_entropy_min': 1.466240985090816, 'gc_min': 0.07229128208104854, 'gc_max': 0.8846435361180542, 'min_dist_to_indel': 230, 'min_rp_med': 0.02595655908333993, 'max_rp_med': 0.9277647855365214, 'max_n_count': 1.8325457679476087, 'germline_vaf_max': 0.2, 'sd_baseq_max': 5.653298081912485, 'avg_alt_read_mean_baseq_min': 21.21370727757529, 'mean_ref_mapq_min': 44.79252286733721, 'avg_ref_asxs_min': 37.578120554797245, 'avg_altread_variants_max': 3.7003453447647456, 'avg_nonaltread_variants_max': 7.0628783092265826, 'mean_insert_min': 65.97143898763643, 'mean_insert_max': 752.2057080699749, 'sd_insert_max': 185.751684769731, 'avg_read_position_min': 2.1264497287021817, 'avg_read_position_max': 144.399916531751, 'avg_read_length_min': 118.51792637318087, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.1818814944807291, 'strand_bias_max': 0.8345291314042624, 'rp_sd_min_alt': 4, 'rp_sd_min': 8.964290889417356}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,769] Trial 27 finished with value: 2311.8489461856916 and parameters: {'n_total_min': 17, 'depth_percentile_max': 98, 'mean_inset_qual_min': 20, 'mean_del_anchor_qual_min': 25, 'hp_max_1bp': 3, 'hp_max_long': 9, 'max_slippage_reads': 2, 'asxs_min': 17, 'mean_mapq_min': 42, 'avg_alt_nm_max': 2.1439749737565883, 'avg_alt_softclip_max': 2.7169907992496953, 'dist_to_softclip_min': 2, 'variants_20bp_max': 2, 'variants_250bp_max': 9, 'ref_entropy_min': 1.11376873305438, 'gc_min': 0.09001583055524116, 'gc_max': 0.9360799484384171, 'min_dist_to_indel': 99, 'min_rp_med': 0.045951716925419994, 'max_rp_med': 0.970906969672193, 'max_n_count': 2.5826732365844154, 'germline_vaf_max': 0.2, 'sd_baseq_max': 24.568650437755153, 'avg_alt_read_mean_baseq_min': 28.97558158021364, 'mean_ref_mapq_min': 59.82540671667489, 'avg_ref_asxs_min': 47.17451428324798, 'avg_altread_variants_max': 0.8790646392454138, 'avg_nonaltread_variants_max': 5.975089153901015, 'mean_insert_min': 134.43855947884114, 'mean_insert_max': 805.6838844143815, 'sd_insert_max': 87.13616802154151, 'avg_read_position_min': 0.866643925847348, 'avg_read_position_max': 145.9662186690135, 'avg_read_length_min': 93.48617903229463, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2621215011494092, 'strand_bias_max': 0.8872942984661969, 'rp_sd_min_alt': 5, 'rp_sd_min': 10.507825466078838}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,790] Trial 28 finished with value: 2470.522547308156 and parameters: {'n_total_min': 20, 'depth_percentile_max': 96, 'mean_inset_qual_min': 29, 'mean_del_anchor_qual_min': 32, 'hp_max_1bp': 5, 'hp_max_long': 13, 'max_slippage_reads': 3, 'asxs_min': 26, 'mean_mapq_min': 46, 'avg_alt_nm_max': 1.4635186419969566, 'avg_alt_softclip_max': 0.7329949400504524, 'dist_to_softclip_min': 0, 'variants_20bp_max': 3, 'variants_250bp_max': 6, 'ref_entropy_min': 1.21913293743669, 'gc_min': 0.06284663725827794, 'gc_max': 0.9695531634705843, 'min_dist_to_indel': 143, 'min_rp_med': 0.015726062092647673, 'max_rp_med': 0.9582412820662707, 'max_n_count': 2.1007418570857803, 'germline_vaf_max': 0.2, 'sd_baseq_max': 39.1890624767302, 'avg_alt_read_mean_baseq_min': 53.51892980736321, 'mean_ref_mapq_min': 51.49143154709738, 'avg_ref_asxs_min': 33.28846457977893, 'avg_altread_variants_max': 2.6940441326630022, 'avg_nonaltread_variants_max': 4.462807466817077, 'mean_insert_min': 25.545213563815373, 'mean_insert_max': 843.4258597788294, 'sd_insert_max': 302.19104642517095, 'avg_read_position_min': 3.183661611559742, 'avg_read_position_max': 140.575942958801, 'avg_read_length_min': 102.48825649316694, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.29661170407365633, 'strand_bias_max': 0.7466933158748298, 'rp_sd_min_alt': 3, 'rp_sd_min': 14.88174091687696}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,813] Trial 29 finished with value: 2470.522547308156 and parameters: {'n_total_min': 16, 'depth_percentile_max': 97, 'mean_inset_qual_min': 41, 'mean_del_anchor_qual_min': 42, 'hp_max_1bp': 3, 'hp_max_long': 10, 'max_slippage_reads': 2, 'asxs_min': 20, 'mean_mapq_min': 39, 'avg_alt_nm_max': 3.5376939613365948, 'avg_alt_softclip_max': 1.4316589574475056, 'dist_to_softclip_min': 1, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'ref_entropy_min': 1.7609340281640038, 'gc_min': 0.03736738917885715, 'gc_max': 0.8594106887816425, 'min_dist_to_indel': 41, 'min_rp_med': 0.04346183400048403, 'max_rp_med': 0.9458747528293924, 'max_n_count': 1.8228408919071417, 'germline_vaf_max': 0.2, 'sd_baseq_max': 30.81840599634144, 'avg_alt_read_mean_baseq_min': 0.2015128482173827, 'mean_ref_mapq_min': 56.421393973001145, 'avg_ref_asxs_min': 39.09693504206114, 'avg_altread_variants_max': 0.004793916224969497, 'avg_nonaltread_variants_max': 7.297603400170551, 'mean_insert_min': 100.19803616883542, 'mean_insert_max': 996.4957982843307, 'sd_insert_max': 0.10347968470318847, 'avg_read_position_min': 5.46702035510376, 'avg_read_position_max': 147.47128336107525, 'avg_read_length_min': 64.35763708610807, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.15637654770051895, 'strand_bias_max': 0.8016033863681907, 'rp_sd_min_alt': 4, 'rp_sd_min': 12.160538653618927}. Best is trial 19 with value: 702.7662055663793.
# [I 2026-04-24 16:54:38,839] Trial 30 finished with value: 2470.522547308156 and parameters: {'n_total_min': 18, 'depth_percentile_max': 95, 'mean_inset_qual_min': 25, 'mean_del_anchor_qual_min': 21, 'hp_max_1bp': 6, 'hp_max_long': 11, 'max_slippage_reads': 0, 'asxs_min': 11, 'mean_mapq_min': 50, 'avg_alt_nm_max': 0.9276456550765577, 'avg_alt_softclip_max': 0.4107346305649069, 'dist_to_softclip_min': 2, 'variants_20bp_max': 0, 'variants_250bp_max': 10, 'ref_entropy_min': 0.4391575576635723, 'gc_min': 0.11711248731039389, 'gc_max': 0.8217908564397739, 'min_dist_to_indel': 236, 'min_rp_med': 0.03442265947215603, 'max_rp_med': 0.9376564353994092, 'max_n_count': 0.4262861992429463, 'germline_vaf_max': 0.2, 'sd_baseq_max': 6.8330849459986105, 'avg_alt_read_mean_baseq_min': 11.257016189451702, 'mean_ref_mapq_min': 31.709323714195012, 'avg_ref_asxs_min': 32.68099387812703, 'avg_altread_variants_max': 2.1440386136492, 'avg_nonaltread_variants_max': 5.109675265107274, 'mean_insert_min': 2.2883148357059184, 'mean_insert_max': 745.5716655475542, 'sd_insert_max': 232.91226429346796, 'avg_read_position_min': 4.861057436094491, 'avg_read_position_max': 142.49380936592632, 'avg_read_length_min': 83.65962032720927, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.22958306637511353, 'strand_bias_max': 0.8411249316083846, 'rp_sd_min_alt': 6, 'rp_sd_min': 1.2562987927551141}. Best is trial 19 with value: 702.7662055663793.
# ...
# [I 2026-04-24 17:03:37,897] Trial 2990 finished with value: 996.1524751471035 and parameters: {'n_total_min': 15, 'depth_percentile_max': 97, 'mean_inset_qual_min': 25, 'mean_del_anchor_qual_min': 27, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 12, 'mean_mapq_min': 20, 'avg_alt_nm_max': 4.724118842760594, 'avg_alt_softclip_max': 0.09501461526089894, 'dist_to_softclip_min': 3, 'variants_20bp_max': 4, 'variants_250bp_max': 15, 'ref_entropy_min': 0.37868586102429724, 'gc_min': 0.06400163731395156, 'gc_max': 0.8811253413926584, 'min_dist_to_indel': 9, 'min_rp_med': 0.021481169426656725, 'max_rp_med': 0.9481396716928099, 'max_n_count': 2.3262384029913528, 'germline_vaf_max': 0.2, 'sd_baseq_max': 42.35081794734122, 'avg_alt_read_mean_baseq_min': 46.638025304349334, 'mean_ref_mapq_min': 46.21497093029008, 'avg_ref_asxs_min': 51.72462552000924, 'avg_altread_variants_max': 3.515169914084617, 'avg_nonaltread_variants_max': 9.523455891371052, 'mean_insert_min': 2.071450536822449, 'mean_insert_max': 509.18741916157495, 'sd_insert_max': 750.7643365957601, 'avg_read_position_min': 0.5404538577429608, 'avg_read_position_max': 149.4246180363522, 'avg_read_length_min': 53.474658664168025, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.11381664474167011, 'strand_bias_max': 0.7857841858254798, 'rp_sd_min_alt': 8, 'rp_sd_min': 3.302304276287023}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:38,205] Trial 2991 finished with value: 605.5296781103689 and parameters: {'n_total_min': 16, 'depth_percentile_max': 97, 'mean_inset_qual_min': 20, 'mean_del_anchor_qual_min': 26, 'hp_max_1bp': 5, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 12, 'mean_mapq_min': 20, 'avg_alt_nm_max': 4.835654401193916, 'avg_alt_softclip_max': 0.7250825869942, 'dist_to_softclip_min': 3, 'variants_20bp_max': 4, 'variants_250bp_max': 14, 'ref_entropy_min': 0.4435713297950623, 'gc_min': 0.03738767644790624, 'gc_max': 0.8638813771120203, 'min_dist_to_indel': 23, 'min_rp_med': 0.01894524650405679, 'max_rp_med': 0.9440516429659506, 'max_n_count': 2.179588204407249, 'germline_vaf_max': 0.2, 'sd_baseq_max': 41.20059856195858, 'avg_alt_read_mean_baseq_min': 3.608723612019314, 'mean_ref_mapq_min': 43.844220803066136, 'avg_ref_asxs_min': 54.511785505749046, 'avg_altread_variants_max': 3.6260335774482866, 'avg_nonaltread_variants_max': 9.268774748357034, 'mean_insert_min': 7.982133052275792, 'mean_insert_max': 500.0194736304485, 'sd_insert_max': 718.6513445535077, 'avg_read_position_min': 0.3644940183766269, 'avg_read_position_max': 136.294019474949, 'avg_read_length_min': 55.43420319966575, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.1335966341675329, 'strand_bias_max': 0.778899633240882, 'rp_sd_min_alt': 8, 'rp_sd_min': 2.286465273312132}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:38,582] Trial 2992 finished with value: 483.39600053637366 and parameters: {'n_total_min': 14, 'depth_percentile_max': 97, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 25, 'hp_max_1bp': 4, 'hp_max_long': 11, 'max_slippage_reads': 5, 'asxs_min': 10, 'mean_mapq_min': 21, 'avg_alt_nm_max': 4.629494890095365, 'avg_alt_softclip_max': 0.00418640631187675, 'dist_to_softclip_min': 0, 'variants_20bp_max': 4, 'variants_250bp_max': 12, 'ref_entropy_min': 0.536686607699039, 'gc_min': 0.08090818972324382, 'gc_max': 0.8574456558351199, 'min_dist_to_indel': 9, 'min_rp_med': 0.01713035973299284, 'max_rp_med': 0.9454312521002671, 'max_n_count': 2.2513378132900965, 'germline_vaf_max': 0.2, 'sd_baseq_max': 35.36442010428386, 'avg_alt_read_mean_baseq_min': 3.6102032724883486, 'mean_ref_mapq_min': 45.20540235836151, 'avg_ref_asxs_min': 57.369515336590396, 'avg_altread_variants_max': 3.411038021837378, 'avg_nonaltread_variants_max': 9.742988421147164, 'mean_insert_min': 104.76324904563222, 'mean_insert_max': 552.4253029922867, 'sd_insert_max': 682.4886289230632, 'avg_read_position_min': 0.1816052062131801, 'avg_read_position_max': 149.59680163287516, 'avg_read_length_min': 51.68589436660093, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.12947843426608574, 'strand_bias_max': 0.7921773332253248, 'rp_sd_min_alt': 8, 'rp_sd_min': 2.80363456551399}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:38,938] Trial 2993 finished with value: 2344.394108320605 and parameters: {'n_total_min': 15, 'depth_percentile_max': 97, 'mean_inset_qual_min': 26, 'mean_del_anchor_qual_min': 29, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 11, 'mean_mapq_min': 20, 'avg_alt_nm_max': 4.842314476316387, 'avg_alt_softclip_max': 0.3802480642822168, 'dist_to_softclip_min': 2, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.41677233372976813, 'gc_min': 0.0597906745195044, 'gc_max': 0.8475645255409738, 'min_dist_to_indel': 155, 'min_rp_med': 0.020337361631642268, 'max_rp_med': 0.9468672386062605, 'max_n_count': 2.3734143691704013, 'germline_vaf_max': 0.2, 'sd_baseq_max': 39.90880307831011, 'avg_alt_read_mean_baseq_min': 32.1763157964161, 'mean_ref_mapq_min': 42.98334560969404, 'avg_ref_asxs_min': 50.304674761320285, 'avg_altread_variants_max': 3.5507623355826774, 'avg_nonaltread_variants_max': 9.0619972512977, 'mean_insert_min': 8.074657935058788, 'mean_insert_max': 531.3153617401438, 'sd_insert_max': 742.584813626288, 'avg_read_position_min': 0.8890673856935477, 'avg_read_position_max': 149.0894859553555, 'avg_read_length_min': 58.47532056512939, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.042750087618038, 'strand_bias_max': 0.7981274048212196, 'rp_sd_min_alt': 8, 'rp_sd_min': 1.5136913506076777}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:39,304] Trial 2994 finished with value: 367.8031234557062 and parameters: {'n_total_min': 14, 'depth_percentile_max': 97, 'mean_inset_qual_min': 23, 'mean_del_anchor_qual_min': 23, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 10, 'mean_mapq_min': 21, 'avg_alt_nm_max': 4.729427357230932, 'avg_alt_softclip_max': 0.23218477378457095, 'dist_to_softclip_min': 3, 'variants_20bp_max': 4, 'variants_250bp_max': 15, 'ref_entropy_min': 0.4867289877226573, 'gc_min': 0.05279788803790403, 'gc_max': 0.8670576345637548, 'min_dist_to_indel': 17, 'min_rp_med': 0.02269012045489284, 'max_rp_med': 0.9489702694391626, 'max_n_count': 2.1840186013085603, 'germline_vaf_max': 0.2, 'sd_baseq_max': 37.37325808706233, 'avg_alt_read_mean_baseq_min': 50.51826519881737, 'mean_ref_mapq_min': 44.44307838782786, 'avg_ref_asxs_min': 52.950954236914164, 'avg_altread_variants_max': 2.8879401781671845, 'avg_nonaltread_variants_max': 9.506033295546672, 'mean_insert_min': 2.640401168542761, 'mean_insert_max': 516.0105311630348, 'sd_insert_max': 693.4223580630443, 'avg_read_position_min': 0.1809489350951218, 'avg_read_position_max': 149.49375645400121, 'avg_read_length_min': 52.93980853882105, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.11777023517862502, 'strand_bias_max': 0.7802390868443582, 'rp_sd_min_alt': 8, 'rp_sd_min': 3.930442502276162}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:39,690] Trial 2995 finished with value: 500.88782077939777 and parameters: {'n_total_min': 16, 'depth_percentile_max': 97, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 26, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 13, 'mean_mapq_min': 20, 'avg_alt_nm_max': 4.81988010212054, 'avg_alt_softclip_max': 0.001333178404634025, 'dist_to_softclip_min': 3, 'variants_20bp_max': 0, 'variants_250bp_max': 14, 'ref_entropy_min': 0.5020988075586891, 'gc_min': 0.05627586306025603, 'gc_max': 0.8596112668650553, 'min_dist_to_indel': 0, 'min_rp_med': 0.018752423589431605, 'max_rp_med': 0.9398774242760489, 'max_n_count': 2.2694821857706367, 'germline_vaf_max': 0.2, 'sd_baseq_max': 42.167188470655, 'avg_alt_read_mean_baseq_min': 3.9439248211256186, 'mean_ref_mapq_min': 41.93037856332585, 'avg_ref_asxs_min': 20.859829858122822, 'avg_altread_variants_max': 3.330252453503867, 'avg_nonaltread_variants_max': 9.315683681874546, 'mean_insert_min': 122.13473226405229, 'mean_insert_max': 524.0258828177474, 'sd_insert_max': 703.7842658626224, 'avg_read_position_min': 0.002839538461546746, 'avg_read_position_max': 135.70587293972198, 'avg_read_length_min': 51.73283968296177, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.11810131951770668, 'strand_bias_max': 0.7869514138741693, 'rp_sd_min_alt': 8, 'rp_sd_min': 1.2645637755362202}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:40,036] Trial 2996 finished with value: 263.1402643139378 and parameters: {'n_total_min': 15, 'depth_percentile_max': 97, 'mean_inset_qual_min': 24, 'mean_del_anchor_qual_min': 28, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 12, 'mean_mapq_min': 21, 'avg_alt_nm_max': 4.668461289698231, 'avg_alt_softclip_max': 0.6033829199342622, 'dist_to_softclip_min': 3, 'variants_20bp_max': 4, 'variants_250bp_max': 14, 'ref_entropy_min': 0.544969575486979, 'gc_min': 0.053067551226655234, 'gc_max': 0.8521864552726073, 'min_dist_to_indel': 31, 'min_rp_med': 0.016479734835878015, 'max_rp_med': 0.9435352920444336, 'max_n_count': 2.166951896263592, 'germline_vaf_max': 0.2, 'sd_baseq_max': 40.44912405186588, 'avg_alt_read_mean_baseq_min': 49.796685893037086, 'mean_ref_mapq_min': 46.106887712674904, 'avg_ref_asxs_min': 13.950940802175714, 'avg_altread_variants_max': 2.984723550411739, 'avg_nonaltread_variants_max': 9.092090083377188, 'mean_insert_min': 2.3759577083234245, 'mean_insert_max': 536.0197809743808, 'sd_insert_max': 726.8351241367939, 'avg_read_position_min': 0.0003764254212661653, 'avg_read_position_max': 148.88722842035284, 'avg_read_length_min': 55.08788151260585, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.10277946327323509, 'strand_bias_max': 0.802451838432226, 'rp_sd_min_alt': 8, 'rp_sd_min': 3.1918019072844723}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:40,357] Trial 2997 finished with value: 258.322273868466 and parameters: {'n_total_min': 16, 'depth_percentile_max': 97, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 27, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 11, 'mean_mapq_min': 22, 'avg_alt_nm_max': 4.8533162464395865, 'avg_alt_softclip_max': 0.16831737714188266, 'dist_to_softclip_min': 3, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.46847925963279513, 'gc_min': 0.06960343700838131, 'gc_max': 0.8557152568828004, 'min_dist_to_indel': 10, 'min_rp_med': 0.021353415729082892, 'max_rp_med': 0.9464439526655113, 'max_n_count': 2.309286222853544, 'germline_vaf_max': 0.2, 'sd_baseq_max': 38.6809870841195, 'avg_alt_read_mean_baseq_min': 44.95905705141775, 'mean_ref_mapq_min': 43.60392270333977, 'avg_ref_asxs_min': 54.76162879820269, 'avg_altread_variants_max': 3.9765164554051404, 'avg_nonaltread_variants_max': 8.745877694026262, 'mean_insert_min': 0.3255008627864557, 'mean_insert_max': 509.22189066015005, 'sd_insert_max': 757.2638591003655, 'avg_read_position_min': 0.003894078813493245, 'avg_read_position_max': 147.8246908679291, 'avg_read_length_min': 50.10205600932737, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.10439247267905183, 'strand_bias_max': 0.7923891720357379, 'rp_sd_min_alt': 8, 'rp_sd_min': 1.81351209009633}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:40,672] Trial 2998 finished with value: 573.461707926041 and parameters: {'n_total_min': 14, 'depth_percentile_max': 97, 'mean_inset_qual_min': 20, 'mean_del_anchor_qual_min': 24, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 3, 'asxs_min': 10, 'mean_mapq_min': 20, 'avg_alt_nm_max': 4.544066281776977, 'avg_alt_softclip_max': 2.8927560736947733, 'dist_to_softclip_min': 3, 'variants_20bp_max': 4, 'variants_250bp_max': 15, 'ref_entropy_min': 0.42559857328762557, 'gc_min': 0.06017059565152465, 'gc_max': 0.8716363187697058, 'min_dist_to_indel': 0, 'min_rp_med': 0.01570221625782438, 'max_rp_med': 0.9477695271504948, 'max_n_count': 2.188330325537156, 'germline_vaf_max': 0.2, 'sd_baseq_max': 41.330256175278436, 'avg_alt_read_mean_baseq_min': 47.3865468078313, 'mean_ref_mapq_min': 45.35919916410719, 'avg_ref_asxs_min': 51.63230791751361, 'avg_altread_variants_max': 3.779898415569283, 'avg_nonaltread_variants_max': 9.787866623009238, 'mean_insert_min': 0.3515684410753934, 'mean_insert_max': 517.1558518698217, 'sd_insert_max': 711.9032233097066, 'avg_read_position_min': 0.3414804916798511, 'avg_read_position_max': 149.678555897912, 'avg_read_length_min': 53.477649430310514, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.043011689920325696, 'strand_bias_max': 0.7785835713790564, 'rp_sd_min_alt': 8, 'rp_sd_min': 3.5995154089872363}. Best is trial 2835 with value: 237.878083599613.
# [I 2026-04-24 17:03:40,979] Trial 2999 finished with value: 1298.981074905634 and parameters: {'n_total_min': 15, 'depth_percentile_max': 97, 'mean_inset_qual_min': 25, 'mean_del_anchor_qual_min': 27, 'hp_max_1bp': 3, 'hp_max_long': 11, 'max_slippage_reads': 4, 'asxs_min': 42, 'mean_mapq_min': 21, 'avg_alt_nm_max': 4.729124732529193, 'avg_alt_softclip_max': 0.31626788556131774, 'dist_to_softclip_min': 2, 'variants_20bp_max': 4, 'variants_250bp_max': 14, 'ref_entropy_min': 0.541900452827305, 'gc_min': 0.05037945091029593, 'gc_max': 0.8750230798830166, 'min_dist_to_indel': 22, 'min_rp_med': 0.017939501091575185, 'max_rp_med': 0.9450116979872871, 'max_n_count': 2.2518229629783515, 'germline_vaf_max': 0.2, 'sd_baseq_max': 40.05517724282731, 'avg_alt_read_mean_baseq_min': 2.538739728089392, 'mean_ref_mapq_min': 44.467614451179735, 'avg_ref_asxs_min': 45.38330405295102, 'avg_altread_variants_max': 3.1209248772392644, 'avg_nonaltread_variants_max': 9.57666045155565, 'mean_insert_min': 10.066437486758169, 'mean_insert_max': 543.8901936732947, 'sd_insert_max': 744.9888414240197, 'avg_read_position_min': 0.6340892228328653, 'avg_read_position_max': 148.60451784159415, 'avg_read_length_min': 79.56885234891797, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.004709555900740828, 'strand_bias_max': 0.7875612667395254, 'rp_sd_min_alt': 8, 'rp_sd_min': 2.599203182342632}. Best is trial 2835 with value: 237.878083599613.
# [INFO] Best Weighted Deviance: 237.8781
# [INFO] Generating report...
# ------------------------------
# FINAL RESULTS
# ------------------------------
# Total Samples:         18
# Total Observed Indels: 650
# Total Expected Indels: 1068.43
# Weighted Deviance:     255.6687
# Mean Obs/Exp Ratio:    0.6561
# Blacklist Blocked:     0
# CB PON Blocked:        178
# ------------------------------
# INDEL METRICS (Passing Variants)
# ------------------------------
# Insertions: 154 | Deletions: 496
# INS / DEL Ratio:       0.310
# 1bp Indels: 390 | >1bp Indels: 260
# 1bp / >1bp Ratio:      1.500
# ------------------------------

# %%
def run_diagnostic_waterfall(df: pd.DataFrame):
    print("\n" + "="*40)
    print("   DYNAMIC FILTER WATERFALL DIAGNOSTIC")
    print("="*40)
    
    # 1. Define the absolute most relaxed thresholds from your search space
    t = {
        "n_total_min": 15, "depth_percentile_max": 99,
        "mean_inset_qual_min": 20, "mean_del_anchor_qual_min": 20,
        "hp_max_1bp": 6, "hp_max_long": 15, "max_slippage_reads": 5,
        "asxs_min": 10, "mean_mapq_min": 20, "avg_alt_nm_max": 5.0,
        "avg_alt_softclip_max": 5.0, "dist_to_softclip_min": 0,
        "variants_20bp_max": 4, "variants_250bp_max": 15,
        "ref_entropy_min": 0.0, "gc_min": 0.01, "gc_max": 0.99,
        "min_dist_to_indel": 0, "min_rp_med": 0.01, "max_rp_med": 0.99,
        "max_n_count": 3.0, "germline_vaf_max": 0.35,
        
        # New features (most relaxed limits)
        "sd_baseq_max": 50.0,
        "avg_alt_read_mean_baseq_min": 20.0,
        "mean_ref_mapq_min": 20.0,
        "avg_ref_asxs_min": 10.0,
        "avg_altread_variants_max": 5.0,
        "avg_nonaltread_variants_max": 10.0,
        "mean_insert_min": 0.0,
        "mean_insert_max": 1000.0,
        "sd_insert_max": 800.0,
        "avg_read_position_min": 0.0,
        "avg_read_position_max": 150.0,
        "avg_read_length_min": 50.0,
        
        # Conditional
        "strand_bias_n_alt_min": 10, "strand_bias_min": 0.0, "strand_bias_max": 1.0,
        "rp_sd_min_alt": 10, "rp_sd_min": 0.0
    }

    # 2. Define the exact conditions step-by-step
    is_ins = df['INDEL_LENGTH'] > 0
    is_del = df['INDEL_LENGTH'] < 0
    is_1bp = df['INDEL_LENGTH'].abs() == 1
    is_long = df['INDEL_LENGTH'].abs() > 1
    
    enough_reads_sb = df['N_ALT_SSCS'] >= t['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < t['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > t['strand_bias_max'])
    
    enough_reads_rp = df['N_ALT_SSCS'] >= t['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < t['rp_sd_min']

    steps = [
        ("N_TOTAL", df['N_TOTAL'] >= t['n_total_min']),
        ("DEPTH_PERCENTILE", df['DEPTH_PERCENTILE'] <= t['depth_percentile_max']),
        ("MEAN_MAPQ", df['MEAN_MAPQ'] >= t['mean_mapq_min']),
        ("AVG_ASXS", df['AVG_ASXS'] > t['asxs_min']),
        ("INSET/ANCHOR_QUAL", ((is_ins & (df['MEAN_INSET_QUAL'] >= t['mean_inset_qual_min'])) | 
                               (is_del & (df['MEAN_DEL_ANCHOR_QUAL'] >= t['mean_del_anchor_qual_min'])))),
        ("HOMOPOLYMER", ((is_1bp & (df['HOMOPOLYMER_LEN'] <= t['hp_max_1bp'])) | 
                         (is_long & (df['HOMOPOLYMER_LEN'] <= t['hp_max_long'])))),
        ("SLIPPAGE", df['N_SLIPPAGE_SSCS'] <= t['max_slippage_reads']),
        ("VARIANTS_20BP", df['VARIANTS_20BP'] <= t['variants_20bp_max']),
        ("VARIANTS_250BP", df['VARIANTS_250BP'] <= t['variants_250bp_max']),
        ("REF_ENTROPY", df['REF_ENTROPY_40BP'] >= t['ref_entropy_min']),
        ("ALT_SOFTCLIP", df['AVG_ALT_SOFTCLIP'] <= t['avg_alt_softclip_max']),
        ("DIST_SOFTCLIP", df['MEDIAN_DIST_TO_SOFTCLIP'] >= t['dist_to_softclip_min']),
        ("ALT_EXCESS_NM", df['AVG_ALT_EXCESS_NM'] <= t['avg_alt_nm_max']),
        ("GC_CONTENT", (df['GC_CONTENT'] >= t['gc_min']) & (df['GC_CONTENT'] <= t['gc_max'])),
        ("DIST_OTHER_INDEL", df['DIST_TO_OTHER_INDEL'] >= t['min_dist_to_indel']),
        ("RP_MED", (df['RP_MED_SSCS'] >= t['min_rp_med']) & (df['RP_MED_SSCS'] <= t['max_rp_med'])),
        ("ALT_N_COUNT", df['AVG_ALT_N_COUNT'] <= t['max_n_count']),
        ("GERMLINE_VAF", df['VAF_SSCS'] <= t['germline_vaf_max']),
        
        # NEW FEATURES
        ("SD_BASEQ", df['SD_BASEQ'] <= t['sd_baseq_max']),
        ("AVG_ALT_READ_MEAN_BASEQ", df['AVG_ALT_READ_MEAN_BASEQ'] >= t['avg_alt_read_mean_baseq_min']),
        ("MEAN_REF_MAPQ", df['MEAN_REF_MAPQ'] >= t['mean_ref_mapq_min']),
        ("AVG_REF_ASXS", df['AVG_REF_ASXS'] >= t['avg_ref_asxs_min']),
        ("AVG_ALTREAD_VARIANTS", df['AVG_ALTREAD_VARIANTS'] <= t['avg_altread_variants_max']),
        ("AVG_NONALTREAD_VARIANTS", df['AVG_NONALTREAD_VARIANTS'] <= t['avg_nonaltread_variants_max']),
        ("MEAN_INSERT", (df['MEAN_INSERT'] >= t['mean_insert_min']) & (df['MEAN_INSERT'] <= t['mean_insert_max'])),
        ("SD_INSERT", df['SD_INSERT'] <= t['sd_insert_max']),
        ("AVG_READ_POSITION", (df['AVG_READ_POSITION'] >= t['avg_read_position_min']) & (df['AVG_READ_POSITION'] <= t['avg_read_position_max'])),
        ("AVG_READ_LENGTH", df['AVG_READ_LENGTH'] >= t['avg_read_length_min']),
        
        # CONDITIONAL
        ("STRAND_BIAS", ~(enough_reads_sb & bad_bias)),
        ("RP_SD", ~(enough_reads_rp & bad_rp_sd))
    ]

    # 3. Apply sequentially and print drop-off
    current_mask = pd.Series([True] * len(df), index=df.index)
    print(f"{'FILTER STEP':<30} | {'REMAINING':<10} | {'DROPPED HERE':<10}")
    print("-" * 55)
    
    for name, condition in steps:
        prev_count = current_mask.sum()
        current_mask &= condition
        curr_count = current_mask.sum()
        dropped = prev_count - curr_count
        
        print(f"{name:<30} | {curr_count:<10} | {dropped:<10}")
        
        if curr_count == 0:
            print(f"\n[!] TERMINAL DROP: '{name}' killed all remaining variants.")
            break
            
    print("="*40 + "\n")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------
# Configuration
# -----------------------
CSV_PATH = "training_results_indels/observed_expected.csv"
OUTPUT_PNG = "training_results_indels/train_observed_vs_expected_plot.png"

# Check if file exists
if not os.path.exists(CSV_PATH):
    print(f"[ERROR] Could not find {CSV_PATH}. Please run the optimization cell first.")
else:
    # Load table
    df = pd.read_csv(CSV_PATH)

    # -----------------------
    # Data Processing & Aggregation
    # -----------------------
    # Identify cord blood samples
    is_cord = df['sample_type'].str.lower().str.contains('cord')
    
    df_cord = df[is_cord]
    df_other = df[~is_cord]

    # Calculate rates for non-cord samples
    ages = list(df_other["age"].values)
    obs_rates = list(df_other["observed"].values / df_other["bases"].values)
    exp_rates = list(df_other["expected"].values / df_other["bases"].values)

    # Aggregate cord samples if they exist
    if not df_cord.empty:
        total_cord_obs = df_cord["observed"].sum()
        total_cord_exp = df_cord["expected"].sum()
        total_cord_bases = df_cord["bases"].sum()
        
        # Append the aggregated cord blood point
        ages.append(0.0) # Cord blood is age 0
        obs_rates.append(total_cord_obs / total_cord_bases)
        exp_rates.append(total_cord_exp / total_cord_bases)

    # Convert back to numpy arrays for plotting
    ages = np.array(ages)
    obs_rates = np.array(obs_rates)
    exp_rates = np.array(exp_rates)

    # -----------------------
    # Plotting
    # -----------------------
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot Observed (Blue circles)
    ax.scatter(ages, obs_rates, label="Observed", color="#1f77b4", alpha=0.8, marker="o", s=60, edgecolors='k', linewidth=0.5)

    # Plot Expected (Orange crosses)
    ax.scatter(ages, exp_rates, label="Expected", color="#ff7f0e", alpha=0.8, marker="x", s=60, linewidth=2)

    # Styling
    ax.set_xlabel("Age (years)", fontsize=12)
    ax.set_ylabel("Indel rate (Indels per base)", fontsize=12) # Updated to Indel
    
    ax.set_xlim(-2, 100)
    ax.set_ylim(0, 2e-8)
    
    ax.set_title("Observed vs Expected Indel Rate (Training Set)", fontsize=14) # Updated to Indel
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Legend
    ax.legend(loc='upper left', frameon=True, fontsize=10)

    plt.tight_layout()
    
    # Save and Show
    plt.savefig(OUTPUT_PNG, dpi=150)
    print(f"[INFO] Plot saved to: {OUTPUT_PNG}")
    plt.show()
# Out:
# [INFO] Plot saved to: training_results_indels/train_observed_vs_expected_plot.png
