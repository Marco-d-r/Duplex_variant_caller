# %%
import csv
import gzip
import json
import math
import os
import sys
import random
import bisect
from typing import Dict, Any, List, Tuple

import numpy as np
import pandas as pd
import optuna

# -----------------------
# Configuration / Hardcoded Paths
# -----------------------
SAMPLES_CSV = "training_complete_processed_metadata.csv"
OUT_DIR = "training_results"
BLACKLIST_BED = "../../resources/master_blacklist.bed" 
ARTEFACT_GENES_BED = "../../resources/master_blacklist.bed"
EXOME_BED_PATH = "../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed" 
N_TRIALS = 3000
SEED = 42

# -----------------------
# Constants
# -----------------------
GENOME_SIZE = 6.4e9
R_CORD = 2e-8
EPS = 1e-15
CORD_WEIGHT = 3.0

# Set seeds
random.seed(SEED)
np.random.seed(SEED)

# -----------------------
# Math Helpers
# -----------------------
def poisson_deviance(y_arr: np.ndarray, lam_arr: np.ndarray, weights: np.ndarray = None) -> float:
    y = np.asarray(y_arr, dtype=float)
    lam = np.asarray(lam_arr, dtype=float) + EPS
    
    with np.errstate(divide='ignore', invalid='ignore'):
        log_term = np.log(y / lam)
        term1 = np.where(y > 0, y * log_term, 0.0)
    
    dev = 2.0 * (term1 - (y - lam))
    
    if weights is not None:
        dev = dev * weights
        
    return float(np.sum(dev))

def expected_lambda(sample_type: str, age: float, bases: float) -> float:
    st = sample_type.lower()
    current_age = float(age) if age is not None else 0.0
    
    if "cord" in st:
        rate = R_CORD
    elif "pbmc" in st:
        rate = (16 * current_age + 105) / GENOME_SIZE
    else:
        rate = (22 * current_age + 164) / GENOME_SIZE
        
    return rate * bases

# -----------------------
# BED File Lookup Logic
# -----------------------
class BedLookup:
    def __init__(self, bed_path: str, name: str):
        self.intervals = {} 
        self.name = name
        self._load_bed(bed_path)

    def _load_bed(self, bed_path: str):
        if not os.path.exists(bed_path):
            print(f"[WARN] BED file not found: {bed_path}. {self.name} filter will do nothing.", file=sys.stderr)
            return

        print(f"[INFO] Loading {self.name} from {bed_path}...")
        count = 0
        with open(bed_path, 'r') as f:
            for line in f:
                if line.startswith('#') or not line.strip():
                    continue
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                chrom = parts[0]
                start, end = int(parts[1]), int(parts[2])
                
                if chrom not in self.intervals:
                    self.intervals[chrom] = []
                self.intervals[chrom].append((start, end))
                count += 1
        
        for chrom in self.intervals:
            self.intervals[chrom].sort(key=lambda x: x[0])
        print(f"[INFO] Loaded {count} regions for {self.name}.")

    def is_overlapped(self, chrom: str, pos: int) -> bool:
        if chrom not in self.intervals:
            return False
        
        regions = self.intervals[chrom]
        query_idx = pos - 1 
        
        idx = bisect.bisect_right(regions, (query_idx, float('inf')))
        
        for i in range(max(0, idx - 1), -1, -1):
            start, end = regions[i]
            if end <= query_idx:
                break 
            if start <= query_idx < end:
                return True
        return False

# -----------------------
# VCF Parsing to DataFrame
# -----------------------
def parse_vcf_to_df(vcf_path: str, sample_id: str) -> pd.DataFrame:
    data = []
    
    if not os.path.exists(vcf_path):
        print(f"[WARN] File not found: {vcf_path}", file=sys.stderr)
        return pd.DataFrame()

    openf = gzip.open if vcf_path.endswith(".gz") else open
    
    try:
        with openf(vcf_path, "rt") as fh:
            for line in fh:
                if line.startswith("#"):
                    continue
                fields = line.strip().split("\t")
                
                chrom = fields[0]
                pos = int(fields[1])
                ref = fields[3]  # <--- FIXED: Extract REF from VCF column 4
                alt = fields[4]  # <--- FIXED: Extract ALT from VCF column 5
                
                info_str = fields[7]
                info_dict = {}
                for item in info_str.split(";"):
                    if "=" in item:
                        k, v = item.split("=", 1)
                        info_dict[k] = v
                    else:
                        info_dict[item] = "Yes" 
                
                info_dict["sample_id"] = sample_id
                info_dict["CHROM"] = chrom
                info_dict["POS"] = pos
                info_dict["REF"] = ref  # <--- Added
                info_dict["ALT"] = alt  # <--- Added
                data.append(info_dict)
    except Exception as e:
        print(f"[ERROR] Error reading {vcf_path}: {e}", file=sys.stderr)
        return pd.DataFrame()

    if not data:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    
    # --- Type Conversion ---
    def to_num(col, dtype, default):
        if col in df.columns:
            return pd.to_numeric(df[col], errors='coerce').fillna(default).astype(dtype)
        return pd.Series([default]*len(df), index=df.index, dtype=dtype)

    def to_str(col, default):
        if col in df.columns:
            return df[col].fillna(default)
        return pd.Series([default]*len(df), index=df.index)

    df['CHROM'] = to_str('CHROM', 'chr1')
    df['POS'] = to_num('POS', int, 0)
    df['REF'] = to_str('REF', '') # <--- Added
    df['ALT'] = to_str('ALT', '') # <--- Added

    # 1. Base Counts
    df['N_ALT_SSCS'] = to_num('N_ALT_SSCS', int, 0)
    df['N_TOTAL'] = to_num('N_TOTAL', int, 0)
    df['N_ALT'] = to_num('N_ALT', int, 0) 
    df['N_TOTAL_SSCS'] = to_num('N_TOTAL_SSCS', int, 0)
    df['N_TOTAL_SSCS'] = np.where(df['N_TOTAL_SSCS'] <= 0, df['N_TOTAL'], df['N_TOTAL_SSCS'])

    df['DIST_TO_INDEL'] = to_num('DIST_TO_INDEL', int, -1)
    df['HOMOPOLYMER_LEN'] = to_num('HOMOPOLYMER_LEN', int, 0)
    df['DEPTH_PERCENTILE'] = to_num('DP_PERCENT', int, 50)

    # 2. Integer Metrics
    df['VARIANTS_20BP'] = to_num('VARIANTS_20BP', int, 0)
    df['VARIANTS_250BP'] = to_num('VARIANTS_250BP', int, 0)
    df['MEDIAN_DIST_TO_SOFTCLIP'] = to_num('MEDIAN_DIST_TO_SOFTCLIP', int, 1000)

    # 3. Float Metrics
    df['AVG_ASXS'] = to_num('AVG_ALT_ASXS', float, 0.0) 
    df['MEAN_MAPQ'] = to_num('MEAN_ALT_MAPQ', float, 0.0)
    df['MEAN_REF_MAPQ'] = to_num('MEAN_REF_MAPQ', float, 0.0) 
    df['MEAN_BASEQ'] = to_num('MEAN_ALT_BASEQ', float, 0.0) 
    df['SD_BASEQ'] = to_num('SD_ALT_BASEQ', float, 0.0)
    df['GC_CONTENT'] = to_num('GC_CONTENT', float, 0.5)
    df['STRAND_BIAS_SSCS'] = to_num('STRAND_BIAS_SSCS', float, 0.5)
    df['RP_SD_SSCS'] = to_num('RP_SD_SSCS', float, 0.0)
    df['RP_MED_SSCS'] = to_num('RP_MED_SSCS', float, 0.5)
    df['AVG_ALTREAD_VARIANTS'] = to_num('AVG_ALTREAD_VARIANTS', float, 0.0)
    df['AVG_NONALTREAD_VARIANTS'] = to_num('AVG_NONALTREAD_VARIANTS', float, 0.0)
    df['REF_ENTROPY_40BP'] = to_num('REF_ENTROPY_40BP', float, 2.0)
    df['AVG_ALT_SOFTCLIP'] = to_num('AVG_ALT_SOFTCLIP', float, 0.0)
    df['AVG_ALT_N_COUNT'] = to_num('AVG_ALT_N_COUNT', float, 0.0)
    df['AVG_ALT_NM'] = to_num('AVG_ALT_NM', float, 0.0)
    df['MEAN_INSERT'] = to_num('MEAN_INSERT', float, 200.0)
    df['SD_INSERT'] = to_num('SD_INSERT', float, 0)
    df['AVG_ALT_READ_MEAN_BQ'] = to_num('AVG_ALT_READ_MEAN_BQ', float, 0.0)
    
    # --- ADDED: READ POSITION ---
    df['AVG_READ_POSITION'] = to_num('AVG_READ_POSITION', float, 75.0)
    

    # 4. Flags
    df['IN_CORD_PON'] = to_str('IN_CB_PON', "No")
    df['IN_GNOMAD_COMMON'] = to_str('IN_GNOMAD_COMMON', "No")
    df['IN_ENCODE_BLACKLIST'] = to_str('IN_ENCODE_BLACKLIST', "No")
    df['IN_REPEATMASKER'] = to_str('IN_REPEATMASKER', "No")

    # 5. VAFs
    with np.errstate(divide='ignore', invalid='ignore'):
        df['VAF_DCS'] = df['N_ALT'] / df['N_TOTAL']
        df['VAF_DCS'] = df['VAF_DCS'].fillna(0.0)


    return df

# -----------------------
# Vectorized Filtering
# -----------------------
def get_passing_mask(df: pd.DataFrame, thresholds: Dict[str, Any], pon_flags: Dict[str, bool], ignore_blacklists: bool = False) -> pd.Series:
    # 1. BASELINE HARD FILTERS
    mask = (df['N_ALT_SSCS'] > 0) & \
           (df['IN_ENCODE_BLACKLIST'] != "Yes") & \
           (df['IN_REPEATMASKER'] != "Yes")
            #
    
    # --- ADDED: OxoG / Read Position Hard Filter ---
    # Removes variants too close to the start (<4) or end (>138) of the read
    mask &= (df['AVG_READ_POSITION'] >= 4) & (df['AVG_READ_POSITION'] <= 138)

    if pon_flags.get("use_cord_pon", False):
        mask &= (df['IN_CORD_PON'] != "Yes")

    if not ignore_blacklists:
        mask &= (df['IN_CLUSTER_BLACKLIST'] == False)
        mask &= (df['IN_ARTEFACT_BLACKLIST'] == False)

    # 2. DEPTH
    mask &= (df['N_TOTAL'] >= thresholds['n_total_min'])
    mask &= (df['DEPTH_PERCENTILE'] <= thresholds['depth_percentile_max'])

    # 3. QUALITY METRICS
    mask &= (df['AVG_ASXS'] > thresholds['asxs_min'])
    mask &= (df['MEAN_MAPQ'] >= thresholds['mean_mapq_min'])
    mask &= (df['MEAN_REF_MAPQ'] >= thresholds['mean_ref_mapq_min'])
    mask &= (df['MEAN_BASEQ'] >= thresholds['mean_baseq_min'])
    mask &= (df['SD_BASEQ'] <= thresholds['sd_baseq_max'])

    mask &= ((df['DIST_TO_INDEL'] == -1) | (df['DIST_TO_INDEL'] >= thresholds['dist_to_indel_min']))

    # 4. TUNABLE FILTERS
    mask &= (df['VARIANTS_20BP'] <= thresholds['variants_20bp_max'])
    mask &= (df['VARIANTS_250BP'] <= thresholds['variants_250bp_max'])

    mask &= (df['AVG_ALT_SOFTCLIP'] <= thresholds['avg_alt_softclip_max'])
    mask &= (df['MEDIAN_DIST_TO_SOFTCLIP'] >= thresholds['dist_to_softclip_min'])
    mask &= (df['AVG_ALT_N_COUNT'] <= thresholds['avg_alt_n_count_max'])
    mask &= (df['AVG_ALT_NM'] <= thresholds['avg_alt_nm_max'])
    mask &= (df['MEAN_INSERT'] <= thresholds['mean_insert_max'])
    mask &= (df['SD_INSERT'] <= thresholds['sd_insert_max'])

    # 5. CONTEXT & STRAND

    mask &= (df['HOMOPOLYMER_LEN'] <= thresholds['homopolymer_len_max'])

    # Strand Bias 
    enough_reads_sb = df['N_ALT_SSCS'] >= thresholds['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < thresholds['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > thresholds['strand_bias_max'])
    mask &= ~(enough_reads_sb & bad_bias)

    # RP SD 
    enough_reads_rp = df['N_ALT_SSCS'] >= thresholds['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < thresholds['rp_sd_min']
    mask &= ~(enough_reads_rp & bad_rp_sd)

    # RP MED
    mask &= (df['RP_MED_SSCS'] > thresholds['rp_med_min']) & (df['RP_MED_SSCS'] < thresholds['rp_med_max'])


    
    # 7. GERMLINE & COMMON
    mask &= (df['VAF_DCS'] <= thresholds['germline_vaf_max'])
    high_vaf_gnomad = (df['VAF_DCS'] > thresholds['gnomad_vaf_cutoff'])
    is_common = (df['IN_GNOMAD_COMMON'] == "Yes") 
    mask &= ~(high_vaf_gnomad & is_common)

    return mask

# -----------------------
# Optimization Objective
# -----------------------
def make_objective(all_variants_df: pd.DataFrame, samples_meta: List[Dict]):
    
    expected_lambdas = []
    weights = []
    
    for s in samples_meta:
        expected_lambdas.append(expected_lambda(s['sample_type'], s['age'], s['bases']))
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)
            
    exp_arr = np.array(expected_lambdas)
    weights_arr = np.array(weights)

    def objective(trial):
        thresholds = {
            "germline_vaf_max": trial.suggest_float("germline_vaf_max", 0.20, 0.20),
            "gnomad_vaf_cutoff": trial.suggest_float("gnomad_vaf_cutoff", 0.10, 0.20),
            "depth_percentile_max": trial.suggest_int("depth_percentile_max", 95, 99),
            "variants_20bp_max": trial.suggest_int("variants_20bp_max", 0, 2),
            "variants_250bp_max": trial.suggest_int("variants_250bp_max", 0, 4),
            "avg_alt_softclip_max": trial.suggest_float("avg_alt_softclip_max", 0.0, 2.0),
            "dist_to_softclip_min": trial.suggest_int("dist_to_softclip_min", 0, 5),
            "avg_alt_n_count_max": trial.suggest_float("avg_alt_n_count_max", 0.0, 3.0),
            "avg_alt_nm_max": trial.suggest_float("avg_alt_nm_max", 1.0, 2.5),
            "mean_insert_max": trial.suggest_float("mean_insert_max", 80, 800.0),
            "sd_insert_max": trial.suggest_float("sd_insert_max", 0, 800.0),
            "asxs_min": trial.suggest_int("asxs_min", 10, 60),
            "mean_mapq_min": trial.suggest_int("mean_mapq_min", 50, 60),
            "mean_ref_mapq_min": trial.suggest_int("mean_ref_mapq_min", 10, 60),
            "dist_to_indel_min": trial.suggest_int("dist_to_indel_min", 0, 500),
            "mean_baseq_min": trial.suggest_int("mean_baseq_min", 20, 120),
            "sd_baseq_max": trial.suggest_int("sd_baseq_max", 0, 120),
            "strand_bias_n_alt_min": trial.suggest_int("strand_bias_n_alt_min", 1, 6),
            "strand_bias_min": trial.suggest_float("strand_bias_min", 0.0, 0.3),
            "strand_bias_max": trial.suggest_float("strand_bias_max", 0.7, 1.0),
            "rp_sd_min": trial.suggest_float("rp_sd_min", 0.0, 0.1),
            "rp_sd_min_alt": trial.suggest_int("rp_sd_min_alt", 1, 6),
            "homopolymer_len_max": trial.suggest_int("homopolymer_len_max", 0, 12),
            "n_total_min": trial.suggest_int("n_total_min", 20, 20),
            "rp_med_min": trial.suggest_float("rp_med_min", 0.01, 0.1),
            "rp_med_max": trial.suggest_float("rp_med_max", 0.9, 0.99),
        }

        pon_flags = {"use_cord_pon": True}

        pass_mask = get_passing_mask(all_variants_df, thresholds, pon_flags)
        obs_series = all_variants_df[pass_mask].groupby('sample_id').size()
        obs_arr = np.array([obs_series.get(s['sample_id'], 0) for s in samples_meta])

        loss = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
        return loss

    return objective

# -----------------------
# Reporting
# -----------------------
def evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, outdir):
    os.makedirs(outdir, exist_ok=True)
    
    pass_mask_final = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=False)
    pass_mask_clean = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=True)
    
    variants_saved_by_blacklist = pass_mask_clean & (~pass_mask_final)
    count_saved_by_blacklist = variants_saved_by_blacklist.sum()

    obs_series = all_variants_df[pass_mask_final].groupby('sample_id').size()
    
    observed = []
    expected = []
    ids = []
    ages = []
    bases = []
    types = []
    weights = []

    for s in samples_meta:
        sid = s['sample_id']
        obs = obs_series.get(sid, 0)
        lam = expected_lambda(s['sample_type'], s['age'], s['bases'])
        
        ids.append(sid)
        observed.append(obs)
        expected.append(lam)
        ages.append(s['age'])
        bases.append(s['bases'])
        types.append(s['sample_type'])
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)

    obs_arr = np.array(observed)
    exp_arr = np.array(expected)
    weights_arr = np.array(weights)

    with open(os.path.join(outdir, "best_thresholds.json"), "w") as fh:
        config_out = {
            "thresholds": best_thresholds, 
            "pon_flags": pon_flags,
            "blacklists_enforced": True,
            "cord_penalty_weight": CORD_WEIGHT
        }
        json.dump(config_out, fh, indent=2)

    ratio = obs_arr / (exp_arr + EPS)
    dev = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
    mean_ratio = float(np.mean(ratio))
    
    summary = {
        "n_samples": len(samples_meta),
        "obs_mean_over_expected": mean_ratio,
        "total_observed": int(np.sum(obs_arr)),
        "total_expected": float(np.sum(exp_arr)),
        "weighted_poisson_deviance": dev,
        "variants_blocked_by_blacklists": int(count_saved_by_blacklist)
    }
    with open(os.path.join(outdir, "summary.json"), "w") as fh:
        json.dump(summary, fh, indent=2)

    res_df = pd.DataFrame({
        "sample_id": ids,
        "sample_type": types,
        "age": ages,
        "bases": bases,
        "observed": observed,
        "expected": expected,
        "weight_used": weights 
    })
    res_df.to_csv(os.path.join(outdir, "observed_expected.csv"), index=False)
    
    print("-" * 30)
    print("FINAL RESULTS")
    print("-" * 30)
    print(f"Total Samples:      {len(samples_meta)}")
    print(f"Total Observed SNVs: {int(np.sum(obs_arr))}")
    print(f"Total Expected SNVs: {float(np.sum(exp_arr)):.2f}")
    print(f"Weighted Deviance:  {dev:.4f} (Cord weight = {CORD_WEIGHT}x)")
    print(f"Mean Obs/Exp Ratio: {mean_ratio:.4f}")
    print(f"Blacklist Blocked:  {count_saved_by_blacklist} variants (passed filters but hit blacklist)")
    print(f"Results saved to:   {outdir}")
    print("-" * 30)

# -----------------------
# Execution Block
# -----------------------
if __name__ == "__main__":
    print(f"[INFO] Reading metadata from {SAMPLES_CSV}...")
    samples_meta = []
    with open(SAMPLES_CSV, newline='') as csvfile:
        rdr = csv.DictReader(csvfile)
        for r in rdr:
            samples_meta.append({
                "sample_id": r["sample_id"],
                "vcf_path": r["vcf_path"],
                "sample_type": r["sample_type"].lower(),
                "age": float(r["age"]) if r.get("age") else None,
                "bases": float(r["total_callable_bases_in_wes"]),
            })
    print(f"[INFO] Loaded {len(samples_meta)} samples.")

    print("[INFO] Loading VCFs into DataFrame...")
    df_list = []
    for s in samples_meta:
        df_list.append(parse_vcf_to_df(s["vcf_path"], s["sample_id"]))

    if df_list:
        all_variants_df = pd.concat(df_list, ignore_index=True)
    else:
        print("[ERROR] No VCF data loaded. Checking paths in CSV.")
        all_variants_df = pd.DataFrame()

    print(f"[INFO] Total variants loaded: {len(all_variants_df)}")

    if df_list:
        all_variants_df = pd.concat(df_list, ignore_index=True)
        
        # --- NEW: Deduplication ---
        initial_count = len(all_variants_df)
        all_variants_df = all_variants_df.drop_duplicates(
            subset=['sample_id', 'CHROM', 'POS', 'REF', 'ALT']
        )
        removed_count = initial_count - len(all_variants_df)
        print(f"[INFO] Removed {removed_count} duplicate variants (sharing sample, chrom, pos, ref, alt).")
        # --------------------------
        
    else:
        print("[ERROR] No VCF data loaded. Checking paths in CSV.")
        all_variants_df = pd.DataFrame()

    print(f"[INFO] Total unique variants loaded: {len(all_variants_df)}")



    if not all_variants_df.empty:
        # --- NEW: Exome Inclusion Filter ---
        print("[INFO] Restricting variants to Exome targets...")
        bed_lookup_exome = BedLookup(EXOME_BED_PATH, "Exome Targets")
        
        # Create boolean mask for variants inside the exome
        in_exome_mask = all_variants_df.apply(
            lambda row: bed_lookup_exome.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        # Filter the dataframe to only keep variants in the exome
        pre_filter_count = len(all_variants_df)
        all_variants_df = all_variants_df[in_exome_mask].copy()
        post_filter_count = len(all_variants_df)
        print(f"[INFO] Exome filter retained {post_filter_count} out of {pre_filter_count} variants.")

        if all_variants_df.empty:
            print("[WARN] No variants left after applying Exome filter. Exiting.")
            sys.exit(0)
        # -----------------------------------
        

        # -----------------------------------
        # NEW: Dynamic Cord-Shared Filter (Second PoN Layer)
        # -----------------------------------
        print("[INFO] Applying dynamic Cord-Shared PoN filter...")
        pre_pon_rows = len(all_variants_df)

        # 1. Identify which samples are 'cord'
        cord_samples = {s['sample_id'] for s in samples_meta if 'cord' in s['sample_type'].lower()}
        all_variants_df['is_cord'] = all_variants_df['sample_id'].isin(cord_samples)

        # 2. Group by variant coordinates to find sharing across samples
        # Note: Because we deduplicated by sample_id + variant earlier, size() equals unique sample count.
        variant_cols = ['CHROM', 'POS', 'REF', 'ALT']
        sharing_stats = all_variants_df.groupby(variant_cols).agg(
            num_samples=('sample_id', 'size'),
            has_cord=('is_cord', 'any')
        ).reset_index()

        # 3. Target variants shared by >1 sample WHERE at least 1 is a cord
        variants_to_remove = sharing_stats[
            (sharing_stats['num_samples'] > 1) & (sharing_stats['has_cord'] == True)
        ].copy()

        # 4. Filter the main dataframe efficiently using a combined string key
        if not variants_to_remove.empty:
            all_variants_df['var_key'] = (
                all_variants_df['CHROM'].astype(str) + ":" + 
                all_variants_df['POS'].astype(str) + ":" + 
                all_variants_df['REF'] + ":" + 
                all_variants_df['ALT']
            )
            variants_to_remove['var_key'] = (
                variants_to_remove['CHROM'].astype(str) + ":" + 
                variants_to_remove['POS'].astype(str) + ":" + 
                variants_to_remove['REF'] + ":" + 
                variants_to_remove['ALT']
            )

            bad_keys = set(variants_to_remove['var_key'])
            all_variants_df = all_variants_df[~all_variants_df['var_key'].isin(bad_keys)].copy()
            
            # Clean up temporary columns
            all_variants_df.drop(columns=['var_key', 'is_cord'], inplace=True)
        else:
            all_variants_df.drop(columns=['is_cord'], inplace=True)

        removed_rows = pre_pon_rows - len(all_variants_df)
        unique_variants_removed = len(variants_to_remove)
        print(f"[INFO] Dynamic Cord-Shared PoN removed {removed_rows} rows (representing {unique_variants_removed} unique variants).")
        
        if all_variants_df.empty:
            print("[WARN] No variants left after applying Cord-Shared filter. Exiting.")
            sys.exit(0)
        # -----------------------------------



        bed_lookup_cluster = BedLookup(BLACKLIST_BED, "Cluster Blacklist")
        all_variants_df['IN_CLUSTER_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_cluster.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        bed_lookup_genes = BedLookup(ARTEFACT_GENES_BED, "Artefact Gene Blacklist")
        all_variants_df['IN_ARTEFACT_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_genes.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        hits_cluster = all_variants_df['IN_CLUSTER_BLACKLIST'].sum()
        hits_genes = all_variants_df['IN_ARTEFACT_BLACKLIST'].sum()
        print(f"[INFO] Found {hits_cluster} variants in Cluster blacklist.")
        print(f"[INFO] Found {hits_genes} variants in Artefact Gene blacklist.")

        print(f"[INFO] Starting Optuna (Trials={N_TRIALS})...")
        study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=SEED))
        
        objective = make_objective(all_variants_df, samples_meta)
        study.optimize(objective, n_trials=N_TRIALS)

        print(f"[INFO] Best Weighted Deviance: {study.best_value:.4f}")

        best_params = study.best_params
        best_thresholds = {k: v for k, v in best_params.items()}
        pon_flags = {"use_cord_pon": True}
        
        print("[INFO] Generating report...")
        evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, OUT_DIR)
# Out:
# [INFO] Reading metadata from training_complete_processed_metadata.csv...
# [INFO] Loaded 18 samples.
# [INFO] Loading VCFs into DataFrame...
# [INFO] Total variants loaded: 1154904
# [INFO] Removed 252136 duplicate variants (sharing sample, chrom, pos, ref, alt).
# [INFO] Total unique variants loaded: 902768
# [INFO] Restricting variants to Exome targets...
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Exome filter retained 367853 out of 902768 variants.
# [INFO] Applying dynamic Cord-Shared PoN filter...
# [INFO] Dynamic Cord-Shared PoN removed 209765 rows (representing 22607 unique variants).
# [INFO] Loading Cluster Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Cluster Blacklist.
# [INFO] Loading Artefact Gene Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Artefact Gene Blacklist.
# [I 2026-05-05 18:22:31,432] A new study created in memory with name: no-name-893e2885-6c17-4dc7-a25f-93659735f9cf
# [I 2026-05-05 18:22:31,536] Trial 0 finished with value: 27813.5804683451 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.13745401188473624, 'depth_percentile_max': 99, 'variants_20bp_max': 2, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.31203728088487304, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.17425083650459838, 'avg_alt_nm_max': 2.299264218662403, 'mean_insert_max': 512.8028084551104, 'sd_insert_max': 566.4580622368364, 'asxs_min': 11, 'mean_mapq_min': 60, 'mean_ref_mapq_min': 52, 'dist_to_indel_min': 106, 'mean_baseq_min': 38, 'sd_baseq_max': 22, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.15742692948967135, 'strand_bias_max': 0.8295835055926347, 'rp_sd_min': 0.029122914019804193, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 1, 'n_total_min': 20, 'rp_med_min': 0.03629301836816964, 'rp_med_max': 0.9329725658964323}. Best is trial 0 with value: 27813.5804683451.
# [I 2026-05-05 18:22:31,557] Trial 1 finished with value: 41700.784348701185 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1456069984217036, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.184829137724085, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.822634555704315, 'avg_alt_nm_max': 1.2557861855309373, 'mean_insert_max': 126.83714694940124, 'sd_insert_max': 759.1084298026666, 'asxs_min': 59, 'mean_mapq_min': 58, 'mean_ref_mapq_min': 25, 'dist_to_indel_min': 48, 'mean_baseq_min': 89, 'sd_baseq_max': 53, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.14855307303338106, 'strand_bias_max': 0.7103165563345655, 'rp_sd_min': 0.0909320402078782, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.038053996848046986, 'rp_med_max': 0.946806121906003}. Best is trial 0 with value: 27813.5804683451.
# [I 2026-05-05 18:22:31,579] Trial 2 finished with value: 40333.5599668151 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15467102793432796, 'depth_percentile_max': 95, 'variants_20bp_max': 2, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.8789978831283782, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 1.7936999364332555, 'avg_alt_nm_max': 2.3828113525346755, 'mean_insert_max': 143.71460147738205, 'sd_insert_max': 156.78628993531615, 'asxs_min': 12, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 29, 'dist_to_indel_min': 135, 'mean_baseq_min': 103, 'sd_baseq_max': 43, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.16280882494747453, 'strand_bias_max': 0.7422772674924287, 'rp_sd_min': 0.08021969807540397, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 12, 'n_total_min': 20, 'rp_med_min': 0.07950202923669918, 'rp_med_max': 0.9178844113380755}. Best is trial 0 with value: 27813.5804683451.
# [I 2026-05-05 18:22:31,603] Trial 3 finished with value: 9148.76720134947 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10055221171236024, 'depth_percentile_max': 99, 'variants_20bp_max': 2, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.5425406933718915, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.0753971856328177, 'avg_alt_nm_max': 1.1738035892876946, 'mean_insert_max': 701.4344666304273, 'sd_insert_max': 498.63850146204635, 'asxs_min': 26, 'mean_mapq_min': 50, 'mean_ref_mapq_min': 25, 'dist_to_indel_min': 162, 'mean_baseq_min': 93, 'sd_baseq_max': 77, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.14166447754858477, 'strand_bias_max': 0.7358782737814905, 'rp_sd_min': 0.07132447872229951, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 7, 'n_total_min': 20, 'rp_med_min': 0.0793870461959105, 'rp_med_max': 0.9444416036727952}. Best is trial 3 with value: 9148.76720134947.
# [I 2026-05-05 18:22:31,626] Trial 4 finished with value: 14776.089853374355 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15227328293819942, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 0, 'avg_alt_softclip_max': 0.0628583713734685, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.94306794322898, 'avg_alt_nm_max': 1.762856036747054, 'mean_insert_max': 733.4478612267869, 'sd_insert_max': 199.43378331909994, 'asxs_min': 30, 'mean_mapq_min': 58, 'mean_ref_mapq_min': 21, 'dist_to_indel_min': 38, 'mean_baseq_min': 49, 'sd_baseq_max': 19, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.24243611386932507, 'strand_bias_max': 0.8900211269531271, 'rp_sd_min': 0.08714605901877177, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 2, 'n_total_min': 20, 'rp_med_min': 0.09033030986409801, 'rp_med_max': 0.9485408017724085}. Best is trial 3 with value: 9148.76720134947.
# [INFO] Found 19790 variants in Cluster blacklist.
# [INFO] Found 19790 variants in Artefact Gene blacklist.
# [INFO] Starting Optuna (Trials=3000)...
# [I 2026-05-05 18:22:31,648] Trial 5 finished with value: 36329.871808972974 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18074401551640626, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 0, 'avg_alt_softclip_max': 0.45587032508388337, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.4540442977674792, 'avg_alt_nm_max': 2.2910958748845154, 'mean_insert_max': 85.00553398245731, 'sd_insert_max': 408.59784206205256, 'asxs_min': 31, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 16, 'dist_to_indel_min': 169, 'mean_baseq_min': 115, 'sd_baseq_max': 39, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.21090568766855336, 'strand_bias_max': 0.8090888807137881, 'rp_sd_min': 0.09717820827209607, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 3, 'n_total_min': 20, 'rp_med_min': 0.0547523655303147, 'rp_med_max': 0.9270790478835093}. Best is trial 3 with value: 9148.76720134947.
# [I 2026-05-05 18:22:31,673] Trial 6 finished with value: 28966.33567253097 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12848404943774677, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.1029575024999787, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.724797657899961, 'avg_alt_nm_max': 1.3593428360004587, 'mean_insert_max': 184.32430790568063, 'sd_insert_max': 391.5622082220504, 'asxs_min': 60, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 44, 'dist_to_indel_min': 381, 'mean_baseq_min': 44, 'sd_baseq_max': 88, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.18969174917807383, 'strand_bias_max': 0.8900589132282684, 'rp_sd_min': 0.05357746840747585, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 10, 'n_total_min': 20, 'rp_med_min': 0.03887020584745623, 'rp_med_max': 0.9167866659359869}. Best is trial 3 with value: 9148.76720134947.
# [I 2026-05-05 18:22:31,697] Trial 7 finished with value: 26374.339299425726 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10407751415547639, 'depth_percentile_max': 97, 'variants_20bp_max': 2, 'variants_250bp_max': 0, 'avg_alt_softclip_max': 1.024186116598562, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.9355183712283495, 'avg_alt_nm_max': 1.261549643507487, 'mean_insert_max': 577.4751714337755, 'sd_insert_max': 309.3882770404299, 'asxs_min': 57, 'mean_mapq_min': 51, 'mean_ref_mapq_min': 27, 'dist_to_indel_min': 56, 'mean_baseq_min': 113, 'sd_baseq_max': 106, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.1979952138102537, 'strand_bias_max': 0.9451666600603648, 'rp_sd_min': 0.055520081159946236, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 3, 'n_total_min': 20, 'rp_med_min': 0.018379249102530932, 'rp_med_max': 0.9807494182157994}. Best is trial 3 with value: 9148.76720134947.
# [I 2026-05-05 18:22:31,721] Trial 8 finished with value: 24399.150987711495 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19004180571633306, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 1.4519113577404787, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 2.661259272795352, 'avg_alt_nm_max': 2.169813318786436, 'mean_insert_max': 542.2627852310872, 'sd_insert_max': 67.31197199603906, 'asxs_min': 18, 'mean_mapq_min': 59, 'mean_ref_mapq_min': 40, 'dist_to_indel_min': 4, 'mean_baseq_min': 30, 'sd_baseq_max': 80, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.048242415425249596, 'strand_bias_max': 0.8646201368099758, 'rp_sd_min': 0.06918951976926933, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 2, 'n_total_min': 20, 'rp_med_min': 0.07409612992127823, 'rp_med_max': 0.921352417874712}. Best is trial 3 with value: 9148.76720134947.
# [I 2026-05-05 18:22:31,742] Trial 9 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.13253996981592678, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.3152257846006867, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.2810243034842774, 'avg_alt_nm_max': 1.5515737045891502, 'mean_insert_max': 270.9457047308423, 'sd_insert_max': 195.19171470326685, 'asxs_min': 59, 'mean_mapq_min': 54, 'mean_ref_mapq_min': 55, 'dist_to_indel_min': 316, 'mean_baseq_min': 100, 'sd_baseq_max': 60, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.14775530814565915, 'strand_bias_max': 0.7585728963394133, 'rp_sd_min': 0.07224521152615053, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 0, 'n_total_min': 20, 'rp_med_min': 0.06809250663164511, 'rp_med_max': 0.9159399611466345}. Best is trial 3 with value: 9148.76720134947.
# [I 2026-05-05 18:22:31,777] Trial 10 finished with value: 8796.900512121993 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10205598560835617, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.958446964397519, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.0839359893254275, 'avg_alt_nm_max': 1.0166715772340669, 'mean_insert_max': 777.9054123829483, 'sd_insert_max': 590.7244357800166, 'asxs_min': 44, 'mean_mapq_min': 50, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 471, 'mean_baseq_min': 72, 'sd_baseq_max': 113, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.2976693811011921, 'strand_bias_max': 0.7800973218836108, 'rp_sd_min': 0.0019904621458672125, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 6, 'n_total_min': 20, 'rp_med_min': 0.09937906056417158, 'rp_med_max': 0.9679828812839814}. Best is trial 10 with value: 8796.900512121993.
# [I 2026-05-05 18:22:31,812] Trial 11 finished with value: 8815.908409001211 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10273038925364932, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.980848597493513, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 0.987320782294573, 'avg_alt_nm_max': 1.00368316266819, 'mean_insert_max': 765.9628037678684, 'sd_insert_max': 608.0631490585776, 'asxs_min': 44, 'mean_mapq_min': 50, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 483, 'mean_baseq_min': 70, 'sd_baseq_max': 120, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.28320138910932086, 'strand_bias_max': 0.787305748271183, 'rp_sd_min': 0.012132105324176856, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 6, 'n_total_min': 20, 'rp_med_min': 0.09968329953380133, 'rp_med_max': 0.9684517680124745}. Best is trial 10 with value: 8796.900512121993.
# [I 2026-05-05 18:22:31,847] Trial 12 finished with value: 8926.657707312552 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11448152092599799, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.997396887911177, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 0.9596177207906633, 'avg_alt_nm_max': 1.0131688688555713, 'mean_insert_max': 789.5009076026669, 'sd_insert_max': 682.214228163863, 'asxs_min': 46, 'mean_mapq_min': 56, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 494, 'mean_baseq_min': 68, 'sd_baseq_max': 119, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.28990530394927877, 'strand_bias_max': 0.7885717130002732, 'rp_sd_min': 0.0011095702359131474, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 5, 'n_total_min': 20, 'rp_med_min': 0.09994042396529777, 'rp_med_max': 0.9755606420458248}. Best is trial 10 with value: 8796.900512121993.
# [I 2026-05-05 18:22:31,880] Trial 13 finished with value: 8435.97466318576 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12045919637146965, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.7064179301884357, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.5673313750768353, 'avg_alt_nm_max': 1.8921567296010993, 'mean_insert_max': 644.9709229595474, 'sd_insert_max': 617.1897142028579, 'asxs_min': 44, 'mean_mapq_min': 50, 'mean_ref_mapq_min': 12, 'dist_to_indel_min': 494, 'mean_baseq_min': 71, 'sd_baseq_max': 118, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.2947944851220219, 'strand_bias_max': 0.7795494655255186, 'rp_sd_min': 0.00013993156907811345, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 5, 'n_total_min': 20, 'rp_med_min': 0.09991300811507985, 'rp_med_max': 0.9649719949052561}. Best is trial 13 with value: 8435.97466318576.
# [I 2026-05-05 18:22:31,916] Trial 14 finished with value: 8305.319289229306 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1198384642742607, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.6822391326916075, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.5619198536845298, 'avg_alt_nm_max': 1.9162747946004117, 'mean_insert_max': 634.4937034863195, 'sd_insert_max': 780.673049024691, 'asxs_min': 42, 'mean_mapq_min': 55, 'mean_ref_mapq_min': 17, 'dist_to_indel_min': 408, 'mean_baseq_min': 58, 'sd_baseq_max': 98, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.25530396511168374, 'strand_bias_max': 0.9647526644169369, 'rp_sd_min': 0.023699048168794364, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 5, 'n_total_min': 20, 'rp_med_min': 0.060583639000858724, 'rp_med_max': 0.9612030100798195}. Best is trial 14 with value: 8305.319289229306.
# [I 2026-05-05 18:22:31,953] Trial 15 finished with value: 8529.182520963386 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12052381852415332, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.6631996600960104, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.5177352500141479, 'avg_alt_nm_max': 1.9065558013978772, 'mean_insert_max': 404.7406068476306, 'sd_insert_max': 796.1886372715979, 'asxs_min': 38, 'mean_mapq_min': 56, 'mean_ref_mapq_min': 18, 'dist_to_indel_min': 406, 'mean_baseq_min': 54, 'sd_baseq_max': 98, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.25181509726702633, 'strand_bias_max': 0.966150963007428, 'rp_sd_min': 0.027526413323290953, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 4, 'n_total_min': 20, 'rp_med_min': 0.054127384348592184, 'rp_med_max': 0.9580385940792251}. Best is trial 14 with value: 8305.319289229306.
# [I 2026-05-05 18:22:31,987] Trial 16 finished with value: 7640.696923081277 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16505436497069878, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.8664609059353854, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.5401374651009357, 'avg_alt_nm_max': 1.9997507842816795, 'mean_insert_max': 657.2761987135964, 'sd_insert_max': 698.7409445187034, 'asxs_min': 49, 'mean_mapq_min': 55, 'mean_ref_mapq_min': 35, 'dist_to_indel_min': 236, 'mean_baseq_min': 80, 'sd_baseq_max': 95, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.08691977099741752, 'strand_bias_max': 0.9955623242710819, 'rp_sd_min': 0.025461913149858913, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.013847066207167753, 'rp_med_max': 0.9878138691819991}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,022] Trial 17 finished with value: 17404.69700582885 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16758270730044744, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.6709788412324669, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 1.465280397166845, 'avg_alt_nm_max': 2.0609461152677384, 'mean_insert_max': 430.5895492448609, 'sd_insert_max': 712.2937439572627, 'asxs_min': 51, 'mean_mapq_min': 55, 'mean_ref_mapq_min': 35, 'dist_to_indel_min': 250, 'mean_baseq_min': 85, 'sd_baseq_max': 73, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.09392709316833758, 'strand_bias_max': 0.9855158493680825, 'rp_sd_min': 0.03458718736591925, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.019241394114179022, 'rp_med_max': 0.9876133685164324}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,060] Trial 18 finished with value: 9952.207817466433 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16887545518272618, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 0.7413741050859246, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 0.0611224094807834, 'avg_alt_nm_max': 1.6012986167754444, 'mean_insert_max': 624.1127316476154, 'sd_insert_max': 498.52592829013895, 'asxs_min': 51, 'mean_mapq_min': 56, 'mean_ref_mapq_min': 60, 'dist_to_indel_min': 243, 'mean_baseq_min': 20, 'sd_baseq_max': 94, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.016226868697299737, 'strand_bias_max': 0.9491576126183676, 'rp_sd_min': 0.04216410000853663, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.027885449950498666, 'rp_med_max': 0.9015945548947378}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,096] Trial 19 finished with value: 17826.849073440702 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16525797370379403, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.8253615776907927, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.5767535228801897, 'avg_alt_nm_max': 2.049223750116557, 'mean_insert_max': 329.59991527880646, 'sd_insert_max': 681.2919717569159, 'asxs_min': 37, 'mean_mapq_min': 54, 'mean_ref_mapq_min': 33, 'dist_to_indel_min': 310, 'mean_baseq_min': 62, 'sd_baseq_max': 102, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.08573010603432496, 'strand_bias_max': 0.9158161329354774, 'rp_sd_min': 0.019361228131815775, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.01172455389349551, 'rp_med_max': 0.9899324165020185}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,132] Trial 20 finished with value: 9567.375795430757 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19496899034333626, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.0177483484349106, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.4229640239599215, 'avg_alt_nm_max': 1.6310306479707612, 'mean_insert_max': 632.3235044244333, 'sd_insert_max': 793.941852695208, 'asxs_min': 52, 'mean_mapq_min': 57, 'mean_ref_mapq_min': 45, 'dist_to_indel_min': 309, 'mean_baseq_min': 81, 'sd_baseq_max': 5, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.10290129497092915, 'strand_bias_max': 0.9978221440423888, 'rp_sd_min': 0.016562415502713514, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 10, 'n_total_min': 20, 'rp_med_min': 0.0639683118369706, 'rp_med_max': 0.9584418539479878}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,167] Trial 21 finished with value: 8022.305549201725 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11441725576014747, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.7133564697230854, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.6152998760985781, 'avg_alt_nm_max': 1.8434157924794055, 'mean_insert_max': 665.8141680208481, 'sd_insert_max': 657.3417967761625, 'asxs_min': 41, 'mean_mapq_min': 54, 'mean_ref_mapq_min': 16, 'dist_to_indel_min': 422, 'mean_baseq_min': 58, 'sd_baseq_max': 107, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.2519838267171327, 'strand_bias_max': 0.9204796992511609, 'rp_sd_min': 0.00994951922791185, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 7, 'n_total_min': 20, 'rp_med_min': 0.04429220584471029, 'rp_med_max': 0.962412316028116}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,203] Trial 22 finished with value: 7895.977768688148 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1414711370195164, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.2544966281313683, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.7304311983298193, 'avg_alt_nm_max': 1.8436718479809973, 'mean_insert_max': 708.119589022006, 'sd_insert_max': 721.5870300969644, 'asxs_min': 40, 'mean_mapq_min': 54, 'mean_ref_mapq_min': 20, 'dist_to_indel_min': 428, 'mean_baseq_min': 58, 'sd_baseq_max': 87, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.2344297660695417, 'strand_bias_max': 0.9253796160927676, 'rp_sd_min': 0.012629813569943518, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 7, 'n_total_min': 20, 'rp_med_min': 0.049208287344330165, 'rp_med_max': 0.9808874912888864}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,237] Trial 23 finished with value: 19168.29394008373 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1430584376663066, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.2649112935070193, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 0.3776835226635957, 'avg_alt_nm_max': 1.7631111084053466, 'mean_insert_max': 683.1134941209356, 'sd_insert_max': 676.6993937391865, 'asxs_min': 40, 'mean_mapq_min': 54, 'mean_ref_mapq_min': 21, 'dist_to_indel_min': 372, 'mean_baseq_min': 77, 'sd_baseq_max': 85, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.21051719758303047, 'strand_bias_max': 0.9223742050551328, 'rp_sd_min': 0.011103788840617454, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.049338182094371075, 'rp_med_max': 0.9778317492994845}. Best is trial 16 with value: 7640.696923081277.
# [I 2026-05-05 18:22:32,272] Trial 24 finished with value: 6908.78388570787 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1585701487308861, 'depth_percentile_max': 97, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.887942278399713, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.7482655265811852, 'avg_alt_nm_max': 2.048112743748496, 'mean_insert_max': 492.8835474463084, 'sd_insert_max': 518.0126498133423, 'asxs_min': 34, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 31, 'dist_to_indel_min': 202, 'mean_baseq_min': 62, 'sd_baseq_max': 65, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.11615095923009006, 'strand_bias_max': 0.9115921267614637, 'rp_sd_min': 0.03712437645477331, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 7, 'n_total_min': 20, 'rp_med_min': 0.046127066231137534, 'rp_med_max': 0.9817029425126981}. Best is trial 24 with value: 6908.78388570787.
# [I 2026-05-05 18:22:32,307] Trial 25 finished with value: 7474.793984152759 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15842355596863247, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.8719247887377193, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.740100309506498, 'avg_alt_nm_max': 2.068828875303295, 'mean_insert_max': 527.9503362987068, 'sd_insert_max': 527.3373246026106, 'asxs_min': 33, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 31, 'dist_to_indel_min': 210, 'mean_baseq_min': 41, 'sd_baseq_max': 68, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.12005739282924233, 'strand_bias_max': 0.8728505112430718, 'rp_sd_min': 0.04232196698773016, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.030166956380720353, 'rp_med_max': 0.9827246473184018}. Best is trial 24 with value: 6908.78388570787.
# [I 2026-05-05 18:22:32,340] Trial 26 finished with value: 18882.045038673998 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1589900157606059, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.5394963586989576, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.301081336776058, 'avg_alt_nm_max': 2.068634639673291, 'mean_insert_max': 492.068550682699, 'sd_insert_max': 496.80400161210116, 'asxs_min': 33, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 35, 'dist_to_indel_min': 214, 'mean_baseq_min': 36, 'sd_baseq_max': 67, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.1201607585066631, 'strand_bias_max': 0.8454675374709589, 'rp_sd_min': 0.04307993229098816, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.027693336665451908, 'rp_med_max': 0.9727883994512222}. Best is trial 24 with value: 6908.78388570787.
# [I 2026-05-05 18:22:32,376] Trial 27 finished with value: 6397.713481867055 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17675134804388512, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.879596777251893, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.2200579624710703, 'avg_alt_nm_max': 2.4942771050973387, 'mean_insert_max': 465.609288093231, 'sd_insert_max': 393.36326824704156, 'asxs_min': 25, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 31, 'dist_to_indel_min': 207, 'mean_baseq_min': 46, 'sd_baseq_max': 52, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.06193850346730813, 'strand_bias_max': 0.8844742830131073, 'rp_sd_min': 0.04182590131365904, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.027750789252333513, 'rp_med_max': 0.9852703228254663}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,410] Trial 28 finished with value: 6885.443575764157 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17977530870341285, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 1.0911655579182447, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.6468069035896447, 'avg_alt_nm_max': 2.2327875332535827, 'mean_insert_max': 352.6485689777679, 'sd_insert_max': 371.6824497871206, 'asxs_min': 24, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 41, 'dist_to_indel_min': 184, 'mean_baseq_min': 27, 'sd_baseq_max': 56, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.05755767508039572, 'strand_bias_max': 0.8712948699567953, 'rp_sd_min': 0.04548834188033821, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.02723687371514088, 'rp_med_max': 0.9835931897293616}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,446] Trial 29 finished with value: 7570.529517175251 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18099784412536252, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 1.0485107127954538, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.0221573150476173, 'avg_alt_nm_max': 2.449177321853304, 'mean_insert_max': 373.30697391080446, 'sd_insert_max': 380.1674669711675, 'asxs_min': 24, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 39, 'dist_to_indel_min': 113, 'mean_baseq_min': 27, 'sd_baseq_max': 45, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.05752874681265192, 'strand_bias_max': 0.8347139236948308, 'rp_sd_min': 0.061002261338968904, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 10, 'n_total_min': 20, 'rp_med_min': 0.03257893112082178, 'rp_med_max': 0.9372428772453043}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,481] Trial 30 finished with value: 7358.215295570635 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17782186723228732, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 0.29289806200623025, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.2634315407332664, 'avg_alt_nm_max': 2.2397299499897345, 'mean_insert_max': 462.3163916416572, 'sd_insert_max': 282.3511470077468, 'asxs_min': 21, 'mean_mapq_min': 51, 'mean_ref_mapq_min': 49, 'dist_to_indel_min': 191, 'mean_baseq_min': 33, 'sd_baseq_max': 31, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.01116983868686456, 'strand_bias_max': 0.8901798007140413, 'rp_sd_min': 0.03502509429630489, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 12, 'n_total_min': 20, 'rp_med_min': 0.023655496484287598, 'rp_med_max': 0.9711582539314599}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,517] Trial 31 finished with value: 7317.656229567439 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1754783614326315, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 0.26550556765581096, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.6546032157187585, 'avg_alt_nm_max': 2.234520727423462, 'mean_insert_max': 478.203465290147, 'sd_insert_max': 284.6023133979901, 'asxs_min': 23, 'mean_mapq_min': 51, 'mean_ref_mapq_min': 49, 'dist_to_indel_min': 190, 'mean_baseq_min': 31, 'sd_baseq_max': 29, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.004106977345026083, 'strand_bias_max': 0.8915987548561266, 'rp_sd_min': 0.03653115103584649, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 12, 'n_total_min': 20, 'rp_med_min': 0.022241209541421385, 'rp_med_max': 0.9725032065346757}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,552] Trial 32 finished with value: 6993.313683148443 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18672112556276452, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 0.2977144896954427, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.6674687641915105, 'avg_alt_nm_max': 2.493542276787175, 'mean_insert_max': 308.3074961825576, 'sd_insert_max': 312.7960695427997, 'asxs_min': 16, 'mean_mapq_min': 51, 'mean_ref_mapq_min': 39, 'dist_to_indel_min': 272, 'mean_baseq_min': 22, 'sd_baseq_max': 55, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.043192373335507704, 'strand_bias_max': 0.8726426600325824, 'rp_sd_min': 0.03477805777379548, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.03730941127234643, 'rp_med_max': 0.9835492816047909}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,588] Trial 33 finished with value: 6758.074583398301 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1904235628867688, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.57112673846525, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.2531948809726763, 'avg_alt_nm_max': 2.4365904766460553, 'mean_insert_max': 264.24430657564324, 'sd_insert_max': 450.4428788049188, 'asxs_min': 13, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 39, 'dist_to_indel_min': 288, 'mean_baseq_min': 21, 'sd_baseq_max': 57, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.040974723483546485, 'strand_bias_max': 0.8623114060212617, 'rp_sd_min': 0.04837420526438822, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.03916471819805191, 'rp_med_max': 0.982609850154698}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,623] Trial 34 finished with value: 7649.079888678886 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19526612872872118, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.6005006162237746, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.292695501569434, 'avg_alt_nm_max': 2.378459693347412, 'mean_insert_max': 222.9388081840832, 'sd_insert_max': 447.01558332981585, 'asxs_min': 14, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 41, 'dist_to_indel_min': 130, 'mean_baseq_min': 48, 'sd_baseq_max': 51, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.06800428898929156, 'strand_bias_max': 0.8140627002388539, 'rp_sd_min': 0.048590098180010664, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.04319925971669128, 'rp_med_max': 0.9771446612890768}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,658] Trial 35 finished with value: 6577.399310406676 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18757750337402893, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.114677845863563, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.2568362077249815, 'avg_alt_nm_max': 2.402707503189068, 'mean_insert_max': 368.3729522097259, 'sd_insert_max': 448.090704941346, 'asxs_min': 10, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 29, 'dist_to_indel_min': 154, 'mean_baseq_min': 39, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.03167722015223329, 'strand_bias_max': 0.8578706266614331, 'rp_sd_min': 0.060793421366130945, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.0330014048973522, 'rp_med_max': 0.9854682807428335}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,693] Trial 36 finished with value: 6816.9346208863335 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1869702158458826, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.1202396904020824, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.1416203007917696, 'avg_alt_nm_max': 2.3832573013379013, 'mean_insert_max': 358.63037205739255, 'sd_insert_max': 345.9837605412255, 'asxs_min': 11, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 25, 'dist_to_indel_min': 79, 'mean_baseq_min': 25, 'sd_baseq_max': 52, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.026538289839477182, 'strand_bias_max': 0.8541005189134294, 'rp_sd_min': 0.06296276954362176, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 10, 'n_total_min': 20, 'rp_med_min': 0.0346572107621851, 'rp_med_max': 0.952067297916174}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,727] Trial 37 finished with value: 7191.909719288464 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19972001339936976, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.155308318797356, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.2564376654516825, 'avg_alt_nm_max': 2.37641008139353, 'mean_insert_max': 266.0874607998725, 'sd_insert_max': 433.9182136432417, 'asxs_min': 10, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 26, 'dist_to_indel_min': 93, 'mean_baseq_min': 39, 'sd_baseq_max': 45, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.03189513221844245, 'strand_bias_max': 0.849652484497209, 'rp_sd_min': 0.06286972147364535, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.034506245172519635, 'rp_med_max': 0.9542440833086341}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,762] Trial 38 finished with value: 7438.6645244656465 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1884310507210415, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.3937320548459704, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.1721138375417635, 'avg_alt_nm_max': 2.336077367241839, 'mean_insert_max': 397.57605270372, 'sd_insert_max': 331.3697819543539, 'asxs_min': 13, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 29, 'dist_to_indel_min': 149, 'mean_baseq_min': 45, 'sd_baseq_max': 37, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.03006567812954848, 'strand_bias_max': 0.8268184127650645, 'rp_sd_min': 0.08084965031303114, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 12, 'n_total_min': 20, 'rp_med_min': 0.040625936946650607, 'rp_med_max': 0.9370569569389995}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,795] Trial 39 finished with value: 33726.73872286054 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17300916543247896, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.502099587213384, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.4856820455899296, 'avg_alt_nm_max': 2.442922903397188, 'mean_insert_max': 164.74685773794994, 'sd_insert_max': 437.1144721813822, 'asxs_min': 19, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 37, 'dist_to_indel_min': 82, 'mean_baseq_min': 24, 'sd_baseq_max': 50, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.02723501423955279, 'strand_bias_max': 0.860557584983826, 'rp_sd_min': 0.05633372650687588, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 10, 'n_total_min': 20, 'rp_med_min': 0.03476647475639388, 'rp_med_max': 0.9080505383651197}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,828] Trial 40 finished with value: 25066.786526544434 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18605880979758682, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.7480311218090553, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 0.8749447330004353, 'avg_alt_nm_max': 2.178293129269113, 'mean_insert_max': 259.3303269316036, 'sd_insert_max': 260.11218308653247, 'asxs_min': 28, 'mean_mapq_min': 51, 'mean_ref_mapq_min': 24, 'dist_to_indel_min': 58, 'mean_baseq_min': 35, 'sd_baseq_max': 15, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.06368499425498877, 'strand_bias_max': 0.8072335286510732, 'rp_sd_min': 0.07567494572010669, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 10, 'n_total_min': 20, 'rp_med_min': 0.01852085283119795, 'rp_med_max': 0.9502418199720389}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,863] Trial 41 finished with value: 6527.386235487305 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18239392822790718, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.143070273621249, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.6703078055929097, 'avg_alt_nm_max': 2.487836980772983, 'mean_insert_max': 331.1276955023121, 'sd_insert_max': 359.0401101525589, 'asxs_min': 15, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 43, 'dist_to_indel_min': 171, 'mean_baseq_min': 29, 'sd_baseq_max': 59, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.06839419961580952, 'strand_bias_max': 0.9015292308501046, 'rp_sd_min': 0.04843572396120222, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.02451972645264433, 'rp_med_max': 0.9858034897438378}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,899] Trial 42 finished with value: 6502.683352867882 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19242008495495333, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.959721199839586, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.8733781214896386, 'avg_alt_nm_max': 2.495974700743965, 'mean_insert_max': 318.99031314179825, 'sd_insert_max': 358.4706565097589, 'asxs_min': 10, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 44, 'dist_to_indel_min': 159, 'mean_baseq_min': 28, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.07648121554350581, 'strand_bias_max': 0.9031798033389602, 'rp_sd_min': 0.06369016359414295, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.02387234457113279, 'rp_med_max': 0.9864100427537533}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,935] Trial 43 finished with value: 6773.703885689444 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19261678290104173, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.9303409654376833, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.1491805222029585, 'avg_alt_nm_max': 2.4900852493115155, 'mean_insert_max': 306.0732220628505, 'sd_insert_max': 465.13005644434384, 'asxs_min': 16, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 44, 'dist_to_indel_min': 165, 'mean_baseq_min': 42, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.06873140569262465, 'strand_bias_max': 0.9059290156638398, 'rp_sd_min': 0.05139224768065154, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.023588778456908592, 'rp_med_max': 0.9863974463900584}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:32,968] Trial 44 finished with value: 25071.5493468957 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19902356350379724, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.4222019683737859, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.8430414000182798, 'avg_alt_nm_max': 2.3049004971948053, 'mean_insert_max': 198.35354979213074, 'sd_insert_max': 408.19409073633665, 'asxs_min': 15, 'mean_mapq_min': 51, 'mean_ref_mapq_min': 47, 'dist_to_indel_min': 278, 'mean_baseq_min': 30, 'sd_baseq_max': 75, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.045693329896268585, 'strand_bias_max': 0.9019394861891399, 'rp_sd_min': 0.058707454478625534, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.016468915674896677, 'rp_med_max': 0.9775688126846218}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:33,007] Trial 45 finished with value: 6747.242281727602 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17300919392731304, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.9371272833418592, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.7183090121864595, 'avg_alt_nm_max': 2.4399574492227973, 'mean_insert_max': 427.68665724353417, 'sd_insert_max': 238.51874639232068, 'asxs_min': 19, 'mean_mapq_min': 60, 'mean_ref_mapq_min': 44, 'dist_to_indel_min': 131, 'mean_baseq_min': 52, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.07639976261847706, 'strand_bias_max': 0.8811303761173443, 'rp_sd_min': 0.06690610262502558, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.010501059711717426, 'rp_med_max': 0.9893808883595813}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:33,044] Trial 46 finished with value: 6779.584557420432 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1827859857313651, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.197523722820655, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.8058267087055135, 'avg_alt_nm_max': 2.3063410176737142, 'mean_insert_max': 403.5840087872018, 'sd_insert_max': 235.5022415364439, 'asxs_min': 19, 'mean_mapq_min': 60, 'mean_ref_mapq_min': 53, 'dist_to_indel_min': 119, 'mean_baseq_min': 50, 'sd_baseq_max': 63, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.08111064593827078, 'strand_bias_max': 0.701830102855327, 'rp_sd_min': 0.06799862417678329, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.014522392619053935, 'rp_med_max': 0.9889968852840827}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:33,079] Trial 47 finished with value: 6976.827973882258 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1731047639545789, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 0.9623560766273398, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.4102662917846587, 'avg_alt_nm_max': 2.389845413269392, 'mean_insert_max': 442.82076616228085, 'sd_insert_max': 142.60440114688902, 'asxs_min': 21, 'mean_mapq_min': 58, 'mean_ref_mapq_min': 46, 'dist_to_indel_min': 142, 'mean_baseq_min': 51, 'sd_baseq_max': 70, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.1044416576623778, 'strand_bias_max': 0.9368958428383567, 'rp_sd_min': 0.08753596195299213, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 7, 'n_total_min': 20, 'rp_med_min': 0.01030817655584075, 'rp_med_max': 0.9859661128293917}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:33,113] Trial 48 finished with value: 30447.802977285028 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1503312499913147, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 1.5142282472334574, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.01647211881726, 'avg_alt_nm_max': 2.154144920036278, 'mean_insert_max': 99.99281960816307, 'sd_insert_max': 119.32358095885648, 'asxs_min': 10, 'mean_mapq_min': 60, 'mean_ref_mapq_min': 56, 'dist_to_indel_min': 17, 'mean_baseq_min': 46, 'sd_baseq_max': 47, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.14041475364165396, 'strand_bias_max': 0.8821005441363619, 'rp_sd_min': 0.06690782455866252, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 6, 'n_total_min': 20, 'rp_med_min': 0.021787469122313333, 'rp_med_max': 0.9685483071950463}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:33,149] Trial 49 finished with value: 6468.890063384022 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1832927531806442, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.376905832975224, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.6366307728112062, 'avg_alt_nm_max': 2.4723518438891374, 'mean_insert_max': 320.15949083203554, 'sd_insert_max': 222.43268726767417, 'asxs_min': 17, 'mean_mapq_min': 59, 'mean_ref_mapq_min': 43, 'dist_to_indel_min': 164, 'mean_baseq_min': 39, 'sd_baseq_max': 82, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.15979954662193366, 'strand_bias_max': 0.8987836900098107, 'rp_sd_min': 0.05629255846897846, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.030057477578868546, 'rp_med_max': 0.9746240301717298}. Best is trial 27 with value: 6397.713481867055.
# [I 2026-05-05 18:22:33,184] Trial 50 finished with value: 9281.675225893676 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1825391950223531, 'depth_percentile_max': 99, 'variants_20bp_max': 0, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.3001107810081889, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.5146026272858593, 'avg_alt_nm_max': 1.427443062683775, 'mean_insert_max': 309.3690821585418, 'sd_insert_max': 21.284329324757408, 'asxs_min': 16, 'mean_mapq_min': 59, 'mean_ref_mapq_min': 42, 'dist_to_indel_min': 176, 'mean_baseq_min': 38, 'sd_baseq_max': 82, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.13599301758555005, 'strand_bias_max': 0.9347191984283806, 'rp_sd_min': 0.07520906358904561, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 9, 'n_total_min': 20, 'rp_med_min': 0.030287505603885365, 'rp_med_max': 0.9738884548157558}. Best is trial 27 with value: 6397.713481867055.
# ...
# [I 2026-05-05 18:26:43,499] Trial 2984 finished with value: 5544.32638236988 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12038362341452179, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.967004262721595, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.2526908746275844, 'avg_alt_nm_max': 2.3856834834520075, 'mean_insert_max': 666.3938923149618, 'sd_insert_max': 291.75551863351075, 'asxs_min': 10, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 13, 'dist_to_indel_min': 73, 'mean_baseq_min': 71, 'sd_baseq_max': 89, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.18370459506866016, 'strand_bias_max': 0.7825650821907705, 'rp_sd_min': 0.005099930804342529, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.011655353870779563, 'rp_med_max': 0.9406165984422932}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:43,633] Trial 2985 finished with value: 5570.201630145213 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11402982175722537, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.6070293101166836, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.3304869899758858, 'avg_alt_nm_max': 2.331247397350245, 'mean_insert_max': 689.7279566187992, 'sd_insert_max': 261.8137887641438, 'asxs_min': 12, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 14, 'dist_to_indel_min': 63, 'mean_baseq_min': 74, 'sd_baseq_max': 85, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.10197747975351158, 'strand_bias_max': 0.7902097615548029, 'rp_sd_min': 0.003567303590900144, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.010001903759888053, 'rp_med_max': 0.9872553228829104}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:43,766] Trial 2986 finished with value: 5197.870356773417 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11638085423173557, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.6436975033005001, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.2775095775053344, 'avg_alt_nm_max': 2.298080137230963, 'mean_insert_max': 716.1039442259114, 'sd_insert_max': 276.1662615054803, 'asxs_min': 11, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 12, 'dist_to_indel_min': 84, 'mean_baseq_min': 71, 'sd_baseq_max': 96, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10781582810267429, 'strand_bias_max': 0.7942532189030874, 'rp_sd_min': 0.005266370739992931, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.012909833481197364, 'rp_med_max': 0.9881418412691472}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:43,902] Trial 2987 finished with value: 5646.216180372172 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12092689124270112, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.7152647570165561, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.3525067467189675, 'avg_alt_nm_max': 2.3533771261408902, 'mean_insert_max': 697.4910502705367, 'sd_insert_max': 229.00428057107274, 'asxs_min': 12, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 74, 'mean_baseq_min': 114, 'sd_baseq_max': 87, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.09650603538971902, 'strand_bias_max': 0.78378846639974, 'rp_sd_min': 0.002265355441205121, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.014333597777093617, 'rp_med_max': 0.9882704522937111}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,046] Trial 2988 finished with value: 5215.127451775144 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12392684524015263, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.5240078050865085, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.3431003452121282, 'avg_alt_nm_max': 2.3817942461343966, 'mean_insert_max': 670.6273132516704, 'sd_insert_max': 248.82553078076697, 'asxs_min': 10, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 14, 'dist_to_indel_min': 92, 'mean_baseq_min': 67, 'sd_baseq_max': 93, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.08992358488654807, 'strand_bias_max': 0.8060240182709206, 'rp_sd_min': 0.0017852030923393603, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.012972694502445082, 'rp_med_max': 0.9864660827983512}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,185] Trial 2989 finished with value: 5177.620647843346 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11892824876586307, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.5911099011048142, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.203606043259836, 'avg_alt_nm_max': 2.2798297973334445, 'mean_insert_max': 682.9128585174132, 'sd_insert_max': 303.42166882947237, 'asxs_min': 12, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 12, 'dist_to_indel_min': 63, 'mean_baseq_min': 69, 'sd_baseq_max': 84, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.11218518652978304, 'strand_bias_max': 0.7993099394713068, 'rp_sd_min': 0.0017476064330886729, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.01170410268698749, 'rp_med_max': 0.988424532177535}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,326] Trial 2990 finished with value: 5266.4184047657845 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.121480780217244, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.79721802763524, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.283281686114825, 'avg_alt_nm_max': 2.330263071062813, 'mean_insert_max': 725.7736687255599, 'sd_insert_max': 288.87838163740395, 'asxs_min': 11, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 13, 'dist_to_indel_min': 82, 'mean_baseq_min': 65, 'sd_baseq_max': 90, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10201307872802853, 'strand_bias_max': 0.7889146583069767, 'rp_sd_min': 0.003636155242676442, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.010010471142510757, 'rp_med_max': 0.9852022972808637}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,462] Trial 2991 finished with value: 5803.108658907913 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11705095235302375, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.7436974390524236, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.1531840400597286, 'avg_alt_nm_max': 2.3849989539540095, 'mean_insert_max': 369.31127666659256, 'sd_insert_max': 264.34518604654346, 'asxs_min': 54, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 14, 'dist_to_indel_min': 94, 'mean_baseq_min': 72, 'sd_baseq_max': 87, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10854598398827527, 'strand_bias_max': 0.7837073530589586, 'rp_sd_min': 0.005096956862467422, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.06536561101055294, 'rp_med_max': 0.9899971084732735}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,598] Trial 2992 finished with value: 5190.377509601788 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12339294625307139, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.6689275963768829, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.3605738653201565, 'avg_alt_nm_max': 2.357113317824875, 'mean_insert_max': 704.4401182926952, 'sd_insert_max': 241.20626490964028, 'asxs_min': 12, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 64, 'mean_baseq_min': 70, 'sd_baseq_max': 91, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.09701029948539672, 'strand_bias_max': 0.7779892566195439, 'rp_sd_min': 0.0016660247928760182, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.01518063280710189, 'rp_med_max': 0.9884142083001093}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,732] Trial 2993 finished with value: 5636.005089150562 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11567319537855675, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.625320008201263, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.285715069071197, 'avg_alt_nm_max': 2.3082258330685534, 'mean_insert_max': 662.5558905127733, 'sd_insert_max': 276.007904620343, 'asxs_min': 10, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 80, 'mean_baseq_min': 119, 'sd_baseq_max': 84, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10141405361930714, 'strand_bias_max': 0.7935924949875616, 'rp_sd_min': 7.335655064075284e-05, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.011815569055394286, 'rp_med_max': 0.9867715487881524}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,858] Trial 2994 finished with value: 5219.451294210163 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11986421158561587, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.5533915811391478, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.209935616704509, 'avg_alt_nm_max': 2.3538483398090766, 'mean_insert_max': 689.4216465304138, 'sd_insert_max': 201.4336163319621, 'asxs_min': 11, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 13, 'dist_to_indel_min': 74, 'mean_baseq_min': 67, 'sd_baseq_max': 85, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.1124740922951928, 'strand_bias_max': 0.8001671422274472, 'rp_sd_min': 0.0036865875478448887, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.014219404833565787, 'rp_med_max': 0.9884889063244029}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:44,995] Trial 2995 finished with value: 6690.940678048034 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11881664739743689, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.7002930520791172, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.3077416892894782, 'avg_alt_nm_max': 2.3855497499586904, 'mean_insert_max': 677.9983840963032, 'sd_insert_max': 303.38095104577616, 'asxs_min': 12, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 12, 'dist_to_indel_min': 63, 'mean_baseq_min': 74, 'sd_baseq_max': 88, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.08988408738894922, 'strand_bias_max': 0.787051990597162, 'rp_sd_min': 2.007713328836154e-06, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.011661892314927598, 'rp_med_max': 0.9843781851161377}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:45,136] Trial 2996 finished with value: 5152.580682327057 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11184100807670715, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.5952087842191678, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.3559996286462763, 'avg_alt_nm_max': 2.327324535366477, 'mean_insert_max': 712.1006163359858, 'sd_insert_max': 260.98764296202927, 'asxs_min': 10, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 14, 'dist_to_indel_min': 91, 'mean_baseq_min': 65, 'sd_baseq_max': 94, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10336632025992222, 'strand_bias_max': 0.7937838483388472, 'rp_sd_min': 0.0017846317674448991, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.013118364614216853, 'rp_med_max': 0.9899951822505505}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:45,273] Trial 2997 finished with value: 5264.454430698868 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12287592077239885, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.6556431963054103, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.27373613104125, 'avg_alt_nm_max': 2.286716507242169, 'mean_insert_max': 666.990243425915, 'sd_insert_max': 223.99654509089706, 'asxs_min': 12, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 12, 'dist_to_indel_min': 102, 'mean_baseq_min': 69, 'sd_baseq_max': 85, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10812201025958892, 'strand_bias_max': 0.7781835445543615, 'rp_sd_min': 0.0052399854184791315, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.015116508725700521, 'rp_med_max': 0.9866694575213454}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:45,411] Trial 2998 finished with value: 5605.505802087091 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11412581484837102, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.5161983645347191, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.3520712450101982, 'avg_alt_nm_max': 2.3845883862287987, 'mean_insert_max': 690.5338827280832, 'sd_insert_max': 291.7824002984047, 'asxs_min': 11, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 13, 'dist_to_indel_min': 86, 'mean_baseq_min': 104, 'sd_baseq_max': 90, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.20014089496481552, 'strand_bias_max': 0.8060710556448597, 'rp_sd_min': 0.003206645549414551, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.010073461610889966, 'rp_med_max': 0.9883521028237544}. Best is trial 2707 with value: 5128.499406081333.
# [I 2026-05-05 18:26:45,543] Trial 2999 finished with value: 5154.605666041842 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12112603818045559, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 0.6242284210659568, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.0275451405795564, 'avg_alt_nm_max': 2.3547249510944934, 'mean_insert_max': 661.4054793295751, 'sd_insert_max': 238.0192626855441, 'asxs_min': 12, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 74, 'mean_baseq_min': 72, 'sd_baseq_max': 88, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.09470803986362258, 'strand_bias_max': 0.7900695156551683, 'rp_sd_min': 0.0020634995170732383, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.012735315400624307, 'rp_med_max': 0.9899897562304271}. Best is trial 2707 with value: 5128.499406081333.
# [INFO] Best Weighted Deviance: 5128.4994
# [INFO] Generating report...
# ------------------------------
# FINAL RESULTS
# ------------------------------
# Total Samples:      18
# Total Observed SNVs: 11836
# Total Expected SNVs: 20896.61
# Weighted Deviance:  5128.4994 (Cord weight = 3.0x)
# Mean Obs/Exp Ratio: 0.5564
# Blacklist Blocked:  567 variants (passed filters but hit blacklist)
# Results saved to:   training_results
# ------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------
# Configuration
# -----------------------
# Path to the CSV generated in the previous step
CSV_PATH = "training_results/observed_expected.csv"
OUTPUT_PNG = "training_results/observed_vs_expected_plot.png"

# Check if file exists
if not os.path.exists(CSV_PATH):
    print(f"[ERROR] Could not find {CSV_PATH}. Please run the optimization cell first.")
else:
    # Load table
    df = pd.read_csv(CSV_PATH)

    # Convert data arrays
    ages = df["age"].values
    bases = df["bases"].values
    observed = df["observed"].values
    expected = df["expected"].values
    sample_types = df["sample_type"].values

    # Calculate SNV rates per base
    obs_rate = observed / bases
    exp_rate = expected / bases

    # -----------------------
    # Plotting
    # -----------------------
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot Observed (Blue circles)
    ax.scatter(ages, obs_rate, label="Observed", color="#1f77b4", alpha=0.8, marker="o", s=60, edgecolors='k', linewidth=0.5)

    # Plot Expected (Orange crosses)
    ax.scatter(ages, exp_rate, label="Expected", color="#ff7f0e", alpha=0.8, marker="x", s=60, linewidth=2)

    # Styling
    ax.set_xlabel("Age (years)", fontsize=12)
    ax.set_ylabel("SNV rate (SNVs per base)", fontsize=12)
    
    # Handle X-limits (pad slightly around min/max age)
    # If ages has None/NaN (Cord blood sometimes represented as negative or 0), handle gracefully
    valid_ages = ages[~np.isnan(ages)]
    if len(valid_ages) > 0:
        ax.set_xlim(min(valid_ages) - 2, max(valid_ages) + 5)
    else:
        ax.set_xlim(-2, 100)

    # Hardcoded Y-limits from your request
    ax.set_ylim(0, 5.5e-7)
    
    ax.set_title("Observed vs Expected SNV Rate (Training Set)", fontsize=14)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Legend
    ax.legend(loc='upper left', frameon=True, fontsize=10)

    plt.tight_layout()
    
    # Save and Show
    plt.savefig(OUTPUT_PNG, dpi=150)
    print(f"[INFO] Plot saved to: {OUTPUT_PNG}")
    plt.show()
# Out:
# [INFO] Plot saved to: training_results/observed_vs_expected_plot.png

# %%
# Assuming best_thresholds is defined from your Optuna study
ref_entropy_thresh = best_thresholds['ref_entropy_min']

# Calculate failure
fail_entropy = all_variants_df['REF_ENTROPY_40BP'] < ref_entropy_thresh
pct_fail_entropy = (fail_entropy.sum() / len(all_variants_df)) * 100

print(f"Threshold used: {ref_entropy_thresh:.4f}")
print(f"Rows failing ref_entropy filter: {pct_fail_entropy:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Assuming best_thresholds is defined from your Optuna study
# ----> 2 ref_entropy_thresh = best_thresholds['ref_entropy_min']
#       4 # Calculate failure
#       5 fail_entropy = all_variants_df['REF_ENTROPY_40BP'] < ref_entropy_thresh
#
# KeyError: 'ref_entropy_min'

# %%
# Extract relevant thresholds
entropy_min = best_thresholds['ref_entropy_min']
depth_max = best_thresholds['depth_percentile_max']
rp_min = best_thresholds['rp_med_min']
rp_max = best_thresholds['rp_med_max']

# Define individual failure masks
fail_ent = all_variants_df['REF_ENTROPY_40BP'] < entropy_min
fail_dep = all_variants_df['DEPTH_PERCENTILE'] > depth_max
fail_rp  = (all_variants_df['RP_MED_SSCS'] <= rp_min) | (all_variants_df['RP_MED_SSCS'] >= rp_max)

# Combine using OR (|)
combined_fail_mask = fail_ent | fail_dep | fail_rp
pct_combined_fail = (combined_fail_mask.sum() / len(all_variants_df)) * 100

print(f"Rows failing (Entropy OR Depth OR RP_Med): {pct_combined_fail:.2f}%")

# Optional Breakdown
print("-" * 20)
print(f"Breakdown of failures:")
print(f" - Ref Entropy: {fail_ent.mean()*100:.2f}%")
print(f" - Max Depth:   {fail_dep.mean()*100:.2f}%")
print(f" - RP Median:   {fail_rp.mean()*100:.2f}%")
# Out:
# Rows failing (Entropy OR Depth OR RP_Med): 5.99%
# --------------------
# Breakdown of failures:
#  - Ref Entropy: 0.01%
#  - Max Depth:   4.31%
#  - RP Median:   1.72%

# %%
# Extract thresholds
entropy_min = best_thresholds['ref_entropy_min']
depth_max = best_thresholds['depth_percentile_max']
rp_min = best_thresholds['rp_med_min']
rp_max = best_thresholds['rp_med_max']

# Define failure masks
fail_ent = all_variants_df['REF_ENTROPY_40BP'] < entropy_min
fail_dep = all_variants_df['DEPTH_PERCENTILE'] > depth_max
fail_rp  = (all_variants_df['RP_MED_SSCS'] <= rp_min) | (all_variants_df['RP_MED_SSCS'] >= rp_max)

# UPDATED: Cord PoN failure only triggers if VAF < 20%
# We use VAF_SSCS as that is your primary metric for frequency in this script
fail_pon_low_vaf = (all_variants_df['IN_CORD_PON'] == "Yes") & (all_variants_df['VAF_SSCS'] < 0.20)

# Combine using OR (|)
composite_fail_mask = fail_ent | fail_dep | fail_rp | fail_pon_low_vaf
pct_composite_fail = (composite_fail_mask.sum() / len(all_variants_df)) * 100

print(f"Results for Composite Filter (Entropy, Depth, RP_Med, and Cord PoN < 20% VAF):")
print(f"Total rows failing any of these criteria: {pct_composite_fail:.2f}%")

print("-" * 30)
print("Individual Failure Contribution:")
print(f" - Ref Entropy:        {fail_ent.mean()*100:.2f}%")
print(f" - Max Depth:          {fail_dep.mean()*100:.2f}%")
print(f" - RP Median:          {fail_rp.mean()*100:.2f}%")
print(f" - Cord PoN (<20% VAF): {fail_pon_low_vaf.mean()*100:.2f}%")

# Quick check on how many PoN hits were 'saved' by being high VAF
pon_hits_total = (all_variants_df['IN_CORD_PON'] == "Yes").sum()
pon_hits_filtered = fail_pon_low_vaf.sum()
print(f"\nNote: Of {pon_hits_total} total PoN matches, {pon_hits_filtered} were <20% VAF and thus filtered.")
# Out:
# Results for Composite Filter (Entropy, Depth, RP_Med, and Cord PoN < 20% VAF):
# Total rows failing any of these criteria: 32.46%
# ------------------------------
# Individual Failure Contribution:
#  - Ref Entropy:        0.00%
#  - Max Depth:          5.44%
#  - RP Median:          2.90%
#  - Cord PoN (<20% VAF): 29.39%
#
# Note: Of 224694 total PoN matches, 126144 were <20% VAF and thus filtered.

# %%
# 1. Initialize the Exome Lookup
# (Using the path from your script configuration)
exome_lookup = BedLookup(EXOME_BED_PATH, "Exome Targets")

# 2. Filter for any variant flagged by the Cord PoN
pon_variants = all_variants_df[all_variants_df['IN_CORD_PON'] == "Yes"].copy()

# 3. Check which of these are inside the Exome
# We use a lambda to check each unique position found in the PoN subset
print("[INFO] Checking PoN positions against Exome BED...")

# To make this faster, we drop duplicates by position before doing the BED lookup
unique_pon_positions = pon_variants[['CHROM', 'POS']].drop_duplicates()

is_in_exome = unique_pon_positions.apply(
    lambda row: exome_lookup.is_overlapped(row['CHROM'], row['POS']), 
    axis=1
)

# 4. Filter the unique positions and count
exome_pon_positions = unique_pon_positions[is_in_exome]
count_unique_pos = len(exome_pon_positions)

# --- Summary Report ---
total_pon_hits = len(pon_variants)
unique_total_pon_pos = len(unique_pon_positions)

print("-" * 30)
print("CORD PON EXOME ANALYSIS")
print("-" * 30)
print(f"Total PoN-flagged rows in data:      {total_pon_hits}")
print(f"Unique PoN positions (Genome-wide):  {unique_total_pon_pos}")
print(f"Unique PoN positions (Exome-only):   {count_unique_pos}")
print("-" * 30)

# Optional: View the first few positions
if count_unique_pos > 0:
    print("Example Exome PoN positions:")
    print(exome_pon_positions.head())
# Out:
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Checking PoN positions against Exome BED...
# ------------------------------
# CORD PON EXOME ANALYSIS
# ------------------------------
# Total PoN-flagged rows in data:      224694
# Unique PoN positions (Genome-wide):  30667
# Unique PoN positions (Exome-only):   30667
# ------------------------------
# Example Exome PoN positions:
#    CHROM      POS
# 2   chr1   942451
# 10  chr1   966227
# 46  chr1  1313807
# 55  chr1  1495668
# 56  chr1  1495680

# %%
# 1. Extract the best thresholds from your Optuna results
sc_max = best_thresholds['avg_alt_softclip_max']
n_max  = best_thresholds['avg_alt_n_count_max']
nm_max = best_thresholds['avg_alt_nm_max']
ins_max = best_thresholds['mean_insert_max']

# 2. Define failure masks
# Fail if value is STRICTLY GREATER than the max threshold
fail_sc  = all_variants_df['AVG_ALT_SOFTCLIP'] > sc_max
fail_n   = all_variants_df['AVG_ALT_N_COUNT'] > n_max
fail_nm  = all_variants_df['AVG_ALT_NM'] > nm_max
fail_ins = all_variants_df['MEAN_INSERT'] > ins_max

# 3. Combine using OR (|) for a composite technical filter
tech_composite_fail = fail_sc | fail_n | fail_nm | fail_ins
pct_tech_composite = (tech_composite_fail.sum() / len(all_variants_df)) * 100

print(f"Results for Technical Quality Filters:")
print(f"Total rows failing ANY of these 4: {pct_tech_composite:.2f}%")

print("-" * 30)
print("Individual Failure Breakdown:")
print(f" - Softclip Max ({sc_max:.2f}):   {fail_sc.mean()*100:.22f}%")
print(f" - N-Count Max ({n_max:.2f}):    {fail_n.mean()*100:.2f}%")
print(f" - NM (Edit Dist) Max ({nm_max:.2f}): {fail_nm.mean()*100:.2f}%")
print(f" - Mean Insert Max ({ins_max:.1f}):  {fail_ins.mean()*100:.2f}%")

# 4. Identifying the "Noisiest" Filter
metrics = {
    "Softclip": fail_sc.sum(),
    "N-Count": fail_n.sum(),
    "NM-Distance": fail_nm.sum(),
    "Insert-Size": fail_ins.sum()
}
most_aggressive = max(metrics, key=metrics.get)
print("-" * 30)
print(f"The most aggressive filter in this group is: {most_aggressive}")
# Out:
# Results for Technical Quality Filters:
# Total rows failing ANY of these 4: 30.02%
# ------------------------------
# Individual Failure Breakdown:
#  - Softclip Max (1.24):   12.1540576434679277184614%
#  - N-Count Max (2.36):    9.13%
#  - NM (Edit Dist) Max (4.72): 26.12%
#  - Mean Insert Max (677.8):  0.03%
# ------------------------------
# The most aggressive filter in this group is: NM-Distance
