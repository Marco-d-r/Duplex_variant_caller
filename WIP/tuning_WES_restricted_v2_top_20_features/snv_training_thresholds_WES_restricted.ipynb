# %%
import csv
import gzip
import json
import math
import os
import sys
import random
import bisect
from typing import Dict, Any, List, Tuple

import numpy as np
import pandas as pd
import optuna

# -----------------------
# Configuration / Hardcoded Paths
# -----------------------
SAMPLES_CSV = "training_complete_processed_metadata.csv"
OUT_DIR = "training_results_seed_67"
BLACKLIST_BED = "../../resources/master_blacklist.bed" 
ARTEFACT_GENES_BED = "../../resources/master_blacklist.bed"
EXOME_BED_PATH = "../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed" 
N_TRIALS = 3000
SEED = 67

# -----------------------
# Constants
# -----------------------
GENOME_SIZE = 6.4e9
R_CORD = 2e-8
EPS = 1e-15
CORD_WEIGHT = 3.0

# Set seeds
random.seed(SEED)
np.random.seed(SEED)

# -----------------------
# Math Helpers
# -----------------------
def poisson_deviance(y_arr: np.ndarray, lam_arr: np.ndarray, weights: np.ndarray = None) -> float:
    y = np.asarray(y_arr, dtype=float)
    lam = np.asarray(lam_arr, dtype=float) + EPS
    
    with np.errstate(divide='ignore', invalid='ignore'):
        log_term = np.log(y / lam)
        term1 = np.where(y > 0, y * log_term, 0.0)
    
    dev = 2.0 * (term1 - (y - lam))
    
    if weights is not None:
        dev = dev * weights
        
    return float(np.sum(dev))

def expected_lambda(sample_type: str, age: float, bases: float) -> float:
    st = sample_type.lower()
    current_age = float(age) if age is not None else 0.0
    
    if "cord" in st:
        rate = R_CORD
    elif "pbmc" in st:
        rate = (16 * current_age + 105) / GENOME_SIZE
    else:
        rate = (22 * current_age + 164) / GENOME_SIZE
        
    return rate * bases

# -----------------------
# BED File Lookup Logic
# -----------------------
class BedLookup:
    def __init__(self, bed_path: str, name: str):
        self.intervals = {} 
        self.name = name
        self._load_bed(bed_path)

    def _load_bed(self, bed_path: str):
        if not os.path.exists(bed_path):
            print(f"[WARN] BED file not found: {bed_path}. {self.name} filter will do nothing.", file=sys.stderr)
            return

        print(f"[INFO] Loading {self.name} from {bed_path}...")
        count = 0
        with open(bed_path, 'r') as f:
            for line in f:
                if line.startswith('#') or not line.strip():
                    continue
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                chrom = parts[0]
                start, end = int(parts[1]), int(parts[2])
                
                if chrom not in self.intervals:
                    self.intervals[chrom] = []
                self.intervals[chrom].append((start, end))
                count += 1
        
        for chrom in self.intervals:
            self.intervals[chrom].sort(key=lambda x: x[0])
        print(f"[INFO] Loaded {count} regions for {self.name}.")

    def is_overlapped(self, chrom: str, pos: int) -> bool:
        if chrom not in self.intervals:
            return False
        
        regions = self.intervals[chrom]
        query_idx = pos - 1 
        
        idx = bisect.bisect_right(regions, (query_idx, float('inf')))
        
        for i in range(max(0, idx - 1), -1, -1):
            start, end = regions[i]
            if end <= query_idx:
                break 
            if start <= query_idx < end:
                return True
        return False

# -----------------------
# VCF Parsing to DataFrame
# -----------------------
def parse_vcf_to_df(vcf_path: str, sample_id: str) -> pd.DataFrame:
    data = []
    
    if not os.path.exists(vcf_path):
        print(f"[WARN] File not found: {vcf_path}", file=sys.stderr)
        return pd.DataFrame()

    openf = gzip.open if vcf_path.endswith(".gz") else open
    
    try:
        with openf(vcf_path, "rt") as fh:
            for line in fh:
                if line.startswith("#"):
                    continue
                fields = line.strip().split("\t")
                
                chrom = fields[0]
                pos = int(fields[1])
                
                info_str = fields[7]
                info_dict = {}
                for item in info_str.split(";"):
                    if "=" in item:
                        k, v = item.split("=", 1)
                        info_dict[k] = v
                    else:
                        info_dict[item] = "Yes" 
                
                info_dict["sample_id"] = sample_id
                info_dict["CHROM"] = chrom
                info_dict["POS"] = pos
                data.append(info_dict)
    except Exception as e:
        print(f"[ERROR] Error reading {vcf_path}: {e}", file=sys.stderr)
        return pd.DataFrame()

    if not data:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    
    # --- Type Conversion ---
    def to_num(col, dtype, default):
        if col in df.columns:
            return pd.to_numeric(df[col], errors='coerce').fillna(default).astype(dtype)
        return pd.Series([default]*len(df), index=df.index, dtype=dtype)

    def to_str(col, default):
        if col in df.columns:
            return df[col].fillna(default)
        return pd.Series([default]*len(df), index=df.index)

    df['CHROM'] = to_str('CHROM', 'chr1')
    df['POS'] = to_num('POS', int, 0)

    # 1. Base Counts
    df['N_ALT_SSCS'] = to_num('N_ALT_SSCS', int, 0)
    df['N_TOTAL'] = to_num('N_TOTAL', int, 0)
    df['N_ALT'] = to_num('N_ALT', int, 0) 
    df['N_TOTAL_SSCS'] = to_num('N_TOTAL_SSCS', int, 0)
    df['N_TOTAL_SSCS'] = np.where(df['N_TOTAL_SSCS'] <= 0, df['N_TOTAL'], df['N_TOTAL_SSCS'])

    df['DIST_TO_INDEL'] = to_num('DIST_TO_INDEL', int, -1)
    df['HOMOPOLYMER_LEN'] = to_num('HOMOPOLYMER_LEN', int, 0)
    df['DEPTH_PERCENTILE'] = to_num('DP_PERCENT', int, 50)

    # 2. Integer Metrics
    df['VARIANTS_20BP'] = to_num('VARIANTS_20BP', int, 0)
    df['VARIANTS_250BP'] = to_num('VARIANTS_250BP', int, 0)
    df['MEDIAN_DIST_TO_SOFTCLIP'] = to_num('MEDIAN_DIST_TO_SOFTCLIP', int, 1000)

    # 3. Float Metrics
    df['AVG_ASXS'] = to_num('AVG_ALT_ASXS', float, 0.0) 
    df['MEAN_MAPQ'] = to_num('MEAN_ALT_MAPQ', float, 0.0)
    df['MEAN_REF_MAPQ'] = to_num('MEAN_REF_MAPQ', float, 0.0) 
    df['MEAN_BASEQ'] = to_num('MEAN_ALT_BASEQ', float, 0.0) 
    df['SD_BASEQ'] = to_num('SD_ALT_BASEQ', float, 0.0)
    df['GC_CONTENT'] = to_num('GC_CONTENT', float, 0.5)
    df['STRAND_BIAS_SSCS'] = to_num('STRAND_BIAS_SSCS', float, 0.5)
    df['RP_SD_SSCS'] = to_num('RP_SD_SSCS', float, 0.0)
    df['RP_MED_SSCS'] = to_num('RP_MED_SSCS', float, 0.5)
    df['AVG_ALTREAD_VARIANTS'] = to_num('AVG_ALTREAD_VARIANTS', float, 0.0)
    df['AVG_NONALTREAD_VARIANTS'] = to_num('AVG_NONALTREAD_VARIANTS', float, 0.0)
    df['REF_ENTROPY_40BP'] = to_num('REF_ENTROPY_40BP', float, 2.0)
    df['AVG_ALT_SOFTCLIP'] = to_num('AVG_ALT_SOFTCLIP', float, 0.0)
    df['AVG_ALT_N_COUNT'] = to_num('AVG_ALT_N_COUNT', float, 0.0)
    df['AVG_ALT_NM'] = to_num('AVG_ALT_NM', float, 0.0)
    df['MEAN_INSERT'] = to_num('MEAN_INSERT', float, 200.0)
    df['SD_INSERT'] = to_num('SD_INSERT', float, 0)
    df['AVG_ALT_READ_MEAN_BQ'] = to_num('AVG_ALT_READ_MEAN_BQ', float, 0.0)
    
    # --- ADDED: READ POSITION ---
    df['AVG_READ_POSITION'] = to_num('AVG_READ_POSITION', float, 75.0)
    

    # 4. Flags
    df['IN_CORD_PON'] = to_str('IN_CB_PON', "No")
    df['IN_GNOMAD_COMMON'] = to_str('IN_GNOMAD_COMMON', "No")
    df['IN_ENCODE_BLACKLIST'] = to_str('IN_ENCODE_BLACKLIST', "No")
    df['IN_REPEATMASKER'] = to_str('IN_REPEATMASKER', "No")

    # 5. VAFs
    with np.errstate(divide='ignore', invalid='ignore'):
        df['VAF_DCS'] = df['N_ALT'] / df['N_TOTAL']
        df['VAF_DCS'] = df['VAF_DCS'].fillna(0.0)
        df['VAF_SSCS'] = df['N_ALT_SSCS'] / df['N_TOTAL_SSCS']
        df['VAF_SSCS'] = df['VAF_SSCS'].fillna(0.0)

    return df

# -----------------------
# Vectorized Filtering
# -----------------------
def get_passing_mask(df: pd.DataFrame, thresholds: Dict[str, Any], pon_flags: Dict[str, bool], ignore_blacklists: bool = False) -> pd.Series:
    # 1. BASELINE HARD FILTERS
    mask = (df['N_ALT_SSCS'] > 1) & \
           (df['IN_ENCODE_BLACKLIST'] != "Yes") & \
           (df['IN_REPEATMASKER'] != "Yes")
    
    # --- ADDED: OxoG / Read Position Hard Filter ---
    # Removes variants too close to the start (<4) or end (>138) of the read
    mask &= (df['AVG_READ_POSITION'] >= 4) & (df['AVG_READ_POSITION'] <= 138)

    if pon_flags.get("use_cord_pon", False):
        mask &= (df['IN_CORD_PON'] != "Yes")

    if not ignore_blacklists:
        mask &= (df['IN_CLUSTER_BLACKLIST'] == False)
        mask &= (df['IN_ARTEFACT_BLACKLIST'] == False)

    # 2. DEPTH
    mask &= (df['N_TOTAL'] >= thresholds['n_total_min'])
    mask &= (df['DEPTH_PERCENTILE'] <= thresholds['depth_percentile_max'])

    # 3. QUALITY METRICS
    mask &= (df['AVG_ASXS'] > thresholds['asxs_min'])
    mask &= (df['MEAN_MAPQ'] >= thresholds['mean_mapq_min'])
    mask &= (df['MEAN_REF_MAPQ'] >= thresholds['mean_ref_mapq_min'])
    mask &= (df['MEAN_BASEQ'] >= thresholds['mean_baseq_min'])
    mask &= (df['SD_BASEQ'] <= thresholds['sd_baseq_max'])

    mask &= ((df['DIST_TO_INDEL'] == -1) | (df['DIST_TO_INDEL'] >= thresholds['dist_to_indel_min']))

    # 4. TUNABLE FILTERS
    mask &= (df['VARIANTS_20BP'] <= thresholds['variants_20bp_max'])
    mask &= (df['VARIANTS_250BP'] <= thresholds['variants_250bp_max'])

    mask &= (df['AVG_ALT_SOFTCLIP'] <= thresholds['avg_alt_softclip_max'])
    mask &= (df['MEDIAN_DIST_TO_SOFTCLIP'] >= thresholds['dist_to_softclip_min'])
    mask &= (df['AVG_ALT_N_COUNT'] <= thresholds['avg_alt_n_count_max'])
    mask &= (df['AVG_ALT_NM'] <= thresholds['avg_alt_nm_max'])
    mask &= (df['MEAN_INSERT'] <= thresholds['mean_insert_max'])


    # 5. CONTEXT & STRAND

    mask &= (df['HOMOPOLYMER_LEN'] <= thresholds['homopolymer_len_max'])

    # Strand Bias 
    enough_reads_sb = df['N_ALT_SSCS'] >= thresholds['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < thresholds['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > thresholds['strand_bias_max'])
    mask &= ~(enough_reads_sb & bad_bias)

    # RP SD 
    enough_reads_rp = df['N_ALT_SSCS'] >= thresholds['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < thresholds['rp_sd_min']
    mask &= ~(enough_reads_rp & bad_rp_sd)

    # RP MED
    mask &= (df['RP_MED_SSCS'] > thresholds['rp_med_min']) & (df['RP_MED_SSCS'] < thresholds['rp_med_max'])



    # 7. GERMLINE & COMMON
    mask &= (df['VAF_SSCS'] <= thresholds['germline_vaf_max'])
    high_vaf_gnomad = (df['VAF_SSCS'] > thresholds['gnomad_vaf_cutoff'])
    is_common = (df['IN_GNOMAD_COMMON'] == "Yes") 
    mask &= ~(high_vaf_gnomad & is_common)

    return mask

# -----------------------
# Optimization Objective
# -----------------------
def make_objective(all_variants_df: pd.DataFrame, samples_meta: List[Dict]):
    
    expected_lambdas = []
    weights = []
    
    for s in samples_meta:
        expected_lambdas.append(expected_lambda(s['sample_type'], s['age'], s['bases']))
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)
            
    exp_arr = np.array(expected_lambdas)
    weights_arr = np.array(weights)

    def objective(trial):
        thresholds = {
            "germline_vaf_max": trial.suggest_float("germline_vaf_max", 0.20, 0.20),
            "gnomad_vaf_cutoff": trial.suggest_float("gnomad_vaf_cutoff", 0.10, 0.25),
            "depth_percentile_max": trial.suggest_int("depth_percentile_max", 95, 99),
            "variants_20bp_max": trial.suggest_int("variants_20bp_max", 0, 4),
            "variants_250bp_max": trial.suggest_int("variants_250bp_max", 0, 15),
            "avg_alt_softclip_max": trial.suggest_float("avg_alt_softclip_max", 0.0, 2.0),
            "dist_to_softclip_min": trial.suggest_int("dist_to_softclip_min", 0, 5),
            "avg_alt_n_count_max": trial.suggest_float("avg_alt_n_count_max", 0.0, 3.0),
            "avg_alt_nm_max": trial.suggest_float("avg_alt_nm_max", 0.0, 5.0),
            "mean_insert_max": trial.suggest_float("mean_insert_max", 80, 800.0),
            "asxs_min": trial.suggest_int("asxs_min", 10, 60),
            "mean_mapq_min": trial.suggest_int("mean_mapq_min", 20, 60),
            "mean_ref_mapq_min": trial.suggest_int("mean_ref_mapq_min", 10, 60),
            "dist_to_indel_min": trial.suggest_int("dist_to_indel_min", 0, 500),
            "mean_baseq_min": trial.suggest_int("mean_baseq_min", 20, 120),
            "sd_baseq_max": trial.suggest_int("sd_baseq_max", 0, 120),
            "strand_bias_n_alt_min": trial.suggest_int("strand_bias_n_alt_min", 1, 20),
            "strand_bias_min": trial.suggest_float("strand_bias_min", 0.0, 0.3),
            "strand_bias_max": trial.suggest_float("strand_bias_max", 0.7, 1.0),
            "rp_sd_min": trial.suggest_float("rp_sd_min", 0.0, 0.1),
            "rp_sd_min_alt": trial.suggest_int("rp_sd_min_alt", 1, 20),
            "homopolymer_len_max": trial.suggest_int("homopolymer_len_max", 0, 12),
            "n_total_min": trial.suggest_int("n_total_min", 10, 30),
            "rp_med_min": trial.suggest_float("rp_med_min", 0.01, 0.1),
            "rp_med_max": trial.suggest_float("rp_med_max", 0.9, 0.99),
        }

        pon_flags = {"use_cord_pon": True}

        pass_mask = get_passing_mask(all_variants_df, thresholds, pon_flags)
        obs_series = all_variants_df[pass_mask].groupby('sample_id').size()
        obs_arr = np.array([obs_series.get(s['sample_id'], 0) for s in samples_meta])

        loss = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
        return loss

    return objective

# -----------------------
# Reporting
# -----------------------
def evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, outdir):
    os.makedirs(outdir, exist_ok=True)
    
    pass_mask_final = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=False)
    pass_mask_clean = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=True)
    
    variants_saved_by_blacklist = pass_mask_clean & (~pass_mask_final)
    count_saved_by_blacklist = variants_saved_by_blacklist.sum()

    obs_series = all_variants_df[pass_mask_final].groupby('sample_id').size()
    
    observed = []
    expected = []
    ids = []
    ages = []
    bases = []
    types = []
    weights = []

    for s in samples_meta:
        sid = s['sample_id']
        obs = obs_series.get(sid, 0)
        lam = expected_lambda(s['sample_type'], s['age'], s['bases'])
        
        ids.append(sid)
        observed.append(obs)
        expected.append(lam)
        ages.append(s['age'])
        bases.append(s['bases'])
        types.append(s['sample_type'])
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)

    obs_arr = np.array(observed)
    exp_arr = np.array(expected)
    weights_arr = np.array(weights)

    with open(os.path.join(outdir, "best_thresholds.json"), "w") as fh:
        config_out = {
            "thresholds": best_thresholds, 
            "pon_flags": pon_flags,
            "blacklists_enforced": True,
            "cord_penalty_weight": CORD_WEIGHT
        }
        json.dump(config_out, fh, indent=2)

    ratio = obs_arr / (exp_arr + EPS)
    dev = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
    mean_ratio = float(np.mean(ratio))
    
    summary = {
        "n_samples": len(samples_meta),
        "obs_mean_over_expected": mean_ratio,
        "total_observed": int(np.sum(obs_arr)),
        "total_expected": float(np.sum(exp_arr)),
        "weighted_poisson_deviance": dev,
        "variants_blocked_by_blacklists": int(count_saved_by_blacklist)
    }
    with open(os.path.join(outdir, "summary.json"), "w") as fh:
        json.dump(summary, fh, indent=2)

    res_df = pd.DataFrame({
        "sample_id": ids,
        "sample_type": types,
        "age": ages,
        "bases": bases,
        "observed": observed,
        "expected": expected,
        "weight_used": weights 
    })
    res_df.to_csv(os.path.join(outdir, "observed_expected.csv"), index=False)
    
    print("-" * 30)
    print("FINAL RESULTS")
    print("-" * 30)
    print(f"Total Samples:      {len(samples_meta)}")
    print(f"Total Observed SNVs: {int(np.sum(obs_arr))}")
    print(f"Total Expected SNVs: {float(np.sum(exp_arr)):.2f}")
    print(f"Weighted Deviance:  {dev:.4f} (Cord weight = {CORD_WEIGHT}x)")
    print(f"Mean Obs/Exp Ratio: {mean_ratio:.4f}")
    print(f"Blacklist Blocked:  {count_saved_by_blacklist} variants (passed filters but hit blacklist)")
    print(f"Results saved to:   {outdir}")
    print("-" * 30)

# -----------------------
# Execution Block
# -----------------------
if __name__ == "__main__":
    print(f"[INFO] Reading metadata from {SAMPLES_CSV}...")
    samples_meta = []
    with open(SAMPLES_CSV, newline='') as csvfile:
        rdr = csv.DictReader(csvfile)
        for r in rdr:
            samples_meta.append({
                "sample_id": r["sample_id"],
                "vcf_path": r["vcf_path"],
                "sample_type": r["sample_type"].lower(),
                "age": float(r["age"]) if r.get("age") else None,
                "bases": float(r["total_callable_bases_in_wes"]),
            })
    print(f"[INFO] Loaded {len(samples_meta)} samples.")

    print("[INFO] Loading VCFs into DataFrame...")
    df_list = []
    for s in samples_meta:
        df_list.append(parse_vcf_to_df(s["vcf_path"], s["sample_id"]))

    if df_list:
        all_variants_df = pd.concat(df_list, ignore_index=True)
    else:
        print("[ERROR] No VCF data loaded. Checking paths in CSV.")
        all_variants_df = pd.DataFrame()

    print(f"[INFO] Total variants loaded: {len(all_variants_df)}")

    if not all_variants_df.empty:
        # --- NEW: Exome Inclusion Filter ---
        print("[INFO] Restricting variants to Exome targets...")
        bed_lookup_exome = BedLookup(EXOME_BED_PATH, "Exome Targets")
        
        # Create boolean mask for variants inside the exome
        in_exome_mask = all_variants_df.apply(
            lambda row: bed_lookup_exome.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        # Filter the dataframe to only keep variants in the exome
        pre_filter_count = len(all_variants_df)
        all_variants_df = all_variants_df[in_exome_mask].copy()
        post_filter_count = len(all_variants_df)
        print(f"[INFO] Exome filter retained {post_filter_count} out of {pre_filter_count} variants.")

        if all_variants_df.empty:
            print("[WARN] No variants left after applying Exome filter. Exiting.")
            sys.exit(0)
        # -----------------------------------

        bed_lookup_cluster = BedLookup(BLACKLIST_BED, "Cluster Blacklist")
        all_variants_df['IN_CLUSTER_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_cluster.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        bed_lookup_genes = BedLookup(ARTEFACT_GENES_BED, "Artefact Gene Blacklist")
        all_variants_df['IN_ARTEFACT_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_genes.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        hits_cluster = all_variants_df['IN_CLUSTER_BLACKLIST'].sum()
        hits_genes = all_variants_df['IN_ARTEFACT_BLACKLIST'].sum()
        print(f"[INFO] Found {hits_cluster} variants in Cluster blacklist.")
        print(f"[INFO] Found {hits_genes} variants in Artefact Gene blacklist.")

        print(f"[INFO] Starting Optuna (Trials={N_TRIALS})...")
        study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=SEED))
        
        objective = make_objective(all_variants_df, samples_meta)
        study.optimize(objective, n_trials=N_TRIALS)

        print(f"[INFO] Best Weighted Deviance: {study.best_value:.4f}")

        best_params = study.best_params
        best_thresholds = {k: v for k, v in best_params.items()}
        pon_flags = {"use_cord_pon": True}
        
        print("[INFO] Generating report...")
        evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, OUT_DIR)
# Out:
# [INFO] Reading metadata from training_complete_processed_metadata.csv...
# [INFO] Loaded 18 samples.
# [INFO] Loading VCFs into DataFrame...
# [INFO] Total variants loaded: 1154904
# [INFO] Restricting variants to Exome targets...
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Exome filter retained 429190 out of 1154904 variants.
# [INFO] Loading Cluster Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Cluster Blacklist.
# [INFO] Loading Artefact Gene Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Artefact Gene Blacklist.
# [I 2026-04-24 16:44:56,733] A new study created in memory with name: no-name-0748c340-51ef-4f29-9c86-6e8f05da58a6
# [I 2026-04-24 16:44:56,864] Trial 0 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18187771449024678, 'depth_percentile_max': 99, 'variants_20bp_max': 3, 'variants_250bp_max': 5, 'avg_alt_softclip_max': 0.11999585912123578, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 0.639449576053067, 'avg_alt_nm_max': 4.662533250406801, 'mean_insert_max': 600.4291751762207, 'asxs_min': 12, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 40, 'dist_to_indel_min': 126, 'mean_baseq_min': 51, 'sd_baseq_max': 22, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.07717284356826934, 'strand_bias_max': 0.7033342345969755, 'rp_sd_min': 0.04095885098684472, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 0, 'n_total_min': 30, 'rp_med_min': 0.0457909556296146, 'rp_med_max': 0.947669255067939}. Best is trial 0 with value: 43461.544704734064.
# [INFO] Found 79201 variants in Cluster blacklist.
# [INFO] Found 79201 variants in Artefact Gene blacklist.
# [INFO] Starting Optuna (Trials=3000)...
# [I 2026-04-24 16:44:57,014] Trial 1 finished with value: 8318.687254189352 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.13492193689922746, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 11, 'avg_alt_softclip_max': 1.9068491063951534, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.2067547098392606, 'avg_alt_nm_max': 1.7746509976967757, 'mean_insert_max': 666.1977130202101, 'asxs_min': 25, 'mean_mapq_min': 42, 'mean_ref_mapq_min': 59, 'dist_to_indel_min': 91, 'mean_baseq_min': 93, 'sd_baseq_max': 88, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.2908759181318819, 'strand_bias_max': 0.811163062960183, 'rp_sd_min': 0.07069442375214334, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 3, 'n_total_min': 16, 'rp_med_min': 0.022496678974545, 'rp_med_max': 0.9877603368966626}. Best is trial 1 with value: 8318.687254189352.
# [I 2026-04-24 16:44:57,127] Trial 2 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10126178565456956, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 14, 'avg_alt_softclip_max': 0.8009753354245945, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.3423416326329036, 'avg_alt_nm_max': 4.542121863855919, 'mean_insert_max': 542.4533189127762, 'asxs_min': 22, 'mean_mapq_min': 47, 'mean_ref_mapq_min': 31, 'dist_to_indel_min': 112, 'mean_baseq_min': 35, 'sd_baseq_max': 54, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.19138434874425636, 'strand_bias_max': 0.9991496079207524, 'rp_sd_min': 0.052686808332644136, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 0, 'n_total_min': 24, 'rp_med_min': 0.0366775873616204, 'rp_med_max': 0.9692991174263755}. Best is trial 1 with value: 8318.687254189352.
# [I 2026-04-24 16:44:57,231] Trial 3 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12815151276163494, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'avg_alt_softclip_max': 0.3369971862157841, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.8871364153561276, 'avg_alt_nm_max': 0.8362874515002705, 'mean_insert_max': 338.3319575019936, 'asxs_min': 50, 'mean_mapq_min': 52, 'mean_ref_mapq_min': 17, 'dist_to_indel_min': 119, 'mean_baseq_min': 67, 'sd_baseq_max': 114, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.09729978806534557, 'strand_bias_max': 0.7294835842323101, 'rp_sd_min': 0.02127567873974312, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 8, 'n_total_min': 14, 'rp_med_min': 0.08144799162124268, 'rp_med_max': 0.9297550564435939}. Best is trial 1 with value: 8318.687254189352.
# [I 2026-04-24 16:44:57,356] Trial 4 finished with value: 20311.949649013568 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10404426588370169, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 14, 'avg_alt_softclip_max': 1.4030941576868579, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.4136950887500923, 'avg_alt_nm_max': 1.9345445237854713, 'mean_insert_max': 592.1427740297399, 'asxs_min': 24, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 44, 'dist_to_indel_min': 458, 'mean_baseq_min': 31, 'sd_baseq_max': 3, 'strand_bias_n_alt_min': 19, 'strand_bias_min': 0.25719008914944796, 'strand_bias_max': 0.9275495301653105, 'rp_sd_min': 0.046707900027464624, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 7, 'n_total_min': 13, 'rp_med_min': 0.04692461845797147, 'rp_med_max': 0.958745039564556}. Best is trial 1 with value: 8318.687254189352.
# [I 2026-04-24 16:44:57,484] Trial 5 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11276659168916749, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 0, 'avg_alt_softclip_max': 0.9155197448719377, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.000403609939551, 'avg_alt_nm_max': 0.7986904670628853, 'mean_insert_max': 630.0836072778459, 'asxs_min': 48, 'mean_mapq_min': 53, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 366, 'mean_baseq_min': 108, 'sd_baseq_max': 101, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.08621135813931764, 'strand_bias_max': 0.7809023580738979, 'rp_sd_min': 0.06361641300921712, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 10, 'n_total_min': 11, 'rp_med_min': 0.07902545948766732, 'rp_med_max': 0.939198619182878}. Best is trial 1 with value: 8318.687254189352.
# [I 2026-04-24 16:44:57,599] Trial 6 finished with value: 20827.24299233417 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24515604917926223, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 0.946629220592424, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 2.9928728607671116, 'avg_alt_nm_max': 4.637478560336183, 'mean_insert_max': 790.8668860203916, 'asxs_min': 16, 'mean_mapq_min': 46, 'mean_ref_mapq_min': 25, 'dist_to_indel_min': 371, 'mean_baseq_min': 70, 'sd_baseq_max': 98, 'strand_bias_n_alt_min': 19, 'strand_bias_min': 0.014206474159212668, 'strand_bias_max': 0.8688536757548532, 'rp_sd_min': 0.09351081400369349, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 6, 'n_total_min': 25, 'rp_med_min': 0.09014543494217837, 'rp_med_max': 0.9007188785479053}. Best is trial 1 with value: 8318.687254189352.
# [I 2026-04-24 16:44:57,707] Trial 7 finished with value: 18046.47312161395 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2070211539309177, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 10, 'avg_alt_softclip_max': 1.427595229464146, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 0.9498101050735872, 'avg_alt_nm_max': 3.1594289200305994, 'mean_insert_max': 233.9631827119411, 'asxs_min': 36, 'mean_mapq_min': 45, 'mean_ref_mapq_min': 21, 'dist_to_indel_min': 200, 'mean_baseq_min': 94, 'sd_baseq_max': 41, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.2513869923944303, 'strand_bias_max': 0.7139335626865031, 'rp_sd_min': 0.0016067512266857986, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 4, 'n_total_min': 14, 'rp_med_min': 0.05531613838774356, 'rp_med_max': 0.9503983299985374}. Best is trial 1 with value: 8318.687254189352.
# [I 2026-04-24 16:44:57,824] Trial 8 finished with value: 5876.001672760821 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10605240788803602, 'depth_percentile_max': 95, 'variants_20bp_max': 0, 'variants_250bp_max': 11, 'avg_alt_softclip_max': 1.1777445686940666, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.6997398154986554, 'avg_alt_nm_max': 2.534346578052818, 'mean_insert_max': 252.02242837352492, 'asxs_min': 11, 'mean_mapq_min': 28, 'mean_ref_mapq_min': 28, 'dist_to_indel_min': 456, 'mean_baseq_min': 42, 'sd_baseq_max': 120, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.0508509648766152, 'strand_bias_max': 0.8473801404423386, 'rp_sd_min': 0.05322277101770911, 'rp_sd_min_alt': 18, 'homopolymer_len_max': 3, 'n_total_min': 14, 'rp_med_min': 0.09360800924734236, 'rp_med_max': 0.9833660713193367}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:57,930] Trial 9 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19089778776020058, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 1, 'avg_alt_softclip_max': 1.2058536019401407, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 1.6752079485606428, 'avg_alt_nm_max': 4.400720595756668, 'mean_insert_max': 213.5029929877614, 'asxs_min': 40, 'mean_mapq_min': 60, 'mean_ref_mapq_min': 49, 'dist_to_indel_min': 48, 'mean_baseq_min': 100, 'sd_baseq_max': 85, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.24517203445903285, 'strand_bias_max': 0.7869223772236573, 'rp_sd_min': 0.09970400509407394, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 0, 'n_total_min': 25, 'rp_med_min': 0.046131340551488965, 'rp_med_max': 0.9128757970235736}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:58,082] Trial 10 finished with value: 34343.57780227934 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15404524477705148, 'depth_percentile_max': 95, 'variants_20bp_max': 0, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.9935663704359787, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.8524983551720804, 'avg_alt_nm_max': 3.1808366745936842, 'mean_insert_max': 84.78796236841859, 'asxs_min': 10, 'mean_mapq_min': 29, 'mean_ref_mapq_min': 32, 'dist_to_indel_min': 300, 'mean_baseq_min': 22, 'sd_baseq_max': 70, 'strand_bias_n_alt_min': 13, 'strand_bias_min': 0.002492638000436906, 'strand_bias_max': 0.8898947585365913, 'rp_sd_min': 0.07832987708725651, 'rp_sd_min_alt': 19, 'homopolymer_len_max': 3, 'n_total_min': 19, 'rp_med_min': 0.09885786723051919, 'rp_med_max': 0.9897280635520771}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:58,211] Trial 11 finished with value: 8020.485371875414 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.14481789290730185, 'depth_percentile_max': 95, 'variants_20bp_max': 2, 'variants_250bp_max': 11, 'avg_alt_softclip_max': 1.9725924138071138, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.20108529718422985, 'avg_alt_nm_max': 1.9606116858566243, 'mean_insert_max': 432.9162616609598, 'asxs_min': 27, 'mean_mapq_min': 35, 'mean_ref_mapq_min': 57, 'dist_to_indel_min': 498, 'mean_baseq_min': 120, 'sd_baseq_max': 119, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.16871463326053426, 'strand_bias_max': 0.8141685971618036, 'rp_sd_min': 0.06872986983888663, 'rp_sd_min_alt': 15, 'homopolymer_len_max': 3, 'n_total_min': 18, 'rp_med_min': 0.01246272094005983, 'rp_med_max': 0.9865107483490111}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:58,348] Trial 12 finished with value: 6117.055367055718 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1531653929937748, 'depth_percentile_max': 95, 'variants_20bp_max': 2, 'variants_250bp_max': 11, 'avg_alt_softclip_max': 1.6539443753693763, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.1442510301528479, 'avg_alt_nm_max': 2.623311770679149, 'mean_insert_max': 414.5045879883496, 'asxs_min': 29, 'mean_mapq_min': 34, 'mean_ref_mapq_min': 59, 'dist_to_indel_min': 495, 'mean_baseq_min': 53, 'sd_baseq_max': 119, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.16097865865273683, 'strand_bias_max': 0.8336878797160261, 'rp_sd_min': 0.03472420195421579, 'rp_sd_min_alt': 16, 'homopolymer_len_max': 4, 'n_total_min': 19, 'rp_med_min': 0.015014975832762146, 'rp_med_max': 0.9731536535762167}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:58,505] Trial 13 finished with value: 7187.635893280816 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16103835618675497, 'depth_percentile_max': 95, 'variants_20bp_max': 0, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 1.5948611830066008, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.0821520615033555, 'avg_alt_nm_max': 3.161806190894102, 'mean_insert_max': 410.1819432349195, 'asxs_min': 59, 'mean_mapq_min': 35, 'mean_ref_mapq_min': 51, 'dist_to_indel_min': 421, 'mean_baseq_min': 54, 'sd_baseq_max': 116, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.1368979821563977, 'strand_bias_max': 0.9235526466339958, 'rp_sd_min': 0.031018847508884097, 'rp_sd_min_alt': 14, 'homopolymer_len_max': 5, 'n_total_min': 22, 'rp_med_min': 0.06840452537875438, 'rp_med_max': 0.9710470747498319}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:58,626] Trial 14 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.21514333914470826, 'depth_percentile_max': 95, 'variants_20bp_max': 4, 'variants_250bp_max': 15, 'avg_alt_softclip_max': 0.5995027055151022, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 2.434060773007376, 'avg_alt_nm_max': 0.008684321295215458, 'mean_insert_max': 271.84090489806505, 'asxs_min': 32, 'mean_mapq_min': 21, 'mean_ref_mapq_min': 38, 'dist_to_indel_min': 262, 'mean_baseq_min': 50, 'sd_baseq_max': 72, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.04691361598053964, 'strand_bias_max': 0.844551694655256, 'rp_sd_min': 0.01873358634264409, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 2, 'n_total_min': 10, 'rp_med_min': 0.06421043646771073, 'rp_med_max': 0.9744219709727322}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:58,742] Trial 15 finished with value: 10925.504339077006 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12593291757614955, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 12, 'avg_alt_softclip_max': 1.629435694729688, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.6034656991299321, 'avg_alt_nm_max': 2.5976989490740565, 'mean_insert_max': 161.42743696302614, 'asxs_min': 19, 'mean_mapq_min': 29, 'mean_ref_mapq_min': 29, 'dist_to_indel_min': 392, 'mean_baseq_min': 40, 'sd_baseq_max': 103, 'strand_bias_n_alt_min': 16, 'strand_bias_min': 0.11784947588854036, 'strand_bias_max': 0.9023907126370828, 'rp_sd_min': 0.03495388981880051, 'rp_sd_min_alt': 16, 'homopolymer_len_max': 12, 'n_total_min': 17, 'rp_med_min': 0.03258011623660371, 'rp_med_max': 0.9612765982781405}. Best is trial 8 with value: 5876.001672760821.
# [I 2026-04-24 16:44:58,873] Trial 16 finished with value: 3332.7898947466674 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1655043664591179, 'depth_percentile_max': 95, 'variants_20bp_max': 2, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.2196104118652422, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.36424410891551, 'avg_alt_nm_max': 3.8476445280503127, 'mean_insert_max': 339.3637551499115, 'asxs_min': 42, 'mean_mapq_min': 34, 'mean_ref_mapq_min': 46, 'dist_to_indel_min': 500, 'mean_baseq_min': 82, 'sd_baseq_max': 84, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.20745158117657317, 'strand_bias_max': 0.9629363312741761, 'rp_sd_min': 0.05627903371081696, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'n_total_min': 21, 'rp_med_min': 0.014499615586164428, 'rp_med_max': 0.9813275878468235}. Best is trial 16 with value: 3332.7898947466674.
# [I 2026-04-24 16:44:59,029] Trial 17 finished with value: 4446.658080775806 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1712987407931258, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 5, 'avg_alt_softclip_max': 1.1481486169137858, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.4827123774453344, 'avg_alt_nm_max': 3.825949935604378, 'mean_insert_max': 323.4308992482538, 'asxs_min': 43, 'mean_mapq_min': 28, 'mean_ref_mapq_min': 45, 'dist_to_indel_min': 302, 'mean_baseq_min': 81, 'sd_baseq_max': 50, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.2165334399617198, 'strand_bias_max': 0.9785371862296591, 'rp_sd_min': 0.05661020259037765, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 8, 'n_total_min': 22, 'rp_med_min': 0.02656853415637167, 'rp_med_max': 0.9792590290918387}. Best is trial 16 with value: 3332.7898947466674.
# [I 2026-04-24 16:44:59,165] Trial 18 finished with value: 4500.368831560087 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1693727151787437, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 1.2249559283209832, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.2621752719534083, 'avg_alt_nm_max': 4.002211097186814, 'mean_insert_max': 338.31070562125456, 'asxs_min': 44, 'mean_mapq_min': 39, 'mean_ref_mapq_min': 47, 'dist_to_indel_min': 197, 'mean_baseq_min': 81, 'sd_baseq_max': 41, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.20190846870120369, 'strand_bias_max': 0.990911766488303, 'rp_sd_min': 0.08581849398549932, 'rp_sd_min_alt': 12, 'homopolymer_len_max': 10, 'n_total_min': 28, 'rp_med_min': 0.027235646894914433, 'rp_med_max': 0.9299151448233951}. Best is trial 16 with value: 3332.7898947466674.
# [I 2026-04-24 16:44:59,312] Trial 19 finished with value: 3663.6567498870163 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19421422628103246, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 0.6383073302910932, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.1009134838870023, 'avg_alt_nm_max': 3.9111401587794568, 'mean_insert_max': 506.61304726068903, 'asxs_min': 57, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 42, 'dist_to_indel_min': 317, 'mean_baseq_min': 77, 'sd_baseq_max': 54, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.21673072023217982, 'strand_bias_max': 0.9615468848842665, 'rp_sd_min': 0.06069652195286622, 'rp_sd_min_alt': 12, 'homopolymer_len_max': 9, 'n_total_min': 22, 'rp_med_min': 0.021994826384533615, 'rp_med_max': 0.9583098666923392}. Best is trial 16 with value: 3332.7898947466674.
# [I 2026-04-24 16:44:59,438] Trial 20 finished with value: 3247.399368732725 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20364426938676602, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 0.6222772772954746, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.0744028055508634, 'avg_alt_nm_max': 3.8145514574311448, 'mean_insert_max': 503.7028361601413, 'asxs_min': 58, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 37, 'dist_to_indel_min': 326, 'mean_baseq_min': 68, 'sd_baseq_max': 68, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.2907159315275545, 'strand_bias_max': 0.955970756504021, 'rp_sd_min': 0.0767490986902537, 'rp_sd_min_alt': 11, 'homopolymer_len_max': 10, 'n_total_min': 21, 'rp_med_min': 0.010029512253358365, 'rp_med_max': 0.9609355369252454}. Best is trial 20 with value: 3247.399368732725.
# [I 2026-04-24 16:44:59,563] Trial 21 finished with value: 3322.071781863797 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20536138535467702, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 0.6227964720112411, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.012145646461283, 'avg_alt_nm_max': 3.8064323538989395, 'mean_insert_max': 503.324747829488, 'asxs_min': 60, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 36, 'dist_to_indel_min': 313, 'mean_baseq_min': 69, 'sd_baseq_max': 70, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.2880029131374273, 'strand_bias_max': 0.9551098143736274, 'rp_sd_min': 0.07914586898587181, 'rp_sd_min_alt': 11, 'homopolymer_len_max': 10, 'n_total_min': 21, 'rp_med_min': 0.010952973726924251, 'rp_med_max': 0.9605911762307335}. Best is trial 20 with value: 3247.399368732725.
# [I 2026-04-24 16:44:59,722] Trial 22 finished with value: 3280.949503478718 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24085512243866025, 'depth_percentile_max': 97, 'variants_20bp_max': 2, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 0.4255920547208165, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.6762370204069565, 'avg_alt_nm_max': 3.5115117651992582, 'mean_insert_max': 509.3189227619164, 'asxs_min': 53, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 35, 'dist_to_indel_min': 208, 'mean_baseq_min': 65, 'sd_baseq_max': 71, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.2827400552164806, 'strand_bias_max': 0.9533134208532145, 'rp_sd_min': 0.07949625296896773, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 12, 'n_total_min': 21, 'rp_med_min': 0.010923465580357396, 'rp_med_max': 0.9635528485915482}. Best is trial 20 with value: 3247.399368732725.
# [I 2026-04-24 16:44:59,900] Trial 23 finished with value: 3403.2129232637344 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23780536774918562, 'depth_percentile_max': 97, 'variants_20bp_max': 1, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 0.4423354564275581, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.7402676906594734, 'avg_alt_nm_max': 3.693602344847937, 'mean_insert_max': 516.8937786612272, 'asxs_min': 54, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 37, 'dist_to_indel_min': 205, 'mean_baseq_min': 66, 'sd_baseq_max': 69, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.2992926564758894, 'strand_bias_max': 0.9426588645849079, 'rp_sd_min': 0.08035796525263418, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 12, 'n_total_min': 24, 'rp_med_min': 0.011961325520429167, 'rp_med_max': 0.9636589049561467}. Best is trial 20 with value: 3247.399368732725.
# [I 2026-04-24 16:45:00,075] Trial 24 finished with value: 3666.643080565599 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22829092666959203, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 6, 'avg_alt_softclip_max': 0.15129968905369173, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.5653885902464841, 'avg_alt_nm_max': 3.4212244430211474, 'mean_insert_max': 683.3413962142095, 'asxs_min': 53, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 33, 'dist_to_indel_min': 269, 'mean_baseq_min': 63, 'sd_baseq_max': 65, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.27974325398506633, 'strand_bias_max': 0.9497448362180461, 'rp_sd_min': 0.08918161948066615, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 11, 'n_total_min': 20, 'rp_med_min': 0.020870472686227458, 'rp_med_max': 0.9395154905561173}. Best is trial 20 with value: 3247.399368732725.
# [I 2026-04-24 16:45:00,239] Trial 25 finished with value: 3651.43843437091 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.21730558914306333, 'depth_percentile_max': 97, 'variants_20bp_max': 1, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 0.3189675377274361, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.3759173274987204, 'avg_alt_nm_max': 4.220076424047296, 'mean_insert_max': 502.71810033619914, 'asxs_min': 60, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 35, 'dist_to_indel_min': 169, 'mean_baseq_min': 59, 'sd_baseq_max': 77, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.2693448360696274, 'strand_bias_max': 0.9032794042633575, 'rp_sd_min': 0.07555209183180356, 'rp_sd_min_alt': 11, 'homopolymer_len_max': 11, 'n_total_min': 27, 'rp_med_min': 0.033935397772036364, 'rp_med_max': 0.9527160580140114}. Best is trial 20 with value: 3247.399368732725.
# [I 2026-04-24 16:45:00,402] Trial 26 finished with value: 3205.889521052642 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20243154058771232, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 0.7203935113957765, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.109779054368775, 'avg_alt_nm_max': 4.893365184373408, 'mean_insert_max': 458.5362397171799, 'asxs_min': 54, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 24, 'dist_to_indel_min': 333, 'mean_baseq_min': 73, 'sd_baseq_max': 60, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.23765768523025876, 'strand_bias_max': 0.9208452354523281, 'rp_sd_min': 0.08371200929813755, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 10, 'n_total_min': 16, 'rp_med_min': 0.019320441105589968, 'rp_med_max': 0.9654506319226807}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:00,574] Trial 27 finished with value: 4730.126545233053 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23011031517847833, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 0.7974822677930842, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.8505731862720798, 'avg_alt_nm_max': 4.861027399511124, 'mean_insert_max': 746.1082086273833, 'asxs_min': 48, 'mean_mapq_min': 31, 'mean_ref_mapq_min': 22, 'dist_to_indel_min': 245, 'mean_baseq_min': 91, 'sd_baseq_max': 40, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.2409117156920294, 'strand_bias_max': 0.8722881007103579, 'rp_sd_min': 0.096547370951347, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 11, 'n_total_min': 16, 'rp_med_min': 0.018726858002607673, 'rp_med_max': 0.9646591429791939}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:00,729] Trial 28 finished with value: 4353.987796266712 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2497903564139261, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 6, 'avg_alt_softclip_max': 0.5378177002788065, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.186424326348167, 'avg_alt_nm_max': 4.963566838348052, 'mean_insert_max': 573.591648860605, 'asxs_min': 54, 'mean_mapq_min': 26, 'mean_ref_mapq_min': 16, 'dist_to_indel_min': 356, 'mean_baseq_min': 75, 'sd_baseq_max': 25, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.23598669141754208, 'strand_bias_max': 0.9256747076845664, 'rp_sd_min': 0.08688942327658207, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 9, 'n_total_min': 17, 'rp_med_min': 0.0384249824660009, 'rp_med_max': 0.9402631942000786}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:00,864] Trial 29 finished with value: 3721.752130023179 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18844313937530086, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'avg_alt_softclip_max': 0.01973219904424839, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.0783544441440984, 'avg_alt_nm_max': 4.201861886968827, 'mean_insert_max': 456.25986355783084, 'asxs_min': 56, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 40, 'dist_to_indel_min': 162, 'mean_baseq_min': 60, 'sd_baseq_max': 59, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.269002073216023, 'strand_bias_max': 0.9753237693078539, 'rp_sd_min': 0.06976474029522843, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 12, 'n_total_min': 19, 'rp_med_min': 0.027593795025149734, 'rp_med_max': 0.94692023184985}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:00,995] Trial 30 finished with value: 4582.919410452259 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18065747080361383, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 0.7651988305547538, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.618988616231494, 'avg_alt_nm_max': 3.3498467300980175, 'mean_insert_max': 386.71770697592694, 'asxs_min': 50, 'mean_mapq_min': 32, 'mean_ref_mapq_min': 26, 'dist_to_indel_min': 232, 'mean_baseq_min': 47, 'sd_baseq_max': 29, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.18195195397540706, 'strand_bias_max': 0.9347530865776426, 'rp_sd_min': 0.084949310648195, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 9, 'n_total_min': 30, 'rp_med_min': 0.04124126590616302, 'rp_med_max': 0.9538245710754552}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:01,125] Trial 31 finished with value: 3755.310394717216 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20192880070071226, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 0.30889418084058096, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.037907887547337, 'avg_alt_nm_max': 2.8420882041005187, 'mean_insert_max': 472.6893532199367, 'asxs_min': 60, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 36, 'dist_to_indel_min': 307, 'mean_baseq_min': 73, 'sd_baseq_max': 78, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.28518866549797134, 'strand_bias_max': 0.9603775760115905, 'rp_sd_min': 0.07654473673547368, 'rp_sd_min_alt': 11, 'homopolymer_len_max': 10, 'n_total_min': 21, 'rp_med_min': 0.011086082488101973, 'rp_med_max': 0.9676635360423276}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:01,257] Trial 32 finished with value: 3770.5679094049624 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.21843371623607577, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 10, 'avg_alt_softclip_max': 0.6803597300259012, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.5385303092238747, 'avg_alt_nm_max': 4.3608844414645995, 'mean_insert_max': 552.505166304071, 'asxs_min': 56, 'mean_mapq_min': 26, 'mean_ref_mapq_min': 40, 'dist_to_indel_min': 333, 'mean_baseq_min': 84, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.29917276463412923, 'strand_bias_max': 0.9065852221957205, 'rp_sd_min': 0.06660592729783359, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 11, 'n_total_min': 23, 'rp_med_min': 0.01755866211193603, 'rp_med_max': 0.9768308381301392}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:01,385] Trial 33 finished with value: 3430.170351123957 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2037578457668519, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 6, 'avg_alt_softclip_max': 0.4829257130185536, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.8376400383073175, 'avg_alt_nm_max': 3.613535741983106, 'mean_insert_max': 624.616135593853, 'asxs_min': 51, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 32, 'dist_to_indel_min': 283, 'mean_baseq_min': 58, 'sd_baseq_max': 92, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.26902545275075035, 'strand_bias_max': 0.9780642119552918, 'rp_sd_min': 0.09187168460482197, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 8, 'n_total_min': 20, 'rp_med_min': 0.010271699436401712, 'rp_med_max': 0.9572066340167623}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:01,509] Trial 34 finished with value: 4388.676303787062 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22634286540255236, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 0.19160419878923218, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.365795176729482, 'avg_alt_nm_max': 2.2169139896290346, 'mean_insert_max': 477.52835404599324, 'asxs_min': 46, 'mean_mapq_min': 31, 'mean_ref_mapq_min': 24, 'dist_to_indel_min': 337, 'mean_baseq_min': 69, 'sd_baseq_max': 48, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.22671499336756784, 'strand_bias_max': 0.9972516713085512, 'rp_sd_min': 0.07389935322155071, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 10, 'n_total_min': 16, 'rp_med_min': 0.024683240423171934, 'rp_med_max': 0.9670723714245562}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:01,639] Trial 35 finished with value: 6569.713978256117 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18201595282174757, 'depth_percentile_max': 97, 'variants_20bp_max': 1, 'variants_250bp_max': 10, 'avg_alt_softclip_max': 0.41033074809491005, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.9397568480757106, 'avg_alt_nm_max': 1.4168306777421475, 'mean_insert_max': 546.4917064980908, 'asxs_min': 57, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 16, 'dist_to_indel_min': 404, 'mean_baseq_min': 89, 'sd_baseq_max': 77, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.28373243237584606, 'strand_bias_max': 0.9483856804164189, 'rp_sd_min': 0.08402620010955232, 'rp_sd_min_alt': 11, 'homopolymer_len_max': 7, 'n_total_min': 24, 'rp_med_min': 0.020309710925137846, 'rp_med_max': 0.9469027921752912}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:01,792] Trial 36 finished with value: 4730.410019589786 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19901890731399627, 'depth_percentile_max': 98, 'variants_20bp_max': 4, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 0.7342986209613066, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.174871010303978, 'avg_alt_nm_max': 2.9444570156610066, 'mean_insert_max': 389.88307157949316, 'asxs_min': 53, 'mean_mapq_min': 41, 'mean_ref_mapq_min': 30, 'dist_to_indel_min': 248, 'mean_baseq_min': 64, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.25544119064785187, 'strand_bias_max': 0.8851570911131883, 'rp_sd_min': 0.07961636716333229, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 12, 'n_total_min': 18, 'rp_med_min': 0.030300393681469667, 'rp_med_max': 0.9555722091345279}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:01,917] Trial 37 finished with value: 4267.61519842667 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23701077615005975, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 12, 'avg_alt_softclip_max': 0.8740130534552716, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.665788938492742, 'avg_alt_nm_max': 4.618902905588743, 'mean_insert_max': 649.410787296307, 'asxs_min': 39, 'mean_mapq_min': 37, 'mean_ref_mapq_min': 19, 'dist_to_indel_min': 345, 'mean_baseq_min': 74, 'sd_baseq_max': 10, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.2711464802607483, 'strand_bias_max': 0.9209465423846538, 'rp_sd_min': 0.04577349937246461, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 9, 'n_total_min': 12, 'rp_med_min': 0.016115048379932547, 'rp_med_max': 0.9628830341651691}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:02,046] Trial 38 finished with value: 3713.1366259857678 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2069813280523065, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 5, 'avg_alt_softclip_max': 0.9808710694757934, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.310497537222825, 'avg_alt_nm_max': 4.087540328679381, 'mean_insert_max': 587.8819452881617, 'asxs_min': 47, 'mean_mapq_min': 49, 'mean_ref_mapq_min': 42, 'dist_to_indel_min': 91, 'mean_baseq_min': 70, 'sd_baseq_max': 94, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.2878586233204477, 'strand_bias_max': 0.9118902581400339, 'rp_sd_min': 0.061195587274706365, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 7, 'n_total_min': 15, 'rp_med_min': 0.023324041682987615, 'rp_med_max': 0.970273213345926}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:02,173] Trial 39 finished with value: 3769.9995796155313 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2205259860728533, 'depth_percentile_max': 97, 'variants_20bp_max': 2, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 0.5594358844853385, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.2555554727323328, 'avg_alt_nm_max': 3.5012852976670477, 'mean_insert_max': 677.8385881564683, 'asxs_min': 51, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 34, 'dist_to_indel_min': 381, 'mean_baseq_min': 88, 'sd_baseq_max': 107, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.25917695867222806, 'strand_bias_max': 0.9356589758593571, 'rp_sd_min': 0.09605509528857126, 'rp_sd_min_alt': 12, 'homopolymer_len_max': 8, 'n_total_min': 26, 'rp_med_min': 0.05104885395914067, 'rp_med_max': 0.9436840810219427}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:02,302] Trial 40 finished with value: 6478.789511909687 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18148567285896883, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 10, 'avg_alt_softclip_max': 0.34802656860986814, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.8543760718146508, 'avg_alt_nm_max': 4.530473556185195, 'mean_insert_max': 530.1180274482856, 'asxs_min': 58, 'mean_mapq_min': 26, 'mean_ref_mapq_min': 12, 'dist_to_indel_min': 425, 'mean_baseq_min': 98, 'sd_baseq_max': 83, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.23730640887867627, 'strand_bias_max': 0.9694906434281657, 'rp_sd_min': 0.07307684815522661, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 10, 'n_total_min': 21, 'rp_med_min': 0.01769073232840709, 'rp_med_max': 0.951233067808332}. Best is trial 26 with value: 3205.889521052642.
# [I 2026-04-24 16:45:02,432] Trial 41 finished with value: 3131.7467939418725 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2086257793020496, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.1052276884526095, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.563867744162426, 'avg_alt_nm_max': 3.765541076002789, 'mean_insert_max': 373.95768005117526, 'asxs_min': 42, 'mean_mapq_min': 28, 'mean_ref_mapq_min': 53, 'dist_to_indel_min': 152, 'mean_baseq_min': 79, 'sd_baseq_max': 87, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.20086446618772502, 'strand_bias_max': 0.9539427625240964, 'rp_sd_min': 0.06514267782033947, 'rp_sd_min_alt': 18, 'homopolymer_len_max': 6, 'n_total_min': 21, 'rp_med_min': 0.014963176930662441, 'rp_med_max': 0.9812300488480701}. Best is trial 41 with value: 3131.7467939418725.
# [I 2026-04-24 16:45:02,563] Trial 42 finished with value: 3983.3087644210673 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2113226315936569, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.075980346841324, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.596189665220424, 'avg_alt_nm_max': 2.8675787191542583, 'mean_insert_max': 475.7994766965728, 'asxs_min': 55, 'mean_mapq_min': 28, 'mean_ref_mapq_min': 56, 'dist_to_indel_min': 135, 'mean_baseq_min': 77, 'sd_baseq_max': 69, 'strand_bias_n_alt_min': 12, 'strand_bias_min': 0.18965919620235877, 'strand_bias_max': 0.9493121321042646, 'rp_sd_min': 0.06435923041313289, 'rp_sd_min_alt': 14, 'homopolymer_len_max': 11, 'n_total_min': 23, 'rp_med_min': 0.01007849426208595, 'rp_med_max': 0.9755586763680271}. Best is trial 41 with value: 3131.7467939418725.
# [I 2026-04-24 16:45:02,696] Trial 43 finished with value: 2937.5785928456567 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1953479050651696, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 0.8718107794492272, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.8114320614077815, 'avg_alt_nm_max': 4.787209132313503, 'mean_insert_max': 368.9178772397902, 'asxs_min': 50, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 27, 'dist_to_indel_min': 9, 'mean_baseq_min': 69, 'sd_baseq_max': 92, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.2534468095206453, 'strand_bias_max': 0.9871493074065417, 'rp_sd_min': 0.08080054874320215, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 6, 'n_total_min': 20, 'rp_med_min': 0.01454654567794314, 'rp_med_max': 0.9607475723394451}. Best is trial 43 with value: 2937.5785928456567.
# [I 2026-04-24 16:45:02,848] Trial 44 finished with value: 2816.921372590264 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1969281747750197, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 0.8795026192013556, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.7897446747806374, 'avg_alt_nm_max': 4.849615543871754, 'mean_insert_max': 369.184606688327, 'asxs_min': 36, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 52, 'dist_to_indel_min': 56, 'mean_baseq_min': 63, 'sd_baseq_max': 91, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.2531626686784922, 'strand_bias_max': 0.9856714287540183, 'rp_sd_min': 0.07099649437403054, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 6, 'n_total_min': 18, 'rp_med_min': 0.016790672006100234, 'rp_med_max': 0.9870105111105729}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:02,975] Trial 45 finished with value: 17840.519325028163 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19294738511911233, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 4, 'avg_alt_softclip_max': 0.8854521712432628, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.856091217920281, 'avg_alt_nm_max': 4.761185066817433, 'mean_insert_max': 300.7460752743393, 'asxs_min': 36, 'mean_mapq_min': 59, 'mean_ref_mapq_min': 53, 'dist_to_indel_min': 16, 'mean_baseq_min': 57, 'sd_baseq_max': 92, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.22412736175658896, 'strand_bias_max': 0.9889124221401532, 'rp_sd_min': 0.07118769516463276, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 6, 'n_total_min': 18, 'rp_med_min': 0.03009555748491844, 'rp_med_max': 0.9816727566772684}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:03,102] Trial 46 finished with value: 2867.6867327518526 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19613495960058264, 'depth_percentile_max': 96, 'variants_20bp_max': 4, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 1.3599387565410064, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.8936917840035132, 'avg_alt_nm_max': 4.444323542174314, 'mean_insert_max': 379.3779716821646, 'asxs_min': 32, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 52, 'dist_to_indel_min': 50, 'mean_baseq_min': 85, 'sd_baseq_max': 110, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.20075398720821613, 'strand_bias_max': 0.9995636684402901, 'rp_sd_min': 0.048594150213372586, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 6, 'n_total_min': 15, 'rp_med_min': 0.01583534222578092, 'rp_med_max': 0.9856317026058499}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:03,233] Trial 47 finished with value: 3606.6641841720984 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18579286015615257, 'depth_percentile_max': 96, 'variants_20bp_max': 4, 'variants_250bp_max': 6, 'avg_alt_softclip_max': 1.3580887879220014, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.9838783333028642, 'avg_alt_nm_max': 4.995186485481798, 'mean_insert_max': 363.8186712300091, 'asxs_min': 34, 'mean_mapq_min': 27, 'mean_ref_mapq_min': 53, 'dist_to_indel_min': 48, 'mean_baseq_min': 97, 'sd_baseq_max': 111, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.14941048813826116, 'strand_bias_max': 0.9957011318566846, 'rp_sd_min': 0.04585211676790547, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 6, 'n_total_min': 13, 'rp_med_min': 0.036693982083243384, 'rp_med_max': 0.9846973320701082}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:03,362] Trial 48 finished with value: 4628.447245662894 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19699650674750227, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 3, 'avg_alt_softclip_max': 1.3248878250166716, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.7816101086817886, 'avg_alt_nm_max': 4.429732138910483, 'mean_insert_max': 431.62279535291816, 'asxs_min': 31, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 60, 'dist_to_indel_min': 2, 'mean_baseq_min': 86, 'sd_baseq_max': 99, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.17148573623647284, 'strand_bias_max': 0.7522955593651877, 'rp_sd_min': 0.05073101357884707, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 5, 'n_total_min': 15, 'rp_med_min': 0.0813391453358715, 'rp_med_max': 0.9893651802569114}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:03,489] Trial 49 finished with value: 3934.766944290061 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.21024332660176692, 'depth_percentile_max': 96, 'variants_20bp_max': 4, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 1.0581807580401603, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.5294962624988604, 'avg_alt_nm_max': 4.788402909707303, 'mean_insert_max': 287.13619488380573, 'asxs_min': 39, 'mean_mapq_min': 30, 'mean_ref_mapq_min': 49, 'dist_to_indel_min': 53, 'mean_baseq_min': 105, 'sd_baseq_max': 105, 'strand_bias_n_alt_min': 12, 'strand_bias_min': 0.20025669267889362, 'strand_bias_max': 0.9851791585276098, 'rp_sd_min': 0.040108201953514194, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 4, 'n_total_min': 17, 'rp_med_min': 0.06039698816067089, 'rp_med_max': 0.9865879120004937}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:03,614] Trial 50 finished with value: 20204.282430960353 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17778535843791096, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 1.0516201700626704, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.735031346966784, 'avg_alt_nm_max': 4.649790793319853, 'mean_insert_max': 208.7190611761793, 'asxs_min': 25, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 56, 'dist_to_indel_min': 84, 'mean_baseq_min': 117, 'sd_baseq_max': 110, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.18183913259972387, 'strand_bias_max': 0.9731595246656868, 'rp_sd_min': 0.06055791981789236, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 7, 'n_total_min': 15, 'rp_med_min': 0.015710465795368434, 'rp_med_max': 0.9776765455510278}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:03,742] Trial 51 finished with value: 2902.4027209646165 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1983408327301795, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 5, 'avg_alt_softclip_max': 1.4859751311574934, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.8901820833435683, 'avg_alt_nm_max': 4.2627139483026495, 'mean_insert_max': 383.0758441797621, 'asxs_min': 36, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 27, 'dist_to_indel_min': 70, 'mean_baseq_min': 77, 'sd_baseq_max': 88, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.2533781542458051, 'strand_bias_max': 0.9841595302083875, 'rp_sd_min': 0.06885542686567818, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 6, 'n_total_min': 20, 'rp_med_min': 0.02332826979700039, 'rp_med_max': 0.9722798012420774}. Best is trial 44 with value: 2816.921372590264.
# [I 2026-04-24 16:45:03,868] Trial 52 finished with value: 2791.8305829407595 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18751929114161678, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 5, 'avg_alt_softclip_max': 1.5115309768735563, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.9997347967395966, 'avg_alt_nm_max': 4.3243422289485185, 'mean_insert_max': 364.55301870447164, 'asxs_min': 34, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 27, 'dist_to_indel_min': 29, 'mean_baseq_min': 81, 'sd_baseq_max': 95, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.2487688639539051, 'strand_bias_max': 0.9988344565710018, 'rp_sd_min': 0.055822577568199805, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 6, 'n_total_min': 19, 'rp_med_min': 0.019538995882047817, 'rp_med_max': 0.9731430130247319}. Best is trial 52 with value: 2791.8305829407595.
# ...
# [I 2026-04-24 16:59:40,342] Trial 2983 finished with value: 2886.666150394257 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2227414469500774, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.4220241582589248, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.489025100499601, 'avg_alt_nm_max': 4.592453731712758, 'mean_insert_max': 662.9450847340948, 'asxs_min': 19, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 38, 'mean_baseq_min': 33, 'sd_baseq_max': 63, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.11835773576245917, 'strand_bias_max': 0.794443194169032, 'rp_sd_min': 0.03301957052616582, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.025899662916226404, 'rp_med_max': 0.9642684553442376}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:40,736] Trial 2984 finished with value: 2724.4267221832406 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22519782549254475, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.2681462292265206, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.60478735722973, 'avg_alt_nm_max': 4.667861068302863, 'mean_insert_max': 672.4742057317832, 'asxs_min': 20, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 28, 'mean_baseq_min': 29, 'sd_baseq_max': 59, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.11070437245704313, 'strand_bias_max': 0.8023775196615741, 'rp_sd_min': 0.026020441093150153, 'rp_sd_min_alt': 12, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.023993715531386017, 'rp_med_max': 0.9854424918844493}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:41,076] Trial 2985 finished with value: 2567.0918386002036 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23006891071654986, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 1.365773566164376, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.5302287051612096, 'avg_alt_nm_max': 4.659046840688514, 'mean_insert_max': 732.1078486959893, 'asxs_min': 22, 'mean_mapq_min': 21, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 48, 'mean_baseq_min': 33, 'sd_baseq_max': 65, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.11863183844326873, 'strand_bias_max': 0.7986970881421767, 'rp_sd_min': 0.027454484485465242, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.022189919365215655, 'rp_med_max': 0.9866720114520448}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:41,435] Trial 2986 finished with value: 2486.5817411382545 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23340423753249273, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.3266174832858761, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.4402540826981904, 'avg_alt_nm_max': 4.715444141049522, 'mean_insert_max': 692.4372245686701, 'asxs_min': 21, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 44, 'mean_baseq_min': 26, 'sd_baseq_max': 65, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.1064693680121038, 'strand_bias_max': 0.794628547814466, 'rp_sd_min': 0.023557154927037263, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.020698971054048915, 'rp_med_max': 0.9837519380875371}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:41,786] Trial 2987 finished with value: 2682.7709485216365 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23619590870954205, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.259550502824337, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.381482783022217, 'avg_alt_nm_max': 4.728548948876009, 'mean_insert_max': 721.1328458657127, 'asxs_min': 20, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 11, 'mean_baseq_min': 30, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.1134947118867837, 'strand_bias_max': 0.8307090840100022, 'rp_sd_min': 0.02863789036885988, 'rp_sd_min_alt': 14, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.02184527535223572, 'rp_med_max': 0.9867257571075262}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:42,118] Trial 2988 finished with value: 2729.520493315328 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2314036373860538, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.2990045341146395, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.598408865517437, 'avg_alt_nm_max': 4.622089031807921, 'mean_insert_max': 705.4747471354161, 'asxs_min': 19, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 33, 'mean_baseq_min': 33, 'sd_baseq_max': 63, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.10306878215254563, 'strand_bias_max': 0.8071955873959895, 'rp_sd_min': 0.03115692035024608, 'rp_sd_min_alt': 12, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.024342670320133923, 'rp_med_max': 0.9851955252001132}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:42,459] Trial 2989 finished with value: 2672.2472753456277 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2256863007602871, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.2663278057958518, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.586487780920777, 'avg_alt_nm_max': 4.763638940437433, 'mean_insert_max': 678.057890547193, 'asxs_min': 19, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 54, 'mean_baseq_min': 28, 'sd_baseq_max': 66, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.12307600542044426, 'strand_bias_max': 0.8409189538928366, 'rp_sd_min': 0.033838119056879785, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.02023631253279032, 'rp_med_max': 0.9870293382697862}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:42,805] Trial 2990 finished with value: 2486.724669466054 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22030117203570207, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.3814433222518891, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.542900030931293, 'avg_alt_nm_max': 4.564942540129867, 'mean_insert_max': 694.5037059996239, 'asxs_min': 21, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 43, 'mean_baseq_min': 31, 'sd_baseq_max': 66, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.11091680973164168, 'strand_bias_max': 0.8105886870514407, 'rp_sd_min': 0.030200213975392385, 'rp_sd_min_alt': 14, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.018318893684163926, 'rp_med_max': 0.9871805525908001}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:43,140] Trial 2991 finished with value: 2705.869990598385 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23326523187194573, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.3095708526025003, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.4926557196407924, 'avg_alt_nm_max': 4.763144329303149, 'mean_insert_max': 745.7396868430486, 'asxs_min': 20, 'mean_mapq_min': 21, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 52, 'mean_baseq_min': 32, 'sd_baseq_max': 63, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.12838995768828693, 'strand_bias_max': 0.7946662680543469, 'rp_sd_min': 0.025735573368276726, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.021928466380484048, 'rp_med_max': 0.9834168608545529}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:43,506] Trial 2992 finished with value: 5217.893509647353 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22903156904649538, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.7375063184621047, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.601695184404094, 'avg_alt_nm_max': 1.9071362588397638, 'mean_insert_max': 658.2273630995508, 'asxs_min': 22, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 27, 'mean_baseq_min': 24, 'sd_baseq_max': 67, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.10088337523162655, 'strand_bias_max': 0.8232586609470863, 'rp_sd_min': 0.019811988908074365, 'rp_sd_min_alt': 14, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.02017574202002408, 'rp_med_max': 0.9860821166706596}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:43,857] Trial 2993 finished with value: 2516.516941339325 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23445863675914447, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.3470484590281515, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.429943546596434, 'avg_alt_nm_max': 4.676933787512845, 'mean_insert_max': 718.7601699733858, 'asxs_min': 19, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 57, 'mean_baseq_min': 30, 'sd_baseq_max': 65, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.11476660745003078, 'strand_bias_max': 0.7861130240083062, 'rp_sd_min': 0.03385343366882548, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 11, 'rp_med_min': 0.02614280420469001, 'rp_med_max': 0.9899750683597138}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:44,187] Trial 2994 finished with value: 2488.6756063782573 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23754731962506434, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.2704230613301073, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.5219798702612044, 'avg_alt_nm_max': 4.788286178761224, 'mean_insert_max': 679.2011943613827, 'asxs_min': 18, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 7, 'mean_baseq_min': 33, 'sd_baseq_max': 67, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.10669741186473472, 'strand_bias_max': 0.8165706998089548, 'rp_sd_min': 0.0281670925747702, 'rp_sd_min_alt': 12, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.024312815044976142, 'rp_med_max': 0.9870763803703463}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:44,526] Trial 2995 finished with value: 2666.044193922795 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2292212073047176, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.30361762415045, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.596062406908601, 'avg_alt_nm_max': 4.759349189838801, 'mean_insert_max': 712.0487488432234, 'asxs_min': 21, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 39, 'mean_baseq_min': 28, 'sd_baseq_max': 61, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.12008153980289658, 'strand_bias_max': 0.8355108539033217, 'rp_sd_min': 0.024326982070929398, 'rp_sd_min_alt': 14, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.018691429862407745, 'rp_med_max': 0.9855452512439564}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:44,858] Trial 2996 finished with value: 2735.366211458293 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22617417365603024, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.4216342907129405, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.7951797175015631, 'avg_alt_nm_max': 4.605025588977351, 'mean_insert_max': 734.791855615176, 'asxs_min': 20, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 65, 'mean_baseq_min': 33, 'sd_baseq_max': 68, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.0981066599981393, 'strand_bias_max': 0.8287345113143582, 'rp_sd_min': 0.03218664226502123, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 11, 'rp_med_min': 0.023310930097473714, 'rp_med_max': 0.9882845471564534}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:45,189] Trial 2997 finished with value: 2676.4035274512657 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23107712445882342, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'avg_alt_softclip_max': 1.3387242656785943, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.546703615311669, 'avg_alt_nm_max': 4.775784825157036, 'mean_insert_max': 654.3319904625077, 'asxs_min': 18, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 1, 'mean_baseq_min': 26, 'sd_baseq_max': 63, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.110088489597775, 'strand_bias_max': 0.8032749524410349, 'rp_sd_min': 0.021608977015968502, 'rp_sd_min_alt': 14, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.020351088239056556, 'rp_med_max': 0.9841968044904682}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:45,579] Trial 2998 finished with value: 2447.446947055055 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2362442356311789, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'avg_alt_softclip_max': 1.2583023903046768, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.4762963162017466, 'avg_alt_nm_max': 4.704327274304069, 'mean_insert_max': 695.5533889943811, 'asxs_min': 19, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 44, 'mean_baseq_min': 30, 'sd_baseq_max': 65, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.10533921148307979, 'strand_bias_max': 0.8184977920293961, 'rp_sd_min': 0.026697638419481678, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 10, 'rp_med_min': 0.01851778065254504, 'rp_med_max': 0.9881235257891193}. Best is trial 2625 with value: 2415.797952398176.
# [I 2026-04-24 16:59:45,925] Trial 2999 finished with value: 4476.978780303097 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23487186370035362, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 7, 'avg_alt_softclip_max': 1.3822365905777683, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 0.03217159120418778, 'avg_alt_nm_max': 4.799215003127795, 'mean_insert_max': 670.0560143470923, 'asxs_min': 21, 'mean_mapq_min': 21, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 53, 'mean_baseq_min': 32, 'sd_baseq_max': 69, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.09357252446980477, 'strand_bias_max': 0.7912162681252919, 'rp_sd_min': 0.029892981854162566, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 12, 'n_total_min': 11, 'rp_med_min': 0.022020560165774316, 'rp_med_max': 0.9868967970600873}. Best is trial 2625 with value: 2415.797952398176.
# [INFO] Best Weighted Deviance: 2415.7980
# [INFO] Generating report...
# ------------------------------
# FINAL RESULTS
# ------------------------------
# Total Samples:      18
# Total Observed SNVs: 15359
# Total Expected SNVs: 20896.61
# Weighted Deviance:  2415.7980 (Cord weight = 3.0x)
# Mean Obs/Exp Ratio: 0.8620
# Blacklist Blocked:  887 variants (passed filters but hit blacklist)
# Results saved to:   training_results_seed_67
# ------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------
# Configuration
# -----------------------
# Path to the CSV generated in the previous step
CSV_PATH = "training_results/observed_expected.csv"
OUTPUT_PNG = "training_results/observed_vs_expected_plot.png"

# Check if file exists
if not os.path.exists(CSV_PATH):
    print(f"[ERROR] Could not find {CSV_PATH}. Please run the optimization cell first.")
else:
    # Load table
    df = pd.read_csv(CSV_PATH)

    # Convert data arrays
    ages = df["age"].values
    bases = df["bases"].values
    observed = df["observed"].values
    expected = df["expected"].values
    sample_types = df["sample_type"].values

    # Calculate SNV rates per base
    obs_rate = observed / bases
    exp_rate = expected / bases

    # -----------------------
    # Plotting
    # -----------------------
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot Observed (Blue circles)
    ax.scatter(ages, obs_rate, label="Observed", color="#1f77b4", alpha=0.8, marker="o", s=60, edgecolors='k', linewidth=0.5)

    # Plot Expected (Orange crosses)
    ax.scatter(ages, exp_rate, label="Expected", color="#ff7f0e", alpha=0.8, marker="x", s=60, linewidth=2)

    # Styling
    ax.set_xlabel("Age (years)", fontsize=12)
    ax.set_ylabel("SNV rate (SNVs per base)", fontsize=12)
    
    # Handle X-limits (pad slightly around min/max age)
    # If ages has None/NaN (Cord blood sometimes represented as negative or 0), handle gracefully
    valid_ages = ages[~np.isnan(ages)]
    if len(valid_ages) > 0:
        ax.set_xlim(min(valid_ages) - 2, max(valid_ages) + 5)
    else:
        ax.set_xlim(-2, 100)

    # Hardcoded Y-limits from your request
    ax.set_ylim(0, 5.5e-7)
    
    ax.set_title("Observed vs Expected SNV Rate (Training Set)", fontsize=14)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Legend
    ax.legend(loc='upper left', frameon=True, fontsize=10)

    plt.tight_layout()
    
    # Save and Show
    plt.savefig(OUTPUT_PNG, dpi=150)
    print(f"[INFO] Plot saved to: {OUTPUT_PNG}")
    plt.show()
# Out:
# [INFO] Plot saved to: training_results/observed_vs_expected_plot.png

# %%
# Assuming best_thresholds is defined from your Optuna study
ref_entropy_thresh = best_thresholds['ref_entropy_min']

# Calculate failure
fail_entropy = all_variants_df['REF_ENTROPY_40BP'] < ref_entropy_thresh
pct_fail_entropy = (fail_entropy.sum() / len(all_variants_df)) * 100

print(f"Threshold used: {ref_entropy_thresh:.4f}")
print(f"Rows failing ref_entropy filter: {pct_fail_entropy:.2f}%")
# Out:
# Threshold used: 0.8476
# Rows failing ref_entropy filter: 0.01%

# %%
# Extract relevant thresholds
entropy_min = best_thresholds['ref_entropy_min']
depth_max = best_thresholds['depth_percentile_max']
rp_min = best_thresholds['rp_med_min']
rp_max = best_thresholds['rp_med_max']

# Define individual failure masks
fail_ent = all_variants_df['REF_ENTROPY_40BP'] < entropy_min
fail_dep = all_variants_df['DEPTH_PERCENTILE'] > depth_max
fail_rp  = (all_variants_df['RP_MED_SSCS'] <= rp_min) | (all_variants_df['RP_MED_SSCS'] >= rp_max)

# Combine using OR (|)
combined_fail_mask = fail_ent | fail_dep | fail_rp
pct_combined_fail = (combined_fail_mask.sum() / len(all_variants_df)) * 100

print(f"Rows failing (Entropy OR Depth OR RP_Med): {pct_combined_fail:.2f}%")

# Optional Breakdown
print("-" * 20)
print(f"Breakdown of failures:")
print(f" - Ref Entropy: {fail_ent.mean()*100:.2f}%")
print(f" - Max Depth:   {fail_dep.mean()*100:.2f}%")
print(f" - RP Median:   {fail_rp.mean()*100:.2f}%")
# Out:
# Rows failing (Entropy OR Depth OR RP_Med): 5.99%
# --------------------
# Breakdown of failures:
#  - Ref Entropy: 0.01%
#  - Max Depth:   4.31%
#  - RP Median:   1.72%

# %%
# Extract thresholds
entropy_min = best_thresholds['ref_entropy_min']
depth_max = best_thresholds['depth_percentile_max']
rp_min = best_thresholds['rp_med_min']
rp_max = best_thresholds['rp_med_max']

# Define failure masks
fail_ent = all_variants_df['REF_ENTROPY_40BP'] < entropy_min
fail_dep = all_variants_df['DEPTH_PERCENTILE'] > depth_max
fail_rp  = (all_variants_df['RP_MED_SSCS'] <= rp_min) | (all_variants_df['RP_MED_SSCS'] >= rp_max)

# UPDATED: Cord PoN failure only triggers if VAF < 20%
# We use VAF_SSCS as that is your primary metric for frequency in this script
fail_pon_low_vaf = (all_variants_df['IN_CORD_PON'] == "Yes") & (all_variants_df['VAF_SSCS'] < 0.20)

# Combine using OR (|)
composite_fail_mask = fail_ent | fail_dep | fail_rp | fail_pon_low_vaf
pct_composite_fail = (composite_fail_mask.sum() / len(all_variants_df)) * 100

print(f"Results for Composite Filter (Entropy, Depth, RP_Med, and Cord PoN < 20% VAF):")
print(f"Total rows failing any of these criteria: {pct_composite_fail:.2f}%")

print("-" * 30)
print("Individual Failure Contribution:")
print(f" - Ref Entropy:        {fail_ent.mean()*100:.2f}%")
print(f" - Max Depth:          {fail_dep.mean()*100:.2f}%")
print(f" - RP Median:          {fail_rp.mean()*100:.2f}%")
print(f" - Cord PoN (<20% VAF): {fail_pon_low_vaf.mean()*100:.2f}%")

# Quick check on how many PoN hits were 'saved' by being high VAF
pon_hits_total = (all_variants_df['IN_CORD_PON'] == "Yes").sum()
pon_hits_filtered = fail_pon_low_vaf.sum()
print(f"\nNote: Of {pon_hits_total} total PoN matches, {pon_hits_filtered} were <20% VAF and thus filtered.")
# Out:
# Results for Composite Filter (Entropy, Depth, RP_Med, and Cord PoN < 20% VAF):
# Total rows failing any of these criteria: 32.46%
# ------------------------------
# Individual Failure Contribution:
#  - Ref Entropy:        0.00%
#  - Max Depth:          5.44%
#  - RP Median:          2.90%
#  - Cord PoN (<20% VAF): 29.39%
#
# Note: Of 224694 total PoN matches, 126144 were <20% VAF and thus filtered.

# %%
# 1. Initialize the Exome Lookup
# (Using the path from your script configuration)
exome_lookup = BedLookup(EXOME_BED_PATH, "Exome Targets")

# 2. Filter for any variant flagged by the Cord PoN
pon_variants = all_variants_df[all_variants_df['IN_CORD_PON'] == "Yes"].copy()

# 3. Check which of these are inside the Exome
# We use a lambda to check each unique position found in the PoN subset
print("[INFO] Checking PoN positions against Exome BED...")

# To make this faster, we drop duplicates by position before doing the BED lookup
unique_pon_positions = pon_variants[['CHROM', 'POS']].drop_duplicates()

is_in_exome = unique_pon_positions.apply(
    lambda row: exome_lookup.is_overlapped(row['CHROM'], row['POS']), 
    axis=1
)

# 4. Filter the unique positions and count
exome_pon_positions = unique_pon_positions[is_in_exome]
count_unique_pos = len(exome_pon_positions)

# --- Summary Report ---
total_pon_hits = len(pon_variants)
unique_total_pon_pos = len(unique_pon_positions)

print("-" * 30)
print("CORD PON EXOME ANALYSIS")
print("-" * 30)
print(f"Total PoN-flagged rows in data:      {total_pon_hits}")
print(f"Unique PoN positions (Genome-wide):  {unique_total_pon_pos}")
print(f"Unique PoN positions (Exome-only):   {count_unique_pos}")
print("-" * 30)

# Optional: View the first few positions
if count_unique_pos > 0:
    print("Example Exome PoN positions:")
    print(exome_pon_positions.head())
# Out:
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Checking PoN positions against Exome BED...
# ------------------------------
# CORD PON EXOME ANALYSIS
# ------------------------------
# Total PoN-flagged rows in data:      224694
# Unique PoN positions (Genome-wide):  30667
# Unique PoN positions (Exome-only):   30667
# ------------------------------
# Example Exome PoN positions:
#    CHROM      POS
# 2   chr1   942451
# 10  chr1   966227
# 46  chr1  1313807
# 55  chr1  1495668
# 56  chr1  1495680

# %%
# 1. Extract the best thresholds from your Optuna results
sc_max = best_thresholds['avg_alt_softclip_max']
n_max  = best_thresholds['avg_alt_n_count_max']
nm_max = best_thresholds['avg_alt_nm_max']
ins_max = best_thresholds['mean_insert_max']

# 2. Define failure masks
# Fail if value is STRICTLY GREATER than the max threshold
fail_sc  = all_variants_df['AVG_ALT_SOFTCLIP'] > sc_max
fail_n   = all_variants_df['AVG_ALT_N_COUNT'] > n_max
fail_nm  = all_variants_df['AVG_ALT_NM'] > nm_max
fail_ins = all_variants_df['MEAN_INSERT'] > ins_max

# 3. Combine using OR (|) for a composite technical filter
tech_composite_fail = fail_sc | fail_n | fail_nm | fail_ins
pct_tech_composite = (tech_composite_fail.sum() / len(all_variants_df)) * 100

print(f"Results for Technical Quality Filters:")
print(f"Total rows failing ANY of these 4: {pct_tech_composite:.2f}%")

print("-" * 30)
print("Individual Failure Breakdown:")
print(f" - Softclip Max ({sc_max:.2f}):   {fail_sc.mean()*100:.22f}%")
print(f" - N-Count Max ({n_max:.2f}):    {fail_n.mean()*100:.2f}%")
print(f" - NM (Edit Dist) Max ({nm_max:.2f}): {fail_nm.mean()*100:.2f}%")
print(f" - Mean Insert Max ({ins_max:.1f}):  {fail_ins.mean()*100:.2f}%")

# 4. Identifying the "Noisiest" Filter
metrics = {
    "Softclip": fail_sc.sum(),
    "N-Count": fail_n.sum(),
    "NM-Distance": fail_nm.sum(),
    "Insert-Size": fail_ins.sum()
}
most_aggressive = max(metrics, key=metrics.get)
print("-" * 30)
print(f"The most aggressive filter in this group is: {most_aggressive}")
# Out:
# Results for Technical Quality Filters:
# Total rows failing ANY of these 4: 30.02%
# ------------------------------
# Individual Failure Breakdown:
#  - Softclip Max (1.24):   12.1540576434679277184614%
#  - N-Count Max (2.36):    9.13%
#  - NM (Edit Dist) Max (4.72): 26.12%
#  - Mean Insert Max (677.8):  0.03%
# ------------------------------
# The most aggressive filter in this group is: NM-Distance
