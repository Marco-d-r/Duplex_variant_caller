# %%
import csv
import gzip
import json
import math
import os
import sys
import random
import bisect
from typing import Dict, Any, List, Tuple

import numpy as np
import pandas as pd
import optuna

# -----------------------
# Configuration / Hardcoded Paths
# -----------------------
SAMPLES_CSV = "training_processed_metadata.csv"
OUT_DIR = "training_results"
BLACKLIST_BED = "../../resources/master_blacklist.bed" 
ARTEFACT_GENES_BED = "../../resources/master_blacklist.bed"
N_TRIALS = 3000
SEED = 42

# -----------------------
# Constants
# -----------------------
GENOME_SIZE = 6.4e9
R_CORD = 2e-8
EPS = 1e-15
CORD_WEIGHT = 3.0

# Set seeds
random.seed(SEED)
np.random.seed(SEED)

# -----------------------
# Math Helpers
# -----------------------
def poisson_deviance(y_arr: np.ndarray, lam_arr: np.ndarray, weights: np.ndarray = None) -> float:
    y = np.asarray(y_arr, dtype=float)
    lam = np.asarray(lam_arr, dtype=float) + EPS
    
    with np.errstate(divide='ignore', invalid='ignore'):
        log_term = np.log(y / lam)
        term1 = np.where(y > 0, y * log_term, 0.0)
    
    dev = 2.0 * (term1 - (y - lam))
    
    if weights is not None:
        dev = dev * weights
        
    return float(np.sum(dev))

def expected_lambda(sample_type: str, age: float, bases: float) -> float:
    st = sample_type.lower()
    current_age = float(age) if age is not None else 0.0
    
    if "cord" in st:
        rate = R_CORD
    elif "pbmc" in st:
        rate = (16 * current_age + 105) / GENOME_SIZE
    else:
        rate = (22 * current_age + 164) / GENOME_SIZE
        
    return rate * bases

# -----------------------
# BED File Lookup Logic
# -----------------------
class BedLookup:
    def __init__(self, bed_path: str, name: str):
        self.intervals = {} 
        self.name = name
        self._load_bed(bed_path)

    def _load_bed(self, bed_path: str):
        if not os.path.exists(bed_path):
            print(f"[WARN] BED file not found: {bed_path}. {self.name} filter will do nothing.", file=sys.stderr)
            return

        print(f"[INFO] Loading {self.name} from {bed_path}...")
        count = 0
        with open(bed_path, 'r') as f:
            for line in f:
                if line.startswith('#') or not line.strip():
                    continue
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                chrom = parts[0]
                start, end = int(parts[1]), int(parts[2])
                
                if chrom not in self.intervals:
                    self.intervals[chrom] = []
                self.intervals[chrom].append((start, end))
                count += 1
        
        for chrom in self.intervals:
            self.intervals[chrom].sort(key=lambda x: x[0])
        print(f"[INFO] Loaded {count} regions for {self.name}.")

    def is_overlapped(self, chrom: str, pos: int) -> bool:
        if chrom not in self.intervals:
            return False
        
        regions = self.intervals[chrom]
        query_idx = pos - 1 
        
        idx = bisect.bisect_right(regions, (query_idx, float('inf')))
        
        for i in range(max(0, idx - 1), -1, -1):
            start, end = regions[i]
            if end <= query_idx:
                break 
            if start <= query_idx < end:
                return True
        return False

# -----------------------
# VCF Parsing to DataFrame
# -----------------------
def parse_vcf_to_df(vcf_path: str, sample_id: str) -> pd.DataFrame:
    data = []
    
    if not os.path.exists(vcf_path):
        print(f"[WARN] File not found: {vcf_path}", file=sys.stderr)
        return pd.DataFrame()

    openf = gzip.open if vcf_path.endswith(".gz") else open
    
    try:
        with openf(vcf_path, "rt") as fh:
            for line in fh:
                if line.startswith("#"):
                    continue
                fields = line.strip().split("\t")
                
                chrom = fields[0]
                pos = int(fields[1])
                
                info_str = fields[7]
                info_dict = {}
                for item in info_str.split(";"):
                    if "=" in item:
                        k, v = item.split("=", 1)
                        info_dict[k] = v
                    else:
                        info_dict[item] = "Yes" 
                
                info_dict["sample_id"] = sample_id
                info_dict["CHROM"] = chrom
                info_dict["POS"] = pos
                data.append(info_dict)
    except Exception as e:
        print(f"[ERROR] Error reading {vcf_path}: {e}", file=sys.stderr)
        return pd.DataFrame()

    if not data:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    
    # --- Type Conversion ---
    def to_num(col, dtype, default):
        if col in df.columns:
            return pd.to_numeric(df[col], errors='coerce').fillna(default).astype(dtype)
        return pd.Series([default]*len(df), index=df.index, dtype=dtype)

    def to_str(col, default):
        if col in df.columns:
            return df[col].fillna(default)
        return pd.Series([default]*len(df), index=df.index)

    df['CHROM'] = to_str('CHROM', 'chr1')
    df['POS'] = to_num('POS', int, 0)

    # 1. Base Counts
    df['N_ALT_SSCS'] = to_num('N_ALT_SSCS', int, 0)
    df['N_TOTAL'] = to_num('N_TOTAL', int, 0)
    df['N_ALT'] = to_num('N_ALT', int, 0) 
    df['N_TOTAL_SSCS'] = to_num('N_TOTAL_SSCS', int, 0)
    df['N_TOTAL_SSCS'] = np.where(df['N_TOTAL_SSCS'] <= 0, df['N_TOTAL'], df['N_TOTAL_SSCS'])

    df['DIST_TO_INDEL'] = to_num('DIST_TO_INDEL', int, -1)
    df['HOMOPOLYMER_LEN'] = to_num('HOMOPOLYMER_LEN', int, 0)
    df['DEPTH_PERCENTILE'] = to_num('DEPTH_PERCENTILE', int, 50)

    # 2. Integer Metrics
    df['VARIANTS_20BP'] = to_num('VARIANTS_20BP', int, 0)
    df['VARIANTS_250BP'] = to_num('VARIANTS_250BP', int, 0)
    df['MEDIAN_DIST_TO_SOFTCLIP'] = to_num('MEDIAN_DIST_TO_SOFTCLIP', int, 1000)

    # 3. Float Metrics
    df['AVG_ASXS'] = to_num('AVG_ALT_ASXS', float, 0.0) 
    df['MEAN_MAPQ'] = to_num('MEAN_ALT_MAPQ', float, 0.0) 
    df['MEAN_BASEQ'] = to_num('MEAN_ALT_BASEQ', float, 0.0) 
    df['GC_CONTENT'] = to_num('GC_CONTENT', float, 0.5)
    df['STRAND_BIAS_SSCS'] = to_num('STRAND_BIAS_SSCS', float, 0.5)
    df['RP_SD_SSCS'] = to_num('RP_SD_SSCS', float, 0.0)
    df['RP_MED_SSCS'] = to_num('RP_MED_SSCS', float, 0.5)
    df['AVG_ALTREAD_VARIANTS'] = to_num('AVG_ALTREAD_VARIANTS', float, 0.0)
    df['REF_ENTROPY_40BP'] = to_num('REF_ENTROPY_40BP', float, 2.0)
    df['AVG_ALT_SOFTCLIP'] = to_num('AVG_ALT_SOFTCLIP', float, 0.0)
    df['AVG_ALT_N_COUNT'] = to_num('AVG_ALT_N_COUNT', float, 0.0)
    df['AVG_ALT_NM'] = to_num('AVG_ALT_NM', float, 0.0)
    df['MEAN_INSERT'] = to_num('MEAN_INSERT', float, 200.0)
    
    # --- ADDED: READ POSITION ---
    df['AVG_READ_POSITION'] = to_num('AVG_READ_POSITION', float, 75.0)

    # 4. Flags
    df['IN_CORD_PON'] = to_str('IN_CB_PON', "No")
    df['IN_GNOMAD_COMMON'] = to_str('IN_GNOMAD_COMMON', "No")
    df['IN_ENCODE_BLACKLIST'] = to_str('IN_ENCODE_BLACKLIST', "No")
    df['IN_REPEATMASKER'] = to_str('IN_REPEATMASKER', "No")

    # 5. VAFs
    with np.errstate(divide='ignore', invalid='ignore'):
        df['VAF_DCS'] = df['N_ALT'] / df['N_TOTAL']
        df['VAF_DCS'] = df['VAF_DCS'].fillna(0.0)
        df['VAF_SSCS'] = df['N_ALT_SSCS'] / df['N_TOTAL_SSCS']
        df['VAF_SSCS'] = df['VAF_SSCS'].fillna(0.0)

    return df

# -----------------------
# Vectorized Filtering
# -----------------------
def get_passing_mask(df: pd.DataFrame, thresholds: Dict[str, Any], pon_flags: Dict[str, bool], ignore_blacklists: bool = False) -> pd.Series:
    # 1. BASELINE HARD FILTERS
    mask = (df['N_ALT_SSCS'] > 1) & \
           (df['IN_ENCODE_BLACKLIST'] != "Yes") & \
           (df['IN_REPEATMASKER'] != "Yes")
    
    # --- ADDED: OxoG / Read Position Hard Filter ---
    # Removes variants too close to the start (<4) or end (>138) of the read
    mask &= (df['AVG_READ_POSITION'] >= 4) & (df['AVG_READ_POSITION'] <= 138)

    if pon_flags.get("use_cord_pon", False):
        mask &= (df['IN_CORD_PON'] != "Yes")

    if not ignore_blacklists:
        mask &= (df['IN_CLUSTER_BLACKLIST'] == False)
        mask &= (df['IN_ARTEFACT_BLACKLIST'] == False)

    # 2. DEPTH
    mask &= (df['N_TOTAL'] >= thresholds['n_total_min'])
    mask &= (df['DEPTH_PERCENTILE'] <= thresholds['depth_percentile_max'])

    # 3. QUALITY METRICS
    mask &= (df['AVG_ASXS'] > thresholds['asxs_min'])
    mask &= (df['MEAN_MAPQ'] >= thresholds['mean_mapq_min'])
    mask &= (df['MEAN_BASEQ'] >= thresholds['mean_baseq_min'])
    mask &= ((df['DIST_TO_INDEL'] == -1) | (df['DIST_TO_INDEL'] >= thresholds['dist_to_indel_min']))

    # 4. TUNABLE FILTERS
    mask &= (df['VARIANTS_20BP'] <= thresholds['variants_20bp_max'])
    mask &= (df['VARIANTS_250BP'] <= thresholds['variants_250bp_max'])
    mask &= (df['REF_ENTROPY_40BP'] >= thresholds['ref_entropy_min'])
    mask &= (df['AVG_ALT_SOFTCLIP'] <= thresholds['avg_alt_softclip_max'])
    mask &= (df['MEDIAN_DIST_TO_SOFTCLIP'] >= thresholds['dist_to_softclip_min'])
    mask &= (df['AVG_ALT_N_COUNT'] <= thresholds['avg_alt_n_count_max'])
    mask &= (df['AVG_ALT_NM'] <= thresholds['avg_alt_nm_max'])
    mask &= (df['MEAN_INSERT'] <= thresholds['mean_insert_max'])

    # 5. CONTEXT & STRAND
    mask &= (df['GC_CONTENT'] >= thresholds['gc_content_min']) & (df['GC_CONTENT'] <= thresholds['gc_content_max'])
    mask &= (df['HOMOPOLYMER_LEN'] <= thresholds['homopolymer_len_max'])

    # Strand Bias 
    enough_reads_sb = df['N_ALT_SSCS'] >= thresholds['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < thresholds['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > thresholds['strand_bias_max'])
    mask &= ~(enough_reads_sb & bad_bias)

    # RP SD 
    enough_reads_rp = df['N_ALT_SSCS'] >= thresholds['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < thresholds['rp_sd_min']
    mask &= ~(enough_reads_rp & bad_rp_sd)

    # RP MED
    mask &= (df['RP_MED_SSCS'] > thresholds['rp_med_min']) & (df['RP_MED_SSCS'] < thresholds['rp_med_max'])

    # 6. COMPLEX LOGIC
    cond1 = df['AVG_ALTREAD_VARIANTS'] > thresholds['avg_altread_variants_max']
    cond2 = (df['AVG_ALTREAD_VARIANTS'] > thresholds['avg_altread_variants_max_for_high_vaf']) & \
            (df['VAF_DCS'] > thresholds['avg_altread_high_vaf_cutoff'])
    mask &= ~(cond1 | cond2)

    # 7. GERMLINE & COMMON
    mask &= (df['VAF_SSCS'] <= thresholds['germline_vaf_max'])
    high_vaf_gnomad = (df['VAF_SSCS'] > thresholds['gnomad_vaf_cutoff'])
    is_common = (df['IN_GNOMAD_COMMON'] == "Yes") 
    mask &= ~(high_vaf_gnomad & is_common)

    return mask

# -----------------------
# Optimization Objective
# -----------------------
def make_objective(all_variants_df: pd.DataFrame, samples_meta: List[Dict]):
    
    expected_lambdas = []
    weights = []
    
    for s in samples_meta:
        expected_lambdas.append(expected_lambda(s['sample_type'], s['age'], s['bases']))
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)
            
    exp_arr = np.array(expected_lambdas)
    weights_arr = np.array(weights)

    def objective(trial):
        thresholds = {
            "germline_vaf_max": trial.suggest_float("germline_vaf_max", 0.20, 0.20),
            "gnomad_vaf_cutoff": trial.suggest_float("gnomad_vaf_cutoff", 0.10, 0.25),
            "depth_percentile_max": trial.suggest_int("depth_percentile_max", 90, 99),
            "variants_20bp_max": trial.suggest_int("variants_20bp_max", 0, 4),
            "variants_250bp_max": trial.suggest_int("variants_250bp_max", 0, 15),
            "ref_entropy_min": trial.suggest_float("ref_entropy_min", 0.0, 2.1),
            "avg_alt_softclip_max": trial.suggest_float("avg_alt_softclip_max", 0.0, 2.0),
            "dist_to_softclip_min": trial.suggest_int("dist_to_softclip_min", 0, 5),
            "avg_alt_n_count_max": trial.suggest_float("avg_alt_n_count_max", 0.0, 3.0),
            "avg_alt_nm_max": trial.suggest_float("avg_alt_nm_max", 0.0, 5.0),
            "mean_insert_max": trial.suggest_float("mean_insert_max", 80, 800.0),
            "asxs_min": trial.suggest_int("asxs_min", 10, 60),
            "mean_mapq_min": trial.suggest_int("mean_mapq_min", 20, 60),
            "dist_to_indel_min": trial.suggest_int("dist_to_indel_min", 0, 500),
            "mean_baseq_min": trial.suggest_int("mean_baseq_min", 20, 120),
            "gc_content_min": trial.suggest_float("gc_content_min", 0.0, 0.3),
            "gc_content_max": trial.suggest_float("gc_content_max", 0.85, 1.0),
            "strand_bias_n_alt_min": trial.suggest_int("strand_bias_n_alt_min", 1, 20),
            "strand_bias_min": trial.suggest_float("strand_bias_min", 0.0, 0.3),
            "strand_bias_max": trial.suggest_float("strand_bias_max", 0.7, 1.0),
            "rp_sd_min": trial.suggest_float("rp_sd_min", 0.0, 0.1),
            "rp_sd_min_alt": trial.suggest_int("rp_sd_min_alt", 1, 10),
            "homopolymer_len_max": trial.suggest_int("homopolymer_len_max", 0, 12),
            "avg_altread_variants_max": trial.suggest_float("avg_altread_variants_max", 0, 10.0),
            "avg_altread_variants_max_for_high_vaf": trial.suggest_float("avg_altread_variants_max_for_high_vaf", 0, 10.0),
            "avg_altread_high_vaf_cutoff": trial.suggest_float("avg_altread_high_vaf_cutoff", 0.05, 0.35),
            "n_total_min": trial.suggest_int("n_total_min", 1, 30),
            "rp_med_min": trial.suggest_float("rp_med_min", 0.03, 0.1),
            "rp_med_max": trial.suggest_float("rp_med_max", 0.9, 0.97),
        }

        pon_flags = {"use_cord_pon": True}

        pass_mask = get_passing_mask(all_variants_df, thresholds, pon_flags)
        obs_series = all_variants_df[pass_mask].groupby('sample_id').size()
        obs_arr = np.array([obs_series.get(s['sample_id'], 0) for s in samples_meta])

        loss = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
        return loss

    return objective

# -----------------------
# Reporting
# -----------------------
def evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, outdir):
    os.makedirs(outdir, exist_ok=True)
    
    pass_mask_final = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=False)
    pass_mask_clean = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=True)
    
    variants_saved_by_blacklist = pass_mask_clean & (~pass_mask_final)
    count_saved_by_blacklist = variants_saved_by_blacklist.sum()

    obs_series = all_variants_df[pass_mask_final].groupby('sample_id').size()
    
    observed = []
    expected = []
    ids = []
    ages = []
    bases = []
    types = []
    weights = []

    for s in samples_meta:
        sid = s['sample_id']
        obs = obs_series.get(sid, 0)
        lam = expected_lambda(s['sample_type'], s['age'], s['bases'])
        
        ids.append(sid)
        observed.append(obs)
        expected.append(lam)
        ages.append(s['age'])
        bases.append(s['bases'])
        types.append(s['sample_type'])
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)

    obs_arr = np.array(observed)
    exp_arr = np.array(expected)
    weights_arr = np.array(weights)

    with open(os.path.join(outdir, "best_thresholds.json"), "w") as fh:
        config_out = {
            "thresholds": best_thresholds, 
            "pon_flags": pon_flags,
            "blacklists_enforced": True,
            "cord_penalty_weight": CORD_WEIGHT
        }
        json.dump(config_out, fh, indent=2)

    ratio = obs_arr / (exp_arr + EPS)
    dev = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
    mean_ratio = float(np.mean(ratio))
    
    summary = {
        "n_samples": len(samples_meta),
        "obs_mean_over_expected": mean_ratio,
        "total_observed": int(np.sum(obs_arr)),
        "total_expected": float(np.sum(exp_arr)),
        "weighted_poisson_deviance": dev,
        "variants_blocked_by_blacklists": int(count_saved_by_blacklist)
    }
    with open(os.path.join(outdir, "summary.json"), "w") as fh:
        json.dump(summary, fh, indent=2)

    res_df = pd.DataFrame({
        "sample_id": ids,
        "sample_type": types,
        "age": ages,
        "bases": bases,
        "observed": observed,
        "expected": expected,
        "weight_used": weights 
    })
    res_df.to_csv(os.path.join(outdir, "observed_expected.csv"), index=False)
    
    print("-" * 30)
    print("FINAL RESULTS")
    print("-" * 30)
    print(f"Total Samples:      {len(samples_meta)}")
    print(f"Total Observed SNVs: {int(np.sum(obs_arr))}")
    print(f"Total Expected SNVs: {float(np.sum(exp_arr)):.2f}")
    print(f"Weighted Deviance:  {dev:.4f} (Cord weight = {CORD_WEIGHT}x)")
    print(f"Mean Obs/Exp Ratio: {mean_ratio:.4f}")
    print(f"Blacklist Blocked:  {count_saved_by_blacklist} variants (passed filters but hit blacklist)")
    print(f"Results saved to:   {outdir}")
    print("-" * 30)

# -----------------------
# Execution Block
# -----------------------
if __name__ == "__main__":
    print(f"[INFO] Reading metadata from {SAMPLES_CSV}...")
    samples_meta = []
    with open(SAMPLES_CSV, newline='') as csvfile:
        rdr = csv.DictReader(csvfile)
        for r in rdr:
            samples_meta.append({
                "sample_id": r["sample_id"],
                "vcf_path": r["vcf_path"],
                "sample_type": r["sample_type"].lower(),
                "age": float(r["age"]) if r.get("age") else None,
                "bases": float(r["callable_sequenced_bases_padded"]),
            })
    print(f"[INFO] Loaded {len(samples_meta)} samples.")

    print("[INFO] Loading VCFs into DataFrame...")
    df_list = []
    for s in samples_meta:
        df_list.append(parse_vcf_to_df(s["vcf_path"], s["sample_id"]))

    if df_list:
        all_variants_df = pd.concat(df_list, ignore_index=True)
    else:
        print("[ERROR] No VCF data loaded. Checking paths in CSV.")
        all_variants_df = pd.DataFrame()

    print(f"[INFO] Total variants loaded: {len(all_variants_df)}")

    if not all_variants_df.empty:
        bed_lookup_cluster = BedLookup(BLACKLIST_BED, "Cluster Blacklist")
        all_variants_df['IN_CLUSTER_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_cluster.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        bed_lookup_genes = BedLookup(ARTEFACT_GENES_BED, "Artefact Gene Blacklist")
        all_variants_df['IN_ARTEFACT_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_genes.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        hits_cluster = all_variants_df['IN_CLUSTER_BLACKLIST'].sum()
        hits_genes = all_variants_df['IN_ARTEFACT_BLACKLIST'].sum()
        print(f"[INFO] Found {hits_cluster} variants in Cluster blacklist.")
        print(f"[INFO] Found {hits_genes} variants in Artefact Gene blacklist.")

        print(f"[INFO] Starting Optuna (Trials={N_TRIALS})...")
        study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=SEED))
        
        objective = make_objective(all_variants_df, samples_meta)
        study.optimize(objective, n_trials=N_TRIALS)

        print(f"[INFO] Best Weighted Deviance: {study.best_value:.4f}")

        best_params = study.best_params
        best_thresholds = {k: v for k, v in best_params.items()}
        pon_flags = {"use_cord_pon": True}
        
        print("[INFO] Generating report...")
        evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, OUT_DIR)
# Out:
# [INFO] Reading metadata from training_processed_metadata.csv...
# [INFO] Loaded 18 samples.
# [INFO] Loading VCFs into DataFrame...
# [INFO] Total variants loaded: 1154904
# [INFO] Loading Cluster Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Cluster Blacklist.
# [INFO] Loading Artefact Gene Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Artefact Gene Blacklist.
# [I 2026-04-17 11:39:19,399] A new study created in memory with name: no-name-c2d81162-c738-4c14-b196-2d737ff8bb61
# [INFO] Found 211262 variants in Cluster blacklist.
# [INFO] Found 211262 variants in Artefact Gene blacklist.
# [INFO] Starting Optuna (Trials=3000)...
# [I 2026-04-17 11:39:19,885] Trial 0 finished with value: 31547.809644567074 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1561810178271044, 'depth_percentile_max': 99, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'ref_entropy_min': 0.3276391449291167, 'avg_alt_softclip_max': 0.3119890406724053, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.5985284373248057, 'avg_alt_nm_max': 3.005575058716044, 'mean_insert_max': 589.8122560131527, 'asxs_min': 11, 'mean_mapq_min': 59, 'dist_to_indel_min': 417, 'mean_baseq_min': 41, 'gc_content_min': 0.05454749016213018, 'gc_content_max': 0.8775106764780151, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.15742692948967135, 'strand_bias_max': 0.8295835055926347, 'rp_sd_min': 0.029122914019804193, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 1, 'avg_altread_variants_max': 2.9214464853521815, 'avg_altread_variants_max_for_high_vaf': 3.663618432936917, 'avg_altread_high_vaf_cutoff': 0.18682099526511078, 'n_total_min': 24, 'rp_med_min': 0.04397716475108518, 'rp_med_max': 0.9359964106889528}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:20,087] Trial 1 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18886218532930638, 'depth_percentile_max': 90, 'variants_20bp_max': 3, 'variants_250bp_max': 2, 'ref_entropy_min': 0.136608345269087, 'avg_alt_softclip_max': 1.8977710745066665, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 2.4251920443493833, 'avg_alt_nm_max': 1.5230688458668533, 'mean_insert_max': 150.32392208459638, 'asxs_min': 44, 'mean_mapq_min': 38, 'dist_to_indel_min': 61, 'mean_baseq_min': 70, 'gc_content_min': 0.010316556334565519, 'gc_content_max': 0.9863980603118173, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.19875668530619459, 'strand_bias_max': 0.7935133228268233, 'rp_sd_min': 0.05200680211778108, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 9.695846277645586, 'avg_altread_variants_max_for_high_vaf': 7.7513282336111455, 'avg_altread_high_vaf_cutoff': 0.3318496824692567, 'n_total_min': 27, 'rp_med_min': 0.07185299851677596, 'rp_med_max': 0.9645311964516181}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:20,292] Trial 2 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11327387530778793, 'depth_percentile_max': 91, 'variants_20bp_max': 0, 'variants_250bp_max': 5, 'ref_entropy_min': 0.8162223083479122, 'avg_alt_softclip_max': 0.5426980635477918, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 1.0702599800807677, 'avg_alt_nm_max': 1.4046725484369038, 'mean_insert_max': 470.7411798739389, 'asxs_min': 17, 'mean_mapq_min': 52, 'dist_to_indel_min': 37, 'mean_baseq_min': 119, 'gc_content_min': 0.23167343078899721, 'gc_content_max': 0.8798073522301258, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.24463842853645024, 'strand_bias_max': 0.9120572031542851, 'rp_sd_min': 0.07290071680409874, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 0, 'avg_altread_variants_max': 3.5846572854427263, 'avg_altread_variants_max_for_high_vaf': 1.1586905952512971, 'avg_altread_high_vaf_cutoff': 0.30893102776267806, 'n_total_min': 19, 'rp_med_min': 0.053162861739685444, 'rp_med_max': 0.9044490845200217}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:20,495] Trial 3 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.14664734825734935, 'depth_percentile_max': 93, 'variants_20bp_max': 3, 'variants_250bp_max': 10, 'ref_entropy_min': 1.8631467594102857, 'avg_alt_softclip_max': 0.9444298503238986, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.1397343616689852, 'avg_alt_nm_max': 3.803925243084487, 'mean_insert_max': 484.1195822500373, 'asxs_min': 49, 'mean_mapq_min': 40, 'dist_to_indel_min': 261, 'mean_baseq_min': 63, 'gc_content_min': 0.007625738023228556, 'gc_content_max': 0.8661837140489956, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.1909231233791341, 'strand_bias_max': 0.794306794322898, 'rp_sd_min': 0.05085706911647028, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 4.103829230356297, 'avg_altread_variants_max_for_high_vaf': 7.555511385430487, 'avg_altread_high_vaf_cutoff': 0.11863944964748674, 'n_total_min': 3, 'rp_med_min': 0.050282601703963765, 'rp_med_max': 0.9112854901077804}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:20,706] Trial 4 finished with value: 36832.15919872974 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23945464785138595, 'depth_percentile_max': 98, 'variants_20bp_max': 3, 'variants_250bp_max': 13, 'ref_entropy_min': 1.6877113614881405, 'avg_alt_softclip_max': 0.3731401177720717, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 1.6180267257469523, 'avg_alt_nm_max': 4.037200775820312, 'mean_insert_max': 725.1857359449151, 'asxs_min': 26, 'mean_mapq_min': 24, 'dist_to_indel_min': 114, 'mean_baseq_min': 63, 'gc_content_min': 0.24540442977674792, 'gc_content_max': 0.9791095874884516, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.1532241907732697, 'strand_bias_max': 0.8252233009446337, 'rp_sd_min': 0.022210781047073025, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 9.429097039125192, 'avg_altread_variants_max_for_high_vaf': 3.2320293202075523, 'avg_altread_high_vaf_cutoff': 0.20563718652300983, 'n_total_min': 22, 'rp_med_min': 0.05545407216655058, 'rp_med_max': 0.9680247457904673}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:20,908] Trial 5 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2443670942413167, 'depth_percentile_max': 92, 'variants_20bp_max': 2, 'variants_250bp_max': 4, 'ref_entropy_min': 0.598165038192682, 'avg_alt_softclip_max': 0.07377389470906559, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 1.5080370696865844, 'avg_alt_nm_max': 0.25739375624994676, 'mean_insert_max': 280.62545425036024, 'asxs_min': 56, 'mean_mapq_min': 29, 'dist_to_indel_min': 72, 'mean_baseq_min': 69, 'gc_content_min': 0.2956951362331802, 'gc_content_max': 0.886308290726725, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.22848588459861527, 'strand_bias_max': 0.7712912631977199, 'rp_sd_min': 0.07282163486118597, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 8, 'avg_altread_variants_max': 6.335297107608947, 'avg_altread_variants_max_for_high_vaf': 5.357746840747585, 'avg_altread_high_vaf_cutoff': 0.0770869310163225, 'n_total_min': 26, 'rp_med_min': 0.05245460454802151, 'rp_med_max': 0.9130562957279899}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:21,112] Trial 6 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1061162712332146, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 0, 'ref_entropy_min': 1.07539542242849, 'avg_alt_softclip_max': 0.4529915503958759, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.5230992870149743, 'avg_alt_nm_max': 3.45468869051233, 'mean_insert_max': 358.4494493363869, 'asxs_min': 57, 'mean_mapq_min': 25, 'dist_to_indel_min': 170, 'mean_baseq_min': 31, 'gc_content_min': 0.2774080854835688, 'gc_content_max': 0.9816009030071472, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.1979952138102537, 'strand_bias_max': 0.9451666600603648, 'rp_sd_min': 0.055520081159946236, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 0.9310276780589921, 'avg_altread_variants_max_for_high_vaf': 8.972157579533267, 'avg_altread_high_vaf_cutoff': 0.3201254171489991, 'n_total_min': 19, 'rp_med_min': 0.053732085373409046, 'rp_med_max': 0.9244446702228862}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:21,313] Trial 7 finished with value: 79056.55008521218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2088933518305359, 'depth_percentile_max': 98, 'variants_20bp_max': 4, 'variants_250bp_max': 12, 'ref_entropy_min': 1.3482664569240044, 'avg_alt_softclip_max': 0.16827992999009767, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.695662565581238, 'avg_alt_nm_max': 3.0321452982979498, 'mean_insert_max': 86.62187716397335, 'asxs_min': 15, 'mean_mapq_min': 47, 'dist_to_indel_min': 2, 'mean_baseq_min': 36, 'gc_content_min': 0.16462013680997584, 'gc_content_max': 0.953784279653904, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.06728079283816793, 'strand_bias_max': 0.9136537664042608, 'rp_sd_min': 0.02372490874968001, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 9, 'avg_altread_variants_max': 6.496328990472147, 'avg_altread_variants_max_for_high_vaf': 8.49223410494178, 'avg_altread_high_vaf_cutoff': 0.247283867690103, 'n_total_min': 18, 'rp_med_min': 0.036557233747966475, 'rp_med_max': 0.9257401062141604}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:21,516] Trial 8 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1397803551522588, 'depth_percentile_max': 92, 'variants_20bp_max': 4, 'variants_250bp_max': 6, 'ref_entropy_min': 1.873297765871938, 'avg_alt_softclip_max': 1.2622772519945258, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 1.5079112793155764, 'avg_alt_nm_max': 2.8845194231317954, 'mean_insert_max': 434.612739549582, 'asxs_min': 19, 'mean_mapq_min': 49, 'dist_to_indel_min': 140, 'mean_baseq_min': 22, 'gc_content_min': 0.19364168877215035, 'gc_content_max': 0.8765666019110573, 'strand_bias_n_alt_min': 19, 'strand_bias_min': 0.2861785731007762, 'strand_bias_max': 0.9744593170661345, 'rp_sd_min': 0.03701587002554444, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 4.281841483173143, 'avg_altread_variants_max_for_high_vaf': 9.666548190436696, 'avg_altread_high_vaf_cutoff': 0.33908599312677584, 'n_total_min': 26, 'rp_med_min': 0.050611422444871, 'rp_med_max': 0.9269568410021348}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:21,720] Trial 9 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22767050072752854, 'depth_percentile_max': 93, 'variants_20bp_max': 0, 'variants_250bp_max': 8, 'ref_entropy_min': 1.9659250257376402, 'avg_alt_softclip_max': 1.392059593349946, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.2915294813123056, 'avg_alt_nm_max': 3.075036133495849, 'mean_insert_max': 792.8387720750695, 'asxs_min': 17, 'mean_mapq_min': 41, 'dist_to_indel_min': 439, 'mean_baseq_min': 94, 'gc_content_min': 0.20910472229858038, 'gc_content_max': 0.9553726125980664, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.088077553279348, 'strand_bias_max': 0.9428083466435541, 'rp_sd_min': 0.08101133946791808, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 11, 'avg_altread_variants_max': 5.113423988609378, 'avg_altread_variants_max_for_high_vaf': 5.015162946871996, 'avg_altread_high_vaf_cutoff': 0.2894885536900325, 'n_total_min': 20, 'rp_med_min': 0.07913768140803924, 'rp_med_max': 0.955705486860527}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:21,934] Trial 10 finished with value: 77581.3495250657 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16461580820139088, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 9, 'ref_entropy_min': 0.0322722483890191, 'avg_alt_softclip_max': 0.7960866844403535, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.9284196995739857, 'avg_alt_nm_max': 4.734809381950745, 'mean_insert_max': 611.651992202015, 'asxs_min': 33, 'mean_mapq_min': 58, 'dist_to_indel_min': 461, 'mean_baseq_min': 49, 'gc_content_min': 0.07868141364400612, 'gc_content_max': 0.9083922631853261, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.004257669087448901, 'strand_bias_max': 0.706223412488707, 'rp_sd_min': 0.0010515138660440668, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 6, 'avg_altread_variants_max': 0.5267420312430842, 'avg_altread_variants_max_for_high_vaf': 0.8519112997392657, 'avg_altread_high_vaf_cutoff': 0.1542900291489748, 'n_total_min': 11, 'rp_med_min': 0.09304238824590094, 'rp_med_max': 0.9451356175204907}. Best is trial 0 with value: 31547.809644567074.
# [I 2026-04-17 11:39:22,157] Trial 11 finished with value: 27225.924392372013 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18808522855774257, 'depth_percentile_max': 99, 'variants_20bp_max': 2, 'variants_250bp_max': 15, 'ref_entropy_min': 1.4194506021084838, 'avg_alt_softclip_max': 0.4483435147314012, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.0565138243868026, 'avg_alt_nm_max': 4.628177598781944, 'mean_insert_max': 719.6154937107202, 'asxs_min': 29, 'mean_mapq_min': 20, 'dist_to_indel_min': 331, 'mean_baseq_min': 49, 'gc_content_min': 0.09288438119756248, 'gc_content_max': 0.923745602467622, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.12767683930914867, 'strand_bias_max': 0.8503207716804089, 'rp_sd_min': 0.016248611082576532, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 9.826861567778046, 'avg_altread_variants_max_for_high_vaf': 2.888618764578738, 'avg_altread_high_vaf_cutoff': 0.21784383190491063, 'n_total_min': 30, 'rp_med_min': 0.030331808375716265, 'rp_med_max': 0.9447627926389615}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:22,369] Trial 12 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18263840411438773, 'depth_percentile_max': 99, 'variants_20bp_max': 2, 'variants_250bp_max': 15, 'ref_entropy_min': 0.46020852272931256, 'avg_alt_softclip_max': 0.683100189870985, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.1462816854586064, 'avg_alt_nm_max': 4.839047315074387, 'mean_insert_max': 628.1159179220878, 'asxs_min': 31, 'mean_mapq_min': 32, 'dist_to_indel_min': 337, 'mean_baseq_min': 45, 'gc_content_min': 0.09945339551097515, 'gc_content_max': 0.9149278890804092, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.11881800379901832, 'strand_bias_max': 0.8651708337400958, 'rp_sd_min': 7.055239704869404e-05, 'rp_sd_min_alt': 4, 'homopolymer_len_max': 0, 'avg_altread_variants_max': 2.071396070608615, 'avg_altread_variants_max_for_high_vaf': 3.069205577324292, 'avg_altread_high_vaf_cutoff': 0.19970526081543485, 'n_total_min': 30, 'rp_med_min': 0.030857914245546215, 'rp_med_max': 0.9418937149709332}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:22,587] Trial 13 finished with value: 61919.30329428075 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20253627758530038, 'depth_percentile_max': 97, 'variants_20bp_max': 1, 'variants_250bp_max': 15, 'ref_entropy_min': 1.3731563221434888, 'avg_alt_softclip_max': 0.20220441669446365, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.0532965363823883, 'avg_alt_nm_max': 2.2416701488051296, 'mean_insert_max': 615.7276915480245, 'asxs_min': 10, 'mean_mapq_min': 60, 'dist_to_indel_min': 367, 'mean_baseq_min': 50, 'gc_content_min': 0.08177533508679816, 'gc_content_max': 0.8500975366481053, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.14108381192342562, 'strand_bias_max': 0.8500345203940509, 'rp_sd_min': 0.021393045397521838, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 6, 'avg_altread_variants_max': 7.596979899075093, 'avg_altread_variants_max_for_high_vaf': 3.2194178251196672, 'avg_altread_high_vaf_cutoff': 0.20083449411634058, 'n_total_min': 30, 'rp_med_min': 0.039406787797233764, 'rp_med_max': 0.9474186139360684}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:22,812] Trial 14 finished with value: 37075.08388856416 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16148628651383629, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 11, 'ref_entropy_min': 1.2961684984818715, 'avg_alt_softclip_max': 1.1551829330773904, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.987273467757306, 'avg_alt_nm_max': 2.023026799887302, 'mean_insert_max': 703.940965587901, 'asxs_min': 41, 'mean_mapq_min': 20, 'dist_to_indel_min': 366, 'mean_baseq_min': 91, 'gc_content_min': 0.1181659957789147, 'gc_content_max': 0.8971501092454027, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.048282708406680405, 'strand_bias_max': 0.7310153539082545, 'rp_sd_min': 0.033417404610945174, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 8.59172659493634, 'avg_altread_variants_max_for_high_vaf': 2.10794973146392, 'avg_altread_high_vaf_cutoff': 0.25353414970425947, 'n_total_min': 12, 'rp_med_min': 0.0403599493848788, 'rp_med_max': 0.9347621664845203}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:23,031] Trial 15 finished with value: 80529.95575954908 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.13517583522378465, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 13, 'ref_entropy_min': 0.38587735688767677, 'avg_alt_softclip_max': 0.0005242246094260272, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.000920222489964, 'avg_alt_nm_max': 4.199758560524474, 'mean_insert_max': 538.5577912563222, 'asxs_min': 25, 'mean_mapq_min': 35, 'dist_to_indel_min': 266, 'mean_baseq_min': 88, 'gc_content_min': 0.04680188210181176, 'gc_content_max': 0.9360701169810198, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.11194785845191735, 'strand_bias_max': 0.868990879011016, 'rp_sd_min': 0.09619504295502818, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 1, 'avg_altread_variants_max': 2.6408833561501233, 'avg_altread_variants_max_for_high_vaf': 6.224543798910076, 'avg_altread_high_vaf_cutoff': 0.1605204035670888, 'n_total_min': 24, 'rp_med_min': 0.03299216260557492, 'rp_med_max': 0.9541447996850296}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:23,246] Trial 16 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.21020787005975694, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 7, 'ref_entropy_min': 0.9315647528181984, 'avg_alt_softclip_max': 0.37529647360776186, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.5062008838125727, 'avg_alt_nm_max': 0.31772135685050973, 'mean_insert_max': 714.3378219517658, 'asxs_min': 10, 'mean_mapq_min': 55, 'dist_to_indel_min': 412, 'mean_baseq_min': 37, 'gc_content_min': 0.13086745225224053, 'gc_content_max': 0.9321210493725727, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.16127086453413017, 'strand_bias_max': 0.8206688740692796, 'rp_sd_min': 0.014397616936172808, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 5.69705355921529, 'avg_altread_variants_max_for_high_vaf': 4.061527444869388, 'avg_altread_high_vaf_cutoff': 0.249703198115519, 'n_total_min': 13, 'rp_med_min': 0.04310461856350344, 'rp_med_max': 0.9353729718398907}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:23,469] Trial 17 finished with value: 32634.301781812104 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16655907047972482, 'depth_percentile_max': 99, 'variants_20bp_max': 3, 'variants_250bp_max': 3, 'ref_entropy_min': 1.5917896291977092, 'avg_alt_softclip_max': 1.624030249737387, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.0244046878612982, 'avg_alt_nm_max': 4.400726208284187, 'mean_insert_max': 552.9394225719365, 'asxs_min': 25, 'mean_mapq_min': 44, 'dist_to_indel_min': 490, 'mean_baseq_min': 22, 'gc_content_min': 0.050471858003442324, 'gc_content_max': 0.8562221420648243, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.03856965924372291, 'strand_bias_max': 0.8926536679807034, 'rp_sd_min': 0.038161442499256154, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 2.433005882557146, 'avg_altread_variants_max_for_high_vaf': 2.144875364705632, 'avg_altread_high_vaf_cutoff': 0.14841518862479552, 'n_total_min': 7, 'rp_med_min': 0.06518557457423957, 'rp_med_max': 0.9340868078383505}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:23,686] Trial 18 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18815323058570102, 'depth_percentile_max': 95, 'variants_20bp_max': 2, 'variants_250bp_max': 10, 'ref_entropy_min': 0.7606192555322691, 'avg_alt_softclip_max': 0.8036424397080394, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.786438315933827, 'avg_alt_nm_max': 3.582482980395726, 'mean_insert_max': 755.8399521513566, 'asxs_min': 39, 'mean_mapq_min': 28, 'dist_to_indel_min': 303, 'mean_baseq_min': 54, 'gc_content_min': 0.05282879659166849, 'gc_content_max': 0.9020057905406957, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.10583652750265099, 'strand_bias_max': 0.7511860049317727, 'rp_sd_min': 0.011268182711426072, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 9, 'avg_altread_variants_max': 7.799375817829334, 'avg_altread_variants_max_for_high_vaf': 0.0017156401177267355, 'avg_altread_high_vaf_cutoff': 0.07897571640861087, 'n_total_min': 23, 'rp_med_min': 0.06241153080851632, 'rp_med_max': 0.9545166856338605}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:23,906] Trial 19 finished with value: 32620.34309355554 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12080451094897701, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 14, 'ref_entropy_min': 1.16131482804729, 'avg_alt_softclip_max': 0.6232720393274859, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.137262581535873, 'avg_alt_nm_max': 1.0469710688384994, 'mean_insert_max': 658.5202222212911, 'asxs_min': 30, 'mean_mapq_min': 20, 'dist_to_indel_min': 200, 'mean_baseq_min': 81, 'gc_content_min': 0.1371066893546426, 'gc_content_max': 0.9559174471152477, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.1667241587840356, 'strand_bias_max': 0.8260656117793193, 'rp_sd_min': 0.03182704415751334, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 1.5035257320573179, 'avg_altread_variants_max_for_high_vaf': 6.099989712697804, 'avg_altread_high_vaf_cutoff': 0.2242712336009001, 'n_total_min': 28, 'rp_med_min': 0.045103200512316595, 'rp_med_max': 0.9406035276178031}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:24,124] Trial 20 finished with value: 60034.19053139987 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15012892143160278, 'depth_percentile_max': 97, 'variants_20bp_max': 1, 'variants_250bp_max': 8, 'ref_entropy_min': 1.606327555234953, 'avg_alt_softclip_max': 0.2577647821416764, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.4368505111427137, 'avg_alt_nm_max': 2.7068150827348716, 'mean_insert_max': 369.0158711299889, 'asxs_min': 47, 'mean_mapq_min': 54, 'dist_to_indel_min': 398, 'mean_baseq_min': 58, 'gc_content_min': 0.17002357869897708, 'gc_content_max': 0.9212582603253592, 'strand_bias_n_alt_min': 20, 'strand_bias_min': 0.24173849698860622, 'strand_bias_max': 0.7970574649023848, 'rp_sd_min': 0.04348354517136758, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 3.533287798169596, 'avg_altread_variants_max_for_high_vaf': 3.7872466156377587, 'avg_altread_high_vaf_cutoff': 0.17375877257220457, 'n_total_min': 16, 'rp_med_min': 0.030889569087999322, 'rp_med_max': 0.918308313880135}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:24,343] Trial 21 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12435745019019163, 'depth_percentile_max': 99, 'variants_20bp_max': 2, 'variants_250bp_max': 15, 'ref_entropy_min': 1.1557805752645485, 'avg_alt_softclip_max': 0.5931912441509539, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 0.8543884767268383, 'avg_alt_nm_max': 0.8706123788968662, 'mean_insert_max': 656.0662674590374, 'asxs_min': 29, 'mean_mapq_min': 20, 'dist_to_indel_min': 185, 'mean_baseq_min': 78, 'gc_content_min': 0.14553647099914196, 'gc_content_max': 0.9549089312976646, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.1691163492445774, 'strand_bias_max': 0.8302716373870261, 'rp_sd_min': 0.02731886521911875, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 1.4562987008691646, 'avg_altread_variants_max_for_high_vaf': 6.131859897982887, 'avg_altread_high_vaf_cutoff': 0.22522890955436636, 'n_total_min': 28, 'rp_med_min': 0.04478673669687375, 'rp_med_max': 0.9405534739133952}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:24,559] Trial 22 finished with value: 65305.26150365477 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1191959140780695, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 13, 'ref_entropy_min': 1.1759529261851265, 'avg_alt_softclip_max': 0.966356508678117, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.258326653523758, 'avg_alt_nm_max': 1.864558512601446, 'mean_insert_max': 550.5897603016007, 'asxs_min': 37, 'mean_mapq_min': 26, 'dist_to_indel_min': 309, 'mean_baseq_min': 108, 'gc_content_min': 0.1105974445289271, 'gc_content_max': 0.9678325037214653, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.1339870064200806, 'strand_bias_max': 0.8826303653108647, 'rp_sd_min': 0.01135594636412307, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 1, 'avg_altread_variants_max': 0.3519642155530591, 'avg_altread_variants_max_for_high_vaf': 4.332564901850034, 'avg_altread_high_vaf_cutoff': 0.2726702461522409, 'n_total_min': 30, 'rp_med_min': 0.04479357386584846, 'rp_med_max': 0.9481748909198976}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:24,777] Trial 23 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.13193630753419072, 'depth_percentile_max': 98, 'variants_20bp_max': 3, 'variants_250bp_max': 14, 'ref_entropy_min': 1.4792539130110032, 'avg_alt_softclip_max': 0.7200156749252686, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.7985585865755545, 'avg_alt_nm_max': 0.8910159987954811, 'mean_insert_max': 671.0799567070758, 'asxs_min': 22, 'mean_mapq_min': 33, 'dist_to_indel_min': 221, 'mean_baseq_min': 43, 'gc_content_min': 0.08057652327421799, 'gc_content_max': 0.9497805157945101, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.177824980015508, 'strand_bias_max': 0.8356593367251973, 'rp_sd_min': 0.032724445572186726, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 1.6786359368005206, 'avg_altread_variants_max_for_high_vaf': 6.552742899096012, 'avg_altread_high_vaf_cutoff': 0.23173390739563782, 'n_total_min': 24, 'rp_med_min': 0.060358564524774685, 'rp_med_max': 0.9312988089196088}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:24,995] Trial 24 finished with value: 80960.35628651359 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15643623599484327, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.9595381390512138, 'avg_alt_softclip_max': 0.4870567899210061, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 0.5942059003436198, 'avg_alt_nm_max': 2.5147263513603657, 'mean_insert_max': 797.3060625878906, 'asxs_min': 34, 'mean_mapq_min': 20, 'dist_to_indel_min': 213, 'mean_baseq_min': 100, 'gc_content_min': 0.04408891989584224, 'gc_content_max': 0.9339803945757043, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.22248790173771343, 'strand_bias_max': 0.8111501719415922, 'rp_sd_min': 0.06072354177045127, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 3.0168933218971272, 'avg_altread_variants_max_for_high_vaf': 2.0202513863151186, 'avg_altread_high_vaf_cutoff': 0.1214632973670258, 'n_total_min': 28, 'rp_med_min': 0.03609502568027602, 'rp_med_max': 0.9401064246241233}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:25,216] Trial 25 finished with value: 36893.290224884266 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1980504228481304, 'depth_percentile_max': 99, 'variants_20bp_max': 1, 'variants_250bp_max': 12, 'ref_entropy_min': 0.26095617553004236, 'avg_alt_softclip_max': 0.308272106355002, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.7139548507232387, 'avg_alt_nm_max': 1.0409547315577143, 'mean_insert_max': 580.4880046771476, 'asxs_min': 29, 'mean_mapq_min': 24, 'dist_to_indel_min': 295, 'mean_baseq_min': 79, 'gc_content_min': 0.13268030359480915, 'gc_content_max': 0.9670772401096925, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.0843790558152051, 'strand_bias_max': 0.8559463669942783, 'rp_sd_min': 0.014225910067978964, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 1, 'avg_altread_variants_max': 4.67765105794475, 'avg_altread_variants_max_for_high_vaf': 5.530539006691725, 'avg_altread_high_vaf_cutoff': 0.17819697114444438, 'n_total_min': 22, 'rp_med_min': 0.046051459122849386, 'rp_med_max': 0.960288162600544}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:25,435] Trial 26 finished with value: 61668.6646610273 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17379224650481315, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 14, 'ref_entropy_min': 0.7086679564092897, 'avg_alt_softclip_max': 0.6093398389347237, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.2577010892176705, 'avg_alt_nm_max': 3.406491545469502, 'mean_insert_max': 672.1530453089478, 'asxs_min': 14, 'mean_mapq_min': 31, 'dist_to_indel_min': 369, 'mean_baseq_min': 80, 'gc_content_min': 0.023008164576734533, 'gc_content_max': 0.9236974290125912, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.13179797972636612, 'strand_bias_max': 0.7706764857247954, 'rp_sd_min': 0.04376709736968064, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 1.0226442913574616, 'avg_altread_variants_max_for_high_vaf': 4.566841969216657, 'avg_altread_high_vaf_cutoff': 0.21632156109152315, 'n_total_min': 25, 'rp_med_min': 0.0965763386242885, 'rp_med_max': 0.9498056519533209}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:25,655] Trial 27 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1749017739114922, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 1.2364460448526076, 'avg_alt_softclip_max': 1.1122947478372311, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.248590210227577, 'avg_alt_nm_max': 4.5120594659474555, 'mean_insert_max': 749.3960005365285, 'asxs_min': 22, 'mean_mapq_min': 46, 'dist_to_indel_min': 494, 'mean_baseq_min': 38, 'gc_content_min': 0.09034944604186786, 'gc_content_max': 0.9440451841422244, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.27656995918839256, 'strand_bias_max': 0.8401870081070004, 'rp_sd_min': 0.028728505775159077, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 0, 'avg_altread_variants_max': 3.149469549968128, 'avg_altread_variants_max_for_high_vaf': 7.2389464068787275, 'avg_altread_high_vaf_cutoff': 0.13033143374239642, 'n_total_min': 28, 'rp_med_min': 0.08266396318430307, 'rp_med_max': 0.9393052996279767}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:25,869] Trial 28 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10205706883421771, 'depth_percentile_max': 94, 'variants_20bp_max': 3, 'variants_250bp_max': 14, 'ref_entropy_min': 0.9703686080215392, 'avg_alt_softclip_max': 0.8435701396121489, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.832111422516192, 'avg_alt_nm_max': 1.5684913076765397, 'mean_insert_max': 506.1140843822442, 'asxs_min': 53, 'mean_mapq_min': 36, 'dist_to_indel_min': 233, 'mean_baseq_min': 28, 'gc_content_min': 0.1712661747740985, 'gc_content_max': 0.8665561085419772, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.15293265552369817, 'strand_bias_max': 0.8912644245108222, 'rp_sd_min': 0.007000696393759906, 'rp_sd_min_alt': 5, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 0.030706964029883377, 'avg_altread_variants_max_for_high_vaf': 2.6412954473434205, 'avg_altread_high_vaf_cutoff': 0.278514734346589, 'n_total_min': 30, 'rp_med_min': 0.03666348585605882, 'rp_med_max': 0.9293699372798175}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:26,087] Trial 29 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12787736985062428, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 6, 'ref_entropy_min': 0.5142296477850689, 'avg_alt_softclip_max': 1.7585413836304817, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 0.08603282982338945, 'avg_alt_nm_max': 0.5606286384366153, 'mean_insert_max': 232.03309328805793, 'asxs_min': 37, 'mean_mapq_min': 22, 'dist_to_indel_min': 428, 'mean_baseq_min': 71, 'gc_content_min': 0.06546900368818429, 'gc_content_max': 0.9896525332074958, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.21592645179499403, 'strand_bias_max': 0.7771796556539904, 'rp_sd_min': 0.019789733033283928, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 1, 'avg_altread_variants_max': 9.000303377878526, 'avg_altread_variants_max_for_high_vaf': 3.7311356638249653, 'avg_altread_high_vaf_cutoff': 0.18611034412440638, 'n_total_min': 27, 'rp_med_min': 0.06677446089125354, 'rp_med_max': 0.9214285490443604}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:26,302] Trial 30 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.14421991012265678, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 2, 'ref_entropy_min': 2.0832868780703087, 'avg_alt_softclip_max': 0.16361793343870534, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.6228394248364966, 'avg_alt_nm_max': 4.966475946298988, 'mean_insert_max': 435.65421103491315, 'asxs_min': 44, 'mean_mapq_min': 28, 'dist_to_indel_min': 345, 'mean_baseq_min': 56, 'gc_content_min': 0.14251771449876807, 'gc_content_max': 0.9685045699093764, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.18053791340741482, 'strand_bias_max': 0.813309222537739, 'rp_sd_min': 0.04527713479216586, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 2.1761995879302574, 'avg_altread_variants_max_for_high_vaf': 4.695021376487235, 'avg_altread_high_vaf_cutoff': 0.10241527645785113, 'n_total_min': 21, 'rp_med_min': 0.05911902378515346, 'rp_med_max': 0.9445366619887497}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:26,523] Trial 31 finished with value: 32871.660808647175 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16822965028886133, 'depth_percentile_max': 99, 'variants_20bp_max': 3, 'variants_250bp_max': 2, 'ref_entropy_min': 1.5569909467054923, 'avg_alt_softclip_max': 1.895207213657121, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.0122601380650167, 'avg_alt_nm_max': 4.3892059028137105, 'mean_insert_max': 581.0532532722924, 'asxs_min': 25, 'mean_mapq_min': 44, 'dist_to_indel_min': 481, 'mean_baseq_min': 21, 'gc_content_min': 0.02322054645218146, 'gc_content_max': 0.9995967578994663, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.022234429180531284, 'strand_bias_max': 0.9012758779620462, 'rp_sd_min': 0.03937242633301045, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 2.464521705887601, 'avg_altread_variants_max_for_high_vaf': 1.8381087585788412, 'avg_altread_high_vaf_cutoff': 0.14418670209271958, 'n_total_min': 7, 'rp_med_min': 0.0700549828688463, 'rp_med_max': 0.9361050811207486}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:26,740] Trial 32 finished with value: 81049.79597233218 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18416491174430016, 'depth_percentile_max': 90, 'variants_20bp_max': 3, 'variants_250bp_max': 4, 'ref_entropy_min': 1.7736664087439542, 'avg_alt_softclip_max': 0.4643192217669399, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.3180447127409534, 'avg_alt_nm_max': 3.8458086801403906, 'mean_insert_max': 536.3093417979197, 'asxs_min': 22, 'mean_mapq_min': 50, 'dist_to_indel_min': 397, 'mean_baseq_min': 28, 'gc_content_min': 0.033307438561607665, 'gc_content_max': 0.8502744917124958, 'strand_bias_n_alt_min': 12, 'strand_bias_min': 0.04358171365839793, 'strand_bias_max': 0.8740457206396258, 'rp_sd_min': 0.030646742244227854, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 1.7664243632241128, 'avg_altread_variants_max_for_high_vaf': 2.5771096887728993, 'avg_altread_high_vaf_cutoff': 0.18281932633050213, 'n_total_min': 2, 'rp_med_min': 0.07934331897731313, 'rp_med_max': 0.9352923260007828}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:26,962] Trial 33 finished with value: 42050.03035358171 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15264350403710536, 'depth_percentile_max': 99, 'variants_20bp_max': 3, 'variants_250bp_max': 0, 'ref_entropy_min': 1.4735940753807997, 'avg_alt_softclip_max': 1.5562903840068323, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.9020818602323593, 'avg_alt_nm_max': 4.523227591762342, 'mean_insert_max': 667.739234083503, 'asxs_min': 29, 'mean_mapq_min': 42, 'dist_to_indel_min': 457, 'mean_baseq_min': 42, 'gc_content_min': 0.0029598405596475696, 'gc_content_max': 0.8645864487936313, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.09558313396068069, 'strand_bias_max': 0.9236735495816853, 'rp_sd_min': 0.05714139983824085, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 3.720096574472044, 'avg_altread_variants_max_for_high_vaf': 0.715995906081683, 'avg_altread_high_vaf_cutoff': 0.23250879398400182, 'n_total_min': 6, 'rp_med_min': 0.07337096459499509, 'rp_med_max': 0.9314745400129881}. Best is trial 11 with value: 27225.924392372013.
# [I 2026-04-17 11:39:27,184] Trial 34 finished with value: 19813.037724207785 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11249663542351719, 'depth_percentile_max': 98, 'variants_20bp_max': 3, 'variants_250bp_max': 4, 'ref_entropy_min': 1.4329775407765382, 'avg_alt_softclip_max': 1.65835171428777, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.2396428947023383, 'avg_alt_nm_max': 4.030463620218823, 'mean_insert_max': 495.587929450091, 'asxs_min': 19, 'mean_mapq_min': 38, 'dist_to_indel_min': 500, 'mean_baseq_min': 65, 'gc_content_min': 0.061671402825318945, 'gc_content_max': 0.8894379237852879, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.06745698456694611, 'strand_bias_max': 0.7976802179471653, 'rp_sd_min': 0.03765343853028247, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 3.0698548571516096, 'avg_altread_variants_max_for_high_vaf': 1.4473691099690749, 'avg_altread_high_vaf_cutoff': 0.09873979081175809, 'n_total_min': 9, 'rp_med_min': 0.04846696554181703, 'rp_med_max': 0.9023183778564232}. Best is trial 34 with value: 19813.037724207785.
# [I 2026-04-17 11:39:27,405] Trial 35 finished with value: 57979.648739495424 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11336867783666665, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 5, 'ref_entropy_min': 1.4211908505070392, 'avg_alt_softclip_max': 0.3410722134358493, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.2961354007937667, 'avg_alt_nm_max': 4.1130118410323355, 'mean_insert_max': 467.94235510347227, 'asxs_min': 14, 'mean_mapq_min': 38, 'dist_to_indel_min': 278, 'mean_baseq_min': 60, 'gc_content_min': 0.06907795523614124, 'gc_content_max': 0.8885706050252792, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.06572710090294775, 'strand_bias_max': 0.7964209410906603, 'rp_sd_min': 0.01728907303122954, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 5.048453631778848, 'avg_altread_variants_max_for_high_vaf': 1.2944128749091912, 'avg_altread_high_vaf_cutoff': 0.05281387644231236, 'n_total_min': 14, 'rp_med_min': 0.056624776771520516, 'rp_med_max': 0.9099446782449736}. Best is trial 34 with value: 19813.037724207785.
# [I 2026-04-17 11:39:27,627] Trial 36 finished with value: 24692.07557186813 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10897622921480721, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 9, 'ref_entropy_min': 1.7230493239408373, 'avg_alt_softclip_max': 0.5795234733725412, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.9345623243686876, 'avg_alt_nm_max': 3.2780031641612264, 'mean_insert_max': 367.72179738675754, 'asxs_min': 18, 'mean_mapq_min': 23, 'dist_to_indel_min': 456, 'mean_baseq_min': 69, 'gc_content_min': 0.11454958747113683, 'gc_content_max': 0.8767491730560931, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.1982533456052496, 'strand_bias_max': 0.808135234775276, 'rp_sd_min': 0.04911642292435952, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 9.929915965686614, 'avg_altread_variants_max_for_high_vaf': 0.0008852509404495557, 'avg_altread_high_vaf_cutoff': 0.2981933331488492, 'n_total_min': 9, 'rp_med_min': 0.04843741301320496, 'rp_med_max': 0.9005467630161996}. Best is trial 34 with value: 19813.037724207785.
# [I 2026-04-17 11:39:27,844] Trial 37 finished with value: 78677.97048676258 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10969252809134881, 'depth_percentile_max': 96, 'variants_20bp_max': 4, 'variants_250bp_max': 9, 'ref_entropy_min': 1.7687657000793517, 'avg_alt_softclip_max': 1.91360970927509, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.8346765591221224, 'avg_alt_nm_max': 3.7352801669161173, 'mean_insert_max': 367.1633708549672, 'asxs_min': 18, 'mean_mapq_min': 23, 'dist_to_indel_min': 457, 'mean_baseq_min': 67, 'gc_content_min': 0.10963035596505796, 'gc_content_max': 0.8878967428613255, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.2037725429488639, 'strand_bias_max': 0.7820181551885023, 'rp_sd_min': 0.0502523679885426, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 8, 'avg_altread_variants_max': 9.774918545371328, 'avg_altread_variants_max_for_high_vaf': 0.12161410872349032, 'avg_altread_high_vaf_cutoff': 0.2985448203517868, 'n_total_min': 10, 'rp_med_min': 0.049287384487367525, 'rp_med_max': 0.9009726852197526}. Best is trial 34 with value: 19813.037724207785.
# [I 2026-04-17 11:39:28,065] Trial 38 finished with value: 25415.915046036815 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22786432995900166, 'depth_percentile_max': 98, 'variants_20bp_max': 0, 'variants_250bp_max': 6, 'ref_entropy_min': 1.674962043121099, 'avg_alt_softclip_max': 0.10511092908478553, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.6614683185653006, 'avg_alt_nm_max': 3.3328163841097416, 'mean_insert_max': 295.95466348335134, 'asxs_min': 12, 'mean_mapq_min': 27, 'dist_to_indel_min': 411, 'mean_baseq_min': 66, 'gc_content_min': 0.0620297530822686, 'gc_content_max': 0.8768499555805016, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.26497923036808135, 'strand_bias_max': 0.749363044116112, 'rp_sd_min': 0.06436924183166795, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 10, 'avg_altread_variants_max': 7.732529465119962, 'avg_altread_variants_max_for_high_vaf': 1.308468039800401, 'avg_altread_high_vaf_cutoff': 0.10332834850825749, 'n_total_min': 9, 'rp_med_min': 0.04893563872510866, 'rp_med_max': 0.9060817511478185}. Best is trial 34 with value: 19813.037724207785.
# [I 2026-04-17 11:39:28,285] Trial 39 finished with value: 62703.14826582892 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22137427735399784, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 6, 'ref_entropy_min': 1.6993791108054928, 'avg_alt_softclip_max': 0.04337424550294017, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.6027941864037272, 'avg_alt_nm_max': 3.184215261827422, 'mean_insert_max': 266.46547017755927, 'asxs_min': 13, 'mean_mapq_min': 26, 'dist_to_indel_min': 429, 'mean_baseq_min': 73, 'gc_content_min': 0.0938306329186778, 'gc_content_max': 0.8771079003037691, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.26602648646629146, 'strand_bias_max': 0.7491158034260444, 'rp_sd_min': 0.06836550868398335, 'rp_sd_min_alt': 9, 'homopolymer_len_max': 10, 'avg_altread_variants_max': 8.237054913236856, 'avg_altread_variants_max_for_high_vaf': 1.3710442991145926, 'avg_altread_high_vaf_cutoff': 0.349592109318285, 'n_total_min': 10, 'rp_med_min': 0.04988947482607218, 'rp_med_max': 0.9071959976854324}. Best is trial 34 with value: 19813.037724207785.
# [I 2026-04-17 11:39:28,502] Trial 40 finished with value: 80939.97624568554 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2492952816232386, 'depth_percentile_max': 95, 'variants_20bp_max': 0, 'variants_250bp_max': 5, 'ref_entropy_min': 1.9000652457969793, 'avg_alt_softclip_max': 0.12395354782337203, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.7578535416308061, 'avg_alt_nm_max': 3.3020253646110937, 'mean_insert_max': 322.9244021240692, 'asxs_min': 20, 'mean_mapq_min': 30, 'dist_to_indel_min': 393, 'mean_baseq_min': 66, 'gc_content_min': 0.068566508525616, 'gc_content_max': 0.8971973761991555, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.299637324238651, 'strand_bias_max': 0.7488417363589979, 'rp_sd_min': 0.06538945055957204, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 8, 'avg_altread_variants_max': 9.993614309969523, 'avg_altread_variants_max_for_high_vaf': 0.7799590360146347, 'avg_altread_high_vaf_cutoff': 0.09448538478425987, 'n_total_min': 5, 'rp_med_min': 0.05571131382132915, 'rp_med_max': 0.9007336909093256}. Best is trial 34 with value: 19813.037724207785.
# [I 2026-04-17 11:39:28,721] Trial 41 finished with value: 33887.78182782473 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22528376337006775, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 7, 'ref_entropy_min': 1.6759261482119234, 'avg_alt_softclip_max': 0.39512281961148993, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 1.6338573414351116, 'avg_alt_nm_max': 3.8572764517374702, 'mean_insert_max': 165.46672736718733, 'asxs_min': 12, 'mean_mapq_min': 23, 'dist_to_indel_min': 470, 'mean_baseq_min': 62, 'gc_content_min': 0.030025557995517857, 'gc_content_max': 0.8741032206030355, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.24916398041060914, 'strand_bias_max': 0.8045242014104481, 'rp_sd_min': 0.08555579732738958, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 9.16327145177078, 'avg_altread_variants_max_for_high_vaf': 1.4330826235668217, 'avg_altread_high_vaf_cutoff': 0.09974303060109838, 'n_total_min': 9, 'rp_med_min': 0.04086977570263935, 'rp_med_max': 0.9157389883595111}. Best is trial 34 with value: 19813.037724207785.
# ...
# [I 2026-04-17 11:53:29,515] Trial 2987 finished with value: 9645.531473316103 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2499530139420378, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7413920015171815, 'avg_alt_softclip_max': 1.8819642482968715, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.2467851429493235, 'avg_alt_nm_max': 3.8847460817743578, 'mean_insert_max': 734.2157640947572, 'asxs_min': 41, 'mean_mapq_min': 23, 'dist_to_indel_min': 9, 'mean_baseq_min': 51, 'gc_content_min': 0.1528796946413257, 'gc_content_max': 0.9846723034593442, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.29991930197888594, 'strand_bias_max': 0.9263394084965944, 'rp_sd_min': 0.0371154421405373, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.157250760026782, 'avg_altread_variants_max_for_high_vaf': 9.452128494063079, 'avg_altread_high_vaf_cutoff': 0.1988154212208248, 'n_total_min': 5, 'rp_med_min': 0.033425680798407284, 'rp_med_max': 0.9667229055558553}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:29,858] Trial 2988 finished with value: 9343.665051018663 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24992460836038263, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7701987239648328, 'avg_alt_softclip_max': 1.9390409784898024, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.2134870862821208, 'avg_alt_nm_max': 4.069444994207385, 'mean_insert_max': 767.9866751312152, 'asxs_min': 42, 'mean_mapq_min': 22, 'dist_to_indel_min': 25, 'mean_baseq_min': 48, 'gc_content_min': 0.13268291401537974, 'gc_content_max': 0.9792642936487724, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.2851072614645438, 'strand_bias_max': 0.9145705365347516, 'rp_sd_min': 0.006212278150736562, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.514673254562766, 'avg_altread_variants_max_for_high_vaf': 9.263120373886427, 'avg_altread_high_vaf_cutoff': 0.18914710901925166, 'n_total_min': 4, 'rp_med_min': 0.031744486947330376, 'rp_med_max': 0.9650732961000431}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:30,199] Trial 2989 finished with value: 9541.958643335427 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24983147099330957, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7891871871559494, 'avg_alt_softclip_max': 1.885489837365053, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.1225472253334186, 'avg_alt_nm_max': 3.970008539962015, 'mean_insert_max': 748.9287942014483, 'asxs_min': 43, 'mean_mapq_min': 22, 'dist_to_indel_min': 9, 'mean_baseq_min': 51, 'gc_content_min': 0.14716828327919282, 'gc_content_max': 0.9842052668172171, 'strand_bias_n_alt_min': 12, 'strand_bias_min': 0.2896450132989497, 'strand_bias_max': 0.91420618843741, 'rp_sd_min': 0.003715671252960486, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 10, 'avg_altread_variants_max': 9.691549472674827, 'avg_altread_variants_max_for_high_vaf': 9.46677567968909, 'avg_altread_high_vaf_cutoff': 0.18143025476913663, 'n_total_min': 4, 'rp_med_min': 0.03339136995681455, 'rp_med_max': 0.9665770359908616}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:30,544] Trial 2990 finished with value: 9154.815652602932 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.245492458032923, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7997590045014619, 'avg_alt_softclip_max': 1.9264404431197004, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.183124795165893, 'avg_alt_nm_max': 4.1020905997850345, 'mean_insert_max': 763.7299846171696, 'asxs_min': 44, 'mean_mapq_min': 22, 'dist_to_indel_min': 0, 'mean_baseq_min': 52, 'gc_content_min': 0.1592855453266284, 'gc_content_max': 0.9928121186643017, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.28855747767758805, 'strand_bias_max': 0.9100988568243075, 'rp_sd_min': 0.006313062546844047, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.363689712169883, 'avg_altread_variants_max_for_high_vaf': 9.177514551833298, 'avg_altread_high_vaf_cutoff': 0.1901063705219274, 'n_total_min': 4, 'rp_med_min': 0.03322913707259227, 'rp_med_max': 0.9651255935967216}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:30,889] Trial 2991 finished with value: 19155.401977865928 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2454590602162871, 'depth_percentile_max': 98, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.6384397463423372, 'avg_alt_softclip_max': 1.8729661995702769, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 0.561867164596704, 'avg_alt_nm_max': 3.8082552191710346, 'mean_insert_max': 734.7627266402308, 'asxs_min': 59, 'mean_mapq_min': 22, 'dist_to_indel_min': 18, 'mean_baseq_min': 47, 'gc_content_min': 0.142940984429467, 'gc_content_max': 0.9767994847443995, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.29993777786265446, 'strand_bias_max': 0.9149201186812209, 'rp_sd_min': 0.0033512851958934454, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 11, 'avg_altread_variants_max': 9.550555843248855, 'avg_altread_variants_max_for_high_vaf': 9.463062050683797, 'avg_altread_high_vaf_cutoff': 0.19612103620537905, 'n_total_min': 4, 'rp_med_min': 0.031885530668613944, 'rp_med_max': 0.9676569666606524}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:31,237] Trial 2992 finished with value: 9136.557186461676 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24744294190428143, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7071086331828259, 'avg_alt_softclip_max': 1.8715716353137208, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.240061548611319, 'avg_alt_nm_max': 4.038067115780206, 'mean_insert_max': 751.8053508594944, 'asxs_min': 40, 'mean_mapq_min': 23, 'dist_to_indel_min': 0, 'mean_baseq_min': 49, 'gc_content_min': 0.15665331051013734, 'gc_content_max': 0.9803386805918873, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.29982962766383897, 'strand_bias_max': 0.9298189388231388, 'rp_sd_min': 0.005052100842182578, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.82322631634931, 'avg_altread_variants_max_for_high_vaf': 9.116987072125424, 'avg_altread_high_vaf_cutoff': 0.17783993183882127, 'n_total_min': 5, 'rp_med_min': 0.034135523151763256, 'rp_med_max': 0.9665860860850084}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:31,585] Trial 2993 finished with value: 9617.754021451272 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.244719912108156, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.8044563295034697, 'avg_alt_softclip_max': 1.9691460299408021, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.1188465749999144, 'avg_alt_nm_max': 3.960435904601554, 'mean_insert_max': 769.6594738576573, 'asxs_min': 42, 'mean_mapq_min': 22, 'dist_to_indel_min': 26, 'mean_baseq_min': 52, 'gc_content_min': 0.15252065260357203, 'gc_content_max': 0.9894013582679269, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.29024017673219005, 'strand_bias_max': 0.9380700390414131, 'rp_sd_min': 0.0018309116892376192, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 11, 'avg_altread_variants_max': 9.123369787726107, 'avg_altread_variants_max_for_high_vaf': 9.534315789258759, 'avg_altread_high_vaf_cutoff': 0.1858680795008617, 'n_total_min': 5, 'rp_med_min': 0.033254056144395486, 'rp_med_max': 0.9678321390599396}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:31,932] Trial 2994 finished with value: 10873.580499257327 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1413859306403695, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7522967437302933, 'avg_alt_softclip_max': 1.9180050962213284, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.167438236187087, 'avg_alt_nm_max': 4.082155878551496, 'mean_insert_max': 783.5169335834922, 'asxs_min': 41, 'mean_mapq_min': 21, 'dist_to_indel_min': 487, 'mean_baseq_min': 46, 'gc_content_min': 0.1443023256833156, 'gc_content_max': 0.965635274702054, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.2814958739859164, 'strand_bias_max': 0.9160845195583618, 'rp_sd_min': 0.007279988044225661, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.704016975319764, 'avg_altread_variants_max_for_high_vaf': 9.274142007235811, 'avg_altread_high_vaf_cutoff': 0.20202341020801895, 'n_total_min': 29, 'rp_med_min': 0.03172178199468175, 'rp_med_max': 0.9648595488790096}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:32,289] Trial 2995 finished with value: 9506.878906945523 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24718659148865094, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.8192443207873125, 'avg_alt_softclip_max': 1.8652594950853674, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.0804977854877507, 'avg_alt_nm_max': 3.8811265079422177, 'mean_insert_max': 730.6143890389476, 'asxs_min': 42, 'mean_mapq_min': 22, 'dist_to_indel_min': 9, 'mean_baseq_min': 49, 'gc_content_min': 0.13383436562955428, 'gc_content_max': 0.9843981543812508, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.29993385331979966, 'strand_bias_max': 0.9189524497010696, 'rp_sd_min': 0.004409865026569851, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.338105345699981, 'avg_altread_variants_max_for_high_vaf': 9.421751698424083, 'avg_altread_high_vaf_cutoff': 0.1782180447739418, 'n_total_min': 4, 'rp_med_min': 0.034369405262160084, 'rp_med_max': 0.9678848712562917}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:32,633] Trial 2996 finished with value: 40421.25927148392 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24485522495300402, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.796495359197174, 'avg_alt_softclip_max': 1.9088106518029686, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.2422850553674545, 'avg_alt_nm_max': 4.104509773697397, 'mean_insert_max': 745.4751981307445, 'asxs_min': 45, 'mean_mapq_min': 22, 'dist_to_indel_min': 9, 'mean_baseq_min': 53, 'gc_content_min': 0.16364019324953347, 'gc_content_max': 0.9351649529359519, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.29420210515395784, 'strand_bias_max': 0.9189902838908186, 'rp_sd_min': 0.0020902069635205848, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 0.13845593818654223, 'avg_altread_variants_max_for_high_vaf': 9.061259174494582, 'avg_altread_high_vaf_cutoff': 0.19354086760947503, 'n_total_min': 4, 'rp_med_min': 0.03317544226937005, 'rp_med_max': 0.9664641085302158}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:32,974] Trial 2997 finished with value: 9323.080156790147 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2471525831133052, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7075090546517597, 'avg_alt_softclip_max': 1.8603812106170392, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.157222347592367, 'avg_alt_nm_max': 4.011350876903518, 'mean_insert_max': 756.9381879620008, 'asxs_min': 43, 'mean_mapq_min': 23, 'dist_to_indel_min': 17, 'mean_baseq_min': 50, 'gc_content_min': 0.14706477369828103, 'gc_content_max': 0.9852141075358748, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.2871776609715701, 'strand_bias_max': 0.9238217122723965, 'rp_sd_min': 1.356660098503085e-05, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.534981620630072, 'avg_altread_variants_max_for_high_vaf': 9.56447613784609, 'avg_altread_high_vaf_cutoff': 0.18443766368062106, 'n_total_min': 4, 'rp_med_min': 0.031457644701336045, 'rp_med_max': 0.9679897990635062}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:33,348] Trial 2998 finished with value: 10022.119773642382 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24522654104855818, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.8337968088855233, 'avg_alt_softclip_max': 1.999302348691488, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.040722782669609, 'avg_alt_nm_max': 3.781567572970956, 'mean_insert_max': 781.6800554543686, 'asxs_min': 40, 'mean_mapq_min': 32, 'dist_to_indel_min': 17, 'mean_baseq_min': 48, 'gc_content_min': 0.15944361385367495, 'gc_content_max': 0.9340255555909891, 'strand_bias_n_alt_min': 12, 'strand_bias_min': 0.2943893479048368, 'strand_bias_max': 0.9243998187545348, 'rp_sd_min': 0.006063571609234056, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 11, 'avg_altread_variants_max': 9.781800542462372, 'avg_altread_variants_max_for_high_vaf': 9.323003146893866, 'avg_altread_high_vaf_cutoff': 0.17557643189263317, 'n_total_min': 5, 'rp_med_min': 0.031743224980525814, 'rp_med_max': 0.9664910551515412}. Best is trial 2227 with value: 8976.868883597901.
# [I 2026-04-17 11:53:33,718] Trial 2999 finished with value: 15015.822526051496 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24970984662160733, 'depth_percentile_max': 98, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7743164287767224, 'avg_alt_softclip_max': 1.9367303104649187, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.2428557523642114, 'avg_alt_nm_max': 4.119967689515755, 'mean_insert_max': 766.287490036986, 'asxs_min': 41, 'mean_mapq_min': 38, 'dist_to_indel_min': 0, 'mean_baseq_min': 51, 'gc_content_min': 0.15117983463955584, 'gc_content_max': 0.9810727937127046, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2812781959788675, 'strand_bias_max': 0.9201085149610102, 'rp_sd_min': 0.0036274665711283475, 'rp_sd_min_alt': 8, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 9.130324182189861, 'avg_altread_variants_max_for_high_vaf': 9.591006473397275, 'avg_altread_high_vaf_cutoff': 0.19130472772670867, 'n_total_min': 4, 'rp_med_min': 0.03408163199221603, 'rp_med_max': 0.9475227245144097}. Best is trial 2227 with value: 8976.868883597901.
# [INFO] Best Weighted Deviance: 8976.8689
# [INFO] Generating report...
# ------------------------------
# FINAL RESULTS
# ------------------------------
# Total Samples:      18
# Total Observed SNVs: 23835
# Total Expected SNVs: 38935.11
# Weighted Deviance:  8976.8689 (Cord weight = 3.0x)
# Mean Obs/Exp Ratio: 0.7729
# Blacklist Blocked:  1192 variants (passed filters but hit blacklist)
# Results saved to:   training_results
# ------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------
# Configuration
# -----------------------
# Path to the CSV generated in the previous step
CSV_PATH = "training_results/observed_expected.csv"
OUTPUT_PNG = "training_results/observed_vs_expected_plot.png"

# Check if file exists
if not os.path.exists(CSV_PATH):
    print(f"[ERROR] Could not find {CSV_PATH}. Please run the optimization cell first.")
else:
    # Load table
    df = pd.read_csv(CSV_PATH)

    # Convert data arrays
    ages = df["age"].values
    bases = df["bases"].values
    observed = df["observed"].values
    expected = df["expected"].values
    sample_types = df["sample_type"].values

    # Calculate SNV rates per base
    obs_rate = observed / bases
    exp_rate = expected / bases

    # -----------------------
    # Plotting
    # -----------------------
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot Observed (Blue circles)
    ax.scatter(ages, obs_rate, label="Observed", color="#1f77b4", alpha=0.8, marker="o", s=60, edgecolors='k', linewidth=0.5)

    # Plot Expected (Orange crosses)
    ax.scatter(ages, exp_rate, label="Expected", color="#ff7f0e", alpha=0.8, marker="x", s=60, linewidth=2)

    # Styling
    ax.set_xlabel("Age (years)", fontsize=12)
    ax.set_ylabel("SNV rate (SNVs per base)", fontsize=12)
    
    # Handle X-limits (pad slightly around min/max age)
    # If ages has None/NaN (Cord blood sometimes represented as negative or 0), handle gracefully
    valid_ages = ages[~np.isnan(ages)]
    if len(valid_ages) > 0:
        ax.set_xlim(min(valid_ages) - 2, max(valid_ages) + 5)
    else:
        ax.set_xlim(-2, 100)

    # Hardcoded Y-limits from your request
    ax.set_ylim(0, 5.5e-7)
    
    ax.set_title("Observed vs Expected SNV Rate (Training Set)", fontsize=14)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Legend
    ax.legend(loc='upper left', frameon=True, fontsize=10)

    plt.tight_layout()
    
    # Save and Show
    plt.savefig(OUTPUT_PNG, dpi=150)
    print(f"[INFO] Plot saved to: {OUTPUT_PNG}")
    plt.show()
# Out:
# [INFO] Plot saved to: training_results/observed_vs_expected_plot.png
