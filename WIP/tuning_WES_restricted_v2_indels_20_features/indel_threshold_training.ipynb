# %%
import csv
import gzip
import json
import os
import sys
import random
import bisect
from typing import Dict, Any, List

import numpy as np
import pandas as pd
import optuna

# -----------------------
# Configuration / Hardcoded Paths
# -----------------------
SAMPLES_CSV = "training_complete_processed_metadata.csv"
OUT_DIR = "training_results_indels"
BLACKLIST_BED = "../../resources/master_blacklist.bed" 
ARTEFACT_GENES_BED = "../../resources/master_blacklist.bed"
EXOME_BED_PATH = "../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed" # NEW

N_TRIALS = 3000
SEED = 42
# -----------------------
# Constants
# -----------------------
GENOME_SIZE = 6.4e9
R_CORD = 2e-9
EPS = 1e-15
CORD_WEIGHT = 5.0

# Set seeds
random.seed(SEED)
np.random.seed(SEED)

# -----------------------
# Math Helpers
# -----------------------
def poisson_deviance(y_arr: np.ndarray, lam_arr: np.ndarray, weights: np.ndarray = None) -> float:
    y = np.asarray(y_arr, dtype=float)
    lam = np.asarray(lam_arr, dtype=float) + EPS
    
    with np.errstate(divide='ignore', invalid='ignore'):
        log_term = np.log(y / lam)
        term1 = np.where(y > 0, y * log_term, 0.0)
    
    dev = 2.0 * (term1 - (y - lam))
    if weights is not None:
        dev = dev * weights
        
    return float(np.sum(dev))

def expected_lambda(sample_type: str, age: float, bases: float) -> float:
    st = str(sample_type).lower()
    current_age = float(age) if pd.notna(age) else 0.0
    
    if "cord" in st:
        rate = R_CORD
    elif "pbmc" in st:
        rate = R_CORD + (0.7 * current_age) / GENOME_SIZE
    elif "t_cell" in st or "tcell" in st or "t-cell" in st:
        rate = (14.5 / GENOME_SIZE) + (1.0 * current_age) / GENOME_SIZE
    else:
        # Fallback to the original baseline if an unknown type appears
        rate = R_CORD + (2.0 * current_age) / GENOME_SIZE
        
    return rate * bases

# -----------------------
# BED File Lookup Logic
# -----------------------
class BedLookup:
    def __init__(self, bed_path: str, name: str):
        self.intervals = {} 
        self.name = name
        self._load_bed(bed_path)

    def _load_bed(self, bed_path: str):
        if not os.path.exists(bed_path):
            print(f"[WARN] BED file not found: {bed_path}. {self.name} filter will do nothing.", file=sys.stderr)
            return

        print(f"[INFO] Loading {self.name} from {bed_path}...")
        count = 0
        with open(bed_path, 'r') as f:
            for line in f:
                if line.startswith('#') or not line.strip():
                    continue
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                chrom, start, end = parts[0], int(parts[1]), int(parts[2])
                
                if chrom not in self.intervals:
                    self.intervals[chrom] = []
                self.intervals[chrom].append((start, end))
                count += 1
        
        for chrom in self.intervals:
            self.intervals[chrom].sort(key=lambda x: x[0])
        print(f"[INFO] Loaded {count} regions for {self.name}.")

    def is_overlapped(self, chrom: str, pos: int) -> bool:
        if chrom not in self.intervals:
            return False
        
        regions = self.intervals[chrom]
        query_idx = pos - 1 
        idx = bisect.bisect_right(regions, (query_idx, float('inf')))
        
        for i in range(max(0, idx - 1), -1, -1):
            start, end = regions[i]
            if end <= query_idx:
                break 
            if start <= query_idx < end:
                return True
        return False

# -----------------------
# VCF Parsing to DataFrame
# -----------------------
def parse_vcf_to_df(vcf_path: str, sample_id: str) -> pd.DataFrame:
    data = []
    if not os.path.exists(vcf_path):
        print(f"[WARN] File not found: {vcf_path}", file=sys.stderr)
        return pd.DataFrame()

    openf = gzip.open if vcf_path.endswith(".gz") else open
    try:
        with openf(vcf_path, "rt") as fh:
            for line in fh:
                if line.startswith("#"):
                    continue
                fields = line.strip().split("\t")
                chrom, pos = fields[0], int(fields[1])
                alt = fields[4] # NEW: Extract the ALT sequence
                info_str = fields[7]
                info_dict = {k: v for item in info_str.split(";") for k, v in [item.split("=", 1) if "=" in item else (item, "Yes")]}
                
                # NEW: Added ALT to the dictionary
                info_dict.update({"sample_id": sample_id, "CHROM": chrom, "POS": pos, "ALT": alt})
                data.append(info_dict)
    except Exception as e:
        print(f"[ERROR] Error reading {vcf_path}: {e}", file=sys.stderr)
        return pd.DataFrame()

    if not data:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    
    def to_num(col, dtype, default):
        return pd.to_numeric(df[col], errors='coerce').fillna(default).astype(dtype) if col in df.columns else pd.Series([default]*len(df), dtype=dtype)

    def to_str(col, default):
        return df[col].fillna(default) if col in df.columns else pd.Series([default]*len(df))

    df['CHROM'] = to_str('CHROM', 'chr1')
    df['ALT'] = to_str('ALT', '') # NEW: String column for ALT
    df['POS'] = to_num('POS', int, 0)
    df['INDEL_LENGTH'] = to_num('INDEL_LENGTH', int, 0)
    df['MEAN_INSET_QUAL'] = to_num('MEAN_INSET_QUAL', float, -1.0)
    df['MEAN_DEL_ANCHOR_QUAL'] = to_num('MEAN_DEL_ANCHOR_QUAL', float, -1.0)
    df['HOMOPOLYMER_LEN'] = to_num('HOMOPOLYMER_LEN', int, 0)
    df['N_SLIPPAGE_SSCS'] = to_num('N_SLIPPAGE_SSCS', int, 0)
    df['GC_CONTENT'] = to_num('GC_CONTENT', float, 0.5) 
    df['DIST_TO_OTHER_INDEL'] = to_num('DIST_TO_OTHER_INDEL', int, 10000)
    df['RP_MED_SSCS'] = to_num('RP_MED_SSCS', float, 75.0)
    df['SD_BASEQ'] = to_num('SD_BASEQ', float, 1000) #NEW 1
    df['AVG_ALT_READ_MEAN_BASEQ'] = to_num('AVG_ALT_READ_MEAN_BQ', float, 0) # NEW 2
    df['MEAN_REF_MAPQ'] = to_num('MEAN_REF_MAPQ', float, 0.0) # NEW 3
    df['AVG_REF_ASXS'] = to_num('AVG_REF_ASXS', float, 0.0) # NEW 4
    df['AVG_ALTREAD_VARIANTS'] = to_num('AVG_ALTREAD_VARIANTS', float, 1000) # NEW 5
    df['AVG_NONALTREAD_VARIANTS'] = to_num('AVG_NONALTREAD_VARIANTS', float, 1000) # NEW 6
    df['MEAN_INSERT'] = to_num('MEAN_INSERT', float, 1000) # NEW 7
    df['SD_INSERT'] = to_num('SD_INSERT', float, 1000) # NEW 8
    df['AVG_READ_POSITION'] = to_num('AVG_READ_POSITION', float, 75) # NEW 9
    df['AVG_READ_LENGTH'] = to_num('AVG_READ_LENGTH', float, 150) # NEW 10
    df['RP_SD_SSCS'] = to_num('RP_SD_SSCS', float, 0) # Not sure if to use this metric...
    df['STRAND_BIAS_SSCS'] = to_num('STRAND_BIAS_SSCS', float, 1) # Will use this and RP_SD above but conditional to a minimum N_ALT_SSCS, just as for the SNV caller
    df['AVG_ALT_N_COUNT'] = to_num('AVG_ALT_N_COUNT', float, 0.0)
    df['N_ALT_SSCS'] = to_num('N_ALT_SSCS', int, 0)
    df['N_TOTAL'] = to_num('N_TOTAL', int, 0)
    df['N_ALT'] = to_num('N_ALT', int, 0) 
    df['N_TOTAL_SSCS'] = to_num('N_TOTAL_SSCS', int, -1)
    df['DEPTH_PERCENTILE'] = to_num('DEPTH_PERCENTILE', int, 50)
    df['VARIANTS_20BP'] = to_num('VARIANTS_20BP', int, 0)
    df['VARIANTS_250BP'] = to_num('VARIANTS_250BP', int, 0)
    df['MEDIAN_DIST_TO_SOFTCLIP'] = to_num('MEDIAN_DIST_TO_SOFTCLIP', int, 1000)
    df['AVG_ASXS'] = to_num('AVG_ALT_ASXS', float, 0.0) 
    df['MEAN_MAPQ'] = to_num('MEAN_ALT_MAPQ', float, 0.0) 
    df['AVG_ALT_EXCESS_NM'] = to_num('AVG_ALT_EXCESS_NM', float, 0.0)
    df['AVG_ALT_SOFTCLIP'] = to_num('AVG_ALT_SOFTCLIP', float, 0.0)
    df['REF_ENTROPY_40BP'] = to_num('REF_ENTROPY_40BP', float, 2.0)
    df['IN_BLACKLIST'] = to_str('IN_BLACKLIST', "NO")
    df['IN_GNOMAD_COMMON'] = to_str('IN_GNOMAD_COMMON', "No")
    df['IN_CB_PON'] = to_str('IN_CB_PON', "No")

    with np.errstate(divide='ignore', invalid='ignore'):
        df['VAF_SSCS'] = (df['N_ALT_SSCS'] / df['N_TOTAL_SSCS']).fillna(0.0)

    return df

# -----------------------
# Aggregation & Filtering Logic
# -----------------------
def aggregate_samples(samples_meta: List[Dict]) -> List[Dict]:
    """Groups all cord blood samples to combat Poisson noise."""
    agg_meta, cord_ids = [], []
    cord_exp, cord_bases = 0.0, 0.0
    
    for s in samples_meta:
        lam = expected_lambda(s['sample_type'], s['age'], s['bases'])
        if "cord" in s['sample_type'].lower():
            cord_ids.append(s['sample_id'])
            cord_exp += lam
            cord_bases += s['bases']
        else:
            agg_meta.append({
                'sample_ids': [s['sample_id']],
                'sample_type': s['sample_type'],
                'age': s['age'],
                'bases': s['bases'],
                'expected_lambda': lam,
                'is_cord': False
            })
            
    if cord_ids:
        agg_meta.append({
            'sample_ids': cord_ids, 
            'sample_type': 'cord_aggregate',
            'age': 0.0, 
            'bases': cord_bases,
            'expected_lambda': cord_exp,
            'is_cord': True
        })
    return agg_meta

def get_static_mask(df: pd.DataFrame, pon_flags: Dict[str, bool], ignore_blacklists: bool = False, ignore_cb_pon: bool = False) -> pd.Series:
    """Filters evaluated ONCE before Optuna runs to save immense computation time."""
    mask = (df['N_TOTAL_SSCS'] > 0) & (df['N_ALT_SSCS'] > 1)
    
    # Filter out insertions that contain 'N' in the inserted sequence
    has_n_in_insertion = (df['INDEL_LENGTH'] > 0) & (df['ALT'].str.contains('N', case=False, na=False))
    mask &= (~has_n_in_insertion)
    
    if pon_flags.get("use_cord_pon", False):
        mask &= (df['IN_BLACKLIST'] != "YES")

    # NEW: Hard filter for IN_CB_PON
    if not ignore_cb_pon:
        mask &= (df['IN_CB_PON'] != "Yes")

    if not ignore_blacklists:
        mask &= (~df['IN_CLUSTER_BLACKLIST']) & (~df['IN_ARTEFACT_BLACKLIST'])
        
    return mask

# -----------------------
# Aggregation & Filtering Logic
# -----------------------
def get_dynamic_mask(df: pd.DataFrame, thresholds: Dict[str, Any]) -> pd.Series:
    """Filters evaluated during every Optuna trial."""
    mask = (df['N_TOTAL'] >= thresholds['n_total_min'])
    mask &= (df['DEPTH_PERCENTILE'] <= thresholds['depth_percentile_max'])
    mask &= (df['MEAN_MAPQ'] >= thresholds['mean_mapq_min'])
    mask &= (df['AVG_ASXS'] > thresholds['asxs_min'])

    is_ins = df['INDEL_LENGTH'] > 0
    is_del = df['INDEL_LENGTH'] < 0
    mask &= ((is_ins & (df['MEAN_INSET_QUAL'] >= thresholds['mean_inset_qual_min'])) | 
             (is_del & (df['MEAN_DEL_ANCHOR_QUAL'] >= thresholds['mean_del_anchor_qual_min'])))


    
    mask &= (df['N_SLIPPAGE_SSCS'] <= thresholds['max_slippage_reads'])

    mask &= (df['VARIANTS_250BP'] <= thresholds['variants_250bp_max'])
    mask &= (df['REF_ENTROPY_40BP'] >= thresholds['ref_entropy_min'])

    mask &= (df['MEDIAN_DIST_TO_SOFTCLIP'] >= thresholds['dist_to_softclip_min'])
    mask &= (df['AVG_ALT_EXCESS_NM'] <= thresholds['avg_alt_nm_max'])

    mask &= (df['DIST_TO_OTHER_INDEL'] >= thresholds['min_dist_to_indel'])
    mask &= (df['RP_MED_SSCS'] >= thresholds['min_rp_med']) & (df['RP_MED_SSCS'] <= thresholds['max_rp_med'])
    mask &= (df['AVG_ALT_N_COUNT'] <= thresholds['max_n_count'])
    mask &= (df['VAF_SSCS'] <= thresholds['germline_vaf_max'])

    # --- NEW FEATURES ---

    mask &= (df['AVG_ALT_READ_MEAN_BASEQ'] >= thresholds['avg_alt_read_mean_baseq_min'])
    mask &= (df['MEAN_REF_MAPQ'] >= thresholds['mean_ref_mapq_min'])


    mask &= (df['AVG_NONALTREAD_VARIANTS'] <= thresholds['avg_nonaltread_variants_max'])

    mask &= (df['SD_INSERT'] <= thresholds['sd_insert_max'])
    mask &= (df['AVG_READ_POSITION'] >= thresholds['avg_read_position_min']) & (df['AVG_READ_POSITION'] <= thresholds['avg_read_position_max'])
    mask &= (df['AVG_READ_LENGTH'] >= thresholds['avg_read_length_min'])

    # Strand Bias (Conditional)
    enough_reads_sb = df['N_ALT_SSCS'] >= thresholds['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < thresholds['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > thresholds['strand_bias_max'])
    mask &= ~(enough_reads_sb & bad_bias)

    # RP SD (Conditional)
    enough_reads_rp = df['N_ALT_SSCS'] >= thresholds['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < thresholds['rp_sd_min']
    mask &= ~(enough_reads_rp & bad_rp_sd)
    
    return mask

# -----------------------
# Optimization Objective
# -----------------------
def make_objective(filtered_df: pd.DataFrame, agg_meta: List[Dict]):
    exp_arr = np.array([m['expected_lambda'] for m in agg_meta])
    weights_arr = np.array([CORD_WEIGHT if m['is_cord'] else 1.0 for m in agg_meta])

    def objective(trial):
        thresholds = {
            "n_total_min": trial.suggest_int("n_total_min", 10, 30),
            "depth_percentile_max": trial.suggest_int("depth_percentile_max", 95, 99),
            "mean_inset_qual_min": trial.suggest_int("mean_inset_qual_min", 20, 50),
            "mean_del_anchor_qual_min": trial.suggest_int("mean_del_anchor_qual_min", 20, 50),

            "max_slippage_reads": trial.suggest_int("max_slippage_reads", 0, 5),
            "asxs_min": trial.suggest_int("asxs_min", 10, 60),
            "mean_mapq_min": trial.suggest_int("mean_mapq_min", 20, 50),
            "avg_alt_nm_max": trial.suggest_float("avg_alt_nm_max", 0.0, 5.0),

            "dist_to_softclip_min": trial.suggest_int("dist_to_softclip_min", 0, 5),

            "variants_250bp_max": trial.suggest_int("variants_250bp_max", 0, 15),
            "ref_entropy_min": trial.suggest_float("ref_entropy_min", 0.0, 2.1),

            "min_dist_to_indel": trial.suggest_int("min_dist_to_indel", 0, 500),
            "min_rp_med": trial.suggest_float("min_rp_med", 0.01, 0.08),
            "max_rp_med": trial.suggest_float("max_rp_med", 0.92, 0.99),
            "max_n_count": trial.suggest_float("max_n_count", 0.0, 3.0),
            "germline_vaf_max": trial.suggest_float("germline_vaf_max", 0.2, 0.2),
            
            # --- NEW FEATURES ---
            

            "avg_alt_read_mean_baseq_min": trial.suggest_float("avg_alt_read_mean_baseq_min", 00.0, 60.0),
            "mean_ref_mapq_min": trial.suggest_float("mean_ref_mapq_min", 20.0, 60.0),


            "avg_nonaltread_variants_max": trial.suggest_float("avg_nonaltread_variants_max", 0.0, 10.0),

            "sd_insert_max": trial.suggest_float("sd_insert_max", 00.0, 800.0),
            "avg_read_position_min": trial.suggest_float("avg_read_position_min", 0.0, 10.0),
            "avg_read_position_max": trial.suggest_float("avg_read_position_max", 130.0, 150.0), 
            "avg_read_length_min": trial.suggest_float("avg_read_length_min", 50.0, 150.0),
            
            # --- CONDITIONAL FEATURES ---
            "strand_bias_n_alt_min": trial.suggest_int("strand_bias_n_alt_min", 3, 10),
            "strand_bias_min": trial.suggest_float("strand_bias_min", 0.0, 0.3),
            "strand_bias_max": trial.suggest_float("strand_bias_max", 0.7, 1.0),
            "rp_sd_min_alt": trial.suggest_int("rp_sd_min_alt", 3, 10),
            "rp_sd_min": trial.suggest_float("rp_sd_min", 0.0, 15.0),
        }

        dyn_mask = get_dynamic_mask(filtered_df, thresholds)
        obs_counts = filtered_df[dyn_mask]['sample_id'].value_counts()
        
        obs_arr = [sum(obs_counts.get(sid, 0) for sid in m['sample_ids']) for m in agg_meta]
        return poisson_deviance(np.array(obs_arr), exp_arr, weights=weights_arr)
    
    return objective

# -----------------------
# Reporting
# -----------------------
def evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, outdir):
    os.makedirs(outdir, exist_ok=True)
    
    # NEW: Added ignore_cb_pon flags to isolate the counts
    static_mask_final = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False, ignore_cb_pon=False)
    static_mask_clean = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=True, ignore_cb_pon=False)
    static_mask_no_cb_pon = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False, ignore_cb_pon=True)
    
    dyn_mask = get_dynamic_mask(all_variants_df, best_thresholds)
    
    pass_mask_final = static_mask_final & dyn_mask
    pass_mask_clean = static_mask_clean & dyn_mask
    pass_mask_no_cb_pon = static_mask_no_cb_pon & dyn_mask # NEW
    
    count_saved_by_blacklist = (pass_mask_clean & (~pass_mask_final)).sum()
    count_saved_by_cb_pon = (pass_mask_no_cb_pon & (~pass_mask_final)).sum() # NEW
    
    obs_series = all_variants_df[pass_mask_final].groupby('sample_id').size()
    
    observed, expected, ids, ages, bases, types, weights = [], [], [], [], [], [], []

    for s in samples_meta:
        sid = s['sample_id']
        ids.append(sid)
        observed.append(obs_series.get(sid, 0))
        expected.append(expected_lambda(s['sample_type'], s['age'], s['bases']))
        ages.append(s['age'])
        bases.append(s['bases'])
        types.append(s['sample_type'])
        weights.append(CORD_WEIGHT if "cord" in s['sample_type'].lower() else 1.0)

    obs_arr, exp_arr, weights_arr = np.array(observed), np.array(expected), np.array(weights)

    with open(os.path.join(outdir, "best_thresholds.json"), "w") as fh:
        json.dump({"thresholds": best_thresholds, "pon_flags": pon_flags, "blacklists_enforced": True, "cord_penalty_weight": CORD_WEIGHT}, fh, indent=2)

    dev = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
    mean_ratio = float(np.mean(obs_arr / (exp_arr + EPS)))
    
    with open(os.path.join(outdir, "summary.json"), "w") as fh:
        json.dump({
            "n_samples": len(samples_meta),
            "obs_mean_over_expected": mean_ratio,
            "total_observed": int(np.sum(obs_arr)),
            "total_expected": float(np.sum(exp_arr)),
            "weighted_poisson_deviance": dev,
            "variants_blocked_by_blacklists": int(count_saved_by_blacklist),
            "variants_blocked_by_cb_pon": int(count_saved_by_cb_pon) # NEW
        }, fh, indent=2)

    pd.DataFrame({
        "sample_id": ids, "sample_type": types, "age": ages, "bases": bases,
        "observed": observed, "expected": expected, "weight_used": weights 
    }).to_csv(os.path.join(outdir, "observed_expected.csv"), index=False)
    
    final_pass_df = all_variants_df[pass_mask_final]
    n_ins = (final_pass_df['INDEL_LENGTH'] > 0).sum()
    n_del = (final_pass_df['INDEL_LENGTH'] < 0).sum()
    n_1bp = (final_pass_df['INDEL_LENGTH'].abs() == 1).sum()
    n_long = (final_pass_df['INDEL_LENGTH'].abs() > 1).sum()
    
    ins_del_ratio = n_ins / n_del if n_del > 0 else 0.0
    bp1_long_ratio = n_1bp / n_long if n_long > 0 else 0.0

    print("-" * 30)
    print("FINAL RESULTS")
    print("-" * 30)
    print(f"Total Samples:         {len(samples_meta)}")
    print(f"Total Observed Indels: {int(np.sum(obs_arr))}")
    print(f"Total Expected Indels: {float(np.sum(exp_arr)):.2f}")
    print(f"Weighted Deviance:     {dev:.4f}")
    print(f"Mean Obs/Exp Ratio:    {mean_ratio:.4f}")
    print(f"Blacklist Blocked:     {count_saved_by_blacklist}")
    print(f"CB PON Blocked:        {count_saved_by_cb_pon}") # NEW
    print("-" * 30)
    print("INDEL METRICS (Passing Variants)")
    print("-" * 30)
    print(f"Insertions: {n_ins} | Deletions: {n_del}")
    print(f"INS / DEL Ratio:       {ins_del_ratio:.3f}")
    print(f"1bp Indels: {n_1bp} | >1bp Indels: {n_long}")
    print(f"1bp / >1bp Ratio:      {bp1_long_ratio:.3f}")
    print("-" * 30)

    
# -----------------------
# Execution Block
# -----------------------
if __name__ == "__main__":
    print(f"[INFO] Reading metadata from {SAMPLES_CSV}...")
    samples_meta = []
    with open(SAMPLES_CSV, newline='') as csvfile:
        for r in csv.DictReader(csvfile):
            samples_meta.append({
                "sample_id": r["sample_id"],
                "vcf_path": r["vcf_path"],
                "sample_type": r["sample_type"].lower(),
                "age": float(r["age"]) if r.get("age") else None,
                "bases": float(r["total_callable_bases_in_wes"]),
            })
    print(f"[INFO] Loaded {len(samples_meta)} samples.")

    print("[INFO] Loading VCFs into DataFrame...")
    df_list = [parse_vcf_to_df(s["vcf_path"], s["sample_id"]) for s in samples_meta]
    all_variants_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    
    print(f"[INFO] Total variants loaded: {len(all_variants_df)}")

    if not all_variants_df.empty:
        chroms = all_variants_df['CHROM'].values
        poses = all_variants_df['POS'].values

        # ---------------------------------------------------------
        # NEW: Filter by WES BED immediately to save computation
        # ---------------------------------------------------------
        bed_lookup_exome = BedLookup(EXOME_BED_PATH, "Exome Targets")
        in_exome_mask = [bed_lookup_exome.is_overlapped(c, p) for c, p in zip(chroms, poses)]
        all_variants_df = all_variants_df[in_exome_mask].reset_index(drop=True)
        print(f"[INFO] Variants remaining after WES target restriction: {len(all_variants_df)}")

        # Proceed only if we still have variants left
        if not all_variants_df.empty:
            # Re-extract chroms and poses for the remaining on-target variants
            chroms = all_variants_df['CHROM'].values
            poses = all_variants_df['POS'].values

            bed_lookup_cluster = BedLookup(BLACKLIST_BED, "Cluster Blacklist")
            all_variants_df['IN_CLUSTER_BLACKLIST'] = [bed_lookup_cluster.is_overlapped(c, p) for c, p in zip(chroms, poses)]
            
            bed_lookup_genes = BedLookup(ARTEFACT_GENES_BED, "Artefact Gene Blacklist")
            all_variants_df['IN_ARTEFACT_BLACKLIST'] = [bed_lookup_genes.is_overlapped(c, p) for c, p in zip(chroms, poses)]
            
            hits_cluster = sum(all_variants_df['IN_CLUSTER_BLACKLIST'])
            print(f"[INFO] Found {hits_cluster} variants in Cluster blacklist.")

            # Aggregate cords for robust optimization
            agg_meta = aggregate_samples(samples_meta)
            
            # Pre-filter static masks to massively speed up Optuna
            pon_flags = {"use_cord_pon": True}
            static_mask = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False)
            static_filtered_df = all_variants_df[static_mask].copy()

            run_diagnostic_waterfall(static_filtered_df)
            # ---------------------------

            print(f"[INFO] Starting Optuna (Trials={N_TRIALS}). Evaluating {len(static_filtered_df)} valid candidates per trial...")

            print(f"[INFO] Starting Optuna (Trials={N_TRIALS}). Evaluating {len(static_filtered_df)} valid candidates per trial...")
            study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=SEED))
            
            objective = make_objective(static_filtered_df, agg_meta)
            study.optimize(objective, n_trials=N_TRIALS)

            print(f"[INFO] Best Weighted Deviance: {study.best_value:.4f}")

            print("[INFO] Generating report...")
            evaluate_and_report(study.best_params, pon_flags, all_variants_df, samples_meta, OUT_DIR)
        else:
            print("[WARN] No variants remained after Exome BED filtering.")
# Out:
# [INFO] Reading metadata from training_complete_processed_metadata.csv...
# [INFO] Loaded 18 samples.
# [INFO] Loading VCFs into DataFrame...
# [INFO] Total variants loaded: 19992
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Variants remaining after WES target restriction: 19312
# [INFO] Loading Cluster Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Cluster Blacklist.
# [INFO] Loading Artefact Gene Blacklist from ../../resources/master_blacklist.bed...
# [I 2026-04-24 17:40:19,848] A new study created in memory with name: no-name-9e241447-bbed-43a1-8d7e-8847f17ddd3b
# [I 2026-04-24 17:40:19,852] Trial 0 finished with value: 2470.522547308156 and parameters: {'n_total_min': 17, 'depth_percentile_max': 99, 'mean_inset_qual_min': 42, 'mean_del_anchor_qual_min': 38, 'max_slippage_reads': 0, 'asxs_min': 17, 'mean_mapq_min': 21, 'avg_alt_nm_max': 4.330880728874676, 'dist_to_softclip_min': 3, 'variants_250bp_max': 11, 'ref_entropy_min': 0.04322743802118514, 'min_dist_to_indel': 485, 'min_rp_med': 0.06827098485602953, 'max_rp_med': 0.9348637377474793, 'max_n_count': 0.5454749016213019, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 11.00427059120603, 'mean_ref_mapq_min': 32.169689718381505, 'avg_nonaltread_variants_max': 5.247564316322379, 'sd_insert_max': 345.5560149136926, 'avg_read_position_min': 2.9122914019804194, 'avg_read_position_max': 142.2370578944476, 'avg_read_length_min': 63.94938606520418, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.1099085529881075, 'strand_bias_max': 0.8368209952651108, 'rp_sd_min_alt': 9, 'rp_sd_min': 2.995106732375396}. Best is trial 0 with value: 2470.522547308156.
# [I 2026-04-24 17:40:19,855] Trial 1 finished with value: 2470.522547308156 and parameters: {'n_total_min': 20, 'depth_percentile_max': 97, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 38, 'max_slippage_reads': 1, 'asxs_min': 13, 'mean_mapq_min': 49, 'avg_alt_nm_max': 4.828160165372797, 'dist_to_softclip_min': 4, 'variants_250bp_max': 4, 'ref_entropy_min': 0.20511143941340615, 'min_dist_to_indel': 342, 'min_rp_med': 0.04081067456177209, 'max_rp_med': 0.9285426764391346, 'max_n_count': 1.4855307303338106, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 2.0633112669131037, 'mean_ref_mapq_min': 56.372816083151285, 'avg_nonaltread_variants_max': 2.587799816000169, 'sd_insert_max': 530.0178274831856, 'avg_read_position_min': 3.1171107608941098, 'avg_read_position_max': 140.4013604235562, 'avg_read_length_min': 104.67102793432797, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.29087538832936755, 'strand_bias_max': 0.9325398470083344, 'rp_sd_min_alt': 10, 'rp_sd_min': 13.422410256414732}. Best is trial 0 with value: 2470.522547308156.
# [I 2026-04-24 17:40:19,858] Trial 2 finished with value: 2470.522547308156 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 26, 'max_slippage_reads': 0, 'asxs_min': 26, 'mean_mapq_min': 32, 'avg_alt_nm_max': 1.3567451588694794, 'dist_to_softclip_min': 4, 'variants_250bp_max': 5, 'ref_entropy_min': 0.5899624703434996, 'min_dist_to_indel': 271, 'min_rp_med': 0.019864695748233387, 'max_rp_med': 0.9761537886527828, 'max_n_count': 0.22365193103931247, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 59.21321619603104, 'mean_ref_mapq_min': 50.889790771866295, 'avg_nonaltread_variants_max': 1.987156815341724, 'sd_insert_max': 4.417693698881919, 'avg_read_position_min': 8.154614284548341, 'avg_read_position_max': 144.13714687695233, 'avg_read_length_min': 122.90071680409874, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.02221339552022711, 'strand_bias_max': 0.8075397185632818, 'rp_sd_min_alt': 3, 'rp_sd_min': 12.946551388133903}. Best is trial 0 with value: 2470.522547308156.
# [I 2026-04-24 17:40:19,862] Trial 3 finished with value: 1760.1353738004725 and parameters: {'n_total_min': 23, 'depth_percentile_max': 96, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 29, 'max_slippage_reads': 1, 'asxs_min': 47, 'mean_mapq_min': 39, 'avg_alt_nm_max': 4.436063712881633, 'dist_to_softclip_min': 2, 'variants_250bp_max': 1, 'ref_entropy_min': 1.4978140531682895, 'min_dist_to_indel': 381, 'min_rp_med': 0.04928940382986474, 'max_rp_med': 0.9739677025968193, 'max_n_count': 1.4813867890931722, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 31.363969762919645, 'mean_ref_mapq_min': 37.101640734341984, 'avg_nonaltread_variants_max': 0.2541912674409519, 'sd_insert_max': 86.31314159464355, 'avg_read_position_min': 0.3142918568673425, 'avg_read_position_max': 142.7282082252756, 'avg_read_length_min': 81.43559810763267, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.2722699421778279, 'strand_bias_max': 0.7747876687446624, 'rp_sd_min_alt': 6, 'rp_sd_min': 11.333267078145731}. Best is trial 3 with value: 1760.1353738004725.
# [I 2026-04-24 17:40:19,865] Trial 4 finished with value: 2470.522547308156 and parameters: {'n_total_min': 14, 'depth_percentile_max': 95, 'mean_inset_qual_min': 28, 'mean_del_anchor_qual_min': 24, 'max_slippage_reads': 5, 'asxs_min': 51, 'mean_mapq_min': 39, 'avg_alt_nm_max': 4.357302950938589, 'dist_to_softclip_min': 4, 'variants_250bp_max': 2, 'ref_entropy_min': 1.8743738968289534, 'min_dist_to_indel': 270, 'min_rp_med': 0.06652081086148438, 'max_rp_med': 0.9827263909946445, 'max_n_count': 0.9540104249155916, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 6.6031154716606055, 'mean_ref_mapq_min': 29.117406501677667, 'avg_nonaltread_variants_max': 4.271077886262563, 'sd_insert_max': 654.4118127379945, 'avg_read_position_min': 8.607305832563434, 'avg_read_position_max': 130.13904261062382, 'avg_read_length_min': 101.07473025775657, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.06663234314121907, 'strand_bias_max': 0.7359596102001048, 'rp_sd_min_alt': 5, 'rp_sd_min': 14.143645558687787}. Best is trial 3 with value: 1760.1353738004725.
# [I 2026-04-24 17:40:19,868] Trial 5 finished with value: 2470.522547308156 and parameters: {'n_total_min': 16, 'depth_percentile_max': 97, 'mean_inset_qual_min': 41, 'mean_del_anchor_qual_min': 31, 'max_slippage_reads': 5, 'asxs_min': 59, 'mean_mapq_min': 27, 'avg_alt_nm_max': 2.4862425294619275, 'dist_to_softclip_min': 1, 'variants_250bp_max': 4, 'ref_entropy_min': 0.07746258944451888, 'min_dist_to_indel': 305, 'min_rp_med': 0.04518753162602031, 'max_rp_med': 0.9236035125874993, 'max_n_count': 0.8359393927098343, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 54.495953157999224, 'mean_ref_mapq_min': 29.582475626678896, 'avg_nonaltread_variants_max': 1.448948720912231, 'sd_insert_max': 391.5622082220504, 'avg_read_position_min': 9.856504541106007, 'avg_read_position_max': 134.84110543023002, 'avg_read_length_min': 117.21355474058785, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.0712912631977199, 'strand_bias_max': 0.9184649045835579, 'rp_sd_min_alt': 5, 'rp_sd_min': 9.484587458903691}. Best is trial 3 with value: 1760.1353738004725.
# [I 2026-04-24 17:40:19,872] Trial 6 finished with value: 2470.522547308156 and parameters: {'n_total_min': 23, 'depth_percentile_max': 97, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 45, 'max_slippage_reads': 1, 'asxs_min': 19, 'mean_mapq_min': 21, 'avg_alt_nm_max': 2.954464715941209, 'dist_to_softclip_min': 4, 'variants_250bp_max': 0, 'ref_entropy_min': 1.07539542242849, 'min_dist_to_indel': 113, 'min_rp_med': 0.055162095328661495, 'max_rp_med': 0.9322056500303494, 'max_n_count': 2.0728132143073976, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 23.204120778032244, 'mean_ref_mapq_min': 57.46919954946938, 'avg_nonaltread_variants_max': 1.3752094414599325, 'sd_insert_max': 272.8530808402068, 'avg_read_position_min': 1.1347352124058907, 'avg_read_position_max': 148.49387236557126, 'avg_read_length_min': 137.7339353380981, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.1979952138102537, 'strand_bias_max': 0.9451666600603648, 'rp_sd_min_alt': 7, 'rp_sd_min': 7.944758675340097}. Best is trial 3 with value: 1760.1353738004725.
# [I 2026-04-24 17:40:19,876] Trial 7 finished with value: 616.8246181671095 and parameters: {'n_total_min': 15, 'depth_percentile_max': 95, 'mean_inset_qual_min': 47, 'mean_del_anchor_qual_min': 47, 'max_slippage_reads': 3, 'asxs_min': 27, 'mean_mapq_min': 30, 'avg_alt_nm_max': 3.629778394351197, 'dist_to_softclip_min': 5, 'variants_250bp_max': 14, 'ref_entropy_min': 1.6377386463010102, 'min_dist_to_indel': 321, 'min_rp_med': 0.01588979754965342, 'max_rp_med': 0.931314009986623, 'max_n_count': 2.695662565581238, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 36.3857435795754, 'mean_ref_mapq_min': 20.367882064665185, 'avg_nonaltread_variants_max': 1.014715428660321, 'sd_insert_max': 530.8014152864447, 'avg_read_position_min': 0.05061583846218687, 'avg_read_position_max': 133.21616102834997, 'avg_read_length_min': 104.87337893665861, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.19558837785078015, 'strand_bias_max': 0.7672807928381679, 'rp_sd_min_alt': 8, 'rp_sd_min': 3.558736312452001}. Best is trial 7 with value: 616.8246181671095.
# [I 2026-04-24 17:40:19,879] Trial 8 finished with value: 2470.522547308156 and parameters: {'n_total_min': 16, 'depth_percentile_max': 98, 'mean_inset_qual_min': 40, 'mean_del_anchor_qual_min': 46, 'max_slippage_reads': 3, 'asxs_min': 38, 'mean_mapq_min': 22, 'avg_alt_nm_max': 1.8385790152971677, 'dist_to_softclip_min': 1, 'variants_250bp_max': 3, 'ref_entropy_min': 2.0433221649801356, 'min_dist_to_indel': 196, 'min_rp_med': 0.07244325886239794, 'max_rp_med': 0.9641797038198084, 'max_n_count': 2.3844339106249453, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 30.158225586311527, 'mean_ref_mapq_min': 43.07615538505436, 'avg_nonaltread_variants_max': 4.925176938188639, 'sd_insert_max': 156.1943902384356, 'avg_read_position_min': 7.224521152615053, 'avg_read_position_max': 135.6154472488171, 'avg_read_length_min': 52.43159664314538, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.05313320382211468, 'strand_bias_max': 0.9821375753058743, 'rp_sd_min_alt': 10, 'rp_sd_min': 13.722965853306729}. Best is trial 7 with value: 616.8246181671095.
# [I 2026-04-24 17:40:19,882] Trial 9 finished with value: 2470.522547308156 and parameters: {'n_total_min': 17, 'depth_percentile_max': 95, 'mean_inset_qual_min': 48, 'mean_del_anchor_qual_min': 33, 'max_slippage_reads': 5, 'asxs_min': 59, 'mean_mapq_min': 46, 'avg_alt_nm_max': 1.4722444603479286, 'dist_to_softclip_min': 2, 'variants_250bp_max': 13, 'ref_entropy_min': 0.6655362108281832, 'min_dist_to_indel': 84, 'min_rp_med': 0.04897608837208452, 'max_rp_med': 0.9855308341912546, 'max_n_count': 2.088089390024919, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 34.203670205361895, 'mean_ref_mapq_min': 23.88705975083074, 'avg_nonaltread_variants_max': 6.150072266991698, 'sd_insert_max': 792.0430800834106, 'avg_read_position_min': 1.4008401523652403, 'avg_read_position_max': 140.36659304727473, 'avg_read_length_min': 137.73730719279556, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.20910472229858038, 'strand_bias_max': 0.9107452251961328, 'rp_sd_min_alt': 5, 'rp_sd_min': 4.403877663967401}. Best is trial 7 with value: 616.8246181671095.
# [I 2026-04-24 17:40:19,900] Trial 10 finished with value: 2470.522547308156 and parameters: {'n_total_min': 10, 'depth_percentile_max': 96, 'mean_inset_qual_min': 50, 'mean_del_anchor_qual_min': 49, 'max_slippage_reads': 3, 'asxs_min': 30, 'mean_mapq_min': 31, 'avg_alt_nm_max': 0.3706008913259202, 'dist_to_softclip_min': 5, 'variants_250bp_max': 15, 'ref_entropy_min': 1.5085988024976804, 'min_dist_to_indel': 450, 'min_rp_med': 0.01164958965595542, 'max_rp_med': 0.9475663631534889, 'max_n_count': 2.9817476165760244, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 45.278796586347156, 'mean_ref_mapq_min': 20.432898343730162, 'avg_nonaltread_variants_max': 9.780711792648397, 'sd_insert_max': 531.8533594836648, 'avg_read_position_min': 5.520262400755189, 'avg_read_position_max': 131.67519365991723, 'avg_read_length_min': 82.17671776002648, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.17664428260682677, 'strand_bias_max': 0.7147487230282631, 'rp_sd_min_alt': 8, 'rp_sd_min': 0.15899032317553274}. Best is trial 7 with value: 616.8246181671095.
# [I 2026-04-24 17:40:19,916] Trial 11 finished with value: 1643.2241654135287 and parameters: {'n_total_min': 30, 'depth_percentile_max': 96, 'mean_inset_qual_min': 31, 'mean_del_anchor_qual_min': 21, 'max_slippage_reads': 2, 'asxs_min': 42, 'mean_mapq_min': 39, 'avg_alt_nm_max': 3.564044142669529, 'dist_to_softclip_min': 0, 'variants_250bp_max': 9, 'ref_entropy_min': 1.548621451868171, 'min_dist_to_indel': 386, 'min_rp_med': 0.02644688672315537, 'max_rp_med': 0.9597387286648549, 'max_n_count': 1.4616032010002526, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 40.81342875022664, 'mean_ref_mapq_min': 39.27436975003055, 'avg_nonaltread_variants_max': 0.26936651568340747, 'sd_insert_max': 132.68996645570948, 'avg_read_position_min': 0.2068362352653356, 'avg_read_position_max': 145.89290728224177, 'avg_read_length_min': 80.07348985782062, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.27007173635542336, 'strand_bias_max': 0.7821218190710311, 'rp_sd_min_alt': 7, 'rp_sd_min': 10.327799790053337}. Best is trial 7 with value: 616.8246181671095.
# [I 2026-04-24 17:40:19,930] Trial 12 finished with value: 2470.522547308156 and parameters: {'n_total_min': 29, 'depth_percentile_max': 96, 'mean_inset_qual_min': 30, 'mean_del_anchor_qual_min': 20, 'max_slippage_reads': 2, 'asxs_min': 39, 'mean_mapq_min': 40, 'avg_alt_nm_max': 3.407552586621136, 'dist_to_softclip_min': 0, 'variants_250bp_max': 9, 'ref_entropy_min': 1.6075031166970544, 'min_dist_to_indel': 401, 'min_rp_med': 0.028478794129071092, 'max_rp_med': 0.9500018392058563, 'max_n_count': 2.96073659154073, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 43.284813651547076, 'mean_ref_mapq_min': 44.22194953039131, 'avg_nonaltread_variants_max': 0.18198280109143708, 'sd_insert_max': 227.44356629622783, 'avg_read_position_min': 2.8563641428925006, 'avg_read_position_max': 149.33619188663957, 'avg_read_length_min': 84.82779981046788, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.24647362852833263, 'strand_bias_max': 0.7694760320597837, 'rp_sd_min_alt': 8, 'rp_sd_min': 5.462421566648266}. Best is trial 7 with value: 616.8246181671095.
# [I 2026-04-24 17:40:19,945] Trial 13 finished with value: 398.65065886373685 and parameters: {'n_total_min': 30, 'depth_percentile_max': 95, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 40, 'max_slippage_reads': 4, 'asxs_min': 30, 'mean_mapq_min': 35, 'avg_alt_nm_max': 3.602241749516541, 'dist_to_softclip_min': 0, 'variants_250bp_max': 8, 'ref_entropy_min': 1.1958741636853603, 'min_dist_to_indel': 180, 'min_rp_med': 0.029714070160105265, 'max_rp_med': 0.942128914615561, 'max_n_count': 1.9195277159430928, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 41.88579840032408, 'mean_ref_mapq_min': 37.692081173712765, 'avg_nonaltread_variants_max': 3.116160072416097, 'sd_insert_max': 503.88338478028743, 'avg_read_position_min': 0.13723780933529567, 'avg_read_position_max': 146.17150414803294, 'avg_read_length_min': 69.86185845341556, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.133940237688982, 'strand_bias_max': 0.8625296398426465, 'rp_sd_min_alt': 7, 'rp_sd_min': 6.9550987097214705}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:19,961] Trial 14 finished with value: 2470.522547308156 and parameters: {'n_total_min': 11, 'depth_percentile_max': 95, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 42, 'max_slippage_reads': 4, 'asxs_min': 28, 'mean_mapq_min': 28, 'avg_alt_nm_max': 3.64209581469683, 'dist_to_softclip_min': 5, 'variants_250bp_max': 15, 'ref_entropy_min': 1.1102180359723794, 'min_dist_to_indel': 171, 'min_rp_med': 0.032643357490582045, 'max_rp_med': 0.9408217294668431, 'max_n_count': 2.4639314840071496, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 19.981451632947884, 'mean_ref_mapq_min': 50.292590645734435, 'avg_nonaltread_variants_max': 3.2629920579530127, 'sd_insert_max': 508.42045057198106, 'avg_read_position_min': 4.139862084027019, 'avg_read_position_max': 136.71778673530622, 'avg_read_length_min': 66.09423613556014, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.13021444283689884, 'strand_bias_max': 0.8661874006739214, 'rp_sd_min_alt': 8, 'rp_sd_min': 6.180220008869242}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:19,976] Trial 15 finished with value: 2470.522547308156 and parameters: {'n_total_min': 26, 'depth_percentile_max': 95, 'mean_inset_qual_min': 45, 'mean_del_anchor_qual_min': 41, 'max_slippage_reads': 4, 'asxs_min': 22, 'mean_mapq_min': 34, 'avg_alt_nm_max': 2.5653373197585063, 'dist_to_softclip_min': 3, 'variants_250bp_max': 7, 'ref_entropy_min': 1.274950781081708, 'min_dist_to_indel': 11, 'min_rp_med': 0.010644805690442353, 'max_rp_med': 0.9416595585793882, 'max_n_count': 2.010667217476804, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 49.77829944806628, 'mean_ref_mapq_min': 33.46630082717777, 'avg_nonaltread_variants_max': 7.306171006433202, 'sd_insert_max': 714.6255298439585, 'avg_read_position_min': 1.696249532271075, 'avg_read_position_max': 138.19773019065286, 'avg_read_length_min': 110.83718726421279, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.15485742844947362, 'strand_bias_max': 0.8657862522144455, 'rp_sd_min_alt': 6, 'rp_sd_min': 2.027742566420817}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:19,993] Trial 16 finished with value: 2470.522547308156 and parameters: {'n_total_min': 20, 'depth_percentile_max': 95, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 49, 'max_slippage_reads': 4, 'asxs_min': 32, 'mean_mapq_min': 26, 'avg_alt_nm_max': 3.810530773609298, 'dist_to_softclip_min': 1, 'variants_250bp_max': 12, 'ref_entropy_min': 0.7045277832940902, 'min_dist_to_indel': 187, 'min_rp_med': 0.019416480164464664, 'max_rp_med': 0.9218103661749508, 'max_n_count': 2.5988920421514985, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 37.80579289463937, 'mean_ref_mapq_min': 25.89347125049504, 'avg_nonaltread_variants_max': 3.4552403055684557, 'sd_insert_max': 605.2601054103523, 'avg_read_position_min': 5.347746531430529, 'avg_read_position_max': 133.1407858541749, 'avg_read_length_min': 91.83111058231248, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.23071131782890808, 'strand_bias_max': 0.8311563459439417, 'rp_sd_min_alt': 9, 'rp_sd_min': 7.7109270095611295}. Best is trial 13 with value: 398.65065886373685.
# [INFO] Loaded 4208652 regions for Artefact Gene Blacklist.
# [INFO] Found 5279 variants in Cluster blacklist.
#
# ========================================
#    DYNAMIC FILTER WATERFALL DIAGNOSTIC
# ========================================
# FILTER STEP                    | REMAINING  | DROPPED HERE
# -------------------------------------------------------
# N_TOTAL                        | 1533       | 29
# DEPTH_PERCENTILE               | 1533       | 0
# MEAN_MAPQ                      | 1504       | 29
# AVG_ASXS                       | 1504       | 0
# INSET/ANCHOR_QUAL              | 1504       | 0
# HOMOPOLYMER                    | 1503       | 1
# SLIPPAGE                       | 1452       | 51
# VARIANTS_20BP                  | 1369       | 83
# VARIANTS_250BP                 | 1287       | 82
# REF_ENTROPY                    | 1287       | 0
# ALT_SOFTCLIP                   | 1259       | 28
# DIST_SOFTCLIP                  | 1259       | 0
# ALT_EXCESS_NM                  | 1208       | 51
# GC_CONTENT                     | 1204       | 4
# DIST_OTHER_INDEL               | 1204       | 0
# RP_MED                         | 1204       | 0
# ALT_N_COUNT                    | 1178       | 26
# GERMLINE_VAF                   | 915        | 263
# SD_BASEQ                       | 892        | 23
# AVG_ALT_READ_MEAN_BASEQ        | 891        | 1
# MEAN_REF_MAPQ                  | 891        | 0
# AVG_REF_ASXS                   | 891        | 0
# AVG_ALTREAD_VARIANTS           | 891        | 0
# AVG_NONALTREAD_VARIANTS        | 890        | 1
# MEAN_INSERT                    | 890        | 0
# SD_INSERT                      | 890        | 0
# AVG_READ_POSITION              | 890        | 0
# AVG_READ_LENGTH                | 888        | 2
# STRAND_BIAS                    | 888        | 0
# RP_SD                          | 888        | 0
# ========================================
#
# [INFO] Starting Optuna (Trials=3000). Evaluating 1562 valid candidates per trial...
# [INFO] Starting Optuna (Trials=3000). Evaluating 1562 valid candidates per trial...
# [I 2026-04-24 17:40:20,011] Trial 17 finished with value: 916.2410470540204 and parameters: {'n_total_min': 27, 'depth_percentile_max': 98, 'mean_inset_qual_min': 33, 'mean_del_anchor_qual_min': 36, 'max_slippage_reads': 3, 'asxs_min': 24, 'mean_mapq_min': 36, 'avg_alt_nm_max': 3.056070976407174, 'dist_to_softclip_min': 2, 'variants_250bp_max': 7, 'ref_entropy_min': 1.84308099697061, 'min_dist_to_indel': 220, 'min_rp_med': 0.034638327709706034, 'max_rp_med': 0.9368615325559647, 'max_n_count': 1.7632656053419005, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 24.772474930417026, 'mean_ref_mapq_min': 20.218343015092522, 'avg_nonaltread_variants_max': 2.851103577524943, 'sd_insert_max': 454.3229195484011, 'avg_read_position_min': 0.017000572794122384, 'avg_read_position_max': 146.97871475078333, 'avg_read_length_min': 65.96237169680929, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.10476367901295207, 'strand_bias_max': 0.87533722573731, 'rp_sd_min_alt': 3, 'rp_sd_min': 3.8501437436009525}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,027] Trial 18 finished with value: 2470.522547308156 and parameters: {'n_total_min': 13, 'depth_percentile_max': 96, 'mean_inset_qual_min': 27, 'mean_del_anchor_qual_min': 43, 'max_slippage_reads': 4, 'asxs_min': 33, 'mean_mapq_min': 44, 'avg_alt_nm_max': 2.265115367366039, 'dist_to_softclip_min': 0, 'variants_250bp_max': 10, 'ref_entropy_min': 0.890777948236888, 'min_dist_to_indel': 135, 'min_rp_med': 0.02100734286200816, 'max_rp_med': 0.9514051431922238, 'max_n_count': 2.6833942217580233, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 49.187217359224206, 'mean_ref_mapq_min': 47.47118615460108, 'avg_nonaltread_variants_max': 7.033331422351365, 'sd_insert_max': 614.95158510639, 'avg_read_position_min': 2.0331634851844704, 'avg_read_position_max': 138.71434579328817, 'avg_read_length_min': 125.00878689285716, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.15940776290107203, 'strand_bias_max': 0.7012807574895121, 'rp_sd_min_alt': 9, 'rp_sd_min': 1.0788171765866026}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,043] Trial 19 finished with value: 2470.522547308156 and parameters: {'n_total_min': 26, 'depth_percentile_max': 95, 'mean_inset_qual_min': 38, 'mean_del_anchor_qual_min': 50, 'max_slippage_reads': 2, 'asxs_min': 14, 'mean_mapq_min': 30, 'avg_alt_nm_max': 4.9092703157319075, 'dist_to_softclip_min': 5, 'variants_250bp_max': 13, 'ref_entropy_min': 1.2630789310349242, 'min_dist_to_indel': 43, 'min_rp_med': 0.0376460621598728, 'max_rp_med': 0.9574432043548918, 'max_n_count': 1.2017893528422068, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 16.487791316526632, 'mean_ref_mapq_min': 35.16350108714497, 'avg_nonaltread_variants_max': 4.0774294839935905, 'sd_insert_max': 435.4384105203426, 'avg_read_position_min': 4.350326481759278, 'avg_read_position_max': 145.013401368893, 'avg_read_length_min': 53.90505846632192, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.19840019561173394, 'strand_bias_max': 0.8051322436584185, 'rp_sd_min_alt': 7, 'rp_sd_min': 6.317307764246362}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,059] Trial 20 finished with value: 2470.522547308156 and parameters: {'n_total_min': 14, 'depth_percentile_max': 98, 'mean_inset_qual_min': 45, 'mean_del_anchor_qual_min': 46, 'max_slippage_reads': 3, 'asxs_min': 45, 'mean_mapq_min': 36, 'avg_alt_nm_max': 4.071682828404275, 'dist_to_softclip_min': 3, 'variants_250bp_max': 6, 'ref_entropy_min': 1.7553067033506946, 'min_dist_to_indel': 319, 'min_rp_med': 0.026063303683246622, 'max_rp_med': 0.943653750215578, 'max_n_count': 1.7947982262338233, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 36.81305277736399, 'mean_ref_mapq_min': 25.44796820211333, 'avg_nonaltread_variants_max': 1.281120357783581, 'sd_insert_max': 311.7674559296763, 'avg_read_position_min': 6.140823224035463, 'avg_read_position_max': 132.85895838397954, 'avg_read_length_min': 90.27451836237512, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.1269797639910158, 'strand_bias_max': 0.7444100397673903, 'rp_sd_min_alt': 4, 'rp_sd_min': 8.626816780082446}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,075] Trial 21 finished with value: 2470.522547308156 and parameters: {'n_total_min': 27, 'depth_percentile_max': 98, 'mean_inset_qual_min': 32, 'mean_del_anchor_qual_min': 37, 'max_slippage_reads': 3, 'asxs_min': 23, 'mean_mapq_min': 35, 'avg_alt_nm_max': 3.118193143842025, 'dist_to_softclip_min': 2, 'variants_250bp_max': 8, 'ref_entropy_min': 2.0605522243516274, 'min_dist_to_indel': 228, 'min_rp_med': 0.032432239516933734, 'max_rp_med': 0.9363117066727568, 'max_n_count': 1.7966293531538888, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 25.0308970228511, 'mean_ref_mapq_min': 20.62728299420609, 'avg_nonaltread_variants_max': 2.8644640591337316, 'sd_insert_max': 455.22686164740514, 'avg_read_position_min': 0.1468431026417737, 'avg_read_position_max': 146.03925915505718, 'avg_read_length_min': 70.48872527584271, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.0972815874720142, 'strand_bias_max': 0.8838291794953149, 'rp_sd_min_alt': 3, 'rp_sd_min': 3.772077997634169}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,091] Trial 22 finished with value: 2169.347483952305 and parameters: {'n_total_min': 28, 'depth_percentile_max': 98, 'mean_inset_qual_min': 34, 'mean_del_anchor_qual_min': 34, 'max_slippage_reads': 4, 'asxs_min': 25, 'mean_mapq_min': 36, 'avg_alt_nm_max': 3.102754796241489, 'dist_to_softclip_min': 1, 'variants_250bp_max': 7, 'ref_entropy_min': 1.824189303550748, 'min_dist_to_indel': 230, 'min_rp_med': 0.016048950831251827, 'max_rp_med': 0.9275366528482167, 'max_n_count': 2.258712848711307, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 25.948320139138165, 'mean_ref_mapq_min': 23.684258217058577, 'avg_nonaltread_variants_max': 2.120563472948162, 'sd_insert_max': 390.11698581178143, 'avg_read_position_min': 0.8280918756375787, 'avg_read_position_max': 147.70656144864142, 'avg_read_length_min': 72.91421217296735, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.09689505796029661, 'strand_bias_max': 0.8849767870828634, 'rp_sd_min_alt': 6, 'rp_sd_min': 4.791629870610978}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,109] Trial 23 finished with value: 2470.522547308156 and parameters: {'n_total_min': 30, 'depth_percentile_max': 97, 'mean_inset_qual_min': 25, 'mean_del_anchor_qual_min': 40, 'max_slippage_reads': 3, 'asxs_min': 36, 'mean_mapq_min': 25, 'avg_alt_nm_max': 2.7311560885648927, 'dist_to_softclip_min': 2, 'variants_250bp_max': 6, 'ref_entropy_min': 1.3237233471562129, 'min_dist_to_indel': 147, 'min_rp_med': 0.0350469094791681, 'max_rp_med': 0.9381961557724487, 'max_n_count': 1.7943283909365806, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 14.598515199795735, 'mean_ref_mapq_min': 30.178638016489508, 'avg_nonaltread_variants_max': 3.726618525636302, 'sd_insert_max': 481.253261712364, 'avg_read_position_min': 2.12812272868326, 'avg_read_position_max': 149.7916623924337, 'avg_read_length_min': 61.11891655216493, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.13693377651173524, 'strand_bias_max': 0.8339641029078817, 'rp_sd_min_alt': 4, 'rp_sd_min': 3.106817656655701}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,126] Trial 24 finished with value: 2470.522547308156 and parameters: {'n_total_min': 25, 'depth_percentile_max': 99, 'mean_inset_qual_min': 34, 'mean_del_anchor_qual_min': 36, 'max_slippage_reads': 2, 'asxs_min': 20, 'mean_mapq_min': 33, 'avg_alt_nm_max': 3.2903548261235986, 'dist_to_softclip_min': 0, 'variants_250bp_max': 11, 'ref_entropy_min': 1.6361653247628465, 'min_dist_to_indel': 254, 'min_rp_med': 0.02537027537837941, 'max_rp_med': 0.9311352466039124, 'max_n_count': 1.1678270133805673, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 28.673449145670038, 'mean_ref_mapq_min': 20.346529301629644, 'avg_nonaltread_variants_max': 2.4179811054219957, 'sd_insert_max': 580.3362833042826, 'avg_read_position_min': 0.8262345568733422, 'avg_read_position_max': 147.27067710105493, 'avg_read_length_min': 149.2136798025456, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.1680072171438856, 'strand_bias_max': 0.8917511393596284, 'rp_sd_min_alt': 8, 'rp_sd_min': 6.556407746192207}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,143] Trial 25 finished with value: 575.6077734264231 and parameters: {'n_total_min': 19, 'depth_percentile_max': 98, 'mean_inset_qual_min': 38, 'mean_del_anchor_qual_min': 40, 'max_slippage_reads': 4, 'asxs_min': 10, 'mean_mapq_min': 43, 'avg_alt_nm_max': 3.988262829546417, 'dist_to_softclip_min': 3, 'variants_250bp_max': 9, 'ref_entropy_min': 1.3982188349739773, 'min_dist_to_indel': 209, 'min_rp_med': 0.056402098430025735, 'max_rp_med': 0.9468341322995594, 'max_n_count': 2.7593224857333514, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 39.55793189485076, 'mean_ref_mapq_min': 26.19102111820615, 'avg_nonaltread_variants_max': 0.9183548882937869, 'sd_insert_max': 738.6301482627973, 'avg_read_position_min': 0.057561016420688324, 'avg_read_position_max': 142.44510605368194, 'avg_read_length_min': 94.22796525849542, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.004235254093615193, 'strand_bias_max': 0.962126382299053, 'rp_sd_min_alt': 7, 'rp_sd_min': 2.17173756900474}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,160] Trial 26 finished with value: 2470.522547308156 and parameters: {'n_total_min': 19, 'depth_percentile_max': 96, 'mean_inset_qual_min': 44, 'mean_del_anchor_qual_min': 44, 'max_slippage_reads': 4, 'asxs_min': 12, 'mean_mapq_min': 43, 'avg_alt_nm_max': 3.956913207873436, 'dist_to_softclip_min': 3, 'variants_250bp_max': 14, 'ref_entropy_min': 0.9021913547417306, 'min_dist_to_indel': 297, 'min_rp_med': 0.057569579631986126, 'max_rp_med': 0.9482671444252551, 'max_n_count': 2.801371327451282, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 47.9156192348667, 'mean_ref_mapq_min': 28.05269597296899, 'avg_nonaltread_variants_max': 0.9683346151849346, 'sd_insert_max': 725.5621973692864, 'avg_read_position_min': 2.335539291085571, 'avg_read_position_max': 142.73762018866668, 'avg_read_length_min': 96.14775329655595, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.015954302060432718, 'strand_bias_max': 0.9767628493238771, 'rp_sd_min_alt': 7, 'rp_sd_min': 2.3312088278165852}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,177] Trial 27 finished with value: 2470.522547308156 and parameters: {'n_total_min': 19, 'depth_percentile_max': 97, 'mean_inset_qual_min': 38, 'mean_del_anchor_qual_min': 40, 'max_slippage_reads': 5, 'asxs_min': 16, 'mean_mapq_min': 50, 'avg_alt_nm_max': 4.526910256423254, 'dist_to_softclip_min': 5, 'variants_250bp_max': 9, 'ref_entropy_min': 1.329733217125258, 'min_dist_to_indel': 340, 'min_rp_med': 0.07819592538266461, 'max_rp_med': 0.9650378205362642, 'max_n_count': 2.293451447839982, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 40.754481417308696, 'mean_ref_mapq_min': 40.44954768675353, 'avg_nonaltread_variants_max': 0.8470163495560821, 'sd_insert_max': 684.189504656892, 'avg_read_position_min': 4.084902713490237, 'avg_read_position_max': 141.50470947182214, 'avg_read_length_min': 111.12019739166165, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.22163603612138372, 'strand_bias_max': 0.9474352502578052, 'rp_sd_min_alt': 8, 'rp_sd_min': 1.350626840165003}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,195] Trial 28 finished with value: 2470.522547308156 and parameters: {'n_total_min': 21, 'depth_percentile_max': 95, 'mean_inset_qual_min': 48, 'mean_del_anchor_qual_min': 39, 'max_slippage_reads': 4, 'asxs_min': 10, 'mean_mapq_min': 42, 'avg_alt_nm_max': 3.950926759886046, 'dist_to_softclip_min': 4, 'variants_250bp_max': 11, 'ref_entropy_min': 1.4256930572524977, 'min_dist_to_indel': 98, 'min_rp_med': 0.06239096584946099, 'max_rp_med': 0.9445175660074134, 'max_n_count': 2.505174569457844, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 37.49710032218014, 'mean_ref_mapq_min': 26.435315478052814, 'avg_nonaltread_variants_max': 1.834417521806499, 'sd_insert_max': 780.3884657301383, 'avg_read_position_min': 0.9734782568984346, 'avg_read_position_max': 143.9967982061643, 'avg_read_length_min': 107.53689149766458, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.003973172041373096, 'strand_bias_max': 0.9688988516776347, 'rp_sd_min_alt': 6, 'rp_sd_min': 0.4398214048077067}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,212] Trial 29 finished with value: 2470.522547308156 and parameters: {'n_total_min': 17, 'depth_percentile_max': 99, 'mean_inset_qual_min': 39, 'mean_del_anchor_qual_min': 47, 'max_slippage_reads': 5, 'asxs_min': 17, 'mean_mapq_min': 47, 'avg_alt_nm_max': 4.642994399877855, 'dist_to_softclip_min': 3, 'variants_250bp_max': 12, 'ref_entropy_min': 1.1519718269856167, 'min_dist_to_indel': 495, 'min_rp_med': 0.05485176148729907, 'max_rp_med': 0.9529920857882099, 'max_n_count': 2.7772330093414554, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 33.50036690167637, 'mean_ref_mapq_min': 32.21440155211257, 'avg_nonaltread_variants_max': 4.711618956846183, 'sd_insert_max': 570.477734316142, 'avg_read_position_min': 2.7254096528692213, 'avg_read_position_max': 138.17803799791594, 'avg_read_length_min': 94.1218085216977, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.055171531492180834, 'strand_bias_max': 0.8050432140991677, 'rp_sd_min_alt': 9, 'rp_sd_min': 3.3016003539475918}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,229] Trial 30 finished with value: 2470.522547308156 and parameters: {'n_total_min': 18, 'depth_percentile_max': 96, 'mean_inset_qual_min': 43, 'mean_del_anchor_qual_min': 32, 'max_slippage_reads': 4, 'asxs_min': 29, 'mean_mapq_min': 29, 'avg_alt_nm_max': 4.164649343827914, 'dist_to_softclip_min': 3, 'variants_250bp_max': 10, 'ref_entropy_min': 0.8866504308588985, 'min_dist_to_indel': 443, 'min_rp_med': 0.04136587962100109, 'max_rp_med': 0.9339631534832892, 'max_n_count': 0.08219919314596758, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 53.06889340552891, 'mean_ref_mapq_min': 35.69595950556599, 'avg_nonaltread_variants_max': 5.652183489556901, 'sd_insert_max': 652.6095966978058, 'avg_read_position_min': 3.3247008556167423, 'avg_read_position_max': 142.0488455875677, 'avg_read_length_min': 74.08530757634925, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.17947640880969246, 'strand_bias_max': 0.9974385685701774, 'rp_sd_min_alt': 7, 'rp_sd_min': 2.380310037595554}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,247] Trial 31 finished with value: 483.3196746169918 and parameters: {'n_total_min': 28, 'depth_percentile_max': 98, 'mean_inset_qual_min': 32, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 3, 'asxs_min': 25, 'mean_mapq_min': 37, 'avg_alt_nm_max': 3.55638618378424, 'dist_to_softclip_min': 1, 'variants_250bp_max': 8, 'ref_entropy_min': 1.7002149305853451, 'min_dist_to_indel': 213, 'min_rp_med': 0.030205179569499065, 'max_rp_med': 0.9375273241958312, 'max_n_count': 1.9149782825277222, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 41.400246920033844, 'mean_ref_mapq_min': 22.847119659470295, 'avg_nonaltread_variants_max': 3.0979145411770768, 'sd_insert_max': 334.1220449347213, 'avg_read_position_min': 0.13229198538473058, 'avg_read_position_max': 146.88576763793853, 'avg_read_length_min': 61.39680559456312, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10272162212426478, 'strand_bias_max': 0.8382464491262743, 'rp_sd_min_alt': 8, 'rp_sd_min': 4.377752705576583}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,284] Trial 32 finished with value: 1930.8033868873301 and parameters: {'n_total_min': 24, 'depth_percentile_max': 98, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 38, 'max_slippage_reads': 3, 'asxs_min': 34, 'mean_mapq_min': 41, 'avg_alt_nm_max': 3.5672251637563903, 'dist_to_softclip_min': 1, 'variants_250bp_max': 8, 'ref_entropy_min': 1.7197098510259008, 'min_dist_to_indel': 170, 'min_rp_med': 0.015556114792211693, 'max_rp_med': 0.9267097313943035, 'max_n_count': 2.008566569092197, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 42.661541600052175, 'mean_ref_mapq_min': 22.57540252375706, 'avg_nonaltread_variants_max': 0.7534338023406986, 'sd_insert_max': 345.6378368058335, 'avg_read_position_min': 0.7452194103821438, 'avg_read_position_max': 144.0838118402299, 'avg_read_length_min': 58.75567150603276, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.03323887320454931, 'strand_bias_max': 0.8216981313508925, 'rp_sd_min_alt': 9, 'rp_sd_min': 5.284771752269265}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,302] Trial 33 finished with value: 2470.522547308156 and parameters: {'n_total_min': 28, 'depth_percentile_max': 99, 'mean_inset_qual_min': 29, 'mean_del_anchor_qual_min': 30, 'max_slippage_reads': 3, 'asxs_min': 27, 'mean_mapq_min': 37, 'avg_alt_nm_max': 3.814024879438735, 'dist_to_softclip_min': 0, 'variants_250bp_max': 5, 'ref_entropy_min': 1.936560221873062, 'min_dist_to_indel': 219, 'min_rp_med': 0.04141227163997335, 'max_rp_med': 0.9452773969674431, 'max_n_count': 2.2206137188831874, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 46.50219124978062, 'mean_ref_mapq_min': 23.15252826361195, 'avg_nonaltread_variants_max': 2.024968779143297, 'sd_insert_max': 355.85118635520143, 'avg_read_position_min': 1.5049452994383319, 'avg_read_position_max': 145.47302121645978, 'avg_read_length_min': 50.007341267311, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.0784754700615532, 'strand_bias_max': 0.8521454347070441, 'rp_sd_min_alt': 8, 'rp_sd_min': 7.008765656627439}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,319] Trial 34 finished with value: 1695.8676137279149 and parameters: {'n_total_min': 12, 'depth_percentile_max': 97, 'mean_inset_qual_min': 26, 'mean_del_anchor_qual_min': 34, 'max_slippage_reads': 2, 'asxs_min': 31, 'mean_mapq_min': 32, 'avg_alt_nm_max': 4.258238216593807, 'dist_to_softclip_min': 1, 'variants_250bp_max': 10, 'ref_entropy_min': 1.4289174712666708, 'min_dist_to_indel': 354, 'min_rp_med': 0.022412310643155173, 'max_rp_med': 0.9394349397842198, 'max_n_count': 1.6462830138481177, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 38.8930395558547, 'mean_ref_mapq_min': 27.494532205848706, 'avg_nonaltread_variants_max': 2.9846632960227355, 'sd_insert_max': 235.19530225884324, 'avg_read_position_min': 0.715995906081683, 'avg_read_position_max': 141.16703623598946, 'avg_read_length_min': 86.92008136914966, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.14243413161415963, 'strand_bias_max': 0.757643818823972, 'rp_sd_min_alt': 7, 'rp_sd_min': 4.96721006058375}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,337] Trial 35 finished with value: 715.4966500570795 and parameters: {'n_total_min': 15, 'depth_percentile_max': 98, 'mean_inset_qual_min': 42, 'mean_del_anchor_qual_min': 27, 'max_slippage_reads': 4, 'asxs_min': 20, 'mean_mapq_min': 38, 'avg_alt_nm_max': 0.4834911586017441, 'dist_to_softclip_min': 4, 'variants_250bp_max': 6, 'ref_entropy_min': 1.6512401202967624, 'min_dist_to_indel': 281, 'min_rp_med': 0.04752634643961627, 'max_rp_med': 0.9301366108120914, 'max_n_count': 2.789699937268454, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 34.52319970803055, 'mean_ref_mapq_min': 59.63365042110582, 'avg_nonaltread_variants_max': 2.415193164005718, 'sd_insert_max': 529.6715590602589, 'avg_read_position_min': 0.026661290286924853, 'avg_read_position_max': 143.50013283065636, 'avg_read_length_min': 102.0811090823663, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.11227468971221863, 'strand_bias_max': 0.7889601811255431, 'rp_sd_min_alt': 10, 'rp_sd_min': 1.6575726066147993}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,356] Trial 36 finished with value: 2470.522547308156 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 32, 'mean_del_anchor_qual_min': 42, 'max_slippage_reads': 3, 'asxs_min': 27, 'mean_mapq_min': 45, 'avg_alt_nm_max': 4.730069860778814, 'dist_to_softclip_min': 0, 'variants_250bp_max': 8, 'ref_entropy_min': 1.181431144335289, 'min_dist_to_indel': 242, 'min_rp_med': 0.030634075264265846, 'max_rp_med': 0.9204405870068811, 'max_n_count': 1.3086797181797352, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 52.51922438604231, 'mean_ref_mapq_min': 30.223174238818203, 'avg_nonaltread_variants_max': 4.261708854216773, 'sd_insert_max': 424.84797718498993, 'avg_read_position_min': 1.7332459899930641, 'avg_read_position_max': 139.16024698554637, 'avg_read_length_min': 75.94703935636664, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.040245007166973386, 'strand_bias_max': 0.91729132741924, 'rp_sd_min_alt': 6, 'rp_sd_min': 4.005543621986638}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,375] Trial 37 finished with value: 1187.888490337924 and parameters: {'n_total_min': 21, 'depth_percentile_max': 97, 'mean_inset_qual_min': 38, 'mean_del_anchor_qual_min': 38, 'max_slippage_reads': 4, 'asxs_min': 37, 'mean_mapq_min': 33, 'avg_alt_nm_max': 2.2111584446905006, 'dist_to_softclip_min': 4, 'variants_250bp_max': 4, 'ref_entropy_min': 0.24994951250120534, 'min_dist_to_indel': 199, 'min_rp_med': 0.06114788948081711, 'max_rp_med': 0.9351475679218894, 'max_n_count': 1.5930760891915714, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 55.98556588492184, 'mean_ref_mapq_min': 25.017829436540346, 'avg_nonaltread_variants_max': 1.5440078414442362, 'sd_insert_max': 0.7670265959951053, 'avg_read_position_min': 0.5322072546155591, 'avg_read_position_max': 148.78398780357762, 'avg_read_length_min': 97.63842195876188, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.18378087858729222, 'strand_bias_max': 0.9015847998913473, 'rp_sd_min_alt': 9, 'rp_sd_min': 12.317777217443673}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,394] Trial 38 finished with value: 2470.522547308156 and parameters: {'n_total_min': 29, 'depth_percentile_max': 98, 'mean_inset_qual_min': 24, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 1, 'asxs_min': 14, 'mean_mapq_min': 24, 'avg_alt_nm_max': 2.7947430799842525, 'dist_to_softclip_min': 1, 'variants_250bp_max': 12, 'ref_entropy_min': 1.4266627933302418, 'min_dist_to_indel': 143, 'min_rp_med': 0.015964450255037267, 'max_rp_med': 0.9256700366606718, 'max_n_count': 0.4568207596169669, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 43.72225191815259, 'mean_ref_mapq_min': 52.70274774987149, 'avg_nonaltread_variants_max': 0.5722832784028995, 'sd_insert_max': 311.78650435666736, 'avg_read_position_min': 3.3323030237912405, 'avg_read_position_max': 130.16733585334708, 'avg_read_length_min': 118.21021811553665, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.08263563410037818, 'strand_bias_max': 0.8514549624444159, 'rp_sd_min_alt': 8, 'rp_sd_min': 5.732528491030148}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,412] Trial 39 finished with value: 2470.522547308156 and parameters: {'n_total_min': 24, 'depth_percentile_max': 97, 'mean_inset_qual_min': 41, 'mean_del_anchor_qual_min': 28, 'max_slippage_reads': 0, 'asxs_min': 51, 'mean_mapq_min': 41, 'avg_alt_nm_max': 3.2890388312175824, 'dist_to_softclip_min': 2, 'variants_250bp_max': 5, 'ref_entropy_min': 1.955452707138262, 'min_dist_to_indel': 260, 'min_rp_med': 0.05249300131077809, 'max_rp_med': 0.9559308492502013, 'max_n_count': 2.1224738781310566, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 59.88485469345378, 'mean_ref_mapq_min': 22.301611731391883, 'avg_nonaltread_variants_max': 9.554702588767299, 'sd_insert_max': 493.98111155423226, 'avg_read_position_min': 1.2106493796650677, 'avg_read_position_max': 136.90736329421568, 'avg_read_length_min': 124.62507833777093, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.12126127023587184, 'strand_bias_max': 0.9354418678181153, 'rp_sd_min_alt': 7, 'rp_sd_min': 2.949472382092188}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,431] Trial 40 finished with value: 2470.522547308156 and parameters: {'n_total_min': 15, 'depth_percentile_max': 95, 'mean_inset_qual_min': 48, 'mean_del_anchor_qual_min': 44, 'max_slippage_reads': 5, 'asxs_min': 42, 'mean_mapq_min': 47, 'avg_alt_nm_max': 4.3905251447656255, 'dist_to_softclip_min': 0, 'variants_250bp_max': 2, 'ref_entropy_min': 1.0029319430047563, 'min_dist_to_indel': 281, 'min_rp_med': 0.044534243722414414, 'max_rp_med': 0.9332020133102883, 'max_n_count': 0.720235250829744, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 1.7519327267082048, 'mean_ref_mapq_min': 38.45677688417901, 'avg_nonaltread_variants_max': 0.0026197333640030074, 'sd_insert_max': 561.8820548993357, 'avg_read_position_min': 9.717691402518078, 'avg_read_position_max': 146.71624227149505, 'avg_read_length_min': 77.98527564910164, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2570791544250883, 'strand_bias_max': 0.9587721555348666, 'rp_sd_min_alt': 10, 'rp_sd_min': 14.979605465914249}. Best is trial 13 with value: 398.65065886373685.
# [I 2026-04-24 17:40:20,449] Trial 41 finished with value: 718.9283902384344 and parameters: {'n_total_min': 15, 'depth_percentile_max': 98, 'mean_inset_qual_min': 46, 'mean_del_anchor_qual_min': 29, 'max_slippage_reads': 4, 'asxs_min': 18, 'mean_mapq_min': 39, 'avg_alt_nm_max': 0.5641291923252887, 'dist_to_softclip_min': 4, 'variants_250bp_max': 6, 'ref_entropy_min': 1.6630017116587892, 'min_dist_to_indel': 284, 'min_rp_med': 0.04596282857842594, 'max_rp_med': 0.9285321533425022, 'max_n_count': 2.8123314027936246, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 33.79219043146521, 'mean_ref_mapq_min': 55.47006675404384, 'avg_nonaltread_variants_max': 2.4901729106352577, 'sd_insert_max': 551.0476030315067, 'avg_read_position_min': 0.05934632295244112, 'avg_read_position_max': 143.73144456688055, 'avg_read_length_min': 100.84404513537844, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.299830372959796, 'strand_bias_max': 0.7899349988692045, 'rp_sd_min_alt': 10, 'rp_sd_min': 1.5819660269354703}. Best is trial 13 with value: 398.65065886373685.
# ...
# [I 2026-04-24 17:44:41,646] Trial 2986 finished with value: 230.03653546586185 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 37, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 5, 'asxs_min': 30, 'mean_mapq_min': 23, 'avg_alt_nm_max': 3.8942515189925837, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.7006751402016829, 'min_dist_to_indel': 38, 'min_rp_med': 0.010055434119633843, 'max_rp_med': 0.9488689023985546, 'max_n_count': 2.943973503535552, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 11.837286158858138, 'mean_ref_mapq_min': 23.183372268884042, 'avg_nonaltread_variants_max': 6.957372764060803, 'sd_insert_max': 283.42260477079134, 'avg_read_position_min': 0.00424969267033872, 'avg_read_position_max': 132.56707564486686, 'avg_read_length_min': 68.78079229535211, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.0449510147567921, 'strand_bias_max': 0.9842764750549886, 'rp_sd_min_alt': 10, 'rp_sd_min': 11.664955664902298}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:41,805] Trial 2987 finished with value: 567.0035996522606 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 37, 'max_slippage_reads': 5, 'asxs_min': 30, 'mean_mapq_min': 23, 'avg_alt_nm_max': 3.956216139597245, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6225845002343804, 'min_dist_to_indel': 33, 'min_rp_med': 0.010077995179729266, 'max_rp_med': 0.9479578297270215, 'max_n_count': 2.9969198883162917, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 10.554565925159224, 'mean_ref_mapq_min': 21.502548670330654, 'avg_nonaltread_variants_max': 7.252216376726771, 'sd_insert_max': 310.5424014603255, 'avg_read_position_min': 0.3526011721449135, 'avg_read_position_max': 131.84657206618343, 'avg_read_length_min': 66.52138693576553, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.03974272380185696, 'strand_bias_max': 0.9742468756843736, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.070836680766769}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:41,960] Trial 2988 finished with value: 1040.6673575606228 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 37, 'max_slippage_reads': 5, 'asxs_min': 29, 'mean_mapq_min': 23, 'avg_alt_nm_max': 3.910850527245608, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6169702661459986, 'min_dist_to_indel': 40, 'min_rp_med': 0.04741726494753658, 'max_rp_med': 0.9517246187977931, 'max_n_count': 2.996991345684088, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 10.182636736113366, 'mean_ref_mapq_min': 22.836622088669344, 'avg_nonaltread_variants_max': 7.044167491817782, 'sd_insert_max': 275.38868692161503, 'avg_read_position_min': 0.5643421577395339, 'avg_read_position_max': 132.32551734955902, 'avg_read_length_min': 64.84649570002651, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.05910547539103687, 'strand_bias_max': 0.984813513425531, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.251753456701179}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:42,111] Trial 2989 finished with value: 444.47725114831894 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 48, 'max_slippage_reads': 5, 'asxs_min': 31, 'mean_mapq_min': 23, 'avg_alt_nm_max': 4.057332695400198, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.7176054614864535, 'min_dist_to_indel': 29, 'min_rp_med': 0.010009289145536938, 'max_rp_med': 0.9507644053594727, 'max_n_count': 2.999007443656466, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 11.564281978097474, 'mean_ref_mapq_min': 23.74699055867367, 'avg_nonaltread_variants_max': 7.265993995107072, 'sd_insert_max': 292.6186555336945, 'avg_read_position_min': 0.2973442774256081, 'avg_read_position_max': 131.69778679226576, 'avg_read_length_min': 69.59899171874054, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.03942408917010087, 'strand_bias_max': 0.9736305332802698, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.449130826318648}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:42,281] Trial 2990 finished with value: 334.22779769666494 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 5, 'asxs_min': 30, 'mean_mapq_min': 23, 'avg_alt_nm_max': 4.034891856674619, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6689268842865722, 'min_dist_to_indel': 31, 'min_rp_med': 0.011397331271104583, 'max_rp_med': 0.9200634630075049, 'max_n_count': 2.9995246513001543, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 12.69967326210235, 'mean_ref_mapq_min': 22.598945394539985, 'avg_nonaltread_variants_max': 6.942730135698223, 'sd_insert_max': 274.9274640869296, 'avg_read_position_min': 0.18219350664522124, 'avg_read_position_max': 132.4192984260471, 'avg_read_length_min': 66.53021194582269, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.025610375723953, 'strand_bias_max': 0.9784010713307836, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.131196367568604}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:42,463] Trial 2991 finished with value: 247.34262659078556 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 36, 'max_slippage_reads': 5, 'asxs_min': 31, 'mean_mapq_min': 23, 'avg_alt_nm_max': 3.913322452131056, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6540894015817599, 'min_dist_to_indel': 40, 'min_rp_med': 0.010106538649911997, 'max_rp_med': 0.9530233098080076, 'max_n_count': 1.328590506322326, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 9.585601532726283, 'mean_ref_mapq_min': 23.40709387949998, 'avg_nonaltread_variants_max': 7.079103734487822, 'sd_insert_max': 322.1557168527601, 'avg_read_position_min': 0.004916655012824549, 'avg_read_position_max': 132.5887457580712, 'avg_read_length_min': 64.30352530615247, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.048007451696348666, 'strand_bias_max': 0.9874973241319849, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.378744848175597}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:42,617] Trial 2992 finished with value: 228.2804416162151 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 37, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 5, 'asxs_min': 29, 'mean_mapq_min': 23, 'avg_alt_nm_max': 3.8607510390483486, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6841759375437848, 'min_dist_to_indel': 26, 'min_rp_med': 0.011277358094560335, 'max_rp_med': 0.9312324594190868, 'max_n_count': 2.900015802414177, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 9.336950559769909, 'mean_ref_mapq_min': 21.616759901907525, 'avg_nonaltread_variants_max': 7.075606123819651, 'sd_insert_max': 301.876705644087, 'avg_read_position_min': 0.003991015859580331, 'avg_read_position_max': 132.14278078825635, 'avg_read_length_min': 66.32173525006739, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.03703840400156996, 'strand_bias_max': 0.9809414694364371, 'rp_sd_min_alt': 10, 'rp_sd_min': 11.944981099640884}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:42,768] Trial 2993 finished with value: 529.2064785878017 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 37, 'max_slippage_reads': 5, 'asxs_min': 30, 'mean_mapq_min': 23, 'avg_alt_nm_max': 4.038720362915578, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.5863656740227127, 'min_dist_to_indel': 414, 'min_rp_med': 0.01136832249142738, 'max_rp_med': 0.9530003649704756, 'max_n_count': 2.9988836838374997, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 11.232356554321452, 'mean_ref_mapq_min': 23.63413344899993, 'avg_nonaltread_variants_max': 6.877107370277979, 'sd_insert_max': 285.4434064177866, 'avg_read_position_min': 0.32608032455241204, 'avg_read_position_max': 132.7157293770397, 'avg_read_length_min': 63.82226517114475, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.041087951952057236, 'strand_bias_max': 0.9855573079558478, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.87548960991358}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:42,923] Trial 2994 finished with value: 890.115683445862 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 37, 'max_slippage_reads': 5, 'asxs_min': 30, 'mean_mapq_min': 22, 'avg_alt_nm_max': 3.9315441914834612, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.5737682520524472, 'min_dist_to_indel': 22, 'min_rp_med': 0.010059331579790495, 'max_rp_med': 0.9479495183455823, 'max_n_count': 2.9425650790220033, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 9.292925198139368, 'mean_ref_mapq_min': 22.289840271923282, 'avg_nonaltread_variants_max': 6.9364685153967205, 'sd_insert_max': 308.3205041950326, 'avg_read_position_min': 0.5115347916547377, 'avg_read_position_max': 132.18815250820722, 'avg_read_length_min': 68.33809679355063, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.04717143692417593, 'strand_bias_max': 0.9760152389504986, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.65416049388644}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:43,074] Trial 2995 finished with value: 2470.522547308156 and parameters: {'n_total_min': 11, 'depth_percentile_max': 97, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 36, 'max_slippage_reads': 5, 'asxs_min': 29, 'mean_mapq_min': 22, 'avg_alt_nm_max': 3.822256715833358, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6743931492075353, 'min_dist_to_indel': 33, 'min_rp_med': 0.011544082024467578, 'max_rp_med': 0.9511289502104022, 'max_n_count': 2.8886655580342118, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 10.68366857704676, 'mean_ref_mapq_min': 21.155486564508024, 'avg_nonaltread_variants_max': 7.175192147913355, 'sd_insert_max': 271.8524883911146, 'avg_read_position_min': 9.317221022670216, 'avg_read_position_max': 131.6453906367779, 'avg_read_length_min': 66.36021519596282, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.035353685158251005, 'strand_bias_max': 0.9694743445860504, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.381752790809095}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:43,250] Trial 2996 finished with value: 513.091719038646 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 37, 'mean_del_anchor_qual_min': 36, 'max_slippage_reads': 5, 'asxs_min': 31, 'mean_mapq_min': 23, 'avg_alt_nm_max': 4.019416924683329, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6245381408075392, 'min_dist_to_indel': 42, 'min_rp_med': 0.01133393797360074, 'max_rp_med': 0.949477943059617, 'max_n_count': 2.942807780435212, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 9.250329197056205, 'mean_ref_mapq_min': 23.195491421851656, 'avg_nonaltread_variants_max': 6.822489961880322, 'sd_insert_max': 290.31068224515184, 'avg_read_position_min': 0.3334181526524392, 'avg_read_position_max': 132.7556465088371, 'avg_read_length_min': 64.1408206469723, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.036338017705927504, 'strand_bias_max': 0.9857899363730173, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.62052981601034}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:43,402] Trial 2997 finished with value: 331.7030608763069 and parameters: {'n_total_min': 11, 'depth_percentile_max': 97, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 36, 'max_slippage_reads': 5, 'asxs_min': 29, 'mean_mapq_min': 22, 'avg_alt_nm_max': 3.869254572665993, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6591602840679621, 'min_dist_to_indel': 24, 'min_rp_med': 0.011453858864767207, 'max_rp_med': 0.9528049990270576, 'max_n_count': 2.881060420090862, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 9.866420606584084, 'mean_ref_mapq_min': 20.692064901920535, 'avg_nonaltread_variants_max': 6.732536031845307, 'sd_insert_max': 270.34410403603886, 'avg_read_position_min': 0.1944402278753456, 'avg_read_position_max': 132.48758151391857, 'avg_read_length_min': 64.17931583555905, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.044302065624182256, 'strand_bias_max': 0.9779880667567664, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.524963275406483}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:43,560] Trial 2998 finished with value: 309.1502583902871 and parameters: {'n_total_min': 10, 'depth_percentile_max': 97, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 36, 'max_slippage_reads': 5, 'asxs_min': 31, 'mean_mapq_min': 21, 'avg_alt_nm_max': 3.7999872600592424, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.3916675433686826, 'min_dist_to_indel': 20, 'min_rp_med': 0.011147296762147254, 'max_rp_med': 0.951392980881769, 'max_n_count': 2.9415278243389356, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 10.890422686268364, 'mean_ref_mapq_min': 22.27661398708969, 'avg_nonaltread_variants_max': 7.198099872323079, 'sd_insert_max': 332.57810654151893, 'avg_read_position_min': 0.1762185544566395, 'avg_read_position_max': 132.8708578735651, 'avg_read_length_min': 67.79853132648529, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.05213854119396624, 'strand_bias_max': 0.9678729858350397, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.668522650934033}. Best is trial 2940 with value: 218.30943613289656.
# [I 2026-04-24 17:44:43,716] Trial 2999 finished with value: 229.09886786118773 and parameters: {'n_total_min': 11, 'depth_percentile_max': 97, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 37, 'max_slippage_reads': 5, 'asxs_min': 29, 'mean_mapq_min': 23, 'avg_alt_nm_max': 4.081477021586413, 'dist_to_softclip_min': 2, 'variants_250bp_max': 11, 'ref_entropy_min': 0.6308170862082627, 'min_dist_to_indel': 31, 'min_rp_med': 0.012347173484907442, 'max_rp_med': 0.9494525494681123, 'max_n_count': 2.888068207643538, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 8.647635898047291, 'mean_ref_mapq_min': 20.059544300249467, 'avg_nonaltread_variants_max': 7.598453373180337, 'sd_insert_max': 295.71853045545504, 'avg_read_position_min': 0.0005281194253805569, 'avg_read_position_max': 132.0208977354791, 'avg_read_length_min': 71.39809495595729, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.06736706049406199, 'strand_bias_max': 0.9860572911291585, 'rp_sd_min_alt': 10, 'rp_sd_min': 12.849523523561112}. Best is trial 2940 with value: 218.30943613289656.
# [INFO] Best Weighted Deviance: 218.3094
# [INFO] Generating report...
# ------------------------------
# FINAL RESULTS
# ------------------------------
# Total Samples:         18
# Total Observed Indels: 671
# Total Expected Indels: 1068.43
# Weighted Deviance:     236.1001
# Mean Obs/Exp Ratio:    0.6787
# Blacklist Blocked:     0
# CB PON Blocked:        194
# ------------------------------
# INDEL METRICS (Passing Variants)
# ------------------------------
# Insertions: 154 | Deletions: 517
# INS / DEL Ratio:       0.298
# 1bp Indels: 407 | >1bp Indels: 264
# 1bp / >1bp Ratio:      1.542
# ------------------------------

# %%
def run_diagnostic_waterfall(df: pd.DataFrame):
    print("\n" + "="*40)
    print("   DYNAMIC FILTER WATERFALL DIAGNOSTIC")
    print("="*40)
    
    # 1. Define the absolute most relaxed thresholds from your search space
    t = {
        "n_total_min": 15, "depth_percentile_max": 99,
        "mean_inset_qual_min": 20, "mean_del_anchor_qual_min": 20,
        "hp_max_1bp": 6, "hp_max_long": 15, "max_slippage_reads": 5,
        "asxs_min": 10, "mean_mapq_min": 20, "avg_alt_nm_max": 5.0,
        "avg_alt_softclip_max": 5.0, "dist_to_softclip_min": 0,
        "variants_20bp_max": 4, "variants_250bp_max": 15,
        "ref_entropy_min": 0.0, "gc_min": 0.01, "gc_max": 0.99,
        "min_dist_to_indel": 0, "min_rp_med": 0.01, "max_rp_med": 0.99,
        "max_n_count": 3.0, "germline_vaf_max": 0.35,
        
        # New features (most relaxed limits)
        "sd_baseq_max": 50.0,
        "avg_alt_read_mean_baseq_min": 20.0,
        "mean_ref_mapq_min": 20.0,
        "avg_ref_asxs_min": 10.0,
        "avg_altread_variants_max": 5.0,
        "avg_nonaltread_variants_max": 10.0,
        "mean_insert_min": 0.0,
        "mean_insert_max": 1000.0,
        "sd_insert_max": 800.0,
        "avg_read_position_min": 0.0,
        "avg_read_position_max": 150.0,
        "avg_read_length_min": 50.0,
        
        # Conditional
        "strand_bias_n_alt_min": 10, "strand_bias_min": 0.0, "strand_bias_max": 1.0,
        "rp_sd_min_alt": 10, "rp_sd_min": 0.0
    }

    # 2. Define the exact conditions step-by-step
    is_ins = df['INDEL_LENGTH'] > 0
    is_del = df['INDEL_LENGTH'] < 0
    is_1bp = df['INDEL_LENGTH'].abs() == 1
    is_long = df['INDEL_LENGTH'].abs() > 1
    
    enough_reads_sb = df['N_ALT_SSCS'] >= t['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < t['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > t['strand_bias_max'])
    
    enough_reads_rp = df['N_ALT_SSCS'] >= t['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < t['rp_sd_min']

    steps = [
        ("N_TOTAL", df['N_TOTAL'] >= t['n_total_min']),
        ("DEPTH_PERCENTILE", df['DEPTH_PERCENTILE'] <= t['depth_percentile_max']),
        ("MEAN_MAPQ", df['MEAN_MAPQ'] >= t['mean_mapq_min']),
        ("AVG_ASXS", df['AVG_ASXS'] > t['asxs_min']),
        ("INSET/ANCHOR_QUAL", ((is_ins & (df['MEAN_INSET_QUAL'] >= t['mean_inset_qual_min'])) | 
                               (is_del & (df['MEAN_DEL_ANCHOR_QUAL'] >= t['mean_del_anchor_qual_min'])))),
        ("HOMOPOLYMER", ((is_1bp & (df['HOMOPOLYMER_LEN'] <= t['hp_max_1bp'])) | 
                         (is_long & (df['HOMOPOLYMER_LEN'] <= t['hp_max_long'])))),
        ("SLIPPAGE", df['N_SLIPPAGE_SSCS'] <= t['max_slippage_reads']),
        ("VARIANTS_20BP", df['VARIANTS_20BP'] <= t['variants_20bp_max']),
        ("VARIANTS_250BP", df['VARIANTS_250BP'] <= t['variants_250bp_max']),
        ("REF_ENTROPY", df['REF_ENTROPY_40BP'] >= t['ref_entropy_min']),
        ("ALT_SOFTCLIP", df['AVG_ALT_SOFTCLIP'] <= t['avg_alt_softclip_max']),
        ("DIST_SOFTCLIP", df['MEDIAN_DIST_TO_SOFTCLIP'] >= t['dist_to_softclip_min']),
        ("ALT_EXCESS_NM", df['AVG_ALT_EXCESS_NM'] <= t['avg_alt_nm_max']),
        ("GC_CONTENT", (df['GC_CONTENT'] >= t['gc_min']) & (df['GC_CONTENT'] <= t['gc_max'])),
        ("DIST_OTHER_INDEL", df['DIST_TO_OTHER_INDEL'] >= t['min_dist_to_indel']),
        ("RP_MED", (df['RP_MED_SSCS'] >= t['min_rp_med']) & (df['RP_MED_SSCS'] <= t['max_rp_med'])),
        ("ALT_N_COUNT", df['AVG_ALT_N_COUNT'] <= t['max_n_count']),
        ("GERMLINE_VAF", df['VAF_SSCS'] <= t['germline_vaf_max']),
        
        # NEW FEATURES
        ("SD_BASEQ", df['SD_BASEQ'] <= t['sd_baseq_max']),
        ("AVG_ALT_READ_MEAN_BASEQ", df['AVG_ALT_READ_MEAN_BASEQ'] >= t['avg_alt_read_mean_baseq_min']),
        ("MEAN_REF_MAPQ", df['MEAN_REF_MAPQ'] >= t['mean_ref_mapq_min']),
        ("AVG_REF_ASXS", df['AVG_REF_ASXS'] >= t['avg_ref_asxs_min']),
        ("AVG_ALTREAD_VARIANTS", df['AVG_ALTREAD_VARIANTS'] <= t['avg_altread_variants_max']),
        ("AVG_NONALTREAD_VARIANTS", df['AVG_NONALTREAD_VARIANTS'] <= t['avg_nonaltread_variants_max']),
        ("MEAN_INSERT", (df['MEAN_INSERT'] >= t['mean_insert_min']) & (df['MEAN_INSERT'] <= t['mean_insert_max'])),
        ("SD_INSERT", df['SD_INSERT'] <= t['sd_insert_max']),
        ("AVG_READ_POSITION", (df['AVG_READ_POSITION'] >= t['avg_read_position_min']) & (df['AVG_READ_POSITION'] <= t['avg_read_position_max'])),
        ("AVG_READ_LENGTH", df['AVG_READ_LENGTH'] >= t['avg_read_length_min']),
        
        # CONDITIONAL
        ("STRAND_BIAS", ~(enough_reads_sb & bad_bias)),
        ("RP_SD", ~(enough_reads_rp & bad_rp_sd))
    ]

    # 3. Apply sequentially and print drop-off
    current_mask = pd.Series([True] * len(df), index=df.index)
    print(f"{'FILTER STEP':<30} | {'REMAINING':<10} | {'DROPPED HERE':<10}")
    print("-" * 55)
    
    for name, condition in steps:
        prev_count = current_mask.sum()
        current_mask &= condition
        curr_count = current_mask.sum()
        dropped = prev_count - curr_count
        
        print(f"{name:<30} | {curr_count:<10} | {dropped:<10}")
        
        if curr_count == 0:
            print(f"\n[!] TERMINAL DROP: '{name}' killed all remaining variants.")
            break
            
    print("="*40 + "\n")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------
# Configuration
# -----------------------
CSV_PATH = "training_results_indels/observed_expected.csv"
OUTPUT_PNG = "training_results_indels/train_observed_vs_expected_plot.png"

# Check if file exists
if not os.path.exists(CSV_PATH):
    print(f"[ERROR] Could not find {CSV_PATH}. Please run the optimization cell first.")
else:
    # Load table
    df = pd.read_csv(CSV_PATH)

    # -----------------------
    # Data Processing & Aggregation
    # -----------------------
    # Identify cord blood samples
    is_cord = df['sample_type'].str.lower().str.contains('cord')
    
    df_cord = df[is_cord]
    df_other = df[~is_cord]

    # Calculate rates for non-cord samples
    ages = list(df_other["age"].values)
    obs_rates = list(df_other["observed"].values / df_other["bases"].values)
    exp_rates = list(df_other["expected"].values / df_other["bases"].values)

    # Aggregate cord samples if they exist
    if not df_cord.empty:
        total_cord_obs = df_cord["observed"].sum()
        total_cord_exp = df_cord["expected"].sum()
        total_cord_bases = df_cord["bases"].sum()
        
        # Append the aggregated cord blood point
        ages.append(0.0) # Cord blood is age 0
        obs_rates.append(total_cord_obs / total_cord_bases)
        exp_rates.append(total_cord_exp / total_cord_bases)

    # Convert back to numpy arrays for plotting
    ages = np.array(ages)
    obs_rates = np.array(obs_rates)
    exp_rates = np.array(exp_rates)

    # -----------------------
    # Plotting
    # -----------------------
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot Observed (Blue circles)
    ax.scatter(ages, obs_rates, label="Observed", color="#1f77b4", alpha=0.8, marker="o", s=60, edgecolors='k', linewidth=0.5)

    # Plot Expected (Orange crosses)
    ax.scatter(ages, exp_rates, label="Expected", color="#ff7f0e", alpha=0.8, marker="x", s=60, linewidth=2)

    # Styling
    ax.set_xlabel("Age (years)", fontsize=12)
    ax.set_ylabel("Indel rate (Indels per base)", fontsize=12) # Updated to Indel
    
    ax.set_xlim(-2, 100)
    ax.set_ylim(0, 2e-8)
    
    ax.set_title("Observed vs Expected Indel Rate (Training Set)", fontsize=14) # Updated to Indel
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Legend
    ax.legend(loc='upper left', frameon=True, fontsize=10)

    plt.tight_layout()
    
    # Save and Show
    plt.savefig(OUTPUT_PNG, dpi=150)
    print(f"[INFO] Plot saved to: {OUTPUT_PNG}")
    plt.show()
# Out:
# [INFO] Plot saved to: training_results_indels/train_observed_vs_expected_plot.png
