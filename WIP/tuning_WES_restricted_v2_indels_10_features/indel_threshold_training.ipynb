# %%
import csv
import gzip
import json
import os
import sys
import random
import bisect
from typing import Dict, Any, List

import numpy as np
import pandas as pd
import optuna

# -----------------------
# Configuration / Hardcoded Paths
# -----------------------
SAMPLES_CSV = "training_complete_processed_metadata.csv"
OUT_DIR = "training_results_indels"
BLACKLIST_BED = "../../resources/master_blacklist.bed" 
ARTEFACT_GENES_BED = "../../resources/master_blacklist.bed"
EXOME_BED_PATH = "../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed" # NEW

N_TRIALS = 3000
SEED = 42
# -----------------------
# Constants
# -----------------------
GENOME_SIZE = 6.4e9
R_CORD = 2e-9
EPS = 1e-15
CORD_WEIGHT = 5.0

# Set seeds
random.seed(SEED)
np.random.seed(SEED)

# -----------------------
# Math Helpers
# -----------------------
def poisson_deviance(y_arr: np.ndarray, lam_arr: np.ndarray, weights: np.ndarray = None) -> float:
    y = np.asarray(y_arr, dtype=float)
    lam = np.asarray(lam_arr, dtype=float) + EPS
    
    with np.errstate(divide='ignore', invalid='ignore'):
        log_term = np.log(y / lam)
        term1 = np.where(y > 0, y * log_term, 0.0)
    
    dev = 2.0 * (term1 - (y - lam))
    if weights is not None:
        dev = dev * weights
        
    return float(np.sum(dev))

def expected_lambda(sample_type: str, age: float, bases: float) -> float:
    st = str(sample_type).lower()
    current_age = float(age) if pd.notna(age) else 0.0
    
    if "cord" in st:
        rate = R_CORD
    elif "pbmc" in st:
        rate = R_CORD + (0.7 * current_age) / GENOME_SIZE
    elif "t_cell" in st or "tcell" in st or "t-cell" in st:
        rate = (14.5 / GENOME_SIZE) + (1.0 * current_age) / GENOME_SIZE
    else:
        # Fallback to the original baseline if an unknown type appears
        rate = R_CORD + (2.0 * current_age) / GENOME_SIZE
        
    return rate * bases

# -----------------------
# BED File Lookup Logic
# -----------------------
class BedLookup:
    def __init__(self, bed_path: str, name: str):
        self.intervals = {} 
        self.name = name
        self._load_bed(bed_path)

    def _load_bed(self, bed_path: str):
        if not os.path.exists(bed_path):
            print(f"[WARN] BED file not found: {bed_path}. {self.name} filter will do nothing.", file=sys.stderr)
            return

        print(f"[INFO] Loading {self.name} from {bed_path}...")
        count = 0
        with open(bed_path, 'r') as f:
            for line in f:
                if line.startswith('#') or not line.strip():
                    continue
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                chrom, start, end = parts[0], int(parts[1]), int(parts[2])
                
                if chrom not in self.intervals:
                    self.intervals[chrom] = []
                self.intervals[chrom].append((start, end))
                count += 1
        
        for chrom in self.intervals:
            self.intervals[chrom].sort(key=lambda x: x[0])
        print(f"[INFO] Loaded {count} regions for {self.name}.")

    def is_overlapped(self, chrom: str, pos: int) -> bool:
        if chrom not in self.intervals:
            return False
        
        regions = self.intervals[chrom]
        query_idx = pos - 1 
        idx = bisect.bisect_right(regions, (query_idx, float('inf')))
        
        for i in range(max(0, idx - 1), -1, -1):
            start, end = regions[i]
            if end <= query_idx:
                break 
            if start <= query_idx < end:
                return True
        return False

# -----------------------
# VCF Parsing to DataFrame
# -----------------------
def parse_vcf_to_df(vcf_path: str, sample_id: str) -> pd.DataFrame:
    data = []
    if not os.path.exists(vcf_path):
        print(f"[WARN] File not found: {vcf_path}", file=sys.stderr)
        return pd.DataFrame()

    openf = gzip.open if vcf_path.endswith(".gz") else open
    try:
        with openf(vcf_path, "rt") as fh:
            for line in fh:
                if line.startswith("#"):
                    continue
                fields = line.strip().split("\t")
                chrom, pos = fields[0], int(fields[1])
                alt = fields[4] # NEW: Extract the ALT sequence
                info_str = fields[7]
                info_dict = {k: v for item in info_str.split(";") for k, v in [item.split("=", 1) if "=" in item else (item, "Yes")]}
                
                # NEW: Added ALT to the dictionary
                info_dict.update({"sample_id": sample_id, "CHROM": chrom, "POS": pos, "ALT": alt})
                data.append(info_dict)
    except Exception as e:
        print(f"[ERROR] Error reading {vcf_path}: {e}", file=sys.stderr)
        return pd.DataFrame()

    if not data:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    
    def to_num(col, dtype, default):
        return pd.to_numeric(df[col], errors='coerce').fillna(default).astype(dtype) if col in df.columns else pd.Series([default]*len(df), dtype=dtype)

    def to_str(col, default):
        return df[col].fillna(default) if col in df.columns else pd.Series([default]*len(df))

    df['CHROM'] = to_str('CHROM', 'chr1')
    df['ALT'] = to_str('ALT', '') # NEW: String column for ALT
    df['POS'] = to_num('POS', int, 0)
    df['INDEL_LENGTH'] = to_num('INDEL_LENGTH', int, 0)
    df['MEAN_INSET_QUAL'] = to_num('MEAN_INSET_QUAL', float, -1.0)
    df['MEAN_DEL_ANCHOR_QUAL'] = to_num('MEAN_DEL_ANCHOR_QUAL', float, -1.0)
    df['HOMOPOLYMER_LEN'] = to_num('HOMOPOLYMER_LEN', int, 0)
    df['N_SLIPPAGE_SSCS'] = to_num('N_SLIPPAGE_SSCS', int, 0)
    df['GC_CONTENT'] = to_num('GC_CONTENT', float, 0.5) 
    df['DIST_TO_OTHER_INDEL'] = to_num('DIST_TO_OTHER_INDEL', int, 10000)
    df['RP_MED_SSCS'] = to_num('RP_MED_SSCS', float, 75.0)
    df['SD_BASEQ'] = to_num('SD_BASEQ', float, 1000) #NEW 1
    df['AVG_ALT_READ_MEAN_BASEQ'] = to_num('AVG_ALT_READ_MEAN_BQ', float, 0) # NEW 2
    df['MEAN_REF_MAPQ'] = to_num('MEAN_REF_MAPQ', float, 0.0) # NEW 3
    df['AVG_REF_ASXS'] = to_num('AVG_REF_ASXS', float, 0.0) # NEW 4
    df['AVG_ALTREAD_VARIANTS'] = to_num('AVG_ALTREAD_VARIANTS', float, 1000) # NEW 5
    df['AVG_NONALTREAD_VARIANTS'] = to_num('AVG_NONALTREAD_VARIANTS', float, 1000) # NEW 6
    df['MEAN_INSERT'] = to_num('MEAN_INSERT', float, 1000) # NEW 7
    df['SD_INSERT'] = to_num('SD_INSERT', float, 1000) # NEW 8
    df['AVG_READ_POSITION'] = to_num('AVG_READ_POSITION', float, 75) # NEW 9
    df['AVG_READ_LENGTH'] = to_num('AVG_READ_LENGTH', float, 150) # NEW 10
    df['RP_SD_SSCS'] = to_num('RP_SD_SSCS', float, 0) # Not sure if to use this metric...
    df['STRAND_BIAS_SSCS'] = to_num('STRAND_BIAS_SSCS', float, 1) # Will use this and RP_SD above but conditional to a minimum N_ALT_SSCS, just as for the SNV caller
    df['AVG_ALT_N_COUNT'] = to_num('AVG_ALT_N_COUNT', float, 0.0)
    df['N_ALT_SSCS'] = to_num('N_ALT_SSCS', int, 0)
    df['N_TOTAL'] = to_num('N_TOTAL', int, 0)
    df['N_ALT'] = to_num('N_ALT', int, 0) 
    df['N_TOTAL_SSCS'] = to_num('N_TOTAL_SSCS', int, -1)
    df['DEPTH_PERCENTILE'] = to_num('DEPTH_PERCENTILE', int, 50)
    df['VARIANTS_20BP'] = to_num('VARIANTS_20BP', int, 0)
    df['VARIANTS_250BP'] = to_num('VARIANTS_250BP', int, 0)
    df['MEDIAN_DIST_TO_SOFTCLIP'] = to_num('MEDIAN_DIST_TO_SOFTCLIP', int, 1000)
    df['AVG_ASXS'] = to_num('AVG_ALT_ASXS', float, 0.0) 
    df['MEAN_MAPQ'] = to_num('MEAN_ALT_MAPQ', float, 0.0) 
    df['AVG_ALT_EXCESS_NM'] = to_num('AVG_ALT_EXCESS_NM', float, 0.0)
    df['AVG_ALT_SOFTCLIP'] = to_num('AVG_ALT_SOFTCLIP', float, 0.0)
    df['REF_ENTROPY_40BP'] = to_num('REF_ENTROPY_40BP', float, 2.0)
    df['IN_BLACKLIST'] = to_str('IN_BLACKLIST', "NO")
    df['IN_GNOMAD_COMMON'] = to_str('IN_GNOMAD_COMMON', "No")
    df['IN_CB_PON'] = to_str('IN_CB_PON', "No")

    with np.errstate(divide='ignore', invalid='ignore'):
        df['VAF_SSCS'] = (df['N_ALT_SSCS'] / df['N_TOTAL_SSCS']).fillna(0.0)

    return df

# -----------------------
# Aggregation & Filtering Logic
# -----------------------
def aggregate_samples(samples_meta: List[Dict]) -> List[Dict]:
    """Groups all cord blood samples to combat Poisson noise."""
    agg_meta, cord_ids = [], []
    cord_exp, cord_bases = 0.0, 0.0
    
    for s in samples_meta:
        lam = expected_lambda(s['sample_type'], s['age'], s['bases'])
        if "cord" in s['sample_type'].lower():
            cord_ids.append(s['sample_id'])
            cord_exp += lam
            cord_bases += s['bases']
        else:
            agg_meta.append({
                'sample_ids': [s['sample_id']],
                'sample_type': s['sample_type'],
                'age': s['age'],
                'bases': s['bases'],
                'expected_lambda': lam,
                'is_cord': False
            })
            
    if cord_ids:
        agg_meta.append({
            'sample_ids': cord_ids, 
            'sample_type': 'cord_aggregate',
            'age': 0.0, 
            'bases': cord_bases,
            'expected_lambda': cord_exp,
            'is_cord': True
        })
    return agg_meta

def get_static_mask(df: pd.DataFrame, pon_flags: Dict[str, bool], ignore_blacklists: bool = False, ignore_cb_pon: bool = False) -> pd.Series:
    """Filters evaluated ONCE before Optuna runs to save immense computation time."""
    mask = (df['N_TOTAL_SSCS'] > 0) & (df['N_ALT_SSCS'] > 1)
    
    # Filter out insertions that contain 'N' in the inserted sequence
    has_n_in_insertion = (df['INDEL_LENGTH'] > 0) & (df['ALT'].str.contains('N', case=False, na=False))
    mask &= (~has_n_in_insertion)
    
    if pon_flags.get("use_cord_pon", False):
        mask &= (df['IN_BLACKLIST'] != "YES")

    # NEW: Hard filter for IN_CB_PON
    if not ignore_cb_pon:
        mask &= (df['IN_CB_PON'] != "Yes")

    if not ignore_blacklists:
        mask &= (~df['IN_CLUSTER_BLACKLIST']) & (~df['IN_ARTEFACT_BLACKLIST'])
        
    return mask

# -----------------------
# Aggregation & Filtering Logic
# -----------------------
def get_dynamic_mask(df: pd.DataFrame, thresholds: Dict[str, Any]) -> pd.Series:
    """Filters evaluated during every Optuna trial."""
    mask = (df['N_TOTAL'] >= thresholds['n_total_min'])
    mask &= (df['DEPTH_PERCENTILE'] <= thresholds['depth_percentile_max'])



    is_ins = df['INDEL_LENGTH'] > 0
    is_del = df['INDEL_LENGTH'] < 0
    mask &=   (is_del & (df['MEAN_DEL_ANCHOR_QUAL'] >= thresholds['mean_del_anchor_qual_min']))


    
    mask &= (df['N_SLIPPAGE_SSCS'] <= thresholds['max_slippage_reads'])





    mask &= (df['AVG_ALT_EXCESS_NM'] <= thresholds['avg_alt_nm_max'])

    mask &= (df['DIST_TO_OTHER_INDEL'] >= thresholds['min_dist_to_indel'])
    mask &= (df['RP_MED_SSCS'] >= thresholds['min_rp_med']) & (df['RP_MED_SSCS'] <= thresholds['max_rp_med'])

    mask &= (df['VAF_SSCS'] <= thresholds['germline_vaf_max'])

    # --- NEW FEATURES ---

    mask &= (df['AVG_ALT_READ_MEAN_BASEQ'] >= thresholds['avg_alt_read_mean_baseq_min'])
    mask &= (df['MEAN_REF_MAPQ'] >= thresholds['mean_ref_mapq_min'])


    mask &= (df['AVG_NONALTREAD_VARIANTS'] <= thresholds['avg_nonaltread_variants_max'])

    mask &= (df['SD_INSERT'] <= thresholds['sd_insert_max'])

    mask &= (df['AVG_READ_LENGTH'] >= thresholds['avg_read_length_min'])



    # RP SD (Conditional)
    enough_reads_rp = df['N_ALT_SSCS'] >= thresholds['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < thresholds['rp_sd_min']
    mask &= ~(enough_reads_rp & bad_rp_sd)
    
    return mask

# -----------------------
# Optimization Objective
# -----------------------
def make_objective(filtered_df: pd.DataFrame, agg_meta: List[Dict]):
    exp_arr = np.array([m['expected_lambda'] for m in agg_meta])
    weights_arr = np.array([CORD_WEIGHT if m['is_cord'] else 1.0 for m in agg_meta])

    def objective(trial):
        thresholds = {
            "n_total_min": trial.suggest_int("n_total_min", 10, 30),
            "depth_percentile_max": trial.suggest_int("depth_percentile_max", 95, 99),
            "mean_inset_qual_min": trial.suggest_int("mean_inset_qual_min", 20, 50),
            "mean_del_anchor_qual_min": trial.suggest_int("mean_del_anchor_qual_min", 20, 50),

            "max_slippage_reads": trial.suggest_int("max_slippage_reads", 0, 5),
            "asxs_min": trial.suggest_int("asxs_min", 10, 60),
            "mean_mapq_min": trial.suggest_int("mean_mapq_min", 20, 50),
            "avg_alt_nm_max": trial.suggest_float("avg_alt_nm_max", 0.0, 5.0),

            "dist_to_softclip_min": trial.suggest_int("dist_to_softclip_min", 0, 5),

            "variants_250bp_max": trial.suggest_int("variants_250bp_max", 0, 15),
            "ref_entropy_min": trial.suggest_float("ref_entropy_min", 0.0, 2.1),

            "min_dist_to_indel": trial.suggest_int("min_dist_to_indel", 0, 500),
            "min_rp_med": trial.suggest_float("min_rp_med", 0.01, 0.08),
            "max_rp_med": trial.suggest_float("max_rp_med", 0.92, 0.99),
            "max_n_count": trial.suggest_float("max_n_count", 0.0, 3.0),
            "germline_vaf_max": trial.suggest_float("germline_vaf_max", 0.2, 0.2),
            
            # --- NEW FEATURES ---
            

            "avg_alt_read_mean_baseq_min": trial.suggest_float("avg_alt_read_mean_baseq_min", 00.0, 60.0),
            "mean_ref_mapq_min": trial.suggest_float("mean_ref_mapq_min", 20.0, 60.0),


            "avg_nonaltread_variants_max": trial.suggest_float("avg_nonaltread_variants_max", 0.0, 10.0),

            "sd_insert_max": trial.suggest_float("sd_insert_max", 00.0, 800.0),
            "avg_read_position_min": trial.suggest_float("avg_read_position_min", 0.0, 10.0),
            "avg_read_position_max": trial.suggest_float("avg_read_position_max", 130.0, 150.0), 
            "avg_read_length_min": trial.suggest_float("avg_read_length_min", 50.0, 150.0),
            
            # --- CONDITIONAL FEATURES ---
            "strand_bias_n_alt_min": trial.suggest_int("strand_bias_n_alt_min", 3, 10),
            "strand_bias_min": trial.suggest_float("strand_bias_min", 0.0, 0.3),
            "strand_bias_max": trial.suggest_float("strand_bias_max", 0.7, 1.0),
            "rp_sd_min_alt": trial.suggest_int("rp_sd_min_alt", 3, 10),
            "rp_sd_min": trial.suggest_float("rp_sd_min", 0.0, 15.0),
        }

        dyn_mask = get_dynamic_mask(filtered_df, thresholds)
        obs_counts = filtered_df[dyn_mask]['sample_id'].value_counts()
        
        obs_arr = [sum(obs_counts.get(sid, 0) for sid in m['sample_ids']) for m in agg_meta]
        return poisson_deviance(np.array(obs_arr), exp_arr, weights=weights_arr)
    
    return objective

# -----------------------
# Reporting
# -----------------------
def evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, outdir):
    os.makedirs(outdir, exist_ok=True)
    
    # NEW: Added ignore_cb_pon flags to isolate the counts
    static_mask_final = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False, ignore_cb_pon=False)
    static_mask_clean = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=True, ignore_cb_pon=False)
    static_mask_no_cb_pon = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False, ignore_cb_pon=True)
    
    dyn_mask = get_dynamic_mask(all_variants_df, best_thresholds)
    
    pass_mask_final = static_mask_final & dyn_mask
    pass_mask_clean = static_mask_clean & dyn_mask
    pass_mask_no_cb_pon = static_mask_no_cb_pon & dyn_mask # NEW
    
    count_saved_by_blacklist = (pass_mask_clean & (~pass_mask_final)).sum()
    count_saved_by_cb_pon = (pass_mask_no_cb_pon & (~pass_mask_final)).sum() # NEW
    
    obs_series = all_variants_df[pass_mask_final].groupby('sample_id').size()
    
    observed, expected, ids, ages, bases, types, weights = [], [], [], [], [], [], []

    for s in samples_meta:
        sid = s['sample_id']
        ids.append(sid)
        observed.append(obs_series.get(sid, 0))
        expected.append(expected_lambda(s['sample_type'], s['age'], s['bases']))
        ages.append(s['age'])
        bases.append(s['bases'])
        types.append(s['sample_type'])
        weights.append(CORD_WEIGHT if "cord" in s['sample_type'].lower() else 1.0)

    obs_arr, exp_arr, weights_arr = np.array(observed), np.array(expected), np.array(weights)

    with open(os.path.join(outdir, "best_thresholds.json"), "w") as fh:
        json.dump({"thresholds": best_thresholds, "pon_flags": pon_flags, "blacklists_enforced": True, "cord_penalty_weight": CORD_WEIGHT}, fh, indent=2)

    dev = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
    mean_ratio = float(np.mean(obs_arr / (exp_arr + EPS)))
    
    with open(os.path.join(outdir, "summary.json"), "w") as fh:
        json.dump({
            "n_samples": len(samples_meta),
            "obs_mean_over_expected": mean_ratio,
            "total_observed": int(np.sum(obs_arr)),
            "total_expected": float(np.sum(exp_arr)),
            "weighted_poisson_deviance": dev,
            "variants_blocked_by_blacklists": int(count_saved_by_blacklist),
            "variants_blocked_by_cb_pon": int(count_saved_by_cb_pon) # NEW
        }, fh, indent=2)

    pd.DataFrame({
        "sample_id": ids, "sample_type": types, "age": ages, "bases": bases,
        "observed": observed, "expected": expected, "weight_used": weights 
    }).to_csv(os.path.join(outdir, "observed_expected.csv"), index=False)
    
    final_pass_df = all_variants_df[pass_mask_final]
    n_ins = (final_pass_df['INDEL_LENGTH'] > 0).sum()
    n_del = (final_pass_df['INDEL_LENGTH'] < 0).sum()
    n_1bp = (final_pass_df['INDEL_LENGTH'].abs() == 1).sum()
    n_long = (final_pass_df['INDEL_LENGTH'].abs() > 1).sum()
    
    ins_del_ratio = n_ins / n_del if n_del > 0 else 0.0
    bp1_long_ratio = n_1bp / n_long if n_long > 0 else 0.0

    print("-" * 30)
    print("FINAL RESULTS")
    print("-" * 30)
    print(f"Total Samples:         {len(samples_meta)}")
    print(f"Total Observed Indels: {int(np.sum(obs_arr))}")
    print(f"Total Expected Indels: {float(np.sum(exp_arr)):.2f}")
    print(f"Weighted Deviance:     {dev:.4f}")
    print(f"Mean Obs/Exp Ratio:    {mean_ratio:.4f}")
    print(f"Blacklist Blocked:     {count_saved_by_blacklist}")
    print(f"CB PON Blocked:        {count_saved_by_cb_pon}") # NEW
    print("-" * 30)
    print("INDEL METRICS (Passing Variants)")
    print("-" * 30)
    print(f"Insertions: {n_ins} | Deletions: {n_del}")
    print(f"INS / DEL Ratio:       {ins_del_ratio:.3f}")
    print(f"1bp Indels: {n_1bp} | >1bp Indels: {n_long}")
    print(f"1bp / >1bp Ratio:      {bp1_long_ratio:.3f}")
    print("-" * 30)

    
# -----------------------
# Execution Block
# -----------------------
if __name__ == "__main__":
    print(f"[INFO] Reading metadata from {SAMPLES_CSV}...")
    samples_meta = []
    with open(SAMPLES_CSV, newline='') as csvfile:
        for r in csv.DictReader(csvfile):
            samples_meta.append({
                "sample_id": r["sample_id"],
                "vcf_path": r["vcf_path"],
                "sample_type": r["sample_type"].lower(),
                "age": float(r["age"]) if r.get("age") else None,
                "bases": float(r["total_callable_bases_in_wes"]),
            })
    print(f"[INFO] Loaded {len(samples_meta)} samples.")

    print("[INFO] Loading VCFs into DataFrame...")
    df_list = [parse_vcf_to_df(s["vcf_path"], s["sample_id"]) for s in samples_meta]
    all_variants_df = pd.concat(df_list, ignore_index=True) if df_list else pd.DataFrame()
    
    print(f"[INFO] Total variants loaded: {len(all_variants_df)}")

    if not all_variants_df.empty:
        chroms = all_variants_df['CHROM'].values
        poses = all_variants_df['POS'].values

        # ---------------------------------------------------------
        # NEW: Filter by WES BED immediately to save computation
        # ---------------------------------------------------------
        bed_lookup_exome = BedLookup(EXOME_BED_PATH, "Exome Targets")
        in_exome_mask = [bed_lookup_exome.is_overlapped(c, p) for c, p in zip(chroms, poses)]
        all_variants_df = all_variants_df[in_exome_mask].reset_index(drop=True)
        print(f"[INFO] Variants remaining after WES target restriction: {len(all_variants_df)}")

        # Proceed only if we still have variants left
        if not all_variants_df.empty:
            # Re-extract chroms and poses for the remaining on-target variants
            chroms = all_variants_df['CHROM'].values
            poses = all_variants_df['POS'].values

            bed_lookup_cluster = BedLookup(BLACKLIST_BED, "Cluster Blacklist")
            all_variants_df['IN_CLUSTER_BLACKLIST'] = [bed_lookup_cluster.is_overlapped(c, p) for c, p in zip(chroms, poses)]
            
            bed_lookup_genes = BedLookup(ARTEFACT_GENES_BED, "Artefact Gene Blacklist")
            all_variants_df['IN_ARTEFACT_BLACKLIST'] = [bed_lookup_genes.is_overlapped(c, p) for c, p in zip(chroms, poses)]
            
            hits_cluster = sum(all_variants_df['IN_CLUSTER_BLACKLIST'])
            print(f"[INFO] Found {hits_cluster} variants in Cluster blacklist.")

            # Aggregate cords for robust optimization
            agg_meta = aggregate_samples(samples_meta)
            
            # Pre-filter static masks to massively speed up Optuna
            pon_flags = {"use_cord_pon": True}
            static_mask = get_static_mask(all_variants_df, pon_flags, ignore_blacklists=False)
            static_filtered_df = all_variants_df[static_mask].copy()

            run_diagnostic_waterfall(static_filtered_df)
            # ---------------------------

            print(f"[INFO] Starting Optuna (Trials={N_TRIALS}). Evaluating {len(static_filtered_df)} valid candidates per trial...")

            print(f"[INFO] Starting Optuna (Trials={N_TRIALS}). Evaluating {len(static_filtered_df)} valid candidates per trial...")
            study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=SEED))
            
            objective = make_objective(static_filtered_df, agg_meta)
            study.optimize(objective, n_trials=N_TRIALS)

            print(f"[INFO] Best Weighted Deviance: {study.best_value:.4f}")

            print("[INFO] Generating report...")
            evaluate_and_report(study.best_params, pon_flags, all_variants_df, samples_meta, OUT_DIR)
        else:
            print("[WARN] No variants remained after Exome BED filtering.")
# Out:
# [INFO] Reading metadata from training_complete_processed_metadata.csv...
# [INFO] Loaded 18 samples.
# [INFO] Loading VCFs into DataFrame...
# [INFO] Total variants loaded: 19992
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Variants remaining after WES target restriction: 19312
# [INFO] Loading Cluster Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Cluster Blacklist.
# [INFO] Loading Artefact Gene Blacklist from ../../resources/master_blacklist.bed...
# [I 2026-04-24 17:46:08,343] A new study created in memory with name: no-name-e8fc63fe-9859-4ff5-b30f-dfd69adc23a7
# [I 2026-04-24 17:46:08,346] Trial 0 finished with value: 554.8994579237258 and parameters: {'n_total_min': 17, 'depth_percentile_max': 99, 'mean_inset_qual_min': 42, 'mean_del_anchor_qual_min': 38, 'max_slippage_reads': 0, 'asxs_min': 17, 'mean_mapq_min': 21, 'avg_alt_nm_max': 4.330880728874676, 'dist_to_softclip_min': 3, 'variants_250bp_max': 11, 'ref_entropy_min': 0.04322743802118514, 'min_dist_to_indel': 485, 'min_rp_med': 0.06827098485602953, 'max_rp_med': 0.9348637377474793, 'max_n_count': 0.5454749016213019, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 11.00427059120603, 'mean_ref_mapq_min': 32.169689718381505, 'avg_nonaltread_variants_max': 5.247564316322379, 'sd_insert_max': 345.5560149136926, 'avg_read_position_min': 2.9122914019804194, 'avg_read_position_max': 142.2370578944476, 'avg_read_length_min': 63.94938606520418, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.1099085529881075, 'strand_bias_max': 0.8368209952651108, 'rp_sd_min_alt': 9, 'rp_sd_min': 2.995106732375396}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,348] Trial 1 finished with value: 639.2336147286314 and parameters: {'n_total_min': 20, 'depth_percentile_max': 97, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 38, 'max_slippage_reads': 1, 'asxs_min': 13, 'mean_mapq_min': 49, 'avg_alt_nm_max': 4.828160165372797, 'dist_to_softclip_min': 4, 'variants_250bp_max': 4, 'ref_entropy_min': 0.20511143941340615, 'min_dist_to_indel': 342, 'min_rp_med': 0.04081067456177209, 'max_rp_med': 0.9285426764391346, 'max_n_count': 1.4855307303338106, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 2.0633112669131037, 'mean_ref_mapq_min': 56.372816083151285, 'avg_nonaltread_variants_max': 2.587799816000169, 'sd_insert_max': 530.0178274831856, 'avg_read_position_min': 3.1171107608941098, 'avg_read_position_max': 140.4013604235562, 'avg_read_length_min': 104.67102793432797, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.29087538832936755, 'strand_bias_max': 0.9325398470083344, 'rp_sd_min_alt': 10, 'rp_sd_min': 13.422410256414732}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,351] Trial 2 finished with value: 1062.8168809032068 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 26, 'max_slippage_reads': 0, 'asxs_min': 26, 'mean_mapq_min': 32, 'avg_alt_nm_max': 1.3567451588694794, 'dist_to_softclip_min': 4, 'variants_250bp_max': 5, 'ref_entropy_min': 0.5899624703434996, 'min_dist_to_indel': 271, 'min_rp_med': 0.019864695748233387, 'max_rp_med': 0.9761537886527828, 'max_n_count': 0.22365193103931247, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 59.21321619603104, 'mean_ref_mapq_min': 50.889790771866295, 'avg_nonaltread_variants_max': 1.987156815341724, 'sd_insert_max': 4.417693698881919, 'avg_read_position_min': 8.154614284548341, 'avg_read_position_max': 144.13714687695233, 'avg_read_length_min': 122.90071680409874, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.02221339552022711, 'strand_bias_max': 0.8075397185632818, 'rp_sd_min_alt': 3, 'rp_sd_min': 12.946551388133903}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,353] Trial 3 finished with value: 1686.5902256284173 and parameters: {'n_total_min': 23, 'depth_percentile_max': 96, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 29, 'max_slippage_reads': 1, 'asxs_min': 47, 'mean_mapq_min': 39, 'avg_alt_nm_max': 4.436063712881633, 'dist_to_softclip_min': 2, 'variants_250bp_max': 1, 'ref_entropy_min': 1.4978140531682895, 'min_dist_to_indel': 381, 'min_rp_med': 0.04928940382986474, 'max_rp_med': 0.9739677025968193, 'max_n_count': 1.4813867890931722, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 31.363969762919645, 'mean_ref_mapq_min': 37.101640734341984, 'avg_nonaltread_variants_max': 0.2541912674409519, 'sd_insert_max': 86.31314159464355, 'avg_read_position_min': 0.3142918568673425, 'avg_read_position_max': 142.7282082252756, 'avg_read_length_min': 81.43559810763267, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.2722699421778279, 'strand_bias_max': 0.7747876687446624, 'rp_sd_min_alt': 6, 'rp_sd_min': 11.333267078145731}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,357] Trial 4 finished with value: 616.2476964831005 and parameters: {'n_total_min': 14, 'depth_percentile_max': 95, 'mean_inset_qual_min': 28, 'mean_del_anchor_qual_min': 24, 'max_slippage_reads': 5, 'asxs_min': 51, 'mean_mapq_min': 39, 'avg_alt_nm_max': 4.357302950938589, 'dist_to_softclip_min': 4, 'variants_250bp_max': 2, 'ref_entropy_min': 1.8743738968289534, 'min_dist_to_indel': 270, 'min_rp_med': 0.06652081086148438, 'max_rp_med': 0.9827263909946445, 'max_n_count': 0.9540104249155916, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 6.6031154716606055, 'mean_ref_mapq_min': 29.117406501677667, 'avg_nonaltread_variants_max': 4.271077886262563, 'sd_insert_max': 654.4118127379945, 'avg_read_position_min': 8.607305832563434, 'avg_read_position_max': 130.13904261062382, 'avg_read_length_min': 101.07473025775657, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.06663234314121907, 'strand_bias_max': 0.7359596102001048, 'rp_sd_min_alt': 5, 'rp_sd_min': 14.143645558687787}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,360] Trial 5 finished with value: 796.149033979084 and parameters: {'n_total_min': 16, 'depth_percentile_max': 97, 'mean_inset_qual_min': 41, 'mean_del_anchor_qual_min': 31, 'max_slippage_reads': 5, 'asxs_min': 59, 'mean_mapq_min': 27, 'avg_alt_nm_max': 2.4862425294619275, 'dist_to_softclip_min': 1, 'variants_250bp_max': 4, 'ref_entropy_min': 0.07746258944451888, 'min_dist_to_indel': 305, 'min_rp_med': 0.04518753162602031, 'max_rp_med': 0.9236035125874993, 'max_n_count': 0.8359393927098343, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 54.495953157999224, 'mean_ref_mapq_min': 29.582475626678896, 'avg_nonaltread_variants_max': 1.448948720912231, 'sd_insert_max': 391.5622082220504, 'avg_read_position_min': 9.856504541106007, 'avg_read_position_max': 134.84110543023002, 'avg_read_length_min': 117.21355474058785, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.0712912631977199, 'strand_bias_max': 0.9184649045835579, 'rp_sd_min_alt': 5, 'rp_sd_min': 9.484587458903691}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,363] Trial 6 finished with value: 1029.4234638413118 and parameters: {'n_total_min': 23, 'depth_percentile_max': 97, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 45, 'max_slippage_reads': 1, 'asxs_min': 19, 'mean_mapq_min': 21, 'avg_alt_nm_max': 2.954464715941209, 'dist_to_softclip_min': 4, 'variants_250bp_max': 0, 'ref_entropy_min': 1.07539542242849, 'min_dist_to_indel': 113, 'min_rp_med': 0.055162095328661495, 'max_rp_med': 0.9322056500303494, 'max_n_count': 2.0728132143073976, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 23.204120778032244, 'mean_ref_mapq_min': 57.46919954946938, 'avg_nonaltread_variants_max': 1.3752094414599325, 'sd_insert_max': 272.8530808402068, 'avg_read_position_min': 1.1347352124058907, 'avg_read_position_max': 148.49387236557126, 'avg_read_length_min': 137.7339353380981, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.1979952138102537, 'strand_bias_max': 0.9451666600603648, 'rp_sd_min_alt': 7, 'rp_sd_min': 7.944758675340097}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,366] Trial 7 finished with value: 719.9287271175889 and parameters: {'n_total_min': 15, 'depth_percentile_max': 95, 'mean_inset_qual_min': 47, 'mean_del_anchor_qual_min': 47, 'max_slippage_reads': 3, 'asxs_min': 27, 'mean_mapq_min': 30, 'avg_alt_nm_max': 3.629778394351197, 'dist_to_softclip_min': 5, 'variants_250bp_max': 14, 'ref_entropy_min': 1.6377386463010102, 'min_dist_to_indel': 321, 'min_rp_med': 0.01588979754965342, 'max_rp_med': 0.931314009986623, 'max_n_count': 2.695662565581238, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 36.3857435795754, 'mean_ref_mapq_min': 20.367882064665185, 'avg_nonaltread_variants_max': 1.014715428660321, 'sd_insert_max': 530.8014152864447, 'avg_read_position_min': 0.05061583846218687, 'avg_read_position_max': 133.21616102834997, 'avg_read_length_min': 104.87337893665861, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.19558837785078015, 'strand_bias_max': 0.7672807928381679, 'rp_sd_min_alt': 8, 'rp_sd_min': 3.558736312452001}. Best is trial 0 with value: 554.8994579237258.
# [I 2026-04-24 17:46:08,368] Trial 8 finished with value: 477.3346379297787 and parameters: {'n_total_min': 16, 'depth_percentile_max': 98, 'mean_inset_qual_min': 40, 'mean_del_anchor_qual_min': 46, 'max_slippage_reads': 3, 'asxs_min': 38, 'mean_mapq_min': 22, 'avg_alt_nm_max': 1.8385790152971677, 'dist_to_softclip_min': 1, 'variants_250bp_max': 3, 'ref_entropy_min': 2.0433221649801356, 'min_dist_to_indel': 196, 'min_rp_med': 0.07244325886239794, 'max_rp_med': 0.9641797038198084, 'max_n_count': 2.3844339106249453, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 30.158225586311527, 'mean_ref_mapq_min': 43.07615538505436, 'avg_nonaltread_variants_max': 4.925176938188639, 'sd_insert_max': 156.1943902384356, 'avg_read_position_min': 7.224521152615053, 'avg_read_position_max': 135.6154472488171, 'avg_read_length_min': 52.43159664314538, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.05313320382211468, 'strand_bias_max': 0.9821375753058743, 'rp_sd_min_alt': 10, 'rp_sd_min': 13.722965853306729}. Best is trial 8 with value: 477.3346379297787.
# [I 2026-04-24 17:46:08,372] Trial 9 finished with value: 996.6275661318723 and parameters: {'n_total_min': 17, 'depth_percentile_max': 95, 'mean_inset_qual_min': 48, 'mean_del_anchor_qual_min': 33, 'max_slippage_reads': 5, 'asxs_min': 59, 'mean_mapq_min': 46, 'avg_alt_nm_max': 1.4722444603479286, 'dist_to_softclip_min': 2, 'variants_250bp_max': 13, 'ref_entropy_min': 0.6655362108281832, 'min_dist_to_indel': 84, 'min_rp_med': 0.04897608837208452, 'max_rp_med': 0.9855308341912546, 'max_n_count': 2.088089390024919, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 34.203670205361895, 'mean_ref_mapq_min': 23.88705975083074, 'avg_nonaltread_variants_max': 6.150072266991698, 'sd_insert_max': 792.0430800834106, 'avg_read_position_min': 1.4008401523652403, 'avg_read_position_max': 140.36659304727473, 'avg_read_length_min': 137.73730719279556, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.20910472229858038, 'strand_bias_max': 0.9107452251961328, 'rp_sd_min_alt': 5, 'rp_sd_min': 4.403877663967401}. Best is trial 8 with value: 477.3346379297787.
# [I 2026-04-24 17:46:08,393] Trial 10 finished with value: 623.3757362151246 and parameters: {'n_total_min': 29, 'depth_percentile_max': 98, 'mean_inset_qual_min': 34, 'mean_del_anchor_qual_min': 49, 'max_slippage_reads': 3, 'asxs_min': 39, 'mean_mapq_min': 25, 'avg_alt_nm_max': 0.11273866052240877, 'dist_to_softclip_min': 0, 'variants_250bp_max': 8, 'ref_entropy_min': 2.0840479421714098, 'min_dist_to_indel': 160, 'min_rp_med': 0.07471602079415825, 'max_rp_med': 0.9574936984824843, 'max_n_count': 2.978174654786975, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 45.278796586347156, 'mean_ref_mapq_min': 44.287370961329025, 'avg_nonaltread_variants_max': 9.24159704363425, 'sd_insert_max': 189.55779236246954, 'avg_read_position_min': 5.874520821871226, 'avg_read_position_max': 136.30217759857592, 'avg_read_length_min': 51.26963644615591, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.014750377012138056, 'strand_bias_max': 0.9944238421309097, 'rp_sd_min_alt': 10, 'rp_sd_min': 0.15899032317553274}. Best is trial 8 with value: 477.3346379297787.
# [I 2026-04-24 17:46:08,411] Trial 11 finished with value: 465.1108093635237 and parameters: {'n_total_min': 10, 'depth_percentile_max': 99, 'mean_inset_qual_min': 40, 'mean_del_anchor_qual_min': 40, 'max_slippage_reads': 2, 'asxs_min': 35, 'mean_mapq_min': 20, 'avg_alt_nm_max': 2.0047798484102204, 'dist_to_softclip_min': 0, 'variants_250bp_max': 10, 'ref_entropy_min': 1.1656858240710632, 'min_dist_to_indel': 457, 'min_rp_med': 0.07972118925528493, 'max_rp_med': 0.9489389869784899, 'max_n_count': 0.1087130643596923, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 16.261854052077922, 'mean_ref_mapq_min': 40.53641853562281, 'avg_nonaltread_variants_max': 6.523327566673127, 'sd_insert_max': 277.63892416054824, 'avg_read_position_min': 5.484350037738029, 'avg_read_position_max': 137.2328342080035, 'avg_read_length_min': 51.098918924377124, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.10575433352523238, 'strand_bias_max': 0.8531906409538865, 'rp_sd_min_alt': 9, 'rp_sd_min': 4.453153505452756}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,427] Trial 12 finished with value: 515.4276803382573 and parameters: {'n_total_min': 10, 'depth_percentile_max': 98, 'mean_inset_qual_min': 37, 'mean_del_anchor_qual_min': 42, 'max_slippage_reads': 2, 'asxs_min': 37, 'mean_mapq_min': 20, 'avg_alt_nm_max': 1.7237267473768676, 'dist_to_softclip_min': 0, 'variants_250bp_max': 9, 'ref_entropy_min': 1.2305332736949142, 'min_dist_to_indel': 11, 'min_rp_med': 0.07751614126832757, 'max_rp_med': 0.955524423489755, 'max_n_count': 2.0512930665295093, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 19.220384115475007, 'mean_ref_mapq_min': 43.99864570520639, 'avg_nonaltread_variants_max': 7.490696160239654, 'sd_insert_max': 175.3424146853863, 'avg_read_position_min': 5.9004393379173905, 'avg_read_position_max': 137.53991941532757, 'avg_read_length_min': 79.15709448347843, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.1343938915808057, 'strand_bias_max': 0.8703784718162503, 'rp_sd_min_alt': 9, 'rp_sd_min': 5.989419724782094}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,443] Trial 13 finished with value: 653.7133411267466 and parameters: {'n_total_min': 10, 'depth_percentile_max': 98, 'mean_inset_qual_min': 34, 'mean_del_anchor_qual_min': 42, 'max_slippage_reads': 4, 'asxs_min': 30, 'mean_mapq_min': 26, 'avg_alt_nm_max': 0.4882752537239694, 'dist_to_softclip_min': 1, 'variants_250bp_max': 6, 'ref_entropy_min': 0.811921178016874, 'min_dist_to_indel': 499, 'min_rp_med': 0.06265044533820038, 'max_rp_med': 0.9482918127965314, 'max_n_count': 2.5157612001177467, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 18.056712432947275, 'mean_ref_mapq_min': 39.46616036937704, 'avg_nonaltread_variants_max': 7.1671907640091845, 'sd_insert_max': 238.70410373198183, 'avg_read_position_min': 7.053672718745564, 'avg_read_position_max': 132.5629019623314, 'avg_read_length_min': 52.959999056421445, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.07994370447170951, 'strand_bias_max': 0.995151807578662, 'rp_sd_min_alt': 8, 'rp_sd_min': 9.848291076707472}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,459] Trial 14 finished with value: 488.76650914695585 and parameters: {'n_total_min': 13, 'depth_percentile_max': 99, 'mean_inset_qual_min': 41, 'mean_del_anchor_qual_min': 37, 'max_slippage_reads': 2, 'asxs_min': 41, 'mean_mapq_min': 36, 'avg_alt_nm_max': 2.2680537708841744, 'dist_to_softclip_min': 1, 'variants_250bp_max': 11, 'ref_entropy_min': 1.362919445677126, 'min_dist_to_indel': 191, 'min_rp_med': 0.07995054339586408, 'max_rp_med': 0.9647821142625361, 'max_n_count': 0.231419513462015, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 24.875505395696244, 'mean_ref_mapq_min': 47.112424460377724, 'avg_nonaltread_variants_max': 3.613954739646033, 'sd_insert_max': 141.28381232029466, 'avg_read_position_min': 4.440372538928174, 'avg_read_position_max': 137.80218060985277, 'avg_read_length_min': 73.58998921349196, 'strand_bias_n_alt_min': 6, 'strand_bias_min': 0.15311973774396814, 'strand_bias_max': 0.7090176880376391, 'rp_sd_min_alt': 10, 'rp_sd_min': 0.6630875217975261}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,475] Trial 15 finished with value: 649.8461069050625 and parameters: {'n_total_min': 12, 'depth_percentile_max': 98, 'mean_inset_qual_min': 30, 'mean_del_anchor_qual_min': 43, 'max_slippage_reads': 3, 'asxs_min': 47, 'mean_mapq_min': 24, 'avg_alt_nm_max': 0.8733666380782656, 'dist_to_softclip_min': 0, 'variants_250bp_max': 10, 'ref_entropy_min': 1.7293532061136063, 'min_dist_to_indel': 415, 'min_rp_med': 0.031049561345895225, 'max_rp_med': 0.9443275944511261, 'max_n_count': 1.1478159238881889, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 13.062113799887438, 'mean_ref_mapq_min': 34.89824437333762, 'avg_nonaltread_variants_max': 9.380468275939966, 'sd_insert_max': 309.8380130724244, 'avg_read_position_min': 4.616951234658579, 'avg_read_position_max': 145.9371071800272, 'avg_read_length_min': 61.940995608222835, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.03910017155789766, 'strand_bias_max': 0.8814395781321371, 'rp_sd_min_alt': 8, 'rp_sd_min': 6.396233899552588}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,493] Trial 16 finished with value: 499.6737107711138 and parameters: {'n_total_min': 28, 'depth_percentile_max': 99, 'mean_inset_qual_min': 44, 'mean_del_anchor_qual_min': 49, 'max_slippage_reads': 4, 'asxs_min': 32, 'mean_mapq_min': 30, 'avg_alt_nm_max': 2.8646035380172274, 'dist_to_softclip_min': 1, 'variants_250bp_max': 7, 'ref_entropy_min': 2.04557631655383, 'min_dist_to_indel': 195, 'min_rp_med': 0.05952154651511894, 'max_rp_med': 0.9653867271294863, 'max_n_count': 0.005412750227168681, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 41.424607777123924, 'mean_ref_mapq_min': 51.054712579607944, 'avg_nonaltread_variants_max': 6.00241164751386, 'sd_insert_max': 481.7034839019749, 'avg_read_position_min': 7.019688250592186, 'avg_read_position_max': 138.4258885628054, 'avg_read_length_min': 88.026547063708, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.09781335118566481, 'strand_bias_max': 0.8394699314545814, 'rp_sd_min_alt': 9, 'rp_sd_min': 8.1570463229367}. Best is trial 11 with value: 465.1108093635237.
# [INFO] Loaded 4208652 regions for Artefact Gene Blacklist.
# [INFO] Found 5279 variants in Cluster blacklist.
#
# ========================================
#    DYNAMIC FILTER WATERFALL DIAGNOSTIC
# ========================================
# FILTER STEP                    | REMAINING  | DROPPED HERE
# -------------------------------------------------------
# N_TOTAL                        | 1533       | 29
# DEPTH_PERCENTILE               | 1533       | 0
# MEAN_MAPQ                      | 1504       | 29
# AVG_ASXS                       | 1504       | 0
# INSET/ANCHOR_QUAL              | 1504       | 0
# HOMOPOLYMER                    | 1503       | 1
# SLIPPAGE                       | 1452       | 51
# VARIANTS_20BP                  | 1369       | 83
# VARIANTS_250BP                 | 1287       | 82
# REF_ENTROPY                    | 1287       | 0
# ALT_SOFTCLIP                   | 1259       | 28
# DIST_SOFTCLIP                  | 1259       | 0
# ALT_EXCESS_NM                  | 1208       | 51
# GC_CONTENT                     | 1204       | 4
# DIST_OTHER_INDEL               | 1204       | 0
# RP_MED                         | 1204       | 0
# ALT_N_COUNT                    | 1178       | 26
# GERMLINE_VAF                   | 915        | 263
# SD_BASEQ                       | 892        | 23
# AVG_ALT_READ_MEAN_BASEQ        | 891        | 1
# MEAN_REF_MAPQ                  | 891        | 0
# AVG_REF_ASXS                   | 891        | 0
# AVG_ALTREAD_VARIANTS           | 891        | 0
# AVG_NONALTREAD_VARIANTS        | 890        | 1
# MEAN_INSERT                    | 890        | 0
# SD_INSERT                      | 890        | 0
# AVG_READ_POSITION              | 890        | 0
# AVG_READ_LENGTH                | 888        | 2
# STRAND_BIAS                    | 888        | 0
# RP_SD                          | 888        | 0
# ========================================
#
# [INFO] Starting Optuna (Trials=3000). Evaluating 1562 valid candidates per trial...
# [INFO] Starting Optuna (Trials=3000). Evaluating 1562 valid candidates per trial...
# [I 2026-04-24 17:46:08,510] Trial 17 finished with value: 587.7288222461187 and parameters: {'n_total_min': 20, 'depth_percentile_max': 98, 'mean_inset_qual_min': 37, 'mean_del_anchor_qual_min': 40, 'max_slippage_reads': 2, 'asxs_min': 43, 'mean_mapq_min': 23, 'avg_alt_nm_max': 1.7914005129328536, 'dist_to_softclip_min': 2, 'variants_250bp_max': 3, 'ref_entropy_min': 0.39587504017614206, 'min_dist_to_indel': 436, 'min_rp_med': 0.06954779110567888, 'max_rp_med': 0.9437847597150479, 'max_n_count': 1.8119426292037475, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 28.07676233347587, 'mean_ref_mapq_min': 42.042030784513905, 'avg_nonaltread_variants_max': 8.154010853883214, 'sd_insert_max': 33.33471297120357, 'avg_read_position_min': 6.351268676136867, 'avg_read_position_max': 134.98338122361847, 'avg_read_length_min': 67.75521472780031, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.15612458425769082, 'strand_bias_max': 0.9599291776314486, 'rp_sd_min_alt': 7, 'rp_sd_min': 11.030651472625497}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,527] Trial 18 finished with value: 477.71413017939386 and parameters: {'n_total_min': 12, 'depth_percentile_max': 99, 'mean_inset_qual_min': 45, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 4, 'asxs_min': 21, 'mean_mapq_min': 28, 'avg_alt_nm_max': 3.452284927799982, 'dist_to_softclip_min': 0, 'variants_250bp_max': 15, 'ref_entropy_min': 1.023903653703154, 'min_dist_to_indel': 230, 'min_rp_med': 0.03535397518440896, 'max_rp_med': 0.9637349814531389, 'max_n_count': 1.7299906642738077, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 46.06514183923865, 'mean_ref_mapq_min': 48.65986384316581, 'avg_nonaltread_variants_max': 3.3307883772788545, 'sd_insert_max': 434.38090195307586, 'avg_read_position_min': 3.6743574811753605, 'avg_read_position_max': 132.18592486809206, 'avg_read_length_min': 91.99674189079428, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.04939094343881732, 'strand_bias_max': 0.8925325287676108, 'rp_sd_min_alt': 9, 'rp_sd_min': 14.979613988389293}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,544] Trial 19 finished with value: 662.9237576557489 and parameters: {'n_total_min': 26, 'depth_percentile_max': 97, 'mean_inset_qual_min': 50, 'mean_del_anchor_qual_min': 45, 'max_slippage_reads': 2, 'asxs_min': 34, 'mean_mapq_min': 34, 'avg_alt_nm_max': 2.1079885918618393, 'dist_to_softclip_min': 1, 'variants_250bp_max': 7, 'ref_entropy_min': 0.9966720609638036, 'min_dist_to_indel': 114, 'min_rp_med': 0.056585280579361644, 'max_rp_med': 0.9495962778094261, 'max_n_count': 2.4774203266733177, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 16.487791316526632, 'mean_ref_mapq_min': 38.46592492374841, 'avg_nonaltread_variants_max': 5.156844253083361, 'sd_insert_max': 102.85765606833121, 'avg_read_position_min': 8.128287029151753, 'avg_read_position_max': 130.2486601315025, 'avg_read_length_min': 55.898455252250066, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.0004632295543699344, 'strand_bias_max': 0.8103280909046003, 'rp_sd_min_alt': 3, 'rp_sd_min': 5.230308682286224}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,560] Trial 20 finished with value: 499.11939007746787 and parameters: {'n_total_min': 20, 'depth_percentile_max': 96, 'mean_inset_qual_min': 39, 'mean_del_anchor_qual_min': 21, 'max_slippage_reads': 3, 'asxs_min': 54, 'mean_mapq_min': 20, 'avg_alt_nm_max': 1.063108098154018, 'dist_to_softclip_min': 3, 'variants_250bp_max': 12, 'ref_entropy_min': 1.8010082963150973, 'min_dist_to_indel': 24, 'min_rp_med': 0.07252015175907506, 'max_rp_med': 0.9595976604764006, 'max_n_count': 1.1868018541069827, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 7.732943464250294, 'mean_ref_mapq_min': 53.052448227192826, 'avg_nonaltread_variants_max': 6.4708728873365615, 'sd_insert_max': 243.21230702650232, 'avg_read_position_min': 9.164618251003851, 'avg_read_position_max': 135.61476378800353, 'avg_read_length_min': 69.725867544969, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.1157594209581492, 'strand_bias_max': 0.9572475133221852, 'rp_sd_min_alt': 10, 'rp_sd_min': 1.553920754830842}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,577] Trial 21 finished with value: 470.75716372201293 and parameters: {'n_total_min': 12, 'depth_percentile_max': 99, 'mean_inset_qual_min': 45, 'mean_del_anchor_qual_min': 34, 'max_slippage_reads': 4, 'asxs_min': 21, 'mean_mapq_min': 28, 'avg_alt_nm_max': 3.2512542800608397, 'dist_to_softclip_min': 0, 'variants_250bp_max': 15, 'ref_entropy_min': 0.9667885020801027, 'min_dist_to_indel': 227, 'min_rp_med': 0.03478867529779911, 'max_rp_med': 0.96958308516903, 'max_n_count': 1.7966293531538888, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 48.37954014954856, 'mean_ref_mapq_min': 47.3502084337291, 'avg_nonaltread_variants_max': 3.386706093377277, 'sd_insert_max': 448.001353822959, 'avg_read_position_min': 3.4354840232521267, 'avg_read_position_max': 133.26859048415636, 'avg_read_length_min': 90.71964908823962, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.04711832715969086, 'strand_bias_max': 0.8883317538143809, 'rp_sd_min_alt': 9, 'rp_sd_min': 11.924504114655166}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,593] Trial 22 finished with value: 2470.522547308156 and parameters: {'n_total_min': 10, 'depth_percentile_max': 99, 'mean_inset_qual_min': 44, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 4, 'asxs_min': 24, 'mean_mapq_min': 23, 'avg_alt_nm_max': 3.0267267309639245, 'dist_to_softclip_min': 0, 'variants_250bp_max': 15, 'ref_entropy_min': 1.4320789321360032, 'min_dist_to_indel': 230, 'min_rp_med': 0.02771166634528855, 'max_rp_med': 0.9702592200828626, 'max_n_count': 2.336562338546356, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 39.28288964639859, 'mean_ref_mapq_min': 45.954651459897214, 'avg_nonaltread_variants_max': 4.252381727484584, 'sd_insert_max': 365.9421742698701, 'avg_read_position_min': 5.169624118182123, 'avg_read_position_max': 133.71123328960888, 'avg_read_length_min': 149.85299078350923, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.03572918434883722, 'strand_bias_max': 0.8608365529565937, 'rp_sd_min_alt': 8, 'rp_sd_min': 12.085526516989814}. Best is trial 11 with value: 465.1108093635237.
# [I 2026-04-24 17:46:08,610] Trial 23 finished with value: 409.85121257341854 and parameters: {'n_total_min': 12, 'depth_percentile_max': 98, 'mean_inset_qual_min': 39, 'mean_del_anchor_qual_min': 40, 'max_slippage_reads': 3, 'asxs_min': 14, 'mean_mapq_min': 28, 'avg_alt_nm_max': 3.4014947695767983, 'dist_to_softclip_min': 0, 'variants_250bp_max': 9, 'ref_entropy_min': 0.858513577092229, 'min_dist_to_indel': 161, 'min_rp_med': 0.025753662053295073, 'max_rp_med': 0.9396957711005407, 'max_n_count': 1.7943283909365806, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 46.47051393397453, 'mean_ref_mapq_min': 41.317298243278884, 'avg_nonaltread_variants_max': 4.52669631514493, 'sd_insert_max': 603.0566605375898, 'avg_read_position_min': 2.201666229980444, 'avg_read_position_max': 138.6291356991207, 'avg_read_length_min': 60.27570226281395, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.08922394703212605, 'strand_bias_max': 0.8138435776675239, 'rp_sd_min_alt': 9, 'rp_sd_min': 9.342905950033574}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,640] Trial 24 finished with value: 422.1052984860959 and parameters: {'n_total_min': 12, 'depth_percentile_max': 99, 'mean_inset_qual_min': 32, 'mean_del_anchor_qual_min': 32, 'max_slippage_reads': 4, 'asxs_min': 13, 'mean_mapq_min': 30, 'avg_alt_nm_max': 3.701995887788576, 'dist_to_softclip_min': 0, 'variants_250bp_max': 13, 'ref_entropy_min': 0.851033008869504, 'min_dist_to_indel': 140, 'min_rp_med': 0.01029859540177857, 'max_rp_med': 0.9381929738224992, 'max_n_count': 1.7070619239751512, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 50.076164519632044, 'mean_ref_mapq_min': 41.81472090678672, 'avg_nonaltread_variants_max': 2.9374004098489532, 'sd_insert_max': 580.7918943934383, 'avg_read_position_min': 2.365876112747938, 'avg_read_position_max': 139.18082003970943, 'avg_read_length_min': 77.8756699476175, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.09248741644726968, 'strand_bias_max': 0.8064229118677356, 'rp_sd_min_alt': 9, 'rp_sd_min': 9.255689621085168}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,664] Trial 25 finished with value: 437.8475560261785 and parameters: {'n_total_min': 13, 'depth_percentile_max': 98, 'mean_inset_qual_min': 30, 'mean_del_anchor_qual_min': 29, 'max_slippage_reads': 2, 'asxs_min': 10, 'mean_mapq_min': 34, 'avg_alt_nm_max': 3.8259185654146526, 'dist_to_softclip_min': 0, 'variants_250bp_max': 9, 'ref_entropy_min': 0.7546480538865338, 'min_dist_to_indel': 63, 'min_rp_med': 0.013108990164916231, 'max_rp_med': 0.9385733180824769, 'max_n_count': 1.2571591511083664, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 52.09456408933115, 'mean_ref_mapq_min': 35.94978394421163, 'avg_nonaltread_variants_max': 2.6374271938941938, 'sd_insert_max': 665.031770679217, 'avg_read_position_min': 2.1807589639844287, 'avg_read_position_max': 139.0511704703051, 'avg_read_length_min': 62.26602986321363, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.09400433262438217, 'strand_bias_max': 0.8157395568917127, 'rp_sd_min_alt': 7, 'rp_sd_min': 9.274297544353203}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,681] Trial 26 finished with value: 467.0188332356505 and parameters: {'n_total_min': 18, 'depth_percentile_max': 98, 'mean_inset_qual_min': 30, 'mean_del_anchor_qual_min': 28, 'max_slippage_reads': 3, 'asxs_min': 11, 'mean_mapq_min': 37, 'avg_alt_nm_max': 3.904515274612675, 'dist_to_softclip_min': 1, 'variants_250bp_max': 9, 'ref_entropy_min': 0.7846228585586108, 'min_dist_to_indel': 61, 'min_rp_med': 0.010470347236726144, 'max_rp_med': 0.9405415294778904, 'max_n_count': 1.2964570742077468, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 52.795588294207796, 'mean_ref_mapq_min': 34.43138516021098, 'avg_nonaltread_variants_max': 2.7373822612717635, 'sd_insert_max': 651.2108535707172, 'avg_read_position_min': 2.1204489156364916, 'avg_read_position_max': 139.53836220708385, 'avg_read_length_min': 76.86018902291877, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.1273660272758809, 'strand_bias_max': 0.8070435461294124, 'rp_sd_min_alt': 6, 'rp_sd_min': 9.30307214760935}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,698] Trial 27 finished with value: 477.7793542535428 and parameters: {'n_total_min': 14, 'depth_percentile_max': 98, 'mean_inset_qual_min': 26, 'mean_del_anchor_qual_min': 31, 'max_slippage_reads': 1, 'asxs_min': 15, 'mean_mapq_min': 33, 'avg_alt_nm_max': 3.6926994999964875, 'dist_to_softclip_min': 0, 'variants_250bp_max': 13, 'ref_entropy_min': 0.47574562923496444, 'min_dist_to_indel': 133, 'min_rp_med': 0.02109956834791744, 'max_rp_med': 0.9387419004429555, 'max_n_count': 1.6577174126107588, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 58.05630332524427, 'mean_ref_mapq_min': 34.82053636031533, 'avg_nonaltread_variants_max': 4.249857226530235, 'sd_insert_max': 639.8061990066769, 'avg_read_position_min': 2.113073429737947, 'avg_read_position_max': 141.80588878348064, 'avg_read_length_min': 61.61278191996136, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.08520733261371212, 'strand_bias_max': 0.7786942002098756, 'rp_sd_min_alt': 7, 'rp_sd_min': 7.155160547450707}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,715] Trial 28 finished with value: 548.1162127481263 and parameters: {'n_total_min': 12, 'depth_percentile_max': 96, 'mean_inset_qual_min': 31, 'mean_del_anchor_qual_min': 23, 'max_slippage_reads': 4, 'asxs_min': 10, 'mean_mapq_min': 42, 'avg_alt_nm_max': 4.027596083475472, 'dist_to_softclip_min': 2, 'variants_250bp_max': 12, 'ref_entropy_min': 0.8212479942350968, 'min_dist_to_indel': 66, 'min_rp_med': 0.010768865733773189, 'max_rp_med': 0.92455824333609, 'max_n_count': 0.7262244350401059, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 50.89248669790512, 'mean_ref_mapq_min': 28.584848246997467, 'avg_nonaltread_variants_max': 2.1747574772539657, 'sd_insert_max': 750.5490452488912, 'avg_read_position_min': 2.237345048753603, 'avg_read_position_max': 139.5535150060289, 'avg_read_length_min': 84.8134385453575, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.16096811512483716, 'strand_bias_max': 0.7518576918064015, 'rp_sd_min_alt': 4, 'rp_sd_min': 10.264998586214098}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,733] Trial 29 finished with value: 2085.984206780253 and parameters: {'n_total_min': 14, 'depth_percentile_max': 98, 'mean_inset_qual_min': 26, 'mean_del_anchor_qual_min': 31, 'max_slippage_reads': 0, 'asxs_min': 17, 'mean_mapq_min': 31, 'avg_alt_nm_max': 4.83917621953796, 'dist_to_softclip_min': 3, 'variants_250bp_max': 11, 'ref_entropy_min': 0.37688925931133044, 'min_dist_to_indel': 142, 'min_rp_med': 0.023875096991815288, 'max_rp_med': 0.9367316165538816, 'max_n_count': 1.3663677260006972, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 42.43717120315161, 'mean_ref_mapq_min': 32.195115923844234, 'avg_nonaltread_variants_max': 0.0882521391483495, 'sd_insert_max': 589.1744885182243, 'avg_read_position_min': 3.9387634332534693, 'avg_read_position_max': 142.13476830288045, 'avg_read_length_min': 60.978974909811136, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.1754018784482385, 'strand_bias_max': 0.8215858278951474, 'rp_sd_min_alt': 8, 'rp_sd_min': 8.182648164837902}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,751] Trial 30 finished with value: 445.29487999299283 and parameters: {'n_total_min': 18, 'depth_percentile_max': 99, 'mean_inset_qual_min': 32, 'mean_del_anchor_qual_min': 27, 'max_slippage_reads': 5, 'asxs_min': 14, 'mean_mapq_min': 35, 'avg_alt_nm_max': 3.968797520069751, 'dist_to_softclip_min': 0, 'variants_250bp_max': 9, 'ref_entropy_min': 0.6801583036009594, 'min_dist_to_indel': 37, 'min_rp_med': 0.016659595439499766, 'max_rp_med': 0.9354698122425827, 'max_n_count': 0.41361854017870536, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 54.59779387539561, 'mean_ref_mapq_min': 36.696639727636125, 'avg_nonaltread_variants_max': 2.7556921275774675, 'sd_insert_max': 724.7094188747424, 'avg_read_position_min': 2.472917724242363, 'avg_read_position_max': 143.81482689063918, 'avg_read_length_min': 69.23484189568175, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.097043549018627, 'strand_bias_max': 0.789233087776751, 'rp_sd_min_alt': 6, 'rp_sd_min': 8.892755881608052}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,768] Trial 31 finished with value: 431.85801363408837 and parameters: {'n_total_min': 18, 'depth_percentile_max': 99, 'mean_inset_qual_min': 32, 'mean_del_anchor_qual_min': 27, 'max_slippage_reads': 5, 'asxs_min': 15, 'mean_mapq_min': 34, 'avg_alt_nm_max': 4.025098258078032, 'dist_to_softclip_min': 0, 'variants_250bp_max': 8, 'ref_entropy_min': 0.6323675347599176, 'min_dist_to_indel': 36, 'min_rp_med': 0.01453566712643948, 'max_rp_med': 0.9347143501443714, 'max_n_count': 0.45764698746568455, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 55.19924275317743, 'mean_ref_mapq_min': 37.86587139325311, 'avg_nonaltread_variants_max': 2.937521513441623, 'sd_insert_max': 709.8857947768731, 'avg_read_position_min': 2.473446132032121, 'avg_read_position_max': 146.17356254214965, 'avg_read_length_min': 70.18437394194306, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.09684129851221125, 'strand_bias_max': 0.7899809760716885, 'rp_sd_min_alt': 6, 'rp_sd_min': 8.928522307634243}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,785] Trial 32 finished with value: 415.2498518622012 and parameters: {'n_total_min': 13, 'depth_percentile_max': 99, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 25, 'max_slippage_reads': 5, 'asxs_min': 10, 'mean_mapq_min': 38, 'avg_alt_nm_max': 4.580628736124291, 'dist_to_softclip_min': 0, 'variants_250bp_max': 6, 'ref_entropy_min': 0.8894336917254865, 'min_dist_to_indel': 82, 'min_rp_med': 0.013895619212271035, 'max_rp_med': 0.9280189273672712, 'max_n_count': 0.6146613849792296, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 48.866515148437536, 'mean_ref_mapq_min': 41.25231849481123, 'avg_nonaltread_variants_max': 3.6569211282361236, 'sd_insert_max': 584.4134530049398, 'avg_read_position_min': 1.1546699652066035, 'avg_read_position_max': 148.4729665258702, 'avg_read_length_min': 73.34759955190621, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.13463490427893043, 'strand_bias_max': 0.831935142820694, 'rp_sd_min_alt': 7, 'rp_sd_min': 10.601496777970674}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,802] Trial 33 finished with value: 447.12675430899856 and parameters: {'n_total_min': 18, 'depth_percentile_max': 99, 'mean_inset_qual_min': 37, 'mean_del_anchor_qual_min': 25, 'max_slippage_reads': 5, 'asxs_min': 16, 'mean_mapq_min': 42, 'avg_alt_nm_max': 4.585539449512126, 'dist_to_softclip_min': 1, 'variants_250bp_max': 6, 'ref_entropy_min': 0.5422115401537417, 'min_dist_to_indel': 104, 'min_rp_med': 0.024621882995609516, 'max_rp_med': 0.9269734039224793, 'max_n_count': 0.5324100398067928, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 48.06222028427591, 'mean_ref_mapq_min': 41.01190092832345, 'avg_nonaltread_variants_max': 3.858912897974181, 'sd_insert_max': 566.3799195119891, 'avg_read_position_min': 0.8334716893584782, 'avg_read_position_max': 149.34807121773576, 'avg_read_length_min': 73.9018495735685, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.13855430863462045, 'strand_bias_max': 0.8334756280740806, 'rp_sd_min_alt': 6, 'rp_sd_min': 10.340847654979184}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,819] Trial 34 finished with value: 492.18055510983737 and parameters: {'n_total_min': 16, 'depth_percentile_max': 99, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 20, 'max_slippage_reads': 5, 'asxs_min': 13, 'mean_mapq_min': 38, 'avg_alt_nm_max': 4.1315127784024925, 'dist_to_softclip_min': 0, 'variants_250bp_max': 5, 'ref_entropy_min': 0.9270224933296528, 'min_dist_to_indel': 173, 'min_rp_med': 0.017939652065588833, 'max_rp_med': 0.9205862067903161, 'max_n_count': 0.9872318732536693, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 58.99533482816504, 'mean_ref_mapq_min': 38.653729873439545, 'avg_nonaltread_variants_max': 4.795941434438463, 'sd_insert_max': 706.3216109179891, 'avg_read_position_min': 1.5425640691589315, 'avg_read_position_max': 146.85417519086073, 'avg_read_length_min': 94.54546588129692, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.11979068597513653, 'strand_bias_max': 0.793093201233334, 'rp_sd_min_alt': 7, 'rp_sd_min': 7.039188562999594}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,838] Trial 35 finished with value: 524.4987246812738 and parameters: {'n_total_min': 11, 'depth_percentile_max': 99, 'mean_inset_qual_min': 33, 'mean_del_anchor_qual_min': 26, 'max_slippage_reads': 4, 'asxs_min': 19, 'mean_mapq_min': 42, 'avg_alt_nm_max': 4.6119463756661965, 'dist_to_softclip_min': 1, 'variants_250bp_max': 8, 'ref_entropy_min': 0.23078206357947978, 'min_dist_to_indel': 2, 'min_rp_med': 0.014459674877269287, 'max_rp_med': 0.9312994635371967, 'max_n_count': 1.5575849675948328, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 43.123650859877955, 'mean_ref_mapq_min': 32.2178533743407, 'avg_nonaltread_variants_max': 1.9930072981923534, 'sd_insert_max': 579.7552918767256, 'avg_read_position_min': 2.963734147891477, 'avg_read_position_max': 146.65037507082673, 'avg_read_length_min': 79.59194452289663, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.06553948598127368, 'strand_bias_max': 0.7516377165781257, 'rp_sd_min_alt': 4, 'rp_sd_min': 12.793398951628737}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,856] Trial 36 finished with value: 478.120917023994 and parameters: {'n_total_min': 15, 'depth_percentile_max': 99, 'mean_inset_qual_min': 36, 'mean_del_anchor_qual_min': 23, 'max_slippage_reads': 5, 'asxs_min': 23, 'mean_mapq_min': 29, 'avg_alt_nm_max': 4.262311958737048, 'dist_to_softclip_min': 5, 'variants_250bp_max': 6, 'ref_entropy_min': 1.215556134634824, 'min_dist_to_indel': 89, 'min_rp_med': 0.022367587822672633, 'max_rp_med': 0.9281422720189483, 'max_n_count': 0.381748637948772, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 56.31065657182457, 'mean_ref_mapq_min': 54.551605478101145, 'avg_nonaltread_variants_max': 5.644201590824126, 'sd_insert_max': 498.38045315741834, 'avg_read_position_min': 0.6489857127144454, 'avg_read_position_max': 147.85801195783137, 'avg_read_length_min': 67.48532064066549, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.26077405755242367, 'strand_bias_max': 0.8363730820722323, 'rp_sd_min_alt': 5, 'rp_sd_min': 11.07904091117405}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,875] Trial 37 finished with value: 634.8098894699203 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 28, 'mean_del_anchor_qual_min': 38, 'max_slippage_reads': 5, 'asxs_min': 13, 'mean_mapq_min': 32, 'avg_alt_nm_max': 3.349475930292965, 'dist_to_softclip_min': 0, 'variants_250bp_max': 5, 'ref_entropy_min': 0.9022951683710092, 'min_dist_to_indel': 42, 'min_rp_med': 0.02796418923790389, 'max_rp_med': 0.9421950453124243, 'max_n_count': 1.9112059507952741, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 49.50229826320871, 'mean_ref_mapq_min': 49.531168315134, 'avg_nonaltread_variants_max': 3.024131533504916, 'sd_insert_max': 599.8347785235773, 'avg_read_position_min': 2.8130223585776495, 'avg_read_position_max': 144.82164643433234, 'avg_read_length_min': 111.48629372912364, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.17358170352464847, 'strand_bias_max': 0.7951575748811858, 'rp_sd_min_alt': 6, 'rp_sd_min': 8.524729622984303}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,892] Trial 38 finished with value: 489.68354247776676 and parameters: {'n_total_min': 25, 'depth_percentile_max': 97, 'mean_inset_qual_min': 38, 'mean_del_anchor_qual_min': 29, 'max_slippage_reads': 4, 'asxs_min': 18, 'mean_mapq_min': 40, 'avg_alt_nm_max': 4.910268014993724, 'dist_to_softclip_min': 1, 'variants_250bp_max': 7, 'ref_entropy_min': 0.6223614470738952, 'min_dist_to_indel': 131, 'min_rp_med': 0.01920527390571729, 'max_rp_med': 0.9332518945373779, 'max_n_count': 0.7158449088671917, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 38.03720975311996, 'mean_ref_mapq_min': 45.71552171102686, 'avg_nonaltread_variants_max': 1.5134796952095506, 'sd_insert_max': 695.1384399472928, 'avg_read_position_min': 1.7020057779565136, 'avg_read_position_max': 141.30166725996887, 'avg_read_length_min': 84.32965387973223, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.10956848574973761, 'strand_bias_max': 0.7332655528303665, 'rp_sd_min_alt': 8, 'rp_sd_min': 10.58421545051627}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,910] Trial 39 finished with value: 864.0077066683186 and parameters: {'n_total_min': 14, 'depth_percentile_max': 99, 'mean_inset_qual_min': 25, 'mean_del_anchor_qual_min': 33, 'max_slippage_reads': 5, 'asxs_min': 27, 'mean_mapq_min': 32, 'avg_alt_nm_max': 2.6267150074951653, 'dist_to_softclip_min': 2, 'variants_250bp_max': 4, 'ref_entropy_min': 1.1316374596631902, 'min_dist_to_indel': 163, 'min_rp_med': 0.013457532339584357, 'max_rp_med': 0.921215007769542, 'max_n_count': 1.0035940458631438, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 59.88485469345378, 'mean_ref_mapq_min': 42.01639919945052, 'avg_nonaltread_variants_max': 0.7240479455339504, 'sd_insert_max': 777.0532194746085, 'avg_read_position_min': 0.5710064491008746, 'avg_read_position_max': 143.3160237247456, 'avg_read_length_min': 98.59715615085607, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.07003828967263029, 'strand_bias_max': 0.761435902952542, 'rp_sd_min_alt': 10, 'rp_sd_min': 11.764881296940802}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,928] Trial 40 finished with value: 503.1035957869917 and parameters: {'n_total_min': 15, 'depth_percentile_max': 98, 'mean_inset_qual_min': 35, 'mean_del_anchor_qual_min': 22, 'max_slippage_reads': 4, 'asxs_min': 12, 'mean_mapq_min': 47, 'avg_alt_nm_max': 4.454337897043391, 'dist_to_softclip_min': 0, 'variants_250bp_max': 10, 'ref_entropy_min': 0.2883945671367377, 'min_dist_to_indel': 78, 'min_rp_med': 0.03650568048166565, 'max_rp_med': 0.9460436782891687, 'max_n_count': 2.205756510651583, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 45.672395749263096, 'mean_ref_mapq_min': 27.111102821710553, 'avg_nonaltread_variants_max': 4.679732239457509, 'sd_insert_max': 525.4180438271644, 'avg_read_position_min': 4.132976822483294, 'avg_read_position_max': 149.63183765612456, 'avg_read_length_min': 58.1492445333391, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2338598911566322, 'strand_bias_max': 0.8249906416029188, 'rp_sd_min_alt': 4, 'rp_sd_min': 12.791567612477307}. Best is trial 23 with value: 409.85121257341854.
# [I 2026-04-24 17:46:08,946] Trial 41 finished with value: 423.35857289005185 and parameters: {'n_total_min': 13, 'depth_percentile_max': 97, 'mean_inset_qual_min': 29, 'mean_del_anchor_qual_min': 30, 'max_slippage_reads': 3, 'asxs_min': 10, 'mean_mapq_min': 34, 'avg_alt_nm_max': 3.705172072331145, 'dist_to_softclip_min': 0, 'variants_250bp_max': 8, 'ref_entropy_min': 0.693174695703775, 'min_dist_to_indel': 53, 'min_rp_med': 0.012479978444629931, 'max_rp_med': 0.9372645176984356, 'max_n_count': 1.4873750192971005, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 51.79240624023522, 'mean_ref_mapq_min': 36.494776862032545, 'avg_nonaltread_variants_max': 3.9392656210587385, 'sd_insert_max': 625.7698899627414, 'avg_read_position_min': 2.620137335046751, 'avg_read_position_max': 138.86405230008168, 'avg_read_length_min': 64.56877447956577, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.08904382940375062, 'strand_bias_max': 0.8122211334709726, 'rp_sd_min_alt': 7, 'rp_sd_min': 9.149151372764717}. Best is trial 23 with value: 409.85121257341854.
# ...
# [I 2026-04-24 17:51:08,203] Trial 2986 finished with value: 353.99068361071704 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 34, 'max_slippage_reads': 1, 'asxs_min': 50, 'mean_mapq_min': 27, 'avg_alt_nm_max': 4.166298084378192, 'dist_to_softclip_min': 5, 'variants_250bp_max': 8, 'ref_entropy_min': 1.0379203602848002, 'min_dist_to_indel': 0, 'min_rp_med': 0.07049074238269554, 'max_rp_med': 0.9615225624970676, 'max_n_count': 0.44166252863878946, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 46.84081402633534, 'mean_ref_mapq_min': 39.9212352614265, 'avg_nonaltread_variants_max': 5.504140254422449, 'sd_insert_max': 532.3813917268586, 'avg_read_position_min': 2.035802597870441, 'avg_read_position_max': 143.85501043938592, 'avg_read_length_min': 57.24532878974367, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.24020301830275376, 'strand_bias_max': 0.9034290326269215, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.0008097875456668983}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:08,398] Trial 2987 finished with value: 320.51573129318564 and parameters: {'n_total_min': 21, 'depth_percentile_max': 99, 'mean_inset_qual_min': 25, 'mean_del_anchor_qual_min': 44, 'max_slippage_reads': 5, 'asxs_min': 48, 'mean_mapq_min': 30, 'avg_alt_nm_max': 4.320907221772662, 'dist_to_softclip_min': 5, 'variants_250bp_max': 10, 'ref_entropy_min': 0.9603337190650398, 'min_dist_to_indel': 24, 'min_rp_med': 0.02181834535197086, 'max_rp_med': 0.964322452219113, 'max_n_count': 0.550087085545652, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 40.711043274499126, 'mean_ref_mapq_min': 42.44681204861264, 'avg_nonaltread_variants_max': 5.933625692232048, 'sd_insert_max': 501.482363339278, 'avg_read_position_min': 2.5501155101675033, 'avg_read_position_max': 144.30602379683398, 'avg_read_length_min': 54.380337559617686, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.031117545421665286, 'strand_bias_max': 0.8848428841139284, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.00166635442263379}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:08,612] Trial 2988 finished with value: 293.9155120314297 and parameters: {'n_total_min': 20, 'depth_percentile_max': 99, 'mean_inset_qual_min': 24, 'mean_del_anchor_qual_min': 35, 'max_slippage_reads': 5, 'asxs_min': 52, 'mean_mapq_min': 28, 'avg_alt_nm_max': 4.048982158968475, 'dist_to_softclip_min': 5, 'variants_250bp_max': 1, 'ref_entropy_min': 1.1150785807320447, 'min_dist_to_indel': 0, 'min_rp_med': 0.018503464867855562, 'max_rp_med': 0.968364826397504, 'max_n_count': 0.37818924669647075, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 44.627065437427774, 'mean_ref_mapq_min': 41.004023498297144, 'avg_nonaltread_variants_max': 4.523047165233741, 'sd_insert_max': 610.6393303347619, 'avg_read_position_min': 1.8616917255674243, 'avg_read_position_max': 142.3847447040833, 'avg_read_length_min': 60.84740910320358, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.010076243429979256, 'strand_bias_max': 0.9137951331276798, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.0043410848856426185}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:08,828] Trial 2989 finished with value: 430.92148780924185 and parameters: {'n_total_min': 21, 'depth_percentile_max': 99, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 33, 'max_slippage_reads': 5, 'asxs_min': 34, 'mean_mapq_min': 29, 'avg_alt_nm_max': 3.9025204973649976, 'dist_to_softclip_min': 5, 'variants_250bp_max': 9, 'ref_entropy_min': 0.9075011122248522, 'min_dist_to_indel': 9, 'min_rp_med': 0.016368780206351297, 'max_rp_med': 0.9657591306538604, 'max_n_count': 0.5986794823612697, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 38.900013394282716, 'mean_ref_mapq_min': 43.993512506239355, 'avg_nonaltread_variants_max': 4.808515305869134, 'sd_insert_max': 570.3119430317844, 'avg_read_position_min': 2.3932973699370157, 'avg_read_position_max': 143.56290420656288, 'avg_read_length_min': 51.72957317976098, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.02558406852699902, 'strand_bias_max': 0.8970460754912415, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.5322376250182453}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:09,016] Trial 2990 finished with value: 308.3978761968235 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 32, 'max_slippage_reads': 5, 'asxs_min': 51, 'mean_mapq_min': 27, 'avg_alt_nm_max': 4.203468894913994, 'dist_to_softclip_min': 5, 'variants_250bp_max': 8, 'ref_entropy_min': 0.9755437754144628, 'min_dist_to_indel': 17, 'min_rp_med': 0.02092004941195993, 'max_rp_med': 0.9634505090412017, 'max_n_count': 0.4847193449889233, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 27.043419014041486, 'mean_ref_mapq_min': 40.29725190175527, 'avg_nonaltread_variants_max': 5.827411049383549, 'sd_insert_max': 544.3798062921094, 'avg_read_position_min': 2.751815219599283, 'avg_read_position_max': 144.85704659208673, 'avg_read_length_min': 53.53969258018901, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.01579403506592138, 'strand_bias_max': 0.9026093123978185, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.0004879127817790556}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:09,213] Trial 2991 finished with value: 437.09518603504466 and parameters: {'n_total_min': 21, 'depth_percentile_max': 99, 'mean_inset_qual_min': 23, 'mean_del_anchor_qual_min': 32, 'max_slippage_reads': 5, 'asxs_min': 33, 'mean_mapq_min': 28, 'avg_alt_nm_max': 4.473750878447306, 'dist_to_softclip_min': 5, 'variants_250bp_max': 10, 'ref_entropy_min': 1.0773824075512364, 'min_dist_to_indel': 29, 'min_rp_med': 0.024788128239968857, 'max_rp_med': 0.9668988347327814, 'max_n_count': 0.3300136464786391, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 42.20335357662015, 'mean_ref_mapq_min': 39.40278082507431, 'avg_nonaltread_variants_max': 5.043397329692369, 'sd_insert_max': 516.8283763408514, 'avg_read_position_min': 2.1729702408885876, 'avg_read_position_max': 142.92373747657967, 'avg_read_length_min': 59.1369269711106, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.03933521105986412, 'strand_bias_max': 0.761479808057907, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.7930445518302278}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:09,397] Trial 2992 finished with value: 420.34463253684464 and parameters: {'n_total_min': 19, 'depth_percentile_max': 99, 'mean_inset_qual_min': 24, 'mean_del_anchor_qual_min': 43, 'max_slippage_reads': 5, 'asxs_min': 49, 'mean_mapq_min': 25, 'avg_alt_nm_max': 4.274090154836037, 'dist_to_softclip_min': 5, 'variants_250bp_max': 9, 'ref_entropy_min': 1.0067586475767774, 'min_dist_to_indel': 10, 'min_rp_med': 0.01972874452304493, 'max_rp_med': 0.962303633959639, 'max_n_count': 0.2659113585328867, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 43.76333172678541, 'mean_ref_mapq_min': 37.5339686093441, 'avg_nonaltread_variants_max': 6.061274095514662, 'sd_insert_max': 627.9114340703651, 'avg_read_position_min': 3.0012198963623806, 'avg_read_position_max': 145.55311806325471, 'avg_read_length_min': 56.426400980874625, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.005644237782759402, 'strand_bias_max': 0.8925590204702194, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.5318127748274588}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:09,594] Trial 2993 finished with value: 417.4367692364697 and parameters: {'n_total_min': 20, 'depth_percentile_max': 99, 'mean_inset_qual_min': 23, 'mean_del_anchor_qual_min': 34, 'max_slippage_reads': 5, 'asxs_min': 35, 'mean_mapq_min': 27, 'avg_alt_nm_max': 4.085890917638231, 'dist_to_softclip_min': 5, 'variants_250bp_max': 10, 'ref_entropy_min': 0.9254867953048411, 'min_dist_to_indel': 9, 'min_rp_med': 0.01676948191881804, 'max_rp_med': 0.9687465569768852, 'max_n_count': 0.42290338453278753, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 38.92786986770973, 'mean_ref_mapq_min': 41.456273383005076, 'avg_nonaltread_variants_max': 4.310801968410087, 'sd_insert_max': 591.9665580045092, 'avg_read_position_min': 2.579719733888882, 'avg_read_position_max': 144.06268401198835, 'avg_read_length_min': 51.698071616164086, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.023531185119782166, 'strand_bias_max': 0.885483385727282, 'rp_sd_min_alt': 5, 'rp_sd_min': 5.4207215611913355}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:09,794] Trial 2994 finished with value: 409.3763251625888 and parameters: {'n_total_min': 21, 'depth_percentile_max': 99, 'mean_inset_qual_min': 23, 'mean_del_anchor_qual_min': 33, 'max_slippage_reads': 5, 'asxs_min': 47, 'mean_mapq_min': 26, 'avg_alt_nm_max': 3.994838113226893, 'dist_to_softclip_min': 5, 'variants_250bp_max': 9, 'ref_entropy_min': 1.0419002732807512, 'min_dist_to_indel': 17, 'min_rp_med': 0.021668750800139823, 'max_rp_med': 0.9650792357292616, 'max_n_count': 0.34933265536561103, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 41.39840085535911, 'mean_ref_mapq_min': 42.4292932584817, 'avg_nonaltread_variants_max': 5.558786980125568, 'sd_insert_max': 528.9926946257261, 'avg_read_position_min': 2.356316805509092, 'avg_read_position_max': 143.48484895794456, 'avg_read_length_min': 54.74280789750745, 'strand_bias_n_alt_min': 3, 'strand_bias_min': 0.016752922970677736, 'strand_bias_max': 0.9084347539173498, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.268746854330059}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:09,981] Trial 2995 finished with value: 592.5668104033283 and parameters: {'n_total_min': 21, 'depth_percentile_max': 99, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 45, 'max_slippage_reads': 5, 'asxs_min': 50, 'mean_mapq_min': 28, 'avg_alt_nm_max': 4.39495413125539, 'dist_to_softclip_min': 5, 'variants_250bp_max': 11, 'ref_entropy_min': 1.1271829151147401, 'min_dist_to_indel': 8, 'min_rp_med': 0.018305304472084134, 'max_rp_med': 0.9605186319259227, 'max_n_count': 0.22656206718747773, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 40.48023198706853, 'mean_ref_mapq_min': 38.34561674910862, 'avg_nonaltread_variants_max': 5.225863006936675, 'sd_insert_max': 552.8732628555153, 'avg_read_position_min': 1.978863203109033, 'avg_read_position_max': 144.51212583609131, 'avg_read_length_min': 107.1097917456454, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.030627387956077865, 'strand_bias_max': 0.898176797308495, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.4879543248539521}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:10,170] Trial 2996 finished with value: 410.13575318078904 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 25, 'mean_del_anchor_qual_min': 42, 'max_slippage_reads': 5, 'asxs_min': 52, 'mean_mapq_min': 29, 'avg_alt_nm_max': 3.655187887461976, 'dist_to_softclip_min': 2, 'variants_250bp_max': 8, 'ref_entropy_min': 0.9857132375491691, 'min_dist_to_indel': 0, 'min_rp_med': 0.023441130615223467, 'max_rp_med': 0.9640199424723517, 'max_n_count': 0.49548152891746955, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 42.816713030962475, 'mean_ref_mapq_min': 40.711506599063014, 'avg_nonaltread_variants_max': 5.701837577846155, 'sd_insert_max': 573.6129769833746, 'avg_read_position_min': 2.84665644773904, 'avg_read_position_max': 145.1318048004878, 'avg_read_length_min': 57.704544884502155, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.010064930688011366, 'strand_bias_max': 0.9040403827000162, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.3024284758534586}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:10,361] Trial 2997 finished with value: 313.23949604144036 and parameters: {'n_total_min': 20, 'depth_percentile_max': 99, 'mean_inset_qual_min': 24, 'mean_del_anchor_qual_min': 32, 'max_slippage_reads': 5, 'asxs_min': 31, 'mean_mapq_min': 33, 'avg_alt_nm_max': 4.157297560225295, 'dist_to_softclip_min': 5, 'variants_250bp_max': 10, 'ref_entropy_min': 0.8868304825651169, 'min_dist_to_indel': 24, 'min_rp_med': 0.019874618777115476, 'max_rp_med': 0.9665909649901382, 'max_n_count': 0.4039420252643124, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 37.919263787389745, 'mean_ref_mapq_min': 42.987340716395266, 'avg_nonaltread_variants_max': 5.413949235381294, 'sd_insert_max': 494.27857920454323, 'avg_read_position_min': 5.423444138048464, 'avg_read_position_max': 143.9472364858227, 'avg_read_length_min': 51.72135206462557, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.022125705358372973, 'strand_bias_max': 0.9247550034303624, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.00040462456539026425}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:10,551] Trial 2998 finished with value: 405.35768993644126 and parameters: {'n_total_min': 22, 'depth_percentile_max': 99, 'mean_inset_qual_min': 21, 'mean_del_anchor_qual_min': 44, 'max_slippage_reads': 5, 'asxs_min': 36, 'mean_mapq_min': 27, 'avg_alt_nm_max': 4.253049175278711, 'dist_to_softclip_min': 5, 'variants_250bp_max': 8, 'ref_entropy_min': 0.4913312717710573, 'min_dist_to_indel': 0, 'min_rp_med': 0.02221645762862043, 'max_rp_med': 0.9599074713408349, 'max_n_count': 0.2988058229498182, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 39.38867716785767, 'mean_ref_mapq_min': 39.811792312045746, 'avg_nonaltread_variants_max': 5.885471139491224, 'sd_insert_max': 540.5939847699553, 'avg_read_position_min': 1.6047622128447894, 'avg_read_position_max': 145.91227788166645, 'avg_read_length_min': 53.25070410349221, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.014563924552509887, 'strand_bias_max': 0.8917565557345949, 'rp_sd_min_alt': 5, 'rp_sd_min': 1.1757965526539418}. Best is trial 2454 with value: 286.8805111536298.
# [I 2026-04-24 17:51:10,735] Trial 2999 finished with value: 954.6377555975151 and parameters: {'n_total_min': 21, 'depth_percentile_max': 99, 'mean_inset_qual_min': 22, 'mean_del_anchor_qual_min': 21, 'max_slippage_reads': 5, 'asxs_min': 49, 'mean_mapq_min': 26, 'avg_alt_nm_max': 0.9703370311118353, 'dist_to_softclip_min': 5, 'variants_250bp_max': 9, 'ref_entropy_min': 0.9458752315527567, 'min_dist_to_indel': 18, 'min_rp_med': 0.017666994594901994, 'max_rp_med': 0.9625824827936025, 'max_n_count': 0.3615779961243297, 'germline_vaf_max': 0.2, 'avg_alt_read_mean_baseq_min': 44.46869533902994, 'mean_ref_mapq_min': 41.77862462275682, 'avg_nonaltread_variants_max': 4.919574935282543, 'sd_insert_max': 516.4061859993201, 'avg_read_position_min': 2.1505163335505273, 'avg_read_position_max': 143.1689095989893, 'avg_read_length_min': 118.51600799108942, 'strand_bias_n_alt_min': 4, 'strand_bias_min': 0.04883297308462958, 'strand_bias_max': 0.9178011249121294, 'rp_sd_min_alt': 5, 'rp_sd_min': 0.7187680465708715}. Best is trial 2454 with value: 286.8805111536298.
# [INFO] Best Weighted Deviance: 286.8805
# [INFO] Generating report...
# ------------------------------
# FINAL RESULTS
# ------------------------------
# Total Samples:         18
# Total Observed Indels: 629
# Total Expected Indels: 1068.43
# Weighted Deviance:     301.4619
# Mean Obs/Exp Ratio:    0.6494
# Blacklist Blocked:     0
# CB PON Blocked:        515
# ------------------------------
# INDEL METRICS (Passing Variants)
# ------------------------------
# Insertions: 0 | Deletions: 629
# INS / DEL Ratio:       0.000
# 1bp Indels: 330 | >1bp Indels: 299
# 1bp / >1bp Ratio:      1.104
# ------------------------------

# %%
def run_diagnostic_waterfall(df: pd.DataFrame):
    print("\n" + "="*40)
    print("   DYNAMIC FILTER WATERFALL DIAGNOSTIC")
    print("="*40)
    
    # 1. Define the absolute most relaxed thresholds from your search space
    t = {
        "n_total_min": 15, "depth_percentile_max": 99,
        "mean_inset_qual_min": 20, "mean_del_anchor_qual_min": 20,
        "hp_max_1bp": 6, "hp_max_long": 15, "max_slippage_reads": 5,
        "asxs_min": 10, "mean_mapq_min": 20, "avg_alt_nm_max": 5.0,
        "avg_alt_softclip_max": 5.0, "dist_to_softclip_min": 0,
        "variants_20bp_max": 4, "variants_250bp_max": 15,
        "ref_entropy_min": 0.0, "gc_min": 0.01, "gc_max": 0.99,
        "min_dist_to_indel": 0, "min_rp_med": 0.01, "max_rp_med": 0.99,
        "max_n_count": 3.0, "germline_vaf_max": 0.35,
        
        # New features (most relaxed limits)
        "sd_baseq_max": 50.0,
        "avg_alt_read_mean_baseq_min": 20.0,
        "mean_ref_mapq_min": 20.0,
        "avg_ref_asxs_min": 10.0,
        "avg_altread_variants_max": 5.0,
        "avg_nonaltread_variants_max": 10.0,
        "mean_insert_min": 0.0,
        "mean_insert_max": 1000.0,
        "sd_insert_max": 800.0,
        "avg_read_position_min": 0.0,
        "avg_read_position_max": 150.0,
        "avg_read_length_min": 50.0,
        
        # Conditional
        "strand_bias_n_alt_min": 10, "strand_bias_min": 0.0, "strand_bias_max": 1.0,
        "rp_sd_min_alt": 10, "rp_sd_min": 0.0
    }

    # 2. Define the exact conditions step-by-step
    is_ins = df['INDEL_LENGTH'] > 0
    is_del = df['INDEL_LENGTH'] < 0
    is_1bp = df['INDEL_LENGTH'].abs() == 1
    is_long = df['INDEL_LENGTH'].abs() > 1
    
    enough_reads_sb = df['N_ALT_SSCS'] >= t['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < t['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > t['strand_bias_max'])
    
    enough_reads_rp = df['N_ALT_SSCS'] >= t['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < t['rp_sd_min']

    steps = [
        ("N_TOTAL", df['N_TOTAL'] >= t['n_total_min']),
        ("DEPTH_PERCENTILE", df['DEPTH_PERCENTILE'] <= t['depth_percentile_max']),
        ("MEAN_MAPQ", df['MEAN_MAPQ'] >= t['mean_mapq_min']),
        ("AVG_ASXS", df['AVG_ASXS'] > t['asxs_min']),
        ("INSET/ANCHOR_QUAL", ((is_ins & (df['MEAN_INSET_QUAL'] >= t['mean_inset_qual_min'])) | 
                               (is_del & (df['MEAN_DEL_ANCHOR_QUAL'] >= t['mean_del_anchor_qual_min'])))),
        ("HOMOPOLYMER", ((is_1bp & (df['HOMOPOLYMER_LEN'] <= t['hp_max_1bp'])) | 
                         (is_long & (df['HOMOPOLYMER_LEN'] <= t['hp_max_long'])))),
        ("SLIPPAGE", df['N_SLIPPAGE_SSCS'] <= t['max_slippage_reads']),
        ("VARIANTS_20BP", df['VARIANTS_20BP'] <= t['variants_20bp_max']),
        ("VARIANTS_250BP", df['VARIANTS_250BP'] <= t['variants_250bp_max']),
        ("REF_ENTROPY", df['REF_ENTROPY_40BP'] >= t['ref_entropy_min']),
        ("ALT_SOFTCLIP", df['AVG_ALT_SOFTCLIP'] <= t['avg_alt_softclip_max']),
        ("DIST_SOFTCLIP", df['MEDIAN_DIST_TO_SOFTCLIP'] >= t['dist_to_softclip_min']),
        ("ALT_EXCESS_NM", df['AVG_ALT_EXCESS_NM'] <= t['avg_alt_nm_max']),
        ("GC_CONTENT", (df['GC_CONTENT'] >= t['gc_min']) & (df['GC_CONTENT'] <= t['gc_max'])),
        ("DIST_OTHER_INDEL", df['DIST_TO_OTHER_INDEL'] >= t['min_dist_to_indel']),
        ("RP_MED", (df['RP_MED_SSCS'] >= t['min_rp_med']) & (df['RP_MED_SSCS'] <= t['max_rp_med'])),
        ("ALT_N_COUNT", df['AVG_ALT_N_COUNT'] <= t['max_n_count']),
        ("GERMLINE_VAF", df['VAF_SSCS'] <= t['germline_vaf_max']),
        
        # NEW FEATURES
        ("SD_BASEQ", df['SD_BASEQ'] <= t['sd_baseq_max']),
        ("AVG_ALT_READ_MEAN_BASEQ", df['AVG_ALT_READ_MEAN_BASEQ'] >= t['avg_alt_read_mean_baseq_min']),
        ("MEAN_REF_MAPQ", df['MEAN_REF_MAPQ'] >= t['mean_ref_mapq_min']),
        ("AVG_REF_ASXS", df['AVG_REF_ASXS'] >= t['avg_ref_asxs_min']),
        ("AVG_ALTREAD_VARIANTS", df['AVG_ALTREAD_VARIANTS'] <= t['avg_altread_variants_max']),
        ("AVG_NONALTREAD_VARIANTS", df['AVG_NONALTREAD_VARIANTS'] <= t['avg_nonaltread_variants_max']),
        ("MEAN_INSERT", (df['MEAN_INSERT'] >= t['mean_insert_min']) & (df['MEAN_INSERT'] <= t['mean_insert_max'])),
        ("SD_INSERT", df['SD_INSERT'] <= t['sd_insert_max']),
        ("AVG_READ_POSITION", (df['AVG_READ_POSITION'] >= t['avg_read_position_min']) & (df['AVG_READ_POSITION'] <= t['avg_read_position_max'])),
        ("AVG_READ_LENGTH", df['AVG_READ_LENGTH'] >= t['avg_read_length_min']),
        
        # CONDITIONAL
        ("STRAND_BIAS", ~(enough_reads_sb & bad_bias)),
        ("RP_SD", ~(enough_reads_rp & bad_rp_sd))
    ]

    # 3. Apply sequentially and print drop-off
    current_mask = pd.Series([True] * len(df), index=df.index)
    print(f"{'FILTER STEP':<30} | {'REMAINING':<10} | {'DROPPED HERE':<10}")
    print("-" * 55)
    
    for name, condition in steps:
        prev_count = current_mask.sum()
        current_mask &= condition
        curr_count = current_mask.sum()
        dropped = prev_count - curr_count
        
        print(f"{name:<30} | {curr_count:<10} | {dropped:<10}")
        
        if curr_count == 0:
            print(f"\n[!] TERMINAL DROP: '{name}' killed all remaining variants.")
            break
            
    print("="*40 + "\n")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------
# Configuration
# -----------------------
CSV_PATH = "training_results_indels/observed_expected.csv"
OUTPUT_PNG = "training_results_indels/train_observed_vs_expected_plot.png"

# Check if file exists
if not os.path.exists(CSV_PATH):
    print(f"[ERROR] Could not find {CSV_PATH}. Please run the optimization cell first.")
else:
    # Load table
    df = pd.read_csv(CSV_PATH)

    # -----------------------
    # Data Processing & Aggregation
    # -----------------------
    # Identify cord blood samples
    is_cord = df['sample_type'].str.lower().str.contains('cord')
    
    df_cord = df[is_cord]
    df_other = df[~is_cord]

    # Calculate rates for non-cord samples
    ages = list(df_other["age"].values)
    obs_rates = list(df_other["observed"].values / df_other["bases"].values)
    exp_rates = list(df_other["expected"].values / df_other["bases"].values)

    # Aggregate cord samples if they exist
    if not df_cord.empty:
        total_cord_obs = df_cord["observed"].sum()
        total_cord_exp = df_cord["expected"].sum()
        total_cord_bases = df_cord["bases"].sum()
        
        # Append the aggregated cord blood point
        ages.append(0.0) # Cord blood is age 0
        obs_rates.append(total_cord_obs / total_cord_bases)
        exp_rates.append(total_cord_exp / total_cord_bases)

    # Convert back to numpy arrays for plotting
    ages = np.array(ages)
    obs_rates = np.array(obs_rates)
    exp_rates = np.array(exp_rates)

    # -----------------------
    # Plotting
    # -----------------------
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot Observed (Blue circles)
    ax.scatter(ages, obs_rates, label="Observed", color="#1f77b4", alpha=0.8, marker="o", s=60, edgecolors='k', linewidth=0.5)

    # Plot Expected (Orange crosses)
    ax.scatter(ages, exp_rates, label="Expected", color="#ff7f0e", alpha=0.8, marker="x", s=60, linewidth=2)

    # Styling
    ax.set_xlabel("Age (years)", fontsize=12)
    ax.set_ylabel("Indel rate (Indels per base)", fontsize=12) # Updated to Indel
    
    ax.set_xlim(-2, 100)
    ax.set_ylim(0, 2e-8)
    
    ax.set_title("Observed vs Expected Indel Rate (Training Set)", fontsize=14) # Updated to Indel
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Legend
    ax.legend(loc='upper left', frameon=True, fontsize=10)

    plt.tight_layout()
    
    # Save and Show
    plt.savefig(OUTPUT_PNG, dpi=150)
    print(f"[INFO] Plot saved to: {OUTPUT_PNG}")
    plt.show()
# Out:
# [INFO] Plot saved to: training_results_indels/train_observed_vs_expected_plot.png
