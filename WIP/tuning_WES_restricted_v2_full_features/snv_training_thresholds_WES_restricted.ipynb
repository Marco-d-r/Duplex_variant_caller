# %%
import csv
import gzip
import json
import math
import os
import sys
import random
import bisect
from typing import Dict, Any, List, Tuple

import numpy as np
import pandas as pd
import optuna

# -----------------------
# Configuration / Hardcoded Paths
# -----------------------
SAMPLES_CSV = "training_complete_processed_metadata.csv"
OUT_DIR = "training_results"
BLACKLIST_BED = "../../resources/master_blacklist.bed" 
ARTEFACT_GENES_BED = "../../resources/master_blacklist.bed"
EXOME_BED_PATH = "../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed" 
N_TRIALS = 3000
SEED = 42

# -----------------------
# Constants
# -----------------------
GENOME_SIZE = 6.4e9
R_CORD = 2e-8
EPS = 1e-15
CORD_WEIGHT = 3.0

# Set seeds
random.seed(SEED)
np.random.seed(SEED)

# -----------------------
# Math Helpers
# -----------------------
def poisson_deviance(y_arr: np.ndarray, lam_arr: np.ndarray, weights: np.ndarray = None) -> float:
    y = np.asarray(y_arr, dtype=float)
    lam = np.asarray(lam_arr, dtype=float) + EPS
    
    with np.errstate(divide='ignore', invalid='ignore'):
        log_term = np.log(y / lam)
        term1 = np.where(y > 0, y * log_term, 0.0)
    
    dev = 2.0 * (term1 - (y - lam))
    
    if weights is not None:
        dev = dev * weights
        
    return float(np.sum(dev))

def expected_lambda(sample_type: str, age: float, bases: float) -> float:
    st = sample_type.lower()
    current_age = float(age) if age is not None else 0.0
    
    if "cord" in st:
        rate = R_CORD
    elif "pbmc" in st:
        rate = (16 * current_age + 105) / GENOME_SIZE
    else:
        rate = (22 * current_age + 164) / GENOME_SIZE
        
    return rate * bases

# -----------------------
# BED File Lookup Logic
# -----------------------
class BedLookup:
    def __init__(self, bed_path: str, name: str):
        self.intervals = {} 
        self.name = name
        self._load_bed(bed_path)

    def _load_bed(self, bed_path: str):
        if not os.path.exists(bed_path):
            print(f"[WARN] BED file not found: {bed_path}. {self.name} filter will do nothing.", file=sys.stderr)
            return

        print(f"[INFO] Loading {self.name} from {bed_path}...")
        count = 0
        with open(bed_path, 'r') as f:
            for line in f:
                if line.startswith('#') or not line.strip():
                    continue
                parts = line.strip().split()
                if len(parts) < 3:
                    continue
                chrom = parts[0]
                start, end = int(parts[1]), int(parts[2])
                
                if chrom not in self.intervals:
                    self.intervals[chrom] = []
                self.intervals[chrom].append((start, end))
                count += 1
        
        for chrom in self.intervals:
            self.intervals[chrom].sort(key=lambda x: x[0])
        print(f"[INFO] Loaded {count} regions for {self.name}.")

    def is_overlapped(self, chrom: str, pos: int) -> bool:
        if chrom not in self.intervals:
            return False
        
        regions = self.intervals[chrom]
        query_idx = pos - 1 
        
        idx = bisect.bisect_right(regions, (query_idx, float('inf')))
        
        for i in range(max(0, idx - 1), -1, -1):
            start, end = regions[i]
            if end <= query_idx:
                break 
            if start <= query_idx < end:
                return True
        return False

# -----------------------
# VCF Parsing to DataFrame
# -----------------------
def parse_vcf_to_df(vcf_path: str, sample_id: str) -> pd.DataFrame:
    data = []
    
    if not os.path.exists(vcf_path):
        print(f"[WARN] File not found: {vcf_path}", file=sys.stderr)
        return pd.DataFrame()

    openf = gzip.open if vcf_path.endswith(".gz") else open
    
    try:
        with openf(vcf_path, "rt") as fh:
            for line in fh:
                if line.startswith("#"):
                    continue
                fields = line.strip().split("\t")
                
                chrom = fields[0]
                pos = int(fields[1])
                
                info_str = fields[7]
                info_dict = {}
                for item in info_str.split(";"):
                    if "=" in item:
                        k, v = item.split("=", 1)
                        info_dict[k] = v
                    else:
                        info_dict[item] = "Yes" 
                
                info_dict["sample_id"] = sample_id
                info_dict["CHROM"] = chrom
                info_dict["POS"] = pos
                data.append(info_dict)
    except Exception as e:
        print(f"[ERROR] Error reading {vcf_path}: {e}", file=sys.stderr)
        return pd.DataFrame()

    if not data:
        return pd.DataFrame()

    df = pd.DataFrame(data)
    
    # --- Type Conversion ---
    def to_num(col, dtype, default):
        if col in df.columns:
            return pd.to_numeric(df[col], errors='coerce').fillna(default).astype(dtype)
        return pd.Series([default]*len(df), index=df.index, dtype=dtype)

    def to_str(col, default):
        if col in df.columns:
            return df[col].fillna(default)
        return pd.Series([default]*len(df), index=df.index)

    df['CHROM'] = to_str('CHROM', 'chr1')
    df['POS'] = to_num('POS', int, 0)

    # 1. Base Counts
    df['N_ALT_SSCS'] = to_num('N_ALT_SSCS', int, 0)
    df['N_TOTAL'] = to_num('N_TOTAL', int, 0)
    df['N_ALT'] = to_num('N_ALT', int, 0) 
    df['N_TOTAL_SSCS'] = to_num('N_TOTAL_SSCS', int, 0)
    df['N_TOTAL_SSCS'] = np.where(df['N_TOTAL_SSCS'] <= 0, df['N_TOTAL'], df['N_TOTAL_SSCS'])

    df['DIST_TO_INDEL'] = to_num('DIST_TO_INDEL', int, -1)
    df['HOMOPOLYMER_LEN'] = to_num('HOMOPOLYMER_LEN', int, 0)
    df['DEPTH_PERCENTILE'] = to_num('DP_PERCENT', int, 50)

    # 2. Integer Metrics
    df['VARIANTS_20BP'] = to_num('VARIANTS_20BP', int, 0)
    df['VARIANTS_250BP'] = to_num('VARIANTS_250BP', int, 0)
    df['MEDIAN_DIST_TO_SOFTCLIP'] = to_num('MEDIAN_DIST_TO_SOFTCLIP', int, 1000)

    # 3. Float Metrics
    df['AVG_ASXS'] = to_num('AVG_ALT_ASXS', float, 0.0) 
    df['MEAN_MAPQ'] = to_num('MEAN_ALT_MAPQ', float, 0.0)
    df['MEAN_REF_MAPQ'] = to_num('MEAN_REF_MAPQ', float, 0.0) 
    df['MEAN_BASEQ'] = to_num('MEAN_ALT_BASEQ', float, 0.0) 
    df['SD_BASEQ'] = to_num('SD_ALT_BASEQ', float, 0.0)
    df['GC_CONTENT'] = to_num('GC_CONTENT', float, 0.5)
    df['STRAND_BIAS_SSCS'] = to_num('STRAND_BIAS_SSCS', float, 0.5)
    df['RP_SD_SSCS'] = to_num('RP_SD_SSCS', float, 0.0)
    df['RP_MED_SSCS'] = to_num('RP_MED_SSCS', float, 0.5)
    df['AVG_ALTREAD_VARIANTS'] = to_num('AVG_ALTREAD_VARIANTS', float, 0.0)
    df['AVG_NONALTREAD_VARIANTS'] = to_num('AVG_NONALTREAD_VARIANTS', float, 0.0)
    df['REF_ENTROPY_40BP'] = to_num('REF_ENTROPY_40BP', float, 2.0)
    df['AVG_ALT_SOFTCLIP'] = to_num('AVG_ALT_SOFTCLIP', float, 0.0)
    df['AVG_ALT_N_COUNT'] = to_num('AVG_ALT_N_COUNT', float, 0.0)
    df['AVG_ALT_NM'] = to_num('AVG_ALT_NM', float, 0.0)
    df['MEAN_INSERT'] = to_num('MEAN_INSERT', float, 200.0)
    df['SD_INSERT'] = to_num('SD_INSERT', float, 0)
    df['AVG_ALT_READ_MEAN_BQ'] = to_num('AVG_ALT_READ_MEAN_BQ', float, 0.0)
    
    # --- ADDED: READ POSITION ---
    df['AVG_READ_POSITION'] = to_num('AVG_READ_POSITION', float, 75.0)
    

    # 4. Flags
    df['IN_CORD_PON'] = to_str('IN_CB_PON', "No")
    df['IN_GNOMAD_COMMON'] = to_str('IN_GNOMAD_COMMON', "No")
    df['IN_ENCODE_BLACKLIST'] = to_str('IN_ENCODE_BLACKLIST', "No")
    df['IN_REPEATMASKER'] = to_str('IN_REPEATMASKER', "No")

    # 5. VAFs
    with np.errstate(divide='ignore', invalid='ignore'):
        df['VAF_DCS'] = df['N_ALT'] / df['N_TOTAL']
        df['VAF_DCS'] = df['VAF_DCS'].fillna(0.0)
        df['VAF_SSCS'] = df['N_ALT_SSCS'] / df['N_TOTAL_SSCS']
        df['VAF_SSCS'] = df['VAF_SSCS'].fillna(0.0)

    return df

# -----------------------
# Vectorized Filtering
# -----------------------
def get_passing_mask(df: pd.DataFrame, thresholds: Dict[str, Any], pon_flags: Dict[str, bool], ignore_blacklists: bool = False) -> pd.Series:
    # 1. BASELINE HARD FILTERS
    mask = (df['N_ALT_SSCS'] > 1) & \
           (df['IN_ENCODE_BLACKLIST'] != "Yes") & \
           (df['IN_REPEATMASKER'] != "Yes")
    
    # --- ADDED: OxoG / Read Position Hard Filter ---
    # Removes variants too close to the start (<4) or end (>138) of the read
    mask &= (df['AVG_READ_POSITION'] >= 4) & (df['AVG_READ_POSITION'] <= 138)

    if pon_flags.get("use_cord_pon", False):
        mask &= (df['IN_CORD_PON'] != "Yes")

    if not ignore_blacklists:
        mask &= (df['IN_CLUSTER_BLACKLIST'] == False)
        mask &= (df['IN_ARTEFACT_BLACKLIST'] == False)

    # 2. DEPTH
    mask &= (df['N_TOTAL'] >= thresholds['n_total_min'])
    mask &= (df['DEPTH_PERCENTILE'] <= thresholds['depth_percentile_max'])

    # 3. QUALITY METRICS
    mask &= (df['AVG_ASXS'] > thresholds['asxs_min'])
    mask &= (df['MEAN_MAPQ'] >= thresholds['mean_mapq_min'])
    mask &= (df['MEAN_REF_MAPQ'] >= thresholds['mean_ref_mapq_min'])
    mask &= (df['MEAN_BASEQ'] >= thresholds['mean_baseq_min'])
    mask &= (df['SD_BASEQ'] <= thresholds['sd_baseq_max'])
    mask &= (df['AVG_ALT_READ_MEAN_BQ'] >= thresholds['avg_alt_read_mean_bq_min'])
    mask &= ((df['DIST_TO_INDEL'] == -1) | (df['DIST_TO_INDEL'] >= thresholds['dist_to_indel_min']))

    # 4. TUNABLE FILTERS
    mask &= (df['VARIANTS_20BP'] <= thresholds['variants_20bp_max'])
    mask &= (df['VARIANTS_250BP'] <= thresholds['variants_250bp_max'])
    mask &= (df['REF_ENTROPY_40BP'] >= thresholds['ref_entropy_min'])
    mask &= (df['AVG_ALT_SOFTCLIP'] <= thresholds['avg_alt_softclip_max'])
    mask &= (df['MEDIAN_DIST_TO_SOFTCLIP'] >= thresholds['dist_to_softclip_min'])
    mask &= (df['AVG_ALT_N_COUNT'] <= thresholds['avg_alt_n_count_max'])
    mask &= (df['AVG_ALT_NM'] <= thresholds['avg_alt_nm_max'])
    mask &= (df['MEAN_INSERT'] <= thresholds['mean_insert_max'])
    mask &= (df['SD_INSERT'] <= thresholds['sd_insert_max'])

    # 5. CONTEXT & STRAND
    mask &= (df['GC_CONTENT'] >= thresholds['gc_content_min']) & (df['GC_CONTENT'] <= thresholds['gc_content_max'])
    mask &= (df['HOMOPOLYMER_LEN'] <= thresholds['homopolymer_len_max'])

    # Strand Bias 
    enough_reads_sb = df['N_ALT_SSCS'] >= thresholds['strand_bias_n_alt_min']
    bad_bias = (df['STRAND_BIAS_SSCS'] < thresholds['strand_bias_min']) | (df['STRAND_BIAS_SSCS'] > thresholds['strand_bias_max'])
    mask &= ~(enough_reads_sb & bad_bias)

    # RP SD 
    enough_reads_rp = df['N_ALT_SSCS'] >= thresholds['rp_sd_min_alt']
    bad_rp_sd = df['RP_SD_SSCS'] < thresholds['rp_sd_min']
    mask &= ~(enough_reads_rp & bad_rp_sd)

    # RP MED
    mask &= (df['RP_MED_SSCS'] > thresholds['rp_med_min']) & (df['RP_MED_SSCS'] < thresholds['rp_med_max'])

    # 6. COMPLEX LOGIC
    cond1 = df['AVG_ALTREAD_VARIANTS'] > thresholds['avg_altread_variants_max']
    cond2 = (df['AVG_ALTREAD_VARIANTS'] > thresholds['avg_altread_variants_max_for_high_vaf']) & \
            (df['VAF_DCS'] > thresholds['avg_altread_high_vaf_cutoff'])
    mask &= ~(cond1 | cond2)
    mask &= (df['AVG_NONALTREAD_VARIANTS'] <= thresholds['avg_nonaltread_variants_max'])

    # 7. GERMLINE & COMMON
    mask &= (df['VAF_SSCS'] <= thresholds['germline_vaf_max'])
    high_vaf_gnomad = (df['VAF_SSCS'] > thresholds['gnomad_vaf_cutoff'])
    is_common = (df['IN_GNOMAD_COMMON'] == "Yes") 
    mask &= ~(high_vaf_gnomad & is_common)

    return mask

# -----------------------
# Optimization Objective
# -----------------------
def make_objective(all_variants_df: pd.DataFrame, samples_meta: List[Dict]):
    
    expected_lambdas = []
    weights = []
    
    for s in samples_meta:
        expected_lambdas.append(expected_lambda(s['sample_type'], s['age'], s['bases']))
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)
            
    exp_arr = np.array(expected_lambdas)
    weights_arr = np.array(weights)

    def objective(trial):
        thresholds = {
            "germline_vaf_max": trial.suggest_float("germline_vaf_max", 0.20, 0.20),
            "gnomad_vaf_cutoff": trial.suggest_float("gnomad_vaf_cutoff", 0.10, 0.25),
            "depth_percentile_max": trial.suggest_int("depth_percentile_max", 95, 99),
            "variants_20bp_max": trial.suggest_int("variants_20bp_max", 0, 4),
            "variants_250bp_max": trial.suggest_int("variants_250bp_max", 0, 15),
            "ref_entropy_min": trial.suggest_float("ref_entropy_min", 0.0, 2.1),
            "avg_alt_softclip_max": trial.suggest_float("avg_alt_softclip_max", 0.0, 2.0),
            "dist_to_softclip_min": trial.suggest_int("dist_to_softclip_min", 0, 5),
            "avg_alt_n_count_max": trial.suggest_float("avg_alt_n_count_max", 0.0, 3.0),
            "avg_alt_nm_max": trial.suggest_float("avg_alt_nm_max", 0.0, 5.0),
            "mean_insert_max": trial.suggest_float("mean_insert_max", 80, 800.0),
            "sd_insert_max": trial.suggest_float("sd_insert_max", 0, 800.0),
            "asxs_min": trial.suggest_int("asxs_min", 10, 60),
            "mean_mapq_min": trial.suggest_int("mean_mapq_min", 20, 60),
            "mean_ref_mapq_min": trial.suggest_int("mean_ref_mapq_min", 10, 60),
            "dist_to_indel_min": trial.suggest_int("dist_to_indel_min", 0, 500),
            "mean_baseq_min": trial.suggest_int("mean_baseq_min", 20, 120),
            "sd_baseq_max": trial.suggest_int("sd_baseq_max", 0, 120),
            "avg_alt_read_mean_bq_min": trial.suggest_int("avg_alt_read_mean_bq_min", 20, 120),
            "gc_content_min": trial.suggest_float("gc_content_min", 0.0, 0.15),
            "gc_content_max": trial.suggest_float("gc_content_max", 0.85, 1.0),
            "strand_bias_n_alt_min": trial.suggest_int("strand_bias_n_alt_min", 1, 20),
            "strand_bias_min": trial.suggest_float("strand_bias_min", 0.0, 0.3),
            "strand_bias_max": trial.suggest_float("strand_bias_max", 0.7, 1.0),
            "rp_sd_min": trial.suggest_float("rp_sd_min", 0.0, 0.1),
            "rp_sd_min_alt": trial.suggest_int("rp_sd_min_alt", 1, 20),
            "homopolymer_len_max": trial.suggest_int("homopolymer_len_max", 0, 12),
            "avg_altread_variants_max": trial.suggest_float("avg_altread_variants_max", 0, 10.0),
            "avg_altread_variants_max_for_high_vaf": trial.suggest_float("avg_altread_variants_max_for_high_vaf", 0, 10.0),
            "avg_altread_high_vaf_cutoff": trial.suggest_float("avg_altread_high_vaf_cutoff", 0.05, 0.35),
            "avg_nonaltread_variants_max": trial.suggest_float("avg_nonaltread_variants_max", 0, 40.0),
            "n_total_min": trial.suggest_int("n_total_min", 20, 20),
            "rp_med_min": trial.suggest_float("rp_med_min", 0.01, 0.1),
            "rp_med_max": trial.suggest_float("rp_med_max", 0.9, 0.99),
        }

        pon_flags = {"use_cord_pon": True}

        pass_mask = get_passing_mask(all_variants_df, thresholds, pon_flags)
        obs_series = all_variants_df[pass_mask].groupby('sample_id').size()
        obs_arr = np.array([obs_series.get(s['sample_id'], 0) for s in samples_meta])

        loss = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
        return loss

    return objective

# -----------------------
# Reporting
# -----------------------
def evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, outdir):
    os.makedirs(outdir, exist_ok=True)
    
    pass_mask_final = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=False)
    pass_mask_clean = get_passing_mask(all_variants_df, best_thresholds, pon_flags, ignore_blacklists=True)
    
    variants_saved_by_blacklist = pass_mask_clean & (~pass_mask_final)
    count_saved_by_blacklist = variants_saved_by_blacklist.sum()

    obs_series = all_variants_df[pass_mask_final].groupby('sample_id').size()
    
    observed = []
    expected = []
    ids = []
    ages = []
    bases = []
    types = []
    weights = []

    for s in samples_meta:
        sid = s['sample_id']
        obs = obs_series.get(sid, 0)
        lam = expected_lambda(s['sample_type'], s['age'], s['bases'])
        
        ids.append(sid)
        observed.append(obs)
        expected.append(lam)
        ages.append(s['age'])
        bases.append(s['bases'])
        types.append(s['sample_type'])
        
        if "cord" in s['sample_type'].lower():
            weights.append(CORD_WEIGHT)
        else:
            weights.append(1.0)

    obs_arr = np.array(observed)
    exp_arr = np.array(expected)
    weights_arr = np.array(weights)

    with open(os.path.join(outdir, "best_thresholds.json"), "w") as fh:
        config_out = {
            "thresholds": best_thresholds, 
            "pon_flags": pon_flags,
            "blacklists_enforced": True,
            "cord_penalty_weight": CORD_WEIGHT
        }
        json.dump(config_out, fh, indent=2)

    ratio = obs_arr / (exp_arr + EPS)
    dev = poisson_deviance(obs_arr, exp_arr, weights=weights_arr)
    mean_ratio = float(np.mean(ratio))
    
    summary = {
        "n_samples": len(samples_meta),
        "obs_mean_over_expected": mean_ratio,
        "total_observed": int(np.sum(obs_arr)),
        "total_expected": float(np.sum(exp_arr)),
        "weighted_poisson_deviance": dev,
        "variants_blocked_by_blacklists": int(count_saved_by_blacklist)
    }
    with open(os.path.join(outdir, "summary.json"), "w") as fh:
        json.dump(summary, fh, indent=2)

    res_df = pd.DataFrame({
        "sample_id": ids,
        "sample_type": types,
        "age": ages,
        "bases": bases,
        "observed": observed,
        "expected": expected,
        "weight_used": weights 
    })
    res_df.to_csv(os.path.join(outdir, "observed_expected.csv"), index=False)
    
    print("-" * 30)
    print("FINAL RESULTS")
    print("-" * 30)
    print(f"Total Samples:      {len(samples_meta)}")
    print(f"Total Observed SNVs: {int(np.sum(obs_arr))}")
    print(f"Total Expected SNVs: {float(np.sum(exp_arr)):.2f}")
    print(f"Weighted Deviance:  {dev:.4f} (Cord weight = {CORD_WEIGHT}x)")
    print(f"Mean Obs/Exp Ratio: {mean_ratio:.4f}")
    print(f"Blacklist Blocked:  {count_saved_by_blacklist} variants (passed filters but hit blacklist)")
    print(f"Results saved to:   {outdir}")
    print("-" * 30)

# -----------------------
# Execution Block
# -----------------------
if __name__ == "__main__":
    print(f"[INFO] Reading metadata from {SAMPLES_CSV}...")
    samples_meta = []
    with open(SAMPLES_CSV, newline='') as csvfile:
        rdr = csv.DictReader(csvfile)
        for r in rdr:
            samples_meta.append({
                "sample_id": r["sample_id"],
                "vcf_path": r["vcf_path"],
                "sample_type": r["sample_type"].lower(),
                "age": float(r["age"]) if r.get("age") else None,
                "bases": float(r["total_callable_bases_in_wes"]),
            })
    print(f"[INFO] Loaded {len(samples_meta)} samples.")

    print("[INFO] Loading VCFs into DataFrame...")
    df_list = []
    for s in samples_meta:
        df_list.append(parse_vcf_to_df(s["vcf_path"], s["sample_id"]))

    if df_list:
        all_variants_df = pd.concat(df_list, ignore_index=True)
    else:
        print("[ERROR] No VCF data loaded. Checking paths in CSV.")
        all_variants_df = pd.DataFrame()

    print(f"[INFO] Total variants loaded: {len(all_variants_df)}")

    if not all_variants_df.empty:
        # --- NEW: Exome Inclusion Filter ---
        print("[INFO] Restricting variants to Exome targets...")
        bed_lookup_exome = BedLookup(EXOME_BED_PATH, "Exome Targets")
        
        # Create boolean mask for variants inside the exome
        in_exome_mask = all_variants_df.apply(
            lambda row: bed_lookup_exome.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        # Filter the dataframe to only keep variants in the exome
        pre_filter_count = len(all_variants_df)
        all_variants_df = all_variants_df[in_exome_mask].copy()
        post_filter_count = len(all_variants_df)
        print(f"[INFO] Exome filter retained {post_filter_count} out of {pre_filter_count} variants.")

        if all_variants_df.empty:
            print("[WARN] No variants left after applying Exome filter. Exiting.")
            sys.exit(0)
        # -----------------------------------

        bed_lookup_cluster = BedLookup(BLACKLIST_BED, "Cluster Blacklist")
        all_variants_df['IN_CLUSTER_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_cluster.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        bed_lookup_genes = BedLookup(ARTEFACT_GENES_BED, "Artefact Gene Blacklist")
        all_variants_df['IN_ARTEFACT_BLACKLIST'] = all_variants_df.apply(
            lambda row: bed_lookup_genes.is_overlapped(row['CHROM'], row['POS']), axis=1
        )
        
        hits_cluster = all_variants_df['IN_CLUSTER_BLACKLIST'].sum()
        hits_genes = all_variants_df['IN_ARTEFACT_BLACKLIST'].sum()
        print(f"[INFO] Found {hits_cluster} variants in Cluster blacklist.")
        print(f"[INFO] Found {hits_genes} variants in Artefact Gene blacklist.")

        print(f"[INFO] Starting Optuna (Trials={N_TRIALS})...")
        study = optuna.create_study(direction="minimize", sampler=optuna.samplers.TPESampler(seed=SEED))
        
        objective = make_objective(all_variants_df, samples_meta)
        study.optimize(objective, n_trials=N_TRIALS)

        print(f"[INFO] Best Weighted Deviance: {study.best_value:.4f}")

        best_params = study.best_params
        best_thresholds = {k: v for k, v in best_params.items()}
        pon_flags = {"use_cord_pon": True}
        
        print("[INFO] Generating report...")
        evaluate_and_report(best_thresholds, pon_flags, all_variants_df, samples_meta, OUT_DIR)
# Out:
# [INFO] Reading metadata from training_complete_processed_metadata.csv...
# [INFO] Loaded 18 samples.
# [INFO] Loading VCFs into DataFrame...
# [INFO] Total variants loaded: 1154904
# [INFO] Restricting variants to Exome targets...
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Exome filter retained 429190 out of 1154904 variants.
# [INFO] Loading Cluster Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Cluster Blacklist.
# [INFO] Loading Artefact Gene Blacklist from ../../resources/master_blacklist.bed...
# [INFO] Loaded 4208652 regions for Artefact Gene Blacklist.
# [I 2026-04-22 16:55:44,264] A new study created in memory with name: no-name-5f9351c7-85a9-4fdd-a929-7033c7375dcf
# [I 2026-04-22 16:55:44,392] Trial 0 finished with value: 6985.225241348401 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1561810178271044, 'depth_percentile_max': 99, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'ref_entropy_min': 0.3276391449291167, 'avg_alt_softclip_max': 0.3119890406724053, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 2.5985284373248057, 'avg_alt_nm_max': 3.005575058716044, 'mean_insert_max': 589.8122560131527, 'sd_insert_max': 16.467595436641957, 'asxs_min': 59, 'mean_mapq_min': 54, 'mean_ref_mapq_min': 20, 'dist_to_indel_min': 91, 'mean_baseq_min': 38, 'sd_baseq_max': 36, 'avg_alt_read_mean_bq_min': 73, 'gc_content_min': 0.06479175279631737, 'gc_content_max': 0.8936843710297063, 'strand_bias_n_alt_min': 13, 'strand_bias_min': 0.04184815819561255, 'strand_bias_max': 0.7876433945605654, 'rp_sd_min': 0.03663618432936917, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 10, 'avg_altread_variants_max': 1.9967378215835974, 'avg_altread_variants_max_for_high_vaf': 5.142344384136116, 'avg_altread_high_vaf_cutoff': 0.22772437065861273, 'avg_nonaltread_variants_max': 1.858016508799909, 'n_total_min': 20, 'rp_med_min': 0.06467903667112945, 'rp_med_max': 0.9153471711318563}. Best is trial 0 with value: 6985.225241348401.
# [INFO] Found 79201 variants in Cluster blacklist.
# [INFO] Found 79201 variants in Artefact Gene blacklist.
# [INFO] Starting Optuna (Trials=3000)...
# [I 2026-04-22 16:55:44,502] Trial 1 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10975773894779194, 'depth_percentile_max': 99, 'variants_20bp_max': 4, 'variants_250bp_max': 12, 'ref_entropy_min': 0.6396889152640785, 'avg_alt_softclip_max': 0.19534422801276774, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 1.320457481218804, 'avg_alt_nm_max': 0.6101911742238941, 'mean_insert_max': 436.52737528011454, 'sd_insert_max': 27.510816892174716, 'asxs_min': 56, 'mean_mapq_min': 30, 'mean_ref_mapq_min': 43, 'dist_to_indel_min': 156, 'mean_baseq_min': 72, 'sd_baseq_max': 66, 'avg_alt_read_mean_bq_min': 38, 'gc_content_min': 0.14543769416468377, 'gc_content_max': 0.9662699235041672, 'strand_bias_n_alt_min': 19, 'strand_bias_min': 0.26844820512829465, 'strand_bias_max': 0.8793699936433256, 'rp_sd_min': 0.09218742350231168, 'rp_sd_min_alt': 2, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 0.45227288910538066, 'avg_altread_variants_max_for_high_vaf': 3.2533033076326436, 'avg_altread_high_vaf_cutoff': 0.1666031869068446, 'avg_nonaltread_variants_max': 10.853961270955836, 'n_total_min': 20, 'rp_med_min': 0.08458637582367365, 'rp_med_max': 0.932107799402423}. Best is trial 0 with value: 6985.225241348401.
# [I 2026-04-22 16:55:44,612] Trial 2 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.14214017645310711, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 12, 'ref_entropy_min': 0.15655635172751872, 'avg_alt_softclip_max': 1.9737738732010346, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 0.5961470446025172, 'avg_alt_nm_max': 0.027610585618011996, 'mean_insert_max': 667.1322284874806, 'sd_insert_max': 565.4858750780937, 'asxs_min': 47, 'mean_mapq_min': 51, 'mean_ref_mapq_min': 13, 'dist_to_indel_min': 179, 'mean_baseq_min': 31, 'sd_baseq_max': 104, 'avg_alt_read_mean_bq_min': 82, 'gc_content_min': 0.04963470372789738, 'gc_content_max': 0.8595337525429035, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.09755499660802411, 'strand_bias_max': 0.9188818535014192, 'rp_sd_min': 0.06375574713552132, 'rp_sd_min_alt': 18, 'homopolymer_len_max': 6, 'avg_altread_variants_max': 1.195942459383017, 'avg_altread_variants_max_for_high_vaf': 7.13244787222995, 'avg_altread_high_vaf_cutoff': 0.27823551458506923, 'avg_nonaltread_variants_max': 22.45108790277985, 'n_total_min': 20, 'rp_med_min': 0.0793870461959105, 'rp_med_max': 0.9444416036727952}. Best is trial 0 with value: 6985.225241348401.
# [I 2026-04-22 16:55:44,744] Trial 3 finished with value: 6005.987963817511 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1784099244072991, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 1, 'ref_entropy_min': 0.06600128994214192, 'avg_alt_softclip_max': 1.2728208225275608, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.5257120734941083, 'avg_alt_nm_max': 4.537832369630465, 'mean_insert_max': 259.49040498718995, 'sd_insert_max': 328.3063384285038, 'asxs_min': 48, 'mean_mapq_min': 29, 'mean_ref_mapq_min': 13, 'dist_to_indel_min': 145, 'mean_baseq_min': 36, 'sd_baseq_max': 112, 'avg_alt_read_mean_bq_min': 101, 'gc_content_min': 0.09501056347656352, 'gc_content_max': 0.9807190885281577, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.05597101766581075, 'strand_bias_max': 0.9677676995469934, 'rp_sd_min': 0.05393422419156507, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 11, 'avg_altread_variants_max': 3.1800347497186388, 'avg_altread_variants_max_for_high_vaf': 1.1005192452767676, 'avg_altread_high_vaf_cutoff': 0.1183805487625825, 'avg_nonaltread_variants_max': 17.08431154505025, 'n_total_min': 20, 'rp_med_min': 0.08362132893302439, 'rp_med_max': 0.9774657524930709}. Best is trial 3 with value: 6005.987963817511.
# [I 2026-04-22 16:55:44,859] Trial 4 finished with value: 18684.165251470655 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10104281957967862, 'depth_percentile_max': 97, 'variants_20bp_max': 2, 'variants_250bp_max': 3, 'ref_entropy_min': 0.2517172714007339, 'avg_alt_softclip_max': 0.6752303428072559, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 0.9696087960622657, 'avg_alt_nm_max': 2.5939531087168306, 'mean_insert_max': 586.1736504045281, 'sd_insert_max': 290.9036819034352, 'asxs_min': 59, 'mean_mapq_min': 59, 'mean_ref_mapq_min': 22, 'dist_to_indel_min': 249, 'mean_baseq_min': 50, 'sd_baseq_max': 34, 'avg_alt_read_mean_bq_min': 23, 'gc_content_min': 0.09143465009698452, 'gc_content_max': 0.9254018534843292, 'strand_bias_n_alt_min': 2, 'strand_bias_min': 0.08359393927098342, 'strand_bias_max': 0.9724797657899961, 'rp_sd_min': 0.023956189066697244, 'rp_sd_min_alt': 3, 'homopolymer_len_max': 6, 'avg_altread_variants_max': 9.856504541106007, 'avg_altread_variants_max_for_high_vaf': 2.4205527151150044, 'avg_altread_high_vaf_cutoff': 0.25164066422176357, 'avg_nonaltread_variants_max': 30.4647846131487, 'n_total_min': 20, 'rp_med_min': 0.031387378959315974, 'rp_med_max': 0.9655394713750673}. Best is trial 3 with value: 6005.987963817511.
# [I 2026-04-22 16:55:44,968] Trial 5 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.155167469907888, 'depth_percentile_max': 98, 'variants_20bp_max': 3, 'variants_250bp_max': 8, 'ref_entropy_min': 0.18960851711425744, 'avg_alt_softclip_max': 1.670604991178476, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 0.5595555311995627, 'avg_alt_nm_max': 0.20387570777381958, 'mean_insert_max': 505.4429190955341, 'sd_insert_max': 542.0514894738259, 'asxs_min': 10, 'mean_mapq_min': 40, 'mean_ref_mapq_min': 21, 'dist_to_indel_min': 323, 'mean_baseq_min': 37, 'sd_baseq_max': 83, 'avg_alt_read_mean_bq_min': 59, 'gc_content_min': 0.14050949831051018, 'gc_content_max': 0.8706281416218989, 'strand_bias_n_alt_min': 7, 'strand_bias_min': 0.03404205637217672, 'strand_bias_max': 0.9774080854835688, 'rp_sd_min': 0.0877339353380981, 'rp_sd_min_alt': 6, 'homopolymer_len_max': 8, 'avg_altread_variants_max': 8.172222002012159, 'avg_altread_variants_max_for_high_vaf': 5.5520081159946235, 'avg_altread_high_vaf_cutoff': 0.20889517350680195, 'avg_nonaltread_variants_max': 9.674091636018067, 'n_total_min': 20, 'rp_med_min': 0.018379249102530932, 'rp_med_max': 0.9807494182157994}. Best is trial 3 with value: 6005.987963817511.
# [I 2026-04-22 16:55:45,079] Trial 6 finished with value: 15799.50362067789 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23506270857449957, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 5, 'ref_entropy_min': 1.5245069256275028, 'avg_alt_softclip_max': 1.7942205199051542, 'dist_to_softclip_min': 5, 'avg_alt_n_count_max': 2.339626637572872, 'avg_alt_nm_max': 3.2101582307714387, 'mean_insert_max': 140.58077479643515, 'sd_insert_max': 129.30297127569102, 'asxs_min': 55, 'mean_mapq_min': 44, 'mean_ref_mapq_min': 10, 'dist_to_indel_min': 50, 'mean_baseq_min': 87, 'sd_baseq_max': 0, 'avg_alt_read_mean_bq_min': 36, 'gc_content_min': 0.08231006840498792, 'gc_content_max': 0.953784279653904, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.06728079283816793, 'strand_bias_max': 0.9136537664042608, 'rp_sd_min': 0.02372490874968001, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 9, 'avg_altread_variants_max': 6.496328990472147, 'avg_altread_variants_max_for_high_vaf': 8.49223410494178, 'avg_altread_high_vaf_cutoff': 0.247283867690103, 'avg_nonaltread_variants_max': 22.732344133418863, 'n_total_min': 20, 'rp_med_min': 0.018430729104528323, 'rp_med_max': 0.933094422275349}. Best is trial 3 with value: 6005.987963817511.
# [I 2026-04-22 16:55:45,192] Trial 7 finished with value: 10144.002908858049 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1397803551522588, 'depth_percentile_max': 96, 'variants_20bp_max': 4, 'variants_250bp_max': 6, 'ref_entropy_min': 1.873297765871938, 'avg_alt_softclip_max': 1.2622772519945258, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 1.5079112793155764, 'avg_alt_nm_max': 2.8845194231317954, 'mean_insert_max': 434.612739549582, 'sd_insert_max': 156.1943902384356, 'asxs_min': 46, 'mean_mapq_min': 31, 'mean_ref_mapq_min': 11, 'dist_to_indel_min': 323, 'mean_baseq_min': 37, 'sd_baseq_max': 113, 'avg_alt_read_mean_bq_min': 116, 'gc_content_min': 0.13722965853306726, 'gc_content_max': 0.9055238050383166, 'strand_bias_n_alt_min': 1, 'strand_bias_min': 0.2784955687763176, 'strand_bias_max': 0.8284552444951943, 'rp_sd_min': 0.09666548190436697, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 11, 'avg_altread_variants_max': 2.944488920695857, 'avg_altread_variants_max_for_high_vaf': 3.8509772860192526, 'avg_altread_high_vaf_cutoff': 0.30534100145505705, 'avg_nonaltread_variants_max': 12.676880206251106, 'n_total_min': 20, 'rp_med_min': 0.025254347201748326, 'rp_med_max': 0.9501121136212515}. Best is trial 3 with value: 6005.987963817511.
# [I 2026-04-22 16:55:45,308] Trial 8 finished with value: 5964.390002599312 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24042321612411716, 'depth_percentile_max': 98, 'variants_20bp_max': 2, 'variants_250bp_max': 1, 'ref_entropy_min': 1.2915151760682566, 'avg_alt_softclip_max': 1.9801077002085266, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.55498895709121, 'avg_alt_nm_max': 4.386865359639777, 'mean_insert_max': 613.3534047830271, 'sd_insert_max': 557.6125927962144, 'asxs_min': 45, 'mean_mapq_min': 34, 'mean_ref_mapq_min': 24, 'dist_to_indel_min': 405, 'mean_baseq_min': 101, 'sd_baseq_max': 104, 'avg_alt_read_mean_bq_min': 112, 'gc_content_min': 0.07670135982914067, 'gc_content_max': 0.9252274442030799, 'strand_bias_n_alt_min': 16, 'strand_bias_min': 0.19498917923332953, 'strand_bias_max': 0.910590063177311, 'rp_sd_min': 0.07957926694361012, 'rp_sd_min_alt': 18, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 3.75582952639944, 'avg_altread_variants_max_for_high_vaf': 0.93981939840869, 'avg_altread_high_vaf_cutoff': 0.2234840422988522, 'avg_nonaltread_variants_max': 1.4376909518696834, 'n_total_min': 20, 'rp_med_min': 0.05190382163192142, 'rp_med_max': 0.9488380171236819}. Best is trial 8 with value: 5964.390002599312.
# [I 2026-04-22 16:55:45,418] Trial 9 finished with value: 20336.183582577956 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.14298118781924266, 'depth_percentile_max': 97, 'variants_20bp_max': 0, 'variants_250bp_max': 0, 'ref_entropy_min': 1.7274611773852824, 'avg_alt_softclip_max': 0.7203812828225258, 'dist_to_softclip_min': 0, 'avg_alt_n_count_max': 1.566729780164413, 'avg_alt_nm_max': 3.849967765493054, 'mean_insert_max': 235.39113979772708, 'sd_insert_max': 498.31238065520023, 'asxs_min': 14, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 37, 'dist_to_indel_min': 270, 'mean_baseq_min': 84, 'sd_baseq_max': 87, 'avg_alt_read_mean_bq_min': 118, 'gc_content_min': 0.0774450522451793, 'gc_content_max': 0.8984434709411869, 'strand_bias_n_alt_min': 16, 'strand_bias_min': 0.08124967537862227, 'strand_bias_max': 0.8316914262116908, 'rp_sd_min': 0.007845638134226595, 'rp_sd_min_alt': 1, 'homopolymer_len_max': 12, 'avg_altread_variants_max': 8.359801205122059, 'avg_altread_variants_max_for_high_vaf': 6.95974206093698, 'avg_altread_high_vaf_cutoff': 0.17268588332428098, 'avg_nonaltread_variants_max': 6.931772802833831, 'n_total_min': 20, 'rp_med_min': 0.024079333840397746, 'rp_med_max': 0.9225218608348136}. Best is trial 8 with value: 5964.390002599312.
# [I 2026-04-22 16:55:45,551] Trial 10 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.24692031161741337, 'depth_percentile_max': 95, 'variants_20bp_max': 2, 'variants_250bp_max': 3, 'ref_entropy_min': 1.1877874904309467, 'avg_alt_softclip_max': 1.4663966888090416, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.069924419974333, 'avg_alt_nm_max': 1.6739758811161822, 'mean_insert_max': 794.5011191314427, 'sd_insert_max': 789.8888418612958, 'asxs_min': 30, 'mean_mapq_min': 40, 'mean_ref_mapq_min': 57, 'dist_to_indel_min': 497, 'mean_baseq_min': 114, 'sd_baseq_max': 51, 'avg_alt_read_mean_bq_min': 94, 'gc_content_min': 0.004288739311809162, 'gc_content_max': 0.9361545714066606, 'strand_bias_n_alt_min': 20, 'strand_bias_min': 0.20384040108407575, 'strand_bias_max': 0.7581410610564053, 'rp_sd_min': 0.07256212466606883, 'rp_sd_min_alt': 15, 'homopolymer_len_max': 0, 'avg_altread_variants_max': 4.812884929660226, 'avg_altread_variants_max_for_high_vaf': 0.3307046226619228, 'avg_altread_high_vaf_cutoff': 0.3402309450396179, 'avg_nonaltread_variants_max': 37.92959907905214, 'n_total_min': 20, 'rp_med_min': 0.04683665666568754, 'rp_med_max': 0.9017612756006141}. Best is trial 8 with value: 5964.390002599312.
# [I 2026-04-22 16:55:45,679] Trial 11 finished with value: 8661.360907598153 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20611834019380348, 'depth_percentile_max': 98, 'variants_20bp_max': 1, 'variants_250bp_max': 0, 'ref_entropy_min': 0.9063298681870442, 'avg_alt_softclip_max': 1.0604679067692455, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 1.9653653292730133, 'avg_alt_nm_max': 4.994915572894791, 'mean_insert_max': 290.8232963150078, 'sd_insert_max': 367.97132777337185, 'asxs_min': 36, 'mean_mapq_min': 31, 'mean_ref_mapq_min': 29, 'dist_to_indel_min': 458, 'mean_baseq_min': 117, 'sd_baseq_max': 116, 'avg_alt_read_mean_bq_min': 99, 'gc_content_min': 0.11045173808115194, 'gc_content_max': 0.9969138387659117, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.16082393734109585, 'strand_bias_max': 0.7014220358959269, 'rp_sd_min': 0.05381813834410687, 'rp_sd_min_alt': 15, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 3.938371004774639, 'avg_altread_variants_max_for_high_vaf': 0.15486057430802846, 'avg_altread_high_vaf_cutoff': 0.08599367512565234, 'avg_nonaltread_variants_max': 1.088761055647872, 'n_total_min': 20, 'rp_med_min': 0.06037451564886874, 'rp_med_max': 0.9874909704746908}. Best is trial 8 with value: 5964.390002599312.
# [I 2026-04-22 16:55:45,812] Trial 12 finished with value: 4871.675743697949 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20434732970013295, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 2, 'ref_entropy_min': 1.327840754422442, 'avg_alt_softclip_max': 1.4307466755778608, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.9493584136889024, 'avg_alt_nm_max': 4.991503964851784, 'mean_insert_max': 319.36334187213276, 'sd_insert_max': 700.9451186822357, 'asxs_min': 38, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 29, 'dist_to_indel_min': 404, 'mean_baseq_min': 101, 'sd_baseq_max': 92, 'avg_alt_read_mean_bq_min': 100, 'gc_content_min': 0.03415968642096355, 'gc_content_max': 0.9905786935871705, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.19035308535571027, 'strand_bias_max': 0.9993924501104636, 'rp_sd_min': 0.07708717881022321, 'rp_sd_min_alt': 15, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 5.947473000759628, 'avg_altread_variants_max_for_high_vaf': 1.75671030796326, 'avg_altread_high_vaf_cutoff': 0.09417840790003887, 'avg_nonaltread_variants_max': 17.826536684461114, 'n_total_min': 20, 'rp_med_min': 0.09850111760225505, 'rp_med_max': 0.96692197281803}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:45,947] Trial 13 finished with value: 5328.975654835031 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.21759604627084694, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 3, 'ref_entropy_min': 1.3130943914887492, 'avg_alt_softclip_max': 1.5859895990719421, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.960506620310055, 'avg_alt_nm_max': 4.014444300556918, 'mean_insert_max': 361.14044278671656, 'sd_insert_max': 741.1215274041706, 'asxs_min': 33, 'mean_mapq_min': 22, 'mean_ref_mapq_min': 31, 'dist_to_indel_min': 398, 'mean_baseq_min': 99, 'sd_baseq_max': 89, 'avg_alt_read_mean_bq_min': 105, 'gc_content_min': 0.03296883737463205, 'gc_content_max': 0.999620474272146, 'strand_bias_n_alt_min': 10, 'strand_bias_min': 0.2100066020596013, 'strand_bias_max': 0.924126279823275, 'rp_sd_min': 0.07655881027493917, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 6.266003019192558, 'avg_altread_variants_max_for_high_vaf': 1.6729308121030058, 'avg_altread_high_vaf_cutoff': 0.053192208716698476, 'avg_nonaltread_variants_max': 28.812055613632346, 'n_total_min': 20, 'rp_med_min': 0.09814682442701535, 'rp_med_max': 0.9609899855782166}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:46,080] Trial 14 finished with value: 5196.8293307685935 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20936774832932561, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 4, 'ref_entropy_min': 0.8842466269714777, 'avg_alt_softclip_max': 1.5180037003938778, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.9974207659875884, 'avg_alt_nm_max': 3.772189288655036, 'mean_insert_max': 350.80873314561126, 'sd_insert_max': 732.4434041100225, 'asxs_min': 27, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 42, 'dist_to_indel_min': 394, 'mean_baseq_min': 101, 'sd_baseq_max': 84, 'avg_alt_read_mean_bq_min': 86, 'gc_content_min': 0.02512301570283663, 'gc_content_max': 0.9980582837592181, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.22876974481824863, 'strand_bias_max': 0.9973466902240716, 'rp_sd_min': 0.06988400644340148, 'rp_sd_min_alt': 12, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 6.801822504248029, 'avg_altread_variants_max_for_high_vaf': 2.268388528923691, 'avg_altread_high_vaf_cutoff': 0.05219420961212527, 'avg_nonaltread_variants_max': 29.12101550266425, 'n_total_min': 20, 'rp_med_min': 0.0991443555571954, 'rp_med_max': 0.9644685873854653}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:46,211] Trial 15 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.196570461333703, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 5, 'ref_entropy_min': 0.8703055041533313, 'avg_alt_softclip_max': 1.3791513054871485, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.9808981794965894, 'avg_alt_nm_max': 3.5929800846445277, 'mean_insert_max': 105.90065089711575, 'sd_insert_max': 663.4074868290713, 'asxs_min': 22, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 48, 'dist_to_indel_min': 388, 'mean_baseq_min': 61, 'sd_baseq_max': 62, 'avg_alt_read_mean_bq_min': 85, 'gc_content_min': 0.013739943786893721, 'gc_content_max': 0.9741255605332759, 'strand_bias_n_alt_min': 9, 'strand_bias_min': 0.2509776024874153, 'strand_bias_max': 0.9975110735369889, 'rp_sd_min': 0.06489622978952514, 'rp_sd_min_alt': 11, 'homopolymer_len_max': 0, 'avg_altread_variants_max': 6.230451786427599, 'avg_altread_variants_max_for_high_vaf': 3.7195034331262784, 'avg_altread_high_vaf_cutoff': 0.11962643734882217, 'avg_nonaltread_variants_max': 29.626069695055193, 'n_total_min': 20, 'rp_med_min': 0.09883801311025889, 'rp_med_max': 0.9660289716660737}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:46,346] Trial 16 finished with value: 9414.129672092045 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1885378294551175, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 15, 'ref_entropy_min': 0.636851903214455, 'avg_alt_softclip_max': 0.9910112524569148, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.54813788874798, 'avg_alt_nm_max': 1.949231937329363, 'mean_insert_max': 333.71672734235676, 'sd_insert_max': 679.7270891899888, 'asxs_min': 26, 'mean_mapq_min': 26, 'mean_ref_mapq_min': 41, 'dist_to_indel_min': 352, 'mean_baseq_min': 101, 'sd_baseq_max': 80, 'avg_alt_read_mean_bq_min': 65, 'gc_content_min': 0.02964186169678549, 'gc_content_max': 0.9538684313419494, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.13598206092856632, 'strand_bias_max': 0.9497413202269986, 'rp_sd_min': 0.04249903149032291, 'rp_sd_min_alt': 10, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 7.683250945343828, 'avg_altread_variants_max_for_high_vaf': 2.6052858159736973, 'avg_altread_high_vaf_cutoff': 0.06385558965818339, 'avg_nonaltread_variants_max': 39.67825861452992, 'n_total_min': 20, 'rp_med_min': 0.07352805174907348, 'rp_med_max': 0.9737512322074436}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:46,501] Trial 17 finished with value: 7478.346846757944 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.2180371941975589, 'depth_percentile_max': 95, 'variants_20bp_max': 3, 'variants_250bp_max': 6, 'ref_entropy_min': 1.5823719646467937, 'avg_alt_softclip_max': 1.0509435034932, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.688852753512618, 'avg_alt_nm_max': 4.906083017176, 'mean_insert_max': 180.25417670322423, 'sd_insert_max': 658.7413662968177, 'asxs_min': 40, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 52, 'dist_to_indel_min': 455, 'mean_baseq_min': 85, 'sd_baseq_max': 72, 'avg_alt_read_mean_bq_min': 87, 'gc_content_min': 0.04725789939815963, 'gc_content_max': 0.9871819454185896, 'strand_bias_n_alt_min': 13, 'strand_bias_min': 0.2348284456367266, 'strand_bias_max': 0.8737890528962456, 'rp_sd_min': 0.06585074564269527, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.421438557933518, 'avg_altread_variants_max_for_high_vaf': 2.0566637249603374, 'avg_altread_high_vaf_cutoff': 0.1118772673145122, 'avg_nonaltread_variants_max': 16.057966143607963, 'n_total_min': 20, 'rp_med_min': 0.0905719322114582, 'rp_med_max': 0.9561269119864183}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:46,664] Trial 18 finished with value: 43461.544704734064 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.21784926692509474, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 3, 'ref_entropy_min': 2.0643981751439053, 'avg_alt_softclip_max': 1.7091120483731694, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.197097508380007, 'avg_alt_nm_max': 4.350864128239697, 'mean_insert_max': 383.63725288066775, 'sd_insert_max': 458.55891587454755, 'asxs_min': 20, 'mean_mapq_min': 36, 'mean_ref_mapq_min': 34, 'dist_to_indel_min': 259, 'mean_baseq_min': 74, 'sd_baseq_max': 98, 'avg_alt_read_mean_bq_min': 55, 'gc_content_min': 0.01847545789219884, 'gc_content_max': 0.9563388939974041, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.15829204799157126, 'strand_bias_max': 0.9946081084384565, 'rp_sd_min': 0.08346035275223967, 'rp_sd_min_alt': 7, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 9.661968825805229, 'avg_altread_variants_max_for_high_vaf': 4.276443316174844, 'avg_altread_high_vaf_cutoff': 0.15072273375728204, 'avg_nonaltread_variants_max': 25.64674085752784, 'n_total_min': 20, 'rp_med_min': 0.0708460025860127, 'rp_med_max': 0.9711211333239442}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:46,811] Trial 19 finished with value: 10625.590454188185 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17668890259036477, 'depth_percentile_max': 95, 'variants_20bp_max': 0, 'variants_250bp_max': 2, 'ref_entropy_min': 1.033754180664748, 'avg_alt_softclip_max': 0.8465317599401053, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 0.1964110586262855, 'avg_alt_nm_max': 3.532444496763324, 'mean_insert_max': 495.88658924304104, 'sd_insert_max': 795.8526703337268, 'asxs_min': 39, 'mean_mapq_min': 47, 'mean_ref_mapq_min': 44, 'dist_to_indel_min': 450, 'mean_baseq_min': 108, 'sd_baseq_max': 49, 'avg_alt_read_mean_bq_min': 74, 'gc_content_min': 0.05440559261568892, 'gc_content_max': 0.9853580320431359, 'strand_bias_n_alt_min': 5, 'strand_bias_min': 0.12565825109203715, 'strand_bias_max': 0.9440917978773095, 'rp_sd_min': 0.09998477853784107, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 2, 'avg_altread_variants_max': 7.3118201145065465, 'avg_altread_variants_max_for_high_vaf': 9.561571634722654, 'avg_altread_high_vaf_cutoff': 0.08454160640845876, 'avg_nonaltread_variants_max': 34.8737082598309, 'n_total_min': 20, 'rp_med_min': 0.09162048636035623, 'rp_med_max': 0.9834540781072383}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:46,954] Trial 20 finished with value: 8551.571729539102 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.20167503812639914, 'depth_percentile_max': 96, 'variants_20bp_max': 1, 'variants_250bp_max': 10, 'ref_entropy_min': 0.6397909911242682, 'avg_alt_softclip_max': 1.5270556561032576, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 1.829893614624119, 'avg_alt_nm_max': 2.0163450579499735, 'mean_insert_max': 206.709209466145, 'sd_insert_max': 634.9230973850612, 'asxs_min': 29, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 60, 'dist_to_indel_min': 499, 'mean_baseq_min': 92, 'sd_baseq_max': 6, 'avg_alt_read_mean_bq_min': 106, 'gc_content_min': 0.03120756266829728, 'gc_content_max': 0.9409982984588136, 'strand_bias_n_alt_min': 8, 'strand_bias_min': 0.2938708516235972, 'strand_bias_max': 0.8660136126017979, 'rp_sd_min': 0.04815653333016692, 'rp_sd_min_alt': 15, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 4.935627959094585, 'avg_altread_variants_max_for_high_vaf': 3.0398975842429667, 'avg_altread_high_vaf_cutoff': 0.14254950422518473, 'avg_nonaltread_variants_max': 17.992304665387326, 'n_total_min': 20, 'rp_med_min': 0.09128882181379418, 'rp_med_max': 0.9391747725329711}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:47,097] Trial 21 finished with value: 5211.644436062741 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22020903742476505, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 5, 'ref_entropy_min': 1.3387513108258646, 'avg_alt_softclip_max': 1.5801344560783182, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.9009575722130267, 'avg_alt_nm_max': 3.939413016764602, 'mean_insert_max': 350.72057826750876, 'sd_insert_max': 735.0415779053552, 'asxs_min': 34, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 30, 'dist_to_indel_min': 388, 'mean_baseq_min': 98, 'sd_baseq_max': 94, 'avg_alt_read_mean_bq_min': 92, 'gc_content_min': 0.034714252458568115, 'gc_content_max': 0.999691087401142, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.2074055819899599, 'strand_bias_max': 0.9374841967908479, 'rp_sd_min': 0.0773427472712974, 'rp_sd_min_alt': 13, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 6.9831802687636, 'avg_altread_variants_max_for_high_vaf': 1.4363245184677713, 'avg_altread_high_vaf_cutoff': 0.057033962003797685, 'avg_nonaltread_variants_max': 28.266116510272827, 'n_total_min': 20, 'rp_med_min': 0.09907147828904479, 'rp_med_max': 0.9593772423197926}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:47,232] Trial 22 finished with value: 12774.057263229455 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.23146724280238926, 'depth_percentile_max': 95, 'variants_20bp_max': 1, 'variants_250bp_max': 5, 'ref_entropy_min': 1.5208222585793854, 'avg_alt_softclip_max': 1.2127511888354239, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.803400899544906, 'avg_alt_nm_max': 4.14712408450658, 'mean_insert_max': 321.30653447492494, 'sd_insert_max': 716.7849475770267, 'asxs_min': 24, 'mean_mapq_min': 20, 'mean_ref_mapq_min': 27, 'dist_to_indel_min': 334, 'mean_baseq_min': 120, 'sd_baseq_max': 95, 'avg_alt_read_mean_bq_min': 93, 'gc_content_min': 0.00223740095672606, 'gc_content_max': 0.9693711884297174, 'strand_bias_n_alt_min': 11, 'strand_bias_min': 0.1793487684222334, 'strand_bias_max': 0.9998495307806189, 'rp_sd_min': 0.07330135809451585, 'rp_sd_min_alt': 11, 'homopolymer_len_max': 1, 'avg_altread_variants_max': 7.003051045204371, 'avg_altread_variants_max_for_high_vaf': 1.5131684466384936, 'avg_altread_high_vaf_cutoff': 0.08007151551753772, 'avg_nonaltread_variants_max': 33.397315606921794, 'n_total_min': 20, 'rp_med_min': 0.09806511804368218, 'rp_med_max': 0.9568039668893035}. Best is trial 12 with value: 4871.675743697949.
# [I 2026-04-22 16:55:47,370] Trial 23 finished with value: 4815.004744370985 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.22287709633379657, 'depth_percentile_max': 95, 'variants_20bp_max': 2, 'variants_250bp_max': 7, 'ref_entropy_min': 1.1196015925645517, 'avg_alt_softclip_max': 1.8231276392225129, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.436652385495095, 'avg_alt_nm_max': 4.697683535632078, 'mean_insert_max': 394.9694734425412, 'sd_insert_max': 607.884061117503, 'asxs_min': 34, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 36, 'dist_to_indel_min': 374, 'mean_baseq_min': 108, 'sd_baseq_max': 75, 'avg_alt_read_mean_bq_min': 76, 'gc_content_min': 0.04171069036207906, 'gc_content_max': 0.9993477764496899, 'strand_bias_n_alt_min': 12, 'strand_bias_min': 0.2301735772332391, 'strand_bias_max': 0.9470340139432087, 'rp_sd_min': 0.08666233716813064, 'rp_sd_min_alt': 16, 'homopolymer_len_max': 3, 'avg_altread_variants_max': 8.700483076100054, 'avg_altread_variants_max_for_high_vaf': 0.8311935232137772, 'avg_altread_high_vaf_cutoff': 0.051844929336830936, 'avg_nonaltread_variants_max': 26.139807517400534, 'n_total_min': 20, 'rp_med_min': 0.03985594018643084, 'rp_med_max': 0.9680972199473764}. Best is trial 23 with value: 4815.004744370985.
# [I 2026-04-22 16:55:47,512] Trial 24 finished with value: 3914.3765882200746 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.18913155083272581, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 7, 'ref_entropy_min': 1.0617734058929824, 'avg_alt_softclip_max': 1.8257447865424308, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.4292687855718444, 'avg_alt_nm_max': 4.637966647419481, 'mean_insert_max': 511.86643752535974, 'sd_insert_max': 586.2020216865567, 'asxs_min': 40, 'mean_mapq_min': 26, 'mean_ref_mapq_min': 37, 'dist_to_indel_min': 288, 'mean_baseq_min': 107, 'sd_baseq_max': 73, 'avg_alt_read_mean_bq_min': 78, 'gc_content_min': 0.062265901736487744, 'gc_content_max': 0.9835808763715724, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.0035447395176352314, 'strand_bias_max': 0.9600071130650362, 'rp_sd_min': 0.09039035970211357, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 8.924381181832608, 'avg_altread_variants_max_for_high_vaf': 0.24333371890062905, 'avg_altread_high_vaf_cutoff': 0.10256224592922171, 'avg_nonaltread_variants_max': 21.710251239639994, 'n_total_min': 20, 'rp_med_min': 0.042612853673636715, 'rp_med_max': 0.9708379733729388}. Best is trial 24 with value: 3914.3765882200746.
# [I 2026-04-22 16:55:47,644] Trial 25 finished with value: 3777.223557511177 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1887705404237983, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 7, 'ref_entropy_min': 1.1160095062958044, 'avg_alt_softclip_max': 1.804048488445178, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.38233779026393, 'avg_alt_nm_max': 4.750848788237356, 'mean_insert_max': 507.6303796371784, 'sd_insert_max': 604.439474664578, 'asxs_min': 41, 'mean_mapq_min': 27, 'mean_ref_mapq_min': 35, 'dist_to_indel_min': 215, 'mean_baseq_min': 109, 'sd_baseq_max': 72, 'avg_alt_read_mean_bq_min': 76, 'gc_content_min': 0.06108255511508708, 'gc_content_max': 0.9815943150635877, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.006316856912511971, 'strand_bias_max': 0.9591346853635838, 'rp_sd_min': 0.08711605583260557, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 8.785918264301962, 'avg_altread_variants_max_for_high_vaf': 0.06751246427165436, 'avg_altread_high_vaf_cutoff': 0.09958493984102912, 'avg_nonaltread_variants_max': 21.483925329435333, 'n_total_min': 20, 'rp_med_min': 0.038206870115356166, 'rp_med_max': 0.9886769759358885}. Best is trial 25 with value: 3777.223557511177.
# [I 2026-04-22 16:55:47,778] Trial 26 finished with value: 3906.744333269428 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.19037273964459886, 'depth_percentile_max': 96, 'variants_20bp_max': 2, 'variants_250bp_max': 8, 'ref_entropy_min': 1.1212858274787254, 'avg_alt_softclip_max': 1.830819995875318, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.4336172853024407, 'avg_alt_nm_max': 4.547303131269495, 'mean_insert_max': 506.41873519468186, 'sd_insert_max': 607.3557010689798, 'asxs_min': 43, 'mean_mapq_min': 27, 'mean_ref_mapq_min': 37, 'dist_to_indel_min': 208, 'mean_baseq_min': 109, 'sd_baseq_max': 53, 'avg_alt_read_mean_bq_min': 54, 'gc_content_min': 0.06368847278936624, 'gc_content_max': 0.9769353441381141, 'strand_bias_n_alt_min': 14, 'strand_bias_min': 0.0015008219896184526, 'strand_bias_max': 0.8923214397961354, 'rp_sd_min': 0.0873442110602753, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 9.108237163106928, 'avg_altread_variants_max_for_high_vaf': 0.02884349496150214, 'avg_altread_high_vaf_cutoff': 0.13441063269443299, 'avg_nonaltread_variants_max': 25.729127772372774, 'n_total_min': 20, 'rp_med_min': 0.04041130258027217, 'rp_med_max': 0.9864825960147868}. Best is trial 25 with value: 3777.223557511177.
# [I 2026-04-22 16:55:47,911] Trial 27 finished with value: 3653.876964221866 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16678879655860201, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 10, 'ref_entropy_min': 0.4575194679284381, 'avg_alt_softclip_max': 1.8315303521510775, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.2770637084737517, 'avg_alt_nm_max': 4.532910532330169, 'mean_insert_max': 503.2983333566641, 'sd_insert_max': 456.41553133517016, 'asxs_min': 42, 'mean_mapq_min': 35, 'mean_ref_mapq_min': 38, 'dist_to_indel_min': 220, 'mean_baseq_min': 20, 'sd_baseq_max': 50, 'avg_alt_read_mean_bq_min': 53, 'gc_content_min': 0.06327734456981897, 'gc_content_max': 0.963178751307347, 'strand_bias_n_alt_min': 15, 'strand_bias_min': 0.0053592711666949015, 'strand_bias_max': 0.905920007523626, 'rp_sd_min': 0.09210929729981246, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 8.851376194770182, 'avg_altread_variants_max_for_high_vaf': 0.023376990361079885, 'avg_altread_high_vaf_cutoff': 0.13150303130518995, 'avg_nonaltread_variants_max': 21.874728859750665, 'n_total_min': 20, 'rp_med_min': 0.039256360711051236, 'rp_med_max': 0.9890206507676264}. Best is trial 27 with value: 3653.876964221866.
# [I 2026-04-22 16:55:48,044] Trial 28 finished with value: 7352.5394419834865 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16540653614429404, 'depth_percentile_max': 96, 'variants_20bp_max': 3, 'variants_250bp_max': 11, 'ref_entropy_min': 0.46635925669766076, 'avg_alt_softclip_max': 1.985471739384033, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 1.7979110170344323, 'avg_alt_nm_max': 1.1707714606199686, 'mean_insert_max': 704.6528118263718, 'sd_insert_max': 427.88790188785117, 'asxs_min': 51, 'mean_mapq_min': 38, 'mean_ref_mapq_min': 47, 'dist_to_indel_min': 212, 'mean_baseq_min': 24, 'sd_baseq_max': 31, 'avg_alt_read_mean_bq_min': 49, 'gc_content_min': 0.06302608909337903, 'gc_content_max': 0.9631430055360874, 'strand_bias_n_alt_min': 15, 'strand_bias_min': 0.004013329510054193, 'strand_bias_max': 0.8955494186015615, 'rp_sd_min': 0.09512321137362338, 'rp_sd_min_alt': 19, 'homopolymer_len_max': 8, 'avg_altread_variants_max': 9.218746100464234, 'avg_altread_variants_max_for_high_vaf': 0.04825655075019978, 'avg_altread_high_vaf_cutoff': 0.18560362903534308, 'avg_nonaltread_variants_max': 24.68714869856183, 'n_total_min': 20, 'rp_med_min': 0.035339753659877446, 'rp_med_max': 0.9876348040932795}. Best is trial 27 with value: 3653.876964221866.
# [I 2026-04-22 16:55:48,182] Trial 29 finished with value: 3725.935544878377 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.1629516550105898, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'ref_entropy_min': 0.4447845741828707, 'avg_alt_softclip_max': 0.032301814186069366, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.1784302776864126, 'avg_alt_nm_max': 3.171625498919618, 'mean_insert_max': 578.27127272652, 'sd_insert_max': 502.8203675178496, 'asxs_min': 43, 'mean_mapq_min': 34, 'mean_ref_mapq_min': 33, 'dist_to_indel_min': 107, 'mean_baseq_min': 53, 'sd_baseq_max': 48, 'avg_alt_read_mean_bq_min': 68, 'gc_content_min': 0.10417289899423607, 'gc_content_max': 0.9422206218688953, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.03197728708946432, 'strand_bias_max': 0.8498651154611794, 'rp_sd_min': 0.061436759204323066, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 7.834134258416178, 'avg_altread_variants_max_for_high_vaf': 4.950995670386447, 'avg_altread_high_vaf_cutoff': 0.13760094570671222, 'avg_nonaltread_variants_max': 14.435452620044453, 'n_total_min': 20, 'rp_med_min': 0.05834872345169097, 'rp_med_max': 0.9888963336776475}. Best is trial 27 with value: 3653.876964221866.
# [I 2026-04-22 16:55:48,317] Trial 30 finished with value: 4392.194686700645 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.12725698211804481, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 9, 'ref_entropy_min': 0.426598865743297, 'avg_alt_softclip_max': 0.5411039546680498, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 2.1964810782740822, 'avg_alt_nm_max': 3.1336610238644274, 'mean_insert_max': 587.830821509173, 'sd_insert_max': 494.3708653754052, 'asxs_min': 51, 'mean_mapq_min': 34, 'mean_ref_mapq_min': 33, 'dist_to_indel_min': 105, 'mean_baseq_min': 48, 'sd_baseq_max': 24, 'avg_alt_read_mean_bq_min': 66, 'gc_content_min': 0.11366137824928904, 'gc_content_max': 0.9410384059657595, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.039828243141545545, 'strand_bias_max': 0.7965630640240098, 'rp_sd_min': 0.06096390065228528, 'rp_sd_min_alt': 18, 'homopolymer_len_max': 9, 'avg_altread_variants_max': 7.913742601625722, 'avg_altread_variants_max_for_high_vaf': 5.074370956944201, 'avg_altread_high_vaf_cutoff': 0.16342481976890377, 'avg_nonaltread_variants_max': 5.985261814754471, 'n_total_min': 20, 'rp_med_min': 0.055819150644563206, 'rp_med_max': 0.9767107664157461}. Best is trial 27 with value: 3653.876964221866.
# [I 2026-04-22 16:55:48,448] Trial 31 finished with value: 3287.9622960079696 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16424492320138057, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 9, 'ref_entropy_min': 0.7396194164533956, 'avg_alt_softclip_max': 0.03788214270158552, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.6259298596446095, 'avg_alt_nm_max': 4.256491361123167, 'mean_insert_max': 547.7312554444293, 'sd_insert_max': 488.75314484952173, 'asxs_min': 43, 'mean_mapq_min': 34, 'mean_ref_mapq_min': 39, 'dist_to_indel_min': 208, 'mean_baseq_min': 49, 'sd_baseq_max': 50, 'avg_alt_read_mean_bq_min': 47, 'gc_content_min': 0.06786557926865365, 'gc_content_max': 0.9754464344026708, 'strand_bias_n_alt_min': 13, 'strand_bias_min': 0.02704371712023027, 'strand_bias_max': 0.846885030499674, 'rp_sd_min': 0.08362378978546635, 'rp_sd_min_alt': 20, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 9.260516587517749, 'avg_altread_variants_max_for_high_vaf': 5.947832092558965, 'avg_altread_high_vaf_cutoff': 0.13559905771791347, 'avg_nonaltread_variants_max': 14.798136257849226, 'n_total_min': 20, 'rp_med_min': 0.010001358926199487, 'rp_med_max': 0.989594210139263}. Best is trial 31 with value: 3287.9622960079696.
# [I 2026-04-22 16:55:48,577] Trial 32 finished with value: 3566.8368175907963 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16444151751712585, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 10, 'ref_entropy_min': 0.7018543226525498, 'avg_alt_softclip_max': 0.06240891451490793, 'dist_to_softclip_min': 3, 'avg_alt_n_count_max': 2.624585608693833, 'avg_alt_nm_max': 3.431360212515037, 'mean_insert_max': 547.206304522305, 'sd_insert_max': 391.0355659485889, 'asxs_min': 43, 'mean_mapq_min': 33, 'mean_ref_mapq_min': 40, 'dist_to_indel_min': 112, 'mean_baseq_min': 50, 'sd_baseq_max': 43, 'avg_alt_read_mean_bq_min': 39, 'gc_content_min': 0.08934350198888617, 'gc_content_max': 0.9606089098588038, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.025492976634817067, 'strand_bias_max': 0.8360361888153235, 'rp_sd_min': 0.08248698077632005, 'rp_sd_min_alt': 19, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 9.882408433085617, 'avg_altread_variants_max_for_high_vaf': 5.873753958304445, 'avg_altread_high_vaf_cutoff': 0.1316060221355398, 'avg_nonaltread_variants_max': 13.905004029554268, 'n_total_min': 20, 'rp_med_min': 0.010382267624133334, 'rp_med_max': 0.9897209586596148}. Best is trial 31 with value: 3287.9622960079696.
# [I 2026-04-22 16:55:48,707] Trial 33 finished with value: 3621.660274397729 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.16313878759095848, 'depth_percentile_max': 97, 'variants_20bp_max': 3, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7087160333918966, 'avg_alt_softclip_max': 0.045473342171116884, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 2.6111056604039917, 'avg_alt_nm_max': 3.3698165351827396, 'mean_insert_max': 657.9364095452319, 'sd_insert_max': 262.9492064041395, 'asxs_min': 43, 'mean_mapq_min': 35, 'mean_ref_mapq_min': 39, 'dist_to_indel_min': 4, 'mean_baseq_min': 47, 'sd_baseq_max': 43, 'avg_alt_read_mean_bq_min': 37, 'gc_content_min': 0.10549470002168504, 'gc_content_max': 0.9617871508396072, 'strand_bias_n_alt_min': 20, 'strand_bias_min': 0.029606914023291873, 'strand_bias_max': 0.8441328683736069, 'rp_sd_min': 0.08077924407769893, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 7, 'avg_altread_variants_max': 9.957118660536429, 'avg_altread_variants_max_for_high_vaf': 5.989380452397732, 'avg_altread_high_vaf_cutoff': 0.18939370523642168, 'avg_nonaltread_variants_max': 13.310158658539777, 'n_total_min': 20, 'rp_med_min': 0.010168409795168662, 'rp_med_max': 0.9806196050582894}. Best is trial 31 with value: 3287.9622960079696.
# [I 2026-04-22 16:55:48,842] Trial 34 finished with value: 3785.026564434515 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.15224156736117875, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 14, 'ref_entropy_min': 0.7174837635168512, 'avg_alt_softclip_max': 0.30577743923573264, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 2.6337966557667793, 'avg_alt_nm_max': 3.5800807182910663, 'mean_insert_max': 657.1910612722606, 'sd_insert_max': 241.74039506382704, 'asxs_min': 50, 'mean_mapq_min': 37, 'mean_ref_mapq_min': 41, 'dist_to_indel_min': 19, 'mean_baseq_min': 23, 'sd_baseq_max': 41, 'avg_alt_read_mean_bq_min': 41, 'gc_content_min': 0.0869215205421824, 'gc_content_max': 0.9682454779690197, 'strand_bias_n_alt_min': 20, 'strand_bias_min': 0.05427283174690045, 'strand_bias_max': 0.7988503588387419, 'rp_sd_min': 0.08268910094735195, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 8, 'avg_altread_variants_max': 9.944832873124966, 'avg_altread_variants_max_for_high_vaf': 6.070428758682584, 'avg_altread_high_vaf_cutoff': 0.20188857862687604, 'avg_nonaltread_variants_max': 9.919098759819335, 'n_total_min': 20, 'rp_med_min': 0.011857573557680759, 'rp_med_max': 0.9810899342838129}. Best is trial 31 with value: 3287.9622960079696.
# [I 2026-04-22 16:55:48,978] Trial 35 finished with value: 4856.976869161504 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.17060452506729587, 'depth_percentile_max': 99, 'variants_20bp_max': 3, 'variants_250bp_max': 13, 'ref_entropy_min': 0.7484910700910359, 'avg_alt_softclip_max': 0.03246729246941095, 'dist_to_softclip_min': 4, 'avg_alt_n_count_max': 2.714125822105787, 'avg_alt_nm_max': 2.6795946253573586, 'mean_insert_max': 715.1423157851639, 'sd_insert_max': 370.20336403204766, 'asxs_min': 54, 'mean_mapq_min': 43, 'mean_ref_mapq_min': 47, 'dist_to_indel_min': 140, 'mean_baseq_min': 44, 'sd_baseq_max': 21, 'avg_alt_read_mean_bq_min': 30, 'gc_content_min': 0.09861979896623135, 'gc_content_max': 0.9607273922199497, 'strand_bias_n_alt_min': 19, 'strand_bias_min': 0.022039681939680214, 'strand_bias_max': 0.8430609760959723, 'rp_sd_min': 0.09945646249536456, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 6, 'avg_altread_variants_max': 9.35025905579056, 'avg_altread_variants_max_for_high_vaf': 6.978118608369353, 'avg_altread_high_vaf_cutoff': 0.17080532084253502, 'avg_nonaltread_variants_max': 12.987502629140423, 'n_total_min': 20, 'rp_med_min': 0.01048863108260914, 'rp_med_max': 0.9785602535471832}. Best is trial 31 with value: 3287.9622960079696.
# ...
# [I 2026-04-22 17:07:11,727] Trial 2988 finished with value: 2683.4008078238353 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11377827887378249, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.9141444663856073, 'avg_alt_softclip_max': 1.4103907763193047, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.3215264488720213, 'avg_alt_nm_max': 4.755730178021773, 'mean_insert_max': 729.658223149192, 'sd_insert_max': 356.83693008480896, 'asxs_min': 13, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 25, 'dist_to_indel_min': 16, 'mean_baseq_min': 90, 'sd_baseq_max': 80, 'avg_alt_read_mean_bq_min': 31, 'gc_content_min': 0.1009845521401629, 'gc_content_max': 0.9954069567487229, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.17204113470507426, 'strand_bias_max': 0.9049912231047518, 'rp_sd_min': 0.07474849650426493, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 5.735550512902471, 'avg_altread_variants_max_for_high_vaf': 2.7311905207695846, 'avg_altread_high_vaf_cutoff': 0.239231286373415, 'avg_nonaltread_variants_max': 39.04630986712362, 'n_total_min': 20, 'rp_med_min': 0.015737762775818287, 'rp_med_max': 0.9881835420584154}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:12,045] Trial 2989 finished with value: 2571.649969188548 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11020401101346189, 'depth_percentile_max': 97, 'variants_20bp_max': 2, 'variants_250bp_max': 12, 'ref_entropy_min': 1.0240862024189423, 'avg_alt_softclip_max': 1.3804790955673023, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.268205493195576, 'avg_alt_nm_max': 4.557132039449311, 'mean_insert_max': 714.4089700630166, 'sd_insert_max': 364.7872932972155, 'asxs_min': 14, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 20, 'dist_to_indel_min': 9, 'mean_baseq_min': 85, 'sd_baseq_max': 93, 'avg_alt_read_mean_bq_min': 33, 'gc_content_min': 0.097408782265385, 'gc_content_max': 0.994894181909839, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.18570061349998443, 'strand_bias_max': 0.9052716452460235, 'rp_sd_min': 0.0761590802882067, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.410157267822062, 'avg_altread_variants_max_for_high_vaf': 3.049886373349747, 'avg_altread_high_vaf_cutoff': 0.12116725032023827, 'avg_nonaltread_variants_max': 39.45526287808704, 'n_total_min': 20, 'rp_med_min': 0.01480819656821647, 'rp_med_max': 0.9871163333810965}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:12,379] Trial 2990 finished with value: 2466.5751587976383 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10972904713908627, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.9579738797652013, 'avg_alt_softclip_max': 1.3723880782848012, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.3344741793216857, 'avg_alt_nm_max': 4.763425241042008, 'mean_insert_max': 712.2931433146613, 'sd_insert_max': 355.6423308628795, 'asxs_min': 12, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 23, 'dist_to_indel_min': 0, 'mean_baseq_min': 87, 'sd_baseq_max': 85, 'avg_alt_read_mean_bq_min': 37, 'gc_content_min': 0.09342967467934626, 'gc_content_max': 0.9975652502186523, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.18020246238098694, 'strand_bias_max': 0.9010888766788172, 'rp_sd_min': 0.07598703667761254, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.575026137666828, 'avg_altread_variants_max_for_high_vaf': 2.065026247774841, 'avg_altread_high_vaf_cutoff': 0.2513038617288712, 'avg_nonaltread_variants_max': 39.19765579322202, 'n_total_min': 20, 'rp_med_min': 0.01157329180487826, 'rp_med_max': 0.9883196398186419}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:12,692] Trial 2991 finished with value: 2935.925978612189 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11361902040353719, 'depth_percentile_max': 98, 'variants_20bp_max': 4, 'variants_250bp_max': 12, 'ref_entropy_min': 0.9179755000784184, 'avg_alt_softclip_max': 1.3716544991350552, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.1631618839842806, 'avg_alt_nm_max': 4.662465299370832, 'mean_insert_max': 712.9909746058323, 'sd_insert_max': 337.9037963218485, 'asxs_min': 15, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 21, 'dist_to_indel_min': 34, 'mean_baseq_min': 91, 'sd_baseq_max': 88, 'avg_alt_read_mean_bq_min': 35, 'gc_content_min': 0.10706311869743101, 'gc_content_max': 0.9976052815074624, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.17148043436215307, 'strand_bias_max': 0.9014811474803841, 'rp_sd_min': 0.08012303579523289, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.792230695957793, 'avg_altread_variants_max_for_high_vaf': 2.868485310036584, 'avg_altread_high_vaf_cutoff': 0.23232020696937009, 'avg_nonaltread_variants_max': 39.35607579562854, 'n_total_min': 20, 'rp_med_min': 0.01771640212902424, 'rp_med_max': 0.9871077901793358}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:13,012] Trial 2992 finished with value: 2706.231413308429 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11395841664027666, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 1.043121301276508, 'avg_alt_softclip_max': 1.416427692197451, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.240078409214052, 'avg_alt_nm_max': 4.799030073060624, 'mean_insert_max': 718.4927571613056, 'sd_insert_max': 354.7156976752731, 'asxs_min': 13, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 24, 'dist_to_indel_min': 0, 'mean_baseq_min': 88, 'sd_baseq_max': 83, 'avg_alt_read_mean_bq_min': 36, 'gc_content_min': 0.10231731396309858, 'gc_content_max': 0.9998797624471453, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.17098112080812639, 'strand_bias_max': 0.9103158361451035, 'rp_sd_min': 0.0739858855254537, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.8257437684307485, 'avg_altread_variants_max_for_high_vaf': 3.2294462234666774, 'avg_altread_high_vaf_cutoff': 0.24535597928348654, 'avg_nonaltread_variants_max': 39.42625638997395, 'n_total_min': 20, 'rp_med_min': 0.013010601441825385, 'rp_med_max': 0.9373571185255557}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:13,337] Trial 2993 finished with value: 2536.682801854574 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10832263970923317, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.9041079116019427, 'avg_alt_softclip_max': 1.4090512359981695, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.3308939515976435, 'avg_alt_nm_max': 4.605162833796259, 'mean_insert_max': 703.9062138823397, 'sd_insert_max': 334.2173749908576, 'asxs_min': 13, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 22, 'dist_to_indel_min': 17, 'mean_baseq_min': 85, 'sd_baseq_max': 90, 'avg_alt_read_mean_bq_min': 32, 'gc_content_min': 0.111750740511331, 'gc_content_max': 0.9943531493886096, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.1759549501599683, 'strand_bias_max': 0.9158915682428892, 'rp_sd_min': 0.07423071336363264, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.548357977603001, 'avg_altread_variants_max_for_high_vaf': 2.496738959999066, 'avg_altread_high_vaf_cutoff': 0.2235364100666182, 'avg_nonaltread_variants_max': 39.912392728137625, 'n_total_min': 20, 'rp_med_min': 0.0143774524476564, 'rp_med_max': 0.9873397861384161}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:13,652] Trial 2994 finished with value: 2937.036486173937 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10985815780220604, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.9799459567935096, 'avg_alt_softclip_max': 1.359099034191134, 'dist_to_softclip_min': 1, 'avg_alt_n_count_max': 2.358537058239637, 'avg_alt_nm_max': 4.482591307677908, 'mean_insert_max': 743.6504868753639, 'sd_insert_max': 372.8280610543567, 'asxs_min': 12, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 27, 'dist_to_indel_min': 9, 'mean_baseq_min': 93, 'sd_baseq_max': 80, 'avg_alt_read_mean_bq_min': 34, 'gc_content_min': 0.09856827017525195, 'gc_content_max': 0.9952625673773573, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.16995543819648185, 'strand_bias_max': 0.9035739161948002, 'rp_sd_min': 0.07821002108576122, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.178075438000655, 'avg_altread_variants_max_for_high_vaf': 2.7919031122937694, 'avg_altread_high_vaf_cutoff': 0.2357984259527734, 'avg_nonaltread_variants_max': 38.719150990447055, 'n_total_min': 20, 'rp_med_min': 0.011501706403253799, 'rp_med_max': 0.9883872268878124}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:13,968] Trial 2995 finished with value: 2632.3023272137207 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11100432165413794, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.8966604494593556, 'avg_alt_softclip_max': 1.3766346417096482, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.2877294440270752, 'avg_alt_nm_max': 4.8147363501670775, 'mean_insert_max': 715.2095658565097, 'sd_insert_max': 343.6596359248199, 'asxs_min': 12, 'mean_mapq_min': 24, 'mean_ref_mapq_min': 45, 'dist_to_indel_min': 25, 'mean_baseq_min': 89, 'sd_baseq_max': 86, 'avg_alt_read_mean_bq_min': 30, 'gc_content_min': 0.09500449714905483, 'gc_content_max': 0.9974215658929123, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.18695404353944015, 'strand_bias_max': 0.8980914319383674, 'rp_sd_min': 0.08171933268268934, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.359254429852192, 'avg_altread_variants_max_for_high_vaf': 3.130927673590664, 'avg_altread_high_vaf_cutoff': 0.24027358996557935, 'avg_nonaltread_variants_max': 38.52421179452972, 'n_total_min': 20, 'rp_med_min': 0.016694822861617067, 'rp_med_max': 0.9899308471621867}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:14,283] Trial 2996 finished with value: 2479.465934526051 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10869302978589988, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 12, 'ref_entropy_min': 0.9961318362718141, 'avg_alt_softclip_max': 1.4106245336692351, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.1010712712656052, 'avg_alt_nm_max': 4.674090181165169, 'mean_insert_max': 699.1665185213757, 'sd_insert_max': 333.95651564603094, 'asxs_min': 14, 'mean_mapq_min': 26, 'mean_ref_mapq_min': 25, 'dist_to_indel_min': 0, 'mean_baseq_min': 85, 'sd_baseq_max': 77, 'avg_alt_read_mean_bq_min': 36, 'gc_content_min': 0.10792871687949404, 'gc_content_max': 0.9925326512802441, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.1798368675253976, 'strand_bias_max': 0.9075293739756941, 'rp_sd_min': 0.0736346934822526, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.681095107615445, 'avg_altread_variants_max_for_high_vaf': 2.9720305118094097, 'avg_altread_high_vaf_cutoff': 0.2274330955792427, 'avg_nonaltread_variants_max': 39.30823989271645, 'n_total_min': 20, 'rp_med_min': 0.013305160726175958, 'rp_med_max': 0.9867251727291508}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:14,606] Trial 2997 finished with value: 2668.883689199261 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11393529682763573, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.9351990400747465, 'avg_alt_softclip_max': 1.3503908572663783, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.225944845003749, 'avg_alt_nm_max': 4.747823481265534, 'mean_insert_max': 723.827199688222, 'sd_insert_max': 357.4137031738101, 'asxs_min': 12, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 23, 'dist_to_indel_min': 18, 'mean_baseq_min': 88, 'sd_baseq_max': 83, 'avg_alt_read_mean_bq_min': 33, 'gc_content_min': 0.1055715134598665, 'gc_content_max': 0.9948712956089483, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.1633201162460572, 'strand_bias_max': 0.8993064718781926, 'rp_sd_min': 0.07590035139240724, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 4, 'avg_altread_variants_max': 5.8394455252058215, 'avg_altread_variants_max_for_high_vaf': 2.6353686025603165, 'avg_altread_high_vaf_cutoff': 0.2193927249605684, 'avg_nonaltread_variants_max': 39.97216509225767, 'n_total_min': 20, 'rp_med_min': 0.015410678106742747, 'rp_med_max': 0.9868097656918945}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:14,922] Trial 2998 finished with value: 2919.9673365487624 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.10720784295272219, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.8922927091548601, 'avg_alt_softclip_max': 1.350722452236883, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 2.3705100752069526, 'avg_alt_nm_max': 4.837217296840584, 'mean_insert_max': 665.1961625747572, 'sd_insert_max': 326.96575585514256, 'asxs_min': 15, 'mean_mapq_min': 25, 'mean_ref_mapq_min': 20, 'dist_to_indel_min': 42, 'mean_baseq_min': 91, 'sd_baseq_max': 87, 'avg_alt_read_mean_bq_min': 37, 'gc_content_min': 0.09250253275309717, 'gc_content_max': 0.9928670263596352, 'strand_bias_n_alt_min': 17, 'strand_bias_min': 0.16658970610372925, 'strand_bias_max': 0.8979283505707403, 'rp_sd_min': 0.07191890222519373, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.870932521703186, 'avg_altread_variants_max_for_high_vaf': 3.235535543590681, 'avg_altread_high_vaf_cutoff': 0.23390002607648952, 'avg_nonaltread_variants_max': 39.97223138036872, 'n_total_min': 20, 'rp_med_min': 0.019721928699333244, 'rp_med_max': 0.9884201718519334}. Best is trial 2324 with value: 2411.8101058373036.
# [I 2026-04-22 17:07:15,245] Trial 2999 finished with value: 3722.575056671532 and parameters: {'germline_vaf_max': 0.2, 'gnomad_vaf_cutoff': 0.11136787315419869, 'depth_percentile_max': 97, 'variants_20bp_max': 4, 'variants_250bp_max': 13, 'ref_entropy_min': 0.9603919994470873, 'avg_alt_softclip_max': 1.4150403082679717, 'dist_to_softclip_min': 2, 'avg_alt_n_count_max': 0.811562129632398, 'avg_alt_nm_max': 4.579727459000582, 'mean_insert_max': 750.582370536398, 'sd_insert_max': 347.4519235506908, 'asxs_min': 13, 'mean_mapq_min': 23, 'mean_ref_mapq_min': 22, 'dist_to_indel_min': 9, 'mean_baseq_min': 87, 'sd_baseq_max': 91, 'avg_alt_read_mean_bq_min': 31, 'gc_content_min': 0.09927777796362777, 'gc_content_max': 0.9998932676377484, 'strand_bias_n_alt_min': 18, 'strand_bias_min': 0.17321529019541088, 'strand_bias_max': 0.9033460687195035, 'rp_sd_min': 0.07343263360007671, 'rp_sd_min_alt': 17, 'homopolymer_len_max': 5, 'avg_altread_variants_max': 5.506102799687484, 'avg_altread_variants_max_for_high_vaf': 2.942272752334148, 'avg_altread_high_vaf_cutoff': 0.24840188146079234, 'avg_nonaltread_variants_max': 38.751355240435004, 'n_total_min': 20, 'rp_med_min': 0.01144980204058575, 'rp_med_max': 0.986055743513184}. Best is trial 2324 with value: 2411.8101058373036.
# [INFO] Best Weighted Deviance: 2411.8101
# [INFO] Generating report...
# ------------------------------
# FINAL RESULTS
# ------------------------------
# Total Samples:      18
# Total Observed SNVs: 15442
# Total Expected SNVs: 20896.61
# Weighted Deviance:  2411.8101 (Cord weight = 3.0x)
# Mean Obs/Exp Ratio: 0.8740
# Blacklist Blocked:  941 variants (passed filters but hit blacklist)
# Results saved to:   training_results
# ------------------------------

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# -----------------------
# Configuration
# -----------------------
# Path to the CSV generated in the previous step
CSV_PATH = "training_results/observed_expected.csv"
OUTPUT_PNG = "training_results/observed_vs_expected_plot.png"

# Check if file exists
if not os.path.exists(CSV_PATH):
    print(f"[ERROR] Could not find {CSV_PATH}. Please run the optimization cell first.")
else:
    # Load table
    df = pd.read_csv(CSV_PATH)

    # Convert data arrays
    ages = df["age"].values
    bases = df["bases"].values
    observed = df["observed"].values
    expected = df["expected"].values
    sample_types = df["sample_type"].values

    # Calculate SNV rates per base
    obs_rate = observed / bases
    exp_rate = expected / bases

    # -----------------------
    # Plotting
    # -----------------------
    fig, ax = plt.subplots(figsize=(8, 6))

    # Plot Observed (Blue circles)
    ax.scatter(ages, obs_rate, label="Observed", color="#1f77b4", alpha=0.8, marker="o", s=60, edgecolors='k', linewidth=0.5)

    # Plot Expected (Orange crosses)
    ax.scatter(ages, exp_rate, label="Expected", color="#ff7f0e", alpha=0.8, marker="x", s=60, linewidth=2)

    # Styling
    ax.set_xlabel("Age (years)", fontsize=12)
    ax.set_ylabel("SNV rate (SNVs per base)", fontsize=12)
    
    # Handle X-limits (pad slightly around min/max age)
    # If ages has None/NaN (Cord blood sometimes represented as negative or 0), handle gracefully
    valid_ages = ages[~np.isnan(ages)]
    if len(valid_ages) > 0:
        ax.set_xlim(min(valid_ages) - 2, max(valid_ages) + 5)
    else:
        ax.set_xlim(-2, 100)

    # Hardcoded Y-limits from your request
    ax.set_ylim(0, 5.5e-7)
    
    ax.set_title("Observed vs Expected SNV Rate (Training Set)", fontsize=14)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.5)
    
    # Legend
    ax.legend(loc='upper left', frameon=True, fontsize=10)

    plt.tight_layout()
    
    # Save and Show
    plt.savefig(OUTPUT_PNG, dpi=150)
    print(f"[INFO] Plot saved to: {OUTPUT_PNG}")
    plt.show()
# Out:
# [INFO] Plot saved to: training_results/observed_vs_expected_plot.png

# %%
# Assuming best_thresholds is defined from your Optuna study
ref_entropy_thresh = best_thresholds['ref_entropy_min']

# Calculate failure
fail_entropy = all_variants_df['REF_ENTROPY_40BP'] < ref_entropy_thresh
pct_fail_entropy = (fail_entropy.sum() / len(all_variants_df)) * 100

print(f"Threshold used: {ref_entropy_thresh:.4f}")
print(f"Rows failing ref_entropy filter: {pct_fail_entropy:.2f}%")
# Out:
# Threshold used: 0.8476
# Rows failing ref_entropy filter: 0.01%

# %%
# Extract relevant thresholds
entropy_min = best_thresholds['ref_entropy_min']
depth_max = best_thresholds['depth_percentile_max']
rp_min = best_thresholds['rp_med_min']
rp_max = best_thresholds['rp_med_max']

# Define individual failure masks
fail_ent = all_variants_df['REF_ENTROPY_40BP'] < entropy_min
fail_dep = all_variants_df['DEPTH_PERCENTILE'] > depth_max
fail_rp  = (all_variants_df['RP_MED_SSCS'] <= rp_min) | (all_variants_df['RP_MED_SSCS'] >= rp_max)

# Combine using OR (|)
combined_fail_mask = fail_ent | fail_dep | fail_rp
pct_combined_fail = (combined_fail_mask.sum() / len(all_variants_df)) * 100

print(f"Rows failing (Entropy OR Depth OR RP_Med): {pct_combined_fail:.2f}%")

# Optional Breakdown
print("-" * 20)
print(f"Breakdown of failures:")
print(f" - Ref Entropy: {fail_ent.mean()*100:.2f}%")
print(f" - Max Depth:   {fail_dep.mean()*100:.2f}%")
print(f" - RP Median:   {fail_rp.mean()*100:.2f}%")
# Out:
# Rows failing (Entropy OR Depth OR RP_Med): 5.99%
# --------------------
# Breakdown of failures:
#  - Ref Entropy: 0.01%
#  - Max Depth:   4.31%
#  - RP Median:   1.72%

# %%
# Extract thresholds
entropy_min = best_thresholds['ref_entropy_min']
depth_max = best_thresholds['depth_percentile_max']
rp_min = best_thresholds['rp_med_min']
rp_max = best_thresholds['rp_med_max']

# Define failure masks
fail_ent = all_variants_df['REF_ENTROPY_40BP'] < entropy_min
fail_dep = all_variants_df['DEPTH_PERCENTILE'] > depth_max
fail_rp  = (all_variants_df['RP_MED_SSCS'] <= rp_min) | (all_variants_df['RP_MED_SSCS'] >= rp_max)

# UPDATED: Cord PoN failure only triggers if VAF < 20%
# We use VAF_SSCS as that is your primary metric for frequency in this script
fail_pon_low_vaf = (all_variants_df['IN_CORD_PON'] == "Yes") & (all_variants_df['VAF_SSCS'] < 0.20)

# Combine using OR (|)
composite_fail_mask = fail_ent | fail_dep | fail_rp | fail_pon_low_vaf
pct_composite_fail = (composite_fail_mask.sum() / len(all_variants_df)) * 100

print(f"Results for Composite Filter (Entropy, Depth, RP_Med, and Cord PoN < 20% VAF):")
print(f"Total rows failing any of these criteria: {pct_composite_fail:.2f}%")

print("-" * 30)
print("Individual Failure Contribution:")
print(f" - Ref Entropy:        {fail_ent.mean()*100:.2f}%")
print(f" - Max Depth:          {fail_dep.mean()*100:.2f}%")
print(f" - RP Median:          {fail_rp.mean()*100:.2f}%")
print(f" - Cord PoN (<20% VAF): {fail_pon_low_vaf.mean()*100:.2f}%")

# Quick check on how many PoN hits were 'saved' by being high VAF
pon_hits_total = (all_variants_df['IN_CORD_PON'] == "Yes").sum()
pon_hits_filtered = fail_pon_low_vaf.sum()
print(f"\nNote: Of {pon_hits_total} total PoN matches, {pon_hits_filtered} were <20% VAF and thus filtered.")
# Out:
# Results for Composite Filter (Entropy, Depth, RP_Med, and Cord PoN < 20% VAF):
# Total rows failing any of these criteria: 32.46%
# ------------------------------
# Individual Failure Contribution:
#  - Ref Entropy:        0.00%
#  - Max Depth:          5.44%
#  - RP Median:          2.90%
#  - Cord PoN (<20% VAF): 29.39%
#
# Note: Of 224694 total PoN matches, 126144 were <20% VAF and thus filtered.

# %%
# 1. Initialize the Exome Lookup
# (Using the path from your script configuration)
exome_lookup = BedLookup(EXOME_BED_PATH, "Exome Targets")

# 2. Filter for any variant flagged by the Cord PoN
pon_variants = all_variants_df[all_variants_df['IN_CORD_PON'] == "Yes"].copy()

# 3. Check which of these are inside the Exome
# We use a lambda to check each unique position found in the PoN subset
print("[INFO] Checking PoN positions against Exome BED...")

# To make this faster, we drop duplicates by position before doing the BED lookup
unique_pon_positions = pon_variants[['CHROM', 'POS']].drop_duplicates()

is_in_exome = unique_pon_positions.apply(
    lambda row: exome_lookup.is_overlapped(row['CHROM'], row['POS']), 
    axis=1
)

# 4. Filter the unique positions and count
exome_pon_positions = unique_pon_positions[is_in_exome]
count_unique_pos = len(exome_pon_positions)

# --- Summary Report ---
total_pon_hits = len(pon_variants)
unique_total_pon_pos = len(unique_pon_positions)

print("-" * 30)
print("CORD PON EXOME ANALYSIS")
print("-" * 30)
print(f"Total PoN-flagged rows in data:      {total_pon_hits}")
print(f"Unique PoN positions (Genome-wide):  {unique_total_pon_pos}")
print(f"Unique PoN positions (Exome-only):   {count_unique_pos}")
print("-" * 30)

# Optional: View the first few positions
if count_unique_pos > 0:
    print("Example Exome PoN positions:")
    print(exome_pon_positions.head())
# Out:
# [INFO] Loading Exome Targets from ../../resources/hg38_exome_v2.0.2_targets_sorted_validated.re_annotated.bed...
# [INFO] Loaded 283942 regions for Exome Targets.
# [INFO] Checking PoN positions against Exome BED...
# ------------------------------
# CORD PON EXOME ANALYSIS
# ------------------------------
# Total PoN-flagged rows in data:      224694
# Unique PoN positions (Genome-wide):  30667
# Unique PoN positions (Exome-only):   30667
# ------------------------------
# Example Exome PoN positions:
#    CHROM      POS
# 2   chr1   942451
# 10  chr1   966227
# 46  chr1  1313807
# 55  chr1  1495668
# 56  chr1  1495680

# %%
# 1. Extract the best thresholds from your Optuna results
sc_max = best_thresholds['avg_alt_softclip_max']
n_max  = best_thresholds['avg_alt_n_count_max']
nm_max = best_thresholds['avg_alt_nm_max']
ins_max = best_thresholds['mean_insert_max']

# 2. Define failure masks
# Fail if value is STRICTLY GREATER than the max threshold
fail_sc  = all_variants_df['AVG_ALT_SOFTCLIP'] > sc_max
fail_n   = all_variants_df['AVG_ALT_N_COUNT'] > n_max
fail_nm  = all_variants_df['AVG_ALT_NM'] > nm_max
fail_ins = all_variants_df['MEAN_INSERT'] > ins_max

# 3. Combine using OR (|) for a composite technical filter
tech_composite_fail = fail_sc | fail_n | fail_nm | fail_ins
pct_tech_composite = (tech_composite_fail.sum() / len(all_variants_df)) * 100

print(f"Results for Technical Quality Filters:")
print(f"Total rows failing ANY of these 4: {pct_tech_composite:.2f}%")

print("-" * 30)
print("Individual Failure Breakdown:")
print(f" - Softclip Max ({sc_max:.2f}):   {fail_sc.mean()*100:.22f}%")
print(f" - N-Count Max ({n_max:.2f}):    {fail_n.mean()*100:.2f}%")
print(f" - NM (Edit Dist) Max ({nm_max:.2f}): {fail_nm.mean()*100:.2f}%")
print(f" - Mean Insert Max ({ins_max:.1f}):  {fail_ins.mean()*100:.2f}%")

# 4. Identifying the "Noisiest" Filter
metrics = {
    "Softclip": fail_sc.sum(),
    "N-Count": fail_n.sum(),
    "NM-Distance": fail_nm.sum(),
    "Insert-Size": fail_ins.sum()
}
most_aggressive = max(metrics, key=metrics.get)
print("-" * 30)
print(f"The most aggressive filter in this group is: {most_aggressive}")
# Out:
# Results for Technical Quality Filters:
# Total rows failing ANY of these 4: 30.02%
# ------------------------------
# Individual Failure Breakdown:
#  - Softclip Max (1.24):   12.1540576434679277184614%
#  - N-Count Max (2.36):    9.13%
#  - NM (Edit Dist) Max (4.72): 26.12%
#  - Mean Insert Max (677.8):  0.03%
# ------------------------------
# The most aggressive filter in this group is: NM-Distance
